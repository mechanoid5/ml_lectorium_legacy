# %% [markdown]
# **извлечение признаков из текста на естественном языке**
#
# word2vec : skip-gram
#
#
# Евгений Борисов borisov.e@solarl.ru

# %%
import sys
import re
import gzip
import numpy as np
# import scipy.io

import matplotlib.pyplot as plt

# %%
# загружаем предварительно очищенный текст
with gzip.open('../data/text.txt.gz','rt',encoding='utf-8') as f: text = f.read()

# %%
text
# Out:
# 'диалог из пьесы человек которого никогда не было чёрт как же она болит жмурится а можно у солнца яркость убавить кладёт матвею на голову свою руку боюсь для тебя оно может скоро вовсе погаснуть парень отбрасывает его руку и вскакивает с кровати подозрительно смотрит на молодого человека и одновременно понимает что головная боль прошла хмурится кто ты садится на кровать молчит осторожно подходит к собеседнику неужели пора всё зависит от тебя выбирай почти до самого конца есть возможность повернуть с неправильной дороги я попаду в ад скорей всего да и что это значит ничего я имею в виду что там как всё будет выглядеть этого я сказать не могу придёт время сам всё увидишь кто же сейчас выполняет твои обязанности пока ты здесь сидишь ни кто я это хорошо отлаженный процесс и ни что не может его затормозить остановить или сбить человеческому мозгу этого процесса не понять слишком всё не поземному зачем сюда пришёл ответить-то можешь хочу что-нибудь хорошее сделать ухмыляясь зачем тебе это надо просто так неужели для того что бы сделать что-то хорошее нужна причина тогда спаси меня от смерти не могу почему им же ты помог ухмыляясь я не избавлял их от смерти что-то я не понимаю молодой ты ещё молодой и глупый важно ни то когда умрёшь а то как проживёшь отведённое тебе время пауза помоги мне пожалуйста у каждого человека до последней минуты есть выбор в этом весь смысл того что вы мы созданы по образу и подобию господа за определённый грех он отобрал у вас определённые способности но у вас есть надежда и свобода выбора это самое главное так вот в том возрасте в котором находишься ты можно позволить тебе самому решать и выбирать и лишь иногда корректировать твои действия это им потерянным в этой беготне нужна реальная помощь так сказать навигационная я понял парень мается хочет что-то сказать молчит не торопит его моя семья она разваливается я знаю отец с матерью разводиться собрались сестра старшая связалась с молоденьким голодранцем и периодически из дома пропадает бабка умирает одна а младшая сестрёнка никому не нужна все заняты своими проблемами на неё ни кто внимания не обращает а ты алкоголик покуриваешь травку приворовываешь при чём не только у посторонних но и у родителей а знаешь что пауза кто я такой меня да же нет без их желания я ничего сделать не смогу ты отказываешься мне помочь ты молод ты полон сил ты можешь сделать это сам но как они обозлены им наплевать на всех и в том числе на самих себя если ты не можешь помочь как смогу это сделать я ты их сын сын на которого они махнули рукой блудный сын рецензии написать рецензию мудро и поучительно хороших вам и умных читателей портал прозару предоставляет авторам возможность свободной публикации своих литературных произведений в сети интернет на основании пользовательского договора все авторские права на произведения принадлежат авторам и охраняются законом перепечатка произведений возможна только с согласия его автора к которому вы можете обратиться на его авторской странице ответственность за тексты произведений авторы несут самостоятельно на основании правил публикации и российского законодательства вы также можете посмотреть более подробную информацию о портале и связаться с администрацией ежедневная аудитория портала прозару порядка сто тысяч посетителей которые в общей сумме просматривают более полумиллиона страниц по данным счетчика посещаемости который расположен справа от этого текста в каждой графе указано по две цифры количество просмотров и количество посетителей\n'

# %%
# разрезаем текст на слова
# удаляем пустые элементы
text = [ w for w in text.split() if w ]
text
# Out:
# ['диалог',
#  'из',
#  'пьесы',
#  'человек',
#  'которого',
#  'никогда',
#  'не',
#  'было',
#  'чёрт',
#  'как',
#  'же',
#  'она',
#  'болит',
#  'жмурится',
#  'а',
#  'можно',
#  'у',
#  'солнца',
#  'яркость',
#  'убавить',
#  'кладёт',
#  'матвею',
#  'на',
#  'голову',
#  'свою',
#  'руку',
#  'боюсь',
#  'для',
#  'тебя',
#  'оно',
#  'может',
#  'скоро',
#  'вовсе',
#  'погаснуть',
#  'парень',
#  'отбрасывает',
#  'его',
#  'руку',
#  'и',
#  'вскакивает',
#  'с',
#  'кровати',
#  'подозрительно',
#  'смотрит',
#  'на',
#  'молодого',
#  'человека',
#  'и',
#  'одновременно',
#  'понимает',
#  'что',
#  'головная',
#  'боль',
#  'прошла',
#  'хмурится',
#  'кто',
#  'ты',
#  'садится',
#  'на',
#  'кровать',
#  'молчит',
#  'осторожно',
#  'подходит',
#  'к',
#  'собеседнику',
#  'неужели',
#  'пора',
#  'всё',
#  'зависит',
#  'от',
#  'тебя',
#  'выбирай',
#  'почти',
#  'до',
#  'самого',
#  'конца',
#  'есть',
#  'возможность',
#  'повернуть',
#  'с',
#  'неправильной',
#  'дороги',
#  'я',
#  'попаду',
#  'в',
#  'ад',
#  'скорей',
#  'всего',
#  'да',
#  'и',
#  'что',
#  'это',
#  'значит',
#  'ничего',
#  'я',
#  'имею',
#  'в',
#  'виду',
#  'что',
#  'там',
#  'как',
#  'всё',
#  'будет',
#  'выглядеть',
#  'этого',
#  'я',
#  'сказать',
#  'не',
#  'могу',
#  'придёт',
#  'время',
#  'сам',
#  'всё',
#  'увидишь',
#  'кто',
#  'же',
#  'сейчас',
#  'выполняет',
#  'твои',
#  'обязанности',
#  'пока',
#  'ты',
#  'здесь',
#  'сидишь',
#  'ни',
#  'кто',
#  'я',
#  'это',
#  'хорошо',
#  'отлаженный',
#  'процесс',
#  'и',
#  'ни',
#  'что',
#  'не',
#  'может',
#  'его',
#  'затормозить',
#  'остановить',
#  'или',
#  'сбить',
#  'человеческому',
#  'мозгу',
#  'этого',
#  'процесса',
#  'не',
#  'понять',
#  'слишком',
#  'всё',
#  'не',
#  'поземному',
#  'зачем',
#  'сюда',
#  'пришёл',
#  'ответить-то',
#  'можешь',
#  'хочу',
#  'что-нибудь',
#  'хорошее',
#  'сделать',
#  'ухмыляясь',
#  'зачем',
#  'тебе',
#  'это',
#  'надо',
#  'просто',
#  'так',
#  'неужели',
#  'для',
#  'того',
#  'что',
#  'бы',
#  'сделать',
#  'что-то',
#  'хорошее',
#  'нужна',
#  'причина',
#  'тогда',
#  'спаси',
#  'меня',
#  'от',
#  'смерти',
#  'не',
#  'могу',
#  'почему',
#  'им',
#  'же',
#  'ты',
#  'помог',
#  'ухмыляясь',
#  'я',
#  'не',
#  'избавлял',
#  'их',
#  'от',
#  'смерти',
#  'что-то',
#  'я',
#  'не',
#  'понимаю',
#  'молодой',
#  'ты',
#  'ещё',
#  'молодой',
#  'и',
#  'глупый',
#  'важно',
#  'ни',
#  'то',
#  'когда',
#  'умрёшь',
#  'а',
#  'то',
#  'как',
#  'проживёшь',
#  'отведённое',
#  'тебе',
#  'время',
#  'пауза',
#  'помоги',
#  'мне',
#  'пожалуйста',
#  'у',
#  'каждого',
#  'человека',
#  'до',
#  'последней',
#  'минуты',
#  'есть',
#  'выбор',
#  'в',
#  'этом',
#  'весь',
#  'смысл',
#  'того',
#  'что',
#  'вы',
#  'мы',
#  'созданы',
#  'по',
#  'образу',
#  'и',
#  'подобию',
#  'господа',
#  'за',
#  'определённый',
#  'грех',
#  'он',
#  'отобрал',
#  'у',
#  'вас',
#  'определённые',
#  'способности',
#  'но',
#  'у',
#  'вас',
#  'есть',
#  'надежда',
#  'и',
#  'свобода',
#  'выбора',
#  'это',
#  'самое',
#  'главное',
#  'так',
#  'вот',
#  'в',
#  'том',
#  'возрасте',
#  'в',
#  'котором',
#  'находишься',
#  'ты',
#  'можно',
#  'позволить',
#  'тебе',
#  'самому',
#  'решать',
#  'и',
#  'выбирать',
#  'и',
#  'лишь',
#  'иногда',
#  'корректировать',
#  'твои',
#  'действия',
#  'это',
#  'им',
#  'потерянным',
#  'в',
#  'этой',
#  'беготне',
#  'нужна',
#  'реальная',
#  'помощь',
#  'так',
#  'сказать',
#  'навигационная',
#  'я',
#  'понял',
#  'парень',
#  'мается',
#  'хочет',
#  'что-то',
#  'сказать',
#  'молчит',
#  'не',
#  'торопит',
#  'его',
#  'моя',
#  'семья',
#  'она',
#  'разваливается',
#  'я',
#  'знаю',
#  'отец',
#  'с',
#  'матерью',
#  'разводиться',
#  'собрались',
#  'сестра',
#  'старшая',
#  'связалась',
#  'с',
#  'молоденьким',
#  'голодранцем',
#  'и',
#  'периодически',
#  'из',
#  'дома',
#  'пропадает',
#  'бабка',
#  'умирает',
#  'одна',
#  'а',
#  'младшая',
#  'сестрёнка',
#  'никому',
#  'не',
#  'нужна',
#  'все',
#  'заняты',
#  'своими',
#  'проблемами',
#  'на',
#  'неё',
#  'ни',
#  'кто',
#  'внимания',
#  'не',
#  'обращает',
#  'а',
#  'ты',
#  'алкоголик',
#  'покуриваешь',
#  'травку',
#  'приворовываешь',
#  'при',
#  'чём',
#  'не',
#  'только',
#  'у',
#  'посторонних',
#  'но',
#  'и',
#  'у',
#  'родителей',
#  'а',
#  'знаешь',
#  'что',
#  'пауза',
#  'кто',
#  'я',
#  'такой',
#  'меня',
#  'да',
#  'же',
#  'нет',
#  'без',
#  'их',
#  'желания',
#  'я',
#  'ничего',
#  'сделать',
#  'не',
#  'смогу',
#  'ты',
#  'отказываешься',
#  'мне',
#  'помочь',
#  'ты',
#  'молод',
#  'ты',
#  'полон',
#  'сил',
#  'ты',
#  'можешь',
#  'сделать',
#  'это',
#  'сам',
#  'но',
#  'как',
#  'они',
#  'обозлены',
#  'им',
#  'наплевать',
#  'на',
#  'всех',
#  'и',
#  'в',
#  'том',
#  'числе',
#  'на',
#  'самих',
#  'себя',
#  'если',
#  'ты',
#  'не',
#  'можешь',
#  'помочь',
#  'как',
#  'смогу',
#  'это',
#  'сделать',
#  'я',
#  'ты',
#  'их',
#  'сын',
#  'сын',
#  'на',
#  'которого',
#  'они',
#  'махнули',
#  'рукой',
#  'блудный',
#  'сын',
#  'рецензии',
#  'написать',
#  'рецензию',
#  'мудро',
#  'и',
#  'поучительно',
#  'хороших',
#  'вам',
#  'и',
#  'умных',
#  'читателей',
#  'портал',
#  'прозару',
#  'предоставляет',
#  'авторам',
#  'возможность',
#  'свободной',
#  'публикации',
#  'своих',
#  'литературных',
#  'произведений',
#  'в',
#  'сети',
#  'интернет',
#  'на',
#  'основании',
#  'пользовательского',
#  'договора',
#  'все',
#  'авторские',
#  'права',
#  'на',
#  'произведения',
#  'принадлежат',
#  'авторам',
#  'и',
#  'охраняются',
#  'законом',
#  'перепечатка',
#  'произведений',
#  'возможна',
#  'только',
#  'с',
#  'согласия',
#  'его',
#  'автора',
#  'к',
#  'которому',
#  'вы',
#  'можете',
#  'обратиться',
#  'на',
#  'его',
#  'авторской',
#  'странице',
#  'ответственность',
#  'за',
#  'тексты',
#  'произведений',
#  'авторы',
#  'несут',
#  'самостоятельно',
#  'на',
#  'основании',
#  'правил',
#  'публикации',
#  'и',
#  'российского',
#  'законодательства',
#  'вы',
#  'также',
#  'можете',
#  'посмотреть',
#  'более',
#  'подробную',
#  'информацию',
#  'о',
#  'портале',
#  'и',
#  'связаться',
#  'с',
#  'администрацией',
#  'ежедневная',
#  'аудитория',
#  'портала',
#  'прозару',
#  'порядка',
#  'сто',
#  'тысяч',
#  'посетителей',
#  'которые',
#  'в',
#  'общей',
#  'сумме',
#  'просматривают',
#  'более',
#  'полумиллиона',
#  'страниц',
#  'по',
#  'данным',
#  'счетчика',
#  'посещаемости',
#  'который',
#  'расположен',
#  'справа',
#  'от',
#  'этого',
#  'текста',
#  'в',
#  'каждой',
#  'графе',
#  'указано',
#  'по',
#  'две',
#  'цифры',
#  'количество',
#  'просмотров',
#  'и',
#  'количество',
#  'посетителей']

# %%
words = sorted(set(text)) # словарь из текста
words
# Out:
# ['а',
#  'автора',
#  'авторам',
#  'авторские',
#  'авторской',
#  'авторы',
#  'ад',
#  'администрацией',
#  'алкоголик',
#  'аудитория',
#  'бабка',
#  'беготне',
#  'без',
#  'блудный',
#  'более',
#  'болит',
#  'боль',
#  'боюсь',
#  'будет',
#  'бы',
#  'было',
#  'в',
#  'важно',
#  'вам',
#  'вас',
#  'весь',
#  'виду',
#  'внимания',
#  'вовсе',
#  'возможна',
#  'возможность',
#  'возрасте',
#  'вот',
#  'время',
#  'все',
#  'всего',
#  'всех',
#  'вскакивает',
#  'всё',
#  'вы',
#  'выбирай',
#  'выбирать',
#  'выбор',
#  'выбора',
#  'выглядеть',
#  'выполняет',
#  'главное',
#  'глупый',
#  'головная',
#  'голову',
#  'голодранцем',
#  'господа',
#  'графе',
#  'грех',
#  'да',
#  'данным',
#  'две',
#  'действия',
#  'диалог',
#  'для',
#  'до',
#  'договора',
#  'дома',
#  'дороги',
#  'его',
#  'ежедневная',
#  'если',
#  'есть',
#  'ещё',
#  'же',
#  'желания',
#  'жмурится',
#  'за',
#  'зависит',
#  'законодательства',
#  'законом',
#  'заняты',
#  'затормозить',
#  'зачем',
#  'здесь',
#  'знаешь',
#  'значит',
#  'знаю',
#  'и',
#  'из',
#  'избавлял',
#  'или',
#  'им',
#  'имею',
#  'иногда',
#  'интернет',
#  'информацию',
#  'их',
#  'к',
#  'каждого',
#  'каждой',
#  'как',
#  'кладёт',
#  'когда',
#  'количество',
#  'конца',
#  'корректировать',
#  'которого',
#  'котором',
#  'которому',
#  'которые',
#  'который',
#  'кровати',
#  'кровать',
#  'кто',
#  'литературных',
#  'лишь',
#  'мается',
#  'матвею',
#  'матерью',
#  'махнули',
#  'меня',
#  'минуты',
#  'младшая',
#  'мне',
#  'могу',
#  'может',
#  'можете',
#  'можешь',
#  'можно',
#  'мозгу',
#  'молод',
#  'молоденьким',
#  'молодого',
#  'молодой',
#  'молчит',
#  'моя',
#  'мудро',
#  'мы',
#  'на',
#  'навигационная',
#  'надежда',
#  'надо',
#  'написать',
#  'наплевать',
#  'находишься',
#  'не',
#  'неправильной',
#  'несут',
#  'нет',
#  'неужели',
#  'неё',
#  'ни',
#  'никогда',
#  'никому',
#  'ничего',
#  'но',
#  'нужна',
#  'о',
#  'обозлены',
#  'образу',
#  'обратиться',
#  'обращает',
#  'общей',
#  'обязанности',
#  'одна',
#  'одновременно',
#  'он',
#  'она',
#  'они',
#  'оно',
#  'определённые',
#  'определённый',
#  'основании',
#  'остановить',
#  'осторожно',
#  'от',
#  'отбрасывает',
#  'отведённое',
#  'ответить-то',
#  'ответственность',
#  'отец',
#  'отказываешься',
#  'отлаженный',
#  'отобрал',
#  'охраняются',
#  'парень',
#  'пауза',
#  'перепечатка',
#  'периодически',
#  'по',
#  'повернуть',
#  'погаснуть',
#  'подобию',
#  'подозрительно',
#  'подробную',
#  'подходит',
#  'пожалуйста',
#  'позволить',
#  'поземному',
#  'пока',
#  'покуриваешь',
#  'полон',
#  'полумиллиона',
#  'пользовательского',
#  'помог',
#  'помоги',
#  'помочь',
#  'помощь',
#  'понимает',
#  'понимаю',
#  'понял',
#  'понять',
#  'попаду',
#  'пора',
#  'портал',
#  'портала',
#  'портале',
#  'порядка',
#  'посетителей',
#  'посещаемости',
#  'последней',
#  'посмотреть',
#  'посторонних',
#  'потерянным',
#  'поучительно',
#  'почему',
#  'почти',
#  'права',
#  'правил',
#  'предоставляет',
#  'при',
#  'приворовываешь',
#  'придёт',
#  'принадлежат',
#  'причина',
#  'пришёл',
#  'проблемами',
#  'проживёшь',
#  'прозару',
#  'произведений',
#  'произведения',
#  'пропадает',
#  'просматривают',
#  'просмотров',
#  'просто',
#  'процесс',
#  'процесса',
#  'прошла',
#  'публикации',
#  'пьесы',
#  'разваливается',
#  'разводиться',
#  'расположен',
#  'реальная',
#  'рецензии',
#  'рецензию',
#  'решать',
#  'родителей',
#  'российского',
#  'рукой',
#  'руку',
#  'с',
#  'садится',
#  'сам',
#  'самих',
#  'самого',
#  'самое',
#  'самому',
#  'самостоятельно',
#  'сбить',
#  'свобода',
#  'свободной',
#  'своими',
#  'своих',
#  'свою',
#  'связалась',
#  'связаться',
#  'сделать',
#  'себя',
#  'сейчас',
#  'семья',
#  'сестра',
#  'сестрёнка',
#  'сети',
#  'сидишь',
#  'сил',
#  'сказать',
#  'скорей',
#  'скоро',
#  'слишком',
#  'смерти',
#  'смогу',
#  'смотрит',
#  'смысл',
#  'собеседнику',
#  'собрались',
#  'согласия',
#  'созданы',
#  'солнца',
#  'спаси',
#  'способности',
#  'справа',
#  'старшая',
#  'сто',
#  'страниц',
#  'странице',
#  'сумме',
#  'счетчика',
#  'сын',
#  'сюда',
#  'так',
#  'также',
#  'такой',
#  'там',
#  'твои',
#  'тебе',
#  'тебя',
#  'текста',
#  'тексты',
#  'то',
#  'тогда',
#  'того',
#  'только',
#  'том',
#  'торопит',
#  'травку',
#  'ты',
#  'тысяч',
#  'у',
#  'убавить',
#  'увидишь',
#  'указано',
#  'умирает',
#  'умных',
#  'умрёшь',
#  'ухмыляясь',
#  'хмурится',
#  'хорошее',
#  'хороших',
#  'хорошо',
#  'хочет',
#  'хочу',
#  'цифры',
#  'человек',
#  'человека',
#  'человеческому',
#  'числе',
#  'читателей',
#  'что',
#  'что-нибудь',
#  'что-то',
#  'чём',
#  'чёрт',
#  'это',
#  'этого',
#  'этой',
#  'этом',
#  'я',
#  'яркость']

# %%
# заменяем слова в тексте их номерами в словаре
vocab =  { words[i]:i for i in range(0,len(words)) }
code = [ vocab[w] for w in text ]

# %%
n = len(words) # количество слов в словаре
m = len(code) # количество слов в тексте 
print( "размер словаря: %i слов" % n )
print( "размер текста: %i слов" % m )
# Out:
# размер словаря: 355 слов
# размер текста: 556 слов

# %%
# унитарное кодирование словаря (one-hot-encoding)
Ve = np.eye( n ) 

# кодированный текст (последовательность кодов слов)
Te = Ve[code,:]

# %%
# Te

# %%
# формируем учебный набор...

c = 3  # размер окна контекста, количество слов перед текущим словом и после него
W = [] # слова
C = [] # контекст для слов

for i in range(c,m-c) :
    W.append( Te[i,:] ) # код текущего слова
    # контекст для текущего слова
    C.append( np.vstack( ( Te[i-c:i,:] , Te[i+1:i+c+1,:] ) ).reshape(1,2*c,n) )

# %%
W = np.vstack(W)
W.shape
# Out:
# (550, 355)

# %%
C = np.concatenate(C)
C.shape
# Out:
# (550, 6, 355)

# %%
# np.savez( "result/data.npz", W=W, C=C )
# scipy.io.savemat("result/data.mat", dict(W=W, C=C))

# %% [markdown]
# ---

# %%
# ф-ция активации скрытого слоя - линейная
# def act(s): return s

# ф-ция активации выходного слоя
def softmax(s): 
    e = np.exp(s)
    return e/e.sum(axis=1).reshape(s.shape[0],1)

# %%
def w2v_step(W,Vi,Vo):
    H = W.dot(Vi) # значения скрытого слоя
    U = H.dot(Vo) # состояния выходного слоя
    O = softmax(U) # выход сети
    return H,U,O

# %% [markdown]
# Функция потери
#
# $$E = \left| \sum\limits_i\log\left( \sum\limits_k \exp(U_{ik}) \right) - \sum\limits_i\sum\limits_k\sum\limits_j (U_{ik} * Q_{ijk}) \right| $$
#
#
# $U_{ik}$ состояние k-того нейрона выходного слоя для слова $i$
# $Q_{ij}$ слово $j$ контекста слова $i$
# где ∗ - операция поэлементного умножения векторов

# %%
def w2v_loss(U,C):
    n,cws,v = C.shape 
    # количество примеров
    # размер окна контекста   
    # количество слов в словаре

    Us = np.log( np.exp(U).sum(axis=1) ).sum()

    Uo = 0.0
    for i in range(cws): # для всех слов контекста
        Ci = C[:,i,:].reshape([n,v]) # набор слов контекста i
        Uo += (U*Ci).sum() # значения выходного слоя для слов x контекста i

    return np.abs(Us-Uo)/n

# %%
def w2v_grad(C,W,H,O,Vo):
    n,cws,v = C.shape
        # количество примеров
        # размер окна контекста   
        # количество слов в словаре

    gVi = gVo = 0.0 

    for i in range(cws):
        Ci = C[:,i,:].reshape([n,v]) # слово i контекста
        D = O - Ci # ошибка на слове контекста i
        gVo += D.T.dot(H).T
        gVi += W.T.dot(D).dot(Vo.T)

    return gVi,gVo

# %% [markdown]
# ---

# %%
def w2v_weigth_norm(v,w):
    nn = np.linalg.norm( np.hstack([ v.flatten(), w.flatten() ]) )
    #nn = np.abs( np.hstack([ v.flatten(), w.flatten() ]) ).max()
    return (v/nn,w/nn) if nn!=0.0 else (v,w)

# %% [markdown]
# ---

# %%
n = W.shape[1] # количество слов в словаре
k = 30 # размер скрытого слоя H

Vi = np.random.normal(scale=0.01,size=(n,k))
Vo = np.random.normal(scale=0.01,size=(k,n))

# %%
a = 0.91 # скорость обучения

er = [1e10]

for i in range(100):
    H,U,O = w2v_step(W,Vi,Vo) # вычисляем состояния слоёв и выход
    er.append(w2v_loss(U,C)) # вычисляем ошибку
    print(i+1, er[-1])
    if er[-1]>er[-2]: 
        Vi, Vo = Vi_old, Vo_old
        break
        
    gVi, gVo = w2v_grad(C,W,H,O,Vo) # вычисляем градиент ф-ции потери
    gVi,gVo = w2v_weigth_norm(gVi,gVo) # нормируем значения градиента
    
    Vi_old, Vo_old =  Vi, Vo # сохраняем старые веса
    
    Vi,Vo = Vi-a*gVi, Vo-a*gVo # корректируем веса
# Out:
# 1 5.872179368093904
# 2 5.865129286365777
# 3 5.845918243302306
# 4 5.8073518089601075
# 5 5.747106405207272
# 6 5.663734125946983
# 7 5.55654820907925
# 8 5.425417178119348
# 9 5.270927838998845
# 10 5.095121884353987
# 11 4.903672510085703
# 12 4.706902458393213
# 13 4.505268074022412
# 14 4.2934122402363455
# 15 4.071537209571552
# 16 3.8413725246909483
# 17 3.6049477786605264
# 18 3.3632864412038006
# 19 3.1167716955979308
# 20 2.8660343593027395
# 21 2.6115478973838293
# 22 2.3532925658355737
# 23 2.090935715265536
# 24 1.824138630360098
# 25 1.5527724470649562
# 26 1.2770111762383045
# 27 0.9973342010383005
# 28 0.7144330059110102
# 29 0.4289924774777914
# 30 0.14143173922610747
# 31 0.14820757837917797

# %%
er=er[1:]
plt.plot(er)
plt.grid()
plt.show()

# %% [markdown]
# ---

# %%
from sklearn.metrics.pairwise import pairwise_distances

# %%
D = pairwise_distances(Vi) # матрица расстояний
R = np.argsort(D) # номера слов в порядке увеличения расстояния

# %%
vocab = { i:w for i,w in enumerate(words) } # нумеруем слов в словаре

nn = np.random.permutation(len(words))[:10] # выбираем случайно N слов

# для выбранных слов печатаем близкие по w2v
{ vocab[i] : [ vocab[j] for j in  R[i,1:3]  ] for i in nn }
# Out:
# {'зачем': ['сам', 'придёт'],
#  'твои': ['пока', 'обязанности'],
#  'текста': ['каждой', 'справа'],
#  'просмотров': ['количество', 'цифры'],
#  'помоги': ['пожалуйста', 'жмурится'],
#  'он': ['отобрал', 'грех'],
#  'то': ['умрёшь', 'когда'],
#  'автора': ['согласия', 'которому'],
#  'дома': ['из', 'периодически'],
#  'хочет': ['понял', 'спаси']}
