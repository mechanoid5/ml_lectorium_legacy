# %% [markdown]
# **MLP классификатор (TensorFlow)**
#
# Евгений Борисов  <esborisov@sevsu.ru>

# %% [markdown]
# О методах обучения многослойных нейронных сетей прямого распространения.
# http://mechanoid.su/neural-net-backprop.html
# http://mechanoid.su/neural-net-backprop2.html

# %%
import numpy as np
from numpy import random as rng
import matplotlib.pyplot as plt

# %%
np.set_printoptions(precision=2)

# %% [markdown]
# ## генерируем данные

# %%
n_samples = 1500

# from sklearn.datasets import make_blobs
# X,target = make_blobs( n_samples=n_samples, centers=2,  cluster_std=[1.5, 1.8,] )

# from sklearn.datasets import make_moons
# X,target = make_moons(n_samples=n_samples, noise=.09)

from sklearn.datasets import make_circles
X,target = make_circles(n_samples=n_samples, shuffle=True, noise=.09, factor=.3)
# X = X+(np.random.rand(X.shape[0],X.shape[1])*0.6)


y = np.eye(len(target),2)[target] # [:,np.newaxis]

X.shape, y.shape
# Out:
# ((1500, 2), (1500, 2))

# %%
# нормируем данные
# from sklearn.preprocessing import MinMaxScaler
# X = MinMaxScaler([-1.0,1.0]).fit_transform(X)

# from sklearn.preprocessing   import StandardScaler
# X = StandardScaler().fit(X).transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.5)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((750, 2), (750, 2), (750, 2), (750, 2))

# %%
del X
del y
del target

# %%
def plot_data(ax,X,y,t):
    c = [ ['b','r','g','y'][j] for j in y.astype(int).flatten()  ]
    ax.set_title(t)
    ax.scatter( x=X[:,0], y=X[:,1], c=c,  alpha=0.5 )
    ax.grid()

fig, (ax0,ax1) = plt.subplots(1,2, sharey=True, sharex=True, figsize=(12,5),)
plot_data(ax0,X_train,y_train[:,0],'учебные')    
plot_data(ax1,X_test,y_test[:,0],'тестовые')    
plt.show()

# %% [markdown]
# ## модель

# %% [markdown]
# схема нейрона
#
# ![image.png](attachment:image.png)

# %% [markdown]
# схема MPL
#
# ![image.png](attachment:image.png)

# %%
import tensorflow as tf
from tensorflow.keras import Model 
from tensorflow.keras.layers import Dense 

class MLP(Model):
    def __init__(self,input_size,output_size):
        super().__init__()
        self.dense0 = Dense(units=input_size) # нулевой - распределительный/входной слой
        self.dense1 = Dense(units=10) # первый - обрабатывающий/скрытый слой
        self.dense2 = Dense(units=5) # второй - обрабатывающий/скрытый слой
        self.dense3 = Dense(units=output_size) # третий - обрабатывающий/выходной слой

    def call(self, x): 
        o = self.dense0(x)
        
        o = self.dense1(o) 
        o = tf.nn.sigmoid(o)
        
        o = self.dense2(o) 
        o = tf.nn.sigmoid(o)
        
        o = self.dense3(o)
        o = tf.nn.sigmoid(o)
        return o

# %%
model = MLP( input_size=X_train.shape[1], output_size=y_train.shape[1], )
# model.predict(X_train)

# %% [markdown]
# ## обучаем модель

# %% [markdown]
# функция потери средняя квадратичная ошибка
# $$L=MSQE(y,o)=\frac{1}{m}\sum\limits_{i=0}^m(o_i-y_i)^2$$

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=.1)
loss = tf.keras.losses.MeanSquaredError()
model.compile(loss=loss, optimizer=optimizer, metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import Callback

class AccuracyCallback(Callback): 
    
    def on_epoch_end(self, epoch, logs={}): 
        min_acc=.98
        acc = logs.get('accuracy')
        if acc is not None:
            if(logs.get('accuracy') > min_acc):   
                print('\naccuracy threshold reached\n')
                self.model.stop_training = True

# %%
# %%time

# пакуем данные в формат TF
X_train = tf.cast(X_train,tf.float32)
y_train = tf.cast(y_train,tf.float32)

result = model.fit(
    X_train,
    y_train,
    batch_size=len(y_train)//3, 
    epochs=135,
    callbacks=[AccuracyCallback()],
)
# Out:
# Epoch 1/135
# 3/3 [==============================] - 1s 2ms/step - loss: 0.3007 - accuracy: 0.5212
# Epoch 2/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2612 - accuracy: 0.4885
# Epoch 3/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2550 - accuracy: 0.5222
# Epoch 4/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2469 - accuracy: 0.5530
# Epoch 5/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2440 - accuracy: 0.5055
# Epoch 6/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2348 - accuracy: 0.4967
# Epoch 7/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2209 - accuracy: 0.6720
# Epoch 8/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2054 - accuracy: 0.6908
# Epoch 9/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1955 - accuracy: 0.6805
# Epoch 10/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1826 - accuracy: 0.6772
# Epoch 11/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1738 - accuracy: 0.6773
# Epoch 12/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1632 - accuracy: 0.7490
# Epoch 13/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1467 - accuracy: 0.8588
# Epoch 14/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1377 - accuracy: 0.8538
# Epoch 15/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1243 - accuracy: 0.8648
# Epoch 16/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1130 - accuracy: 0.8620
# Epoch 17/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1105 - accuracy: 0.8582
# Epoch 18/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1081 - accuracy: 0.8570
# Epoch 19/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1047 - accuracy: 0.8635
# Epoch 20/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1057 - accuracy: 0.8668
# Epoch 21/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1116 - accuracy: 0.8603
# Epoch 22/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1097 - accuracy: 0.8585
# Epoch 23/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1130 - accuracy: 0.8563
# Epoch 24/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1062 - accuracy: 0.8638
# Epoch 25/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1120 - accuracy: 0.8557
# Epoch 26/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1093 - accuracy: 0.8600
# Epoch 27/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1101 - accuracy: 0.8592
# Epoch 28/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1118 - accuracy: 0.8478
# Epoch 29/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1106 - accuracy: 0.8537
# Epoch 30/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1047 - accuracy: 0.8703
# Epoch 31/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1066 - accuracy: 0.8593
# Epoch 32/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1054 - accuracy: 0.8648
# Epoch 33/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1046 - accuracy: 0.8628
# Epoch 34/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1047 - accuracy: 0.8663
# Epoch 35/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1122 - accuracy: 0.8547
# Epoch 36/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1059 - accuracy: 0.8662
# Epoch 37/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1116 - accuracy: 0.8540
# Epoch 38/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1088 - accuracy: 0.8598
# Epoch 39/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1115 - accuracy: 0.8523
# Epoch 40/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1032 - accuracy: 0.8700
# Epoch 41/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1064 - accuracy: 0.8610
# Epoch 42/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1060 - accuracy: 0.8608
# Epoch 43/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1085 - accuracy: 0.8575
# Epoch 44/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1032 - accuracy: 0.8670
# Epoch 45/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1053 - accuracy: 0.8618
# Epoch 46/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1103 - accuracy: 0.8553
# Epoch 47/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1073 - accuracy: 0.8573
# Epoch 48/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1049 - accuracy: 0.8680
# Epoch 49/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1074 - accuracy: 0.8570
# Epoch 50/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1044 - accuracy: 0.8645
# Epoch 51/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1087 - accuracy: 0.8605
# Epoch 52/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1057 - accuracy: 0.8668
# Epoch 53/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1057 - accuracy: 0.8633
# Epoch 54/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1071 - accuracy: 0.8653
# Epoch 55/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1057 - accuracy: 0.8607
# Epoch 56/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1029 - accuracy: 0.8640
# Epoch 57/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1095 - accuracy: 0.8578
# Epoch 58/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1067 - accuracy: 0.8573
# Epoch 59/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1067 - accuracy: 0.8658
# Epoch 60/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1042 - accuracy: 0.8645
# Epoch 61/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1050 - accuracy: 0.8645
# Epoch 62/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1070 - accuracy: 0.8593
# Epoch 63/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0989 - accuracy: 0.8715
# Epoch 64/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1146 - accuracy: 0.8525
# Epoch 65/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1103 - accuracy: 0.8565
# Epoch 66/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1050 - accuracy: 0.8617
# Epoch 67/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1020 - accuracy: 0.8718
# Epoch 68/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1095 - accuracy: 0.8605
# Epoch 69/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1018 - accuracy: 0.8608
# Epoch 70/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1020 - accuracy: 0.8663
# Epoch 71/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0983 - accuracy: 0.8638
# Epoch 72/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0827 - accuracy: 0.8795
# Epoch 73/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0572 - accuracy: 0.9437
# Epoch 74/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0308 - accuracy: 0.9915
#
# accuracy threshold reached
#
# CPU times: user 1.08 s, sys: 118 ms, total: 1.2 s
# Wall time: 1.05 s

# %%
# история изменения значений погрешности модели
plt.plot(result.history['accuracy'],label='max acc=%.3f'%(max(result.history['accuracy'])),c='r')
plt.grid()
plt.legend()

# %%
# история изменения значений ф-ции потери
plt.plot(result.history['loss'],label='min loss=%.3f'%(min(result.history['loss'])))
plt.grid()
plt.legend()

# %% [markdown]
# ## тестируем модель

# %%
# пакуем данные в формат TF
X_test = tf.cast(X_test,tf.float32)

# %%
s = model.predict(X_test)[:,1]

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

fpr, tpr, thresholds = roc_curve( y_test[:,1], s )
roc_auc = auc(fpr,tpr)

plt.figure(figsize=(7,7))
plt.grid(True)
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC AUC %0.2f' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# оптимальный порого скора 
#  максимальное количество True Positive при минимальном количестве False Positive
optimal_threshold = thresholds[ np.argmax( np.abs(tpr-fpr) )  ]
optimal_threshold
# Out:
# 0.5694956

# %%
p = (s>optimal_threshold).astype(int)
y = y_test[:,1].astype(int)

# %%
fig, (ax0,ax1) = plt.subplots(1,2, sharey=True, sharex=True, figsize=(12,5),)
plot_data(ax0,X_test,y,'тестовые')    
plot_data(ax1,X_test,p,'результат')    
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y,p))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       372
#            1       1.00      0.99      0.99       378
#
#     accuracy                           0.99       750
#    macro avg       0.99      0.99      0.99       750
# weighted avg       0.99      0.99      0.99       750

# %% [markdown]
# ## карта скоров

# %%
# строим сетку и определяем значения скора классификатора во всех узлах

n=500 # количество разбиений сетки

xx,yy = np.meshgrid(
    np.linspace( X_test[:,0].numpy().min()-.1, X_test[:,0].numpy().max()+.1, n), 
    np.linspace( X_test[:,1].numpy().min()-.1, X_test[:,1].numpy().max()+.1, n)
) # узлы сетки

xy = np.vstack([xx.flatten(),yy.flatten() ]).T # разворачиваем сетку 

# пакуем данные в формат TF
xy = tf.cast(xy,tf.float32)
s = model.predict(xy)[:,1]

plt.figure(figsize=(7,7))
plt.contourf(xx, yy, (1.-s).reshape(n,n), cmap=plt.cm.RdBu)
plt.scatter( x=X_test[:,0], y=X_test[:,1], c=y_test[:,1].astype(int), alpha=.5 )
plt.grid()
