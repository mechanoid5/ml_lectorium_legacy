# %% [markdown]
# **MLP классификатор (Keras Sequential model)**
#
# Евгений Борисов  <esborisov@sevsu.ru>

# %% [markdown]
# О методах обучения многослойных нейронных сетей прямого распространения.
# http://mechanoid.su/neural-net-backprop.html
# http://mechanoid.su/neural-net-backprop2.html

# %%
import numpy as np
from numpy import random as rng
import matplotlib.pyplot as plt

# %%
np.set_printoptions(precision=2)

# %% [markdown]
# ## генерируем данные

# %%
n_samples = 1500

# from sklearn.datasets import make_blobs
# X,target = make_blobs( n_samples=n_samples, centers=2,  cluster_std=[1.5, 1.8,] )

# from sklearn.datasets import make_moons
# X,target = make_moons(n_samples=n_samples, noise=.09)

from sklearn.datasets import make_circles
X,target = make_circles(n_samples=n_samples, shuffle=True, noise=.09, factor=.3)
# X = X+(np.random.rand(X.shape[0],X.shape[1])*0.6)


y = np.eye(len(target),2)[target] # [:,np.newaxis]

X.shape, y.shape
# Out:
# ((1500, 2), (1500, 2))

# %%
# нормируем данные
# from sklearn.preprocessing import MinMaxScaler
# X = MinMaxScaler([-1.0,1.0]).fit_transform(X)

# from sklearn.preprocessing   import StandardScaler
# X = StandardScaler().fit(X).transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.5)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((750, 2), (750, 2), (750, 2), (750, 2))

# %%
del X
del y
del target

# %%
def plot_data(ax,X,y,t):
    c = [ ['b','r','g','y'][j] for j in y.astype(int).flatten()  ]
    ax.set_title(t)
    ax.scatter( x=X[:,0], y=X[:,1], c=c,  alpha=0.5 )
    ax.grid()

fig, (ax0,ax1) = plt.subplots(1,2, sharey=True, sharex=True, figsize=(12,5),)
plot_data(ax0,X_train,y_train[:,0],'учебные')    
plot_data(ax1,X_test,y_test[:,0],'тестовые')    
plt.show()

# %% [markdown]
# ## модель

# %% [markdown]
# схема нейрона
#
# ![image.png](attachment:image.png)

# %% [markdown]
# схема MPL
#
# ![image.png](attachment:image.png)

# %%
import tensorflow as tf
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense 
from tensorflow.keras.activations import sigmoid

model = Sequential([
    Dense(units=X_train.shape[1]),
    Dense(units=10,activation=sigmoid),
    Dense(units=5,activation=sigmoid),
    Dense(units=y_train.shape[1],activation=sigmoid)
])

# %% [markdown]
# ## обучаем модель

# %% [markdown]
# функция потери средняя квадратичная ошибка
# $$L=MSQE(y,o)=\frac{1}{m}\sum\limits_{i=0}^m(o_i-y_i)^2$$

# %%
from tensorflow.keras.callbacks import Callback

class AccuracyCallback(Callback): 
    
    def on_epoch_end(self, epoch, logs={}): 
        min_acc=.98
        acc = logs.get('accuracy')
        if acc is not None:
            if(logs.get('accuracy') > min_acc):   
                print('\naccuracy threshold reached\n')
                self.model.stop_training = True

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=.1)
loss = tf.keras.losses.MeanSquaredError()
model.compile(loss=loss, optimizer=optimizer, metrics=['accuracy'])

# %%
# from tensorflow.python.client import device_lib

# devices = [ d.name for d in device_lib.list_local_devices() if d.device_type=='GPU' ]
# device = devices[0] if len(devices)>0 else 'cpu'
# device

# %%
# пакуем данные в формат TF
X_train = tf.cast(X_train,tf.float32)
y_train = tf.cast(y_train,tf.float32)

# %%
# %%time

result = model.fit(
    X_train,
    y_train,
    batch_size=len(y_train)//3, 
    epochs=135,
    callbacks=[AccuracyCallback()],
)
# Out:
# Epoch 1/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2608 - accuracy: 0.5333
# Epoch 2/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2565 - accuracy: 0.5013
# Epoch 3/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2507 - accuracy: 0.5072
# Epoch 4/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2474 - accuracy: 0.5330
# Epoch 5/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2443 - accuracy: 0.5067
# Epoch 6/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2360 - accuracy: 0.5163
# Epoch 7/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2222 - accuracy: 0.6688
# Epoch 8/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2074 - accuracy: 0.6858
# Epoch 9/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1975 - accuracy: 0.6863
# Epoch 10/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1910 - accuracy: 0.6853
# Epoch 11/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1850 - accuracy: 0.6843
# Epoch 12/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1776 - accuracy: 0.6837
# Epoch 13/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1678 - accuracy: 0.6862
# Epoch 14/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1608 - accuracy: 0.7393
# Epoch 15/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1469 - accuracy: 0.8398
# Epoch 16/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1403 - accuracy: 0.8432
# Epoch 17/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1306 - accuracy: 0.8453
# Epoch 18/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1245 - accuracy: 0.8562
# Epoch 19/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1200 - accuracy: 0.8585
# Epoch 20/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1184 - accuracy: 0.8502
# Epoch 21/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1120 - accuracy: 0.8658
# Epoch 22/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1153 - accuracy: 0.8493
# Epoch 23/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1208 - accuracy: 0.8417
# Epoch 24/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1103 - accuracy: 0.8592
# Epoch 25/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1154 - accuracy: 0.8502
# Epoch 26/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1091 - accuracy: 0.8558
# Epoch 27/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1093 - accuracy: 0.8620
# Epoch 28/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1126 - accuracy: 0.8457
# Epoch 29/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1097 - accuracy: 0.8552
# Epoch 30/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1039 - accuracy: 0.8692
# Epoch 31/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1108 - accuracy: 0.8583
# Epoch 32/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1155 - accuracy: 0.8477
# Epoch 33/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1085 - accuracy: 0.8602
# Epoch 34/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1081 - accuracy: 0.8588
# Epoch 35/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1043 - accuracy: 0.8682
# Epoch 36/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1072 - accuracy: 0.8628
# Epoch 37/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1054 - accuracy: 0.8593
# Epoch 38/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1089 - accuracy: 0.8597
# Epoch 39/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1018 - accuracy: 0.8688
# Epoch 40/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1022 - accuracy: 0.8692
# Epoch 41/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0992 - accuracy: 0.8705
# Epoch 42/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0829 - accuracy: 0.8963
# Epoch 43/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0777 - accuracy: 0.9040
# Epoch 44/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0665 - accuracy: 0.9233
# Epoch 45/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0369 - accuracy: 0.9675
# Epoch 46/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0216 - accuracy: 0.9865
#
# accuracy threshold reached
#
# CPU times: user 819 ms, sys: 83.1 ms, total: 902 ms
# Wall time: 808 ms

# %%
# история изменения значений погрешности модели
plt.plot(result.history['accuracy'],label='max acc=%.3f'%(max(result.history['accuracy'])),c='r')
plt.grid()
plt.legend()

# %%
# история изменения значений ф-ции потери
plt.plot(result.history['loss'],label='min loss=%.3f'%(min(result.history['loss'])))
plt.grid()
plt.legend()

# %% [markdown]
# ## тестируем модель

# %%
# пакуем данные в формат TF
X_test = tf.cast(X_test,tf.float32)

# %%
s = model.predict(X_test)[:,1]

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

fpr, tpr, thresholds = roc_curve( y_test[:,1], s )
roc_auc = auc(fpr,tpr)

plt.figure(figsize=(7,7))
plt.grid(True)
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC AUC %0.2f' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# оптимальный порого скора 
#  максимальное количество True Positive при минимальном количестве False Positive
optimal_threshold = thresholds[ np.argmax( np.abs(tpr-fpr) )  ]
optimal_threshold
# Out:
# 0.730547

# %%
p = (s>optimal_threshold).astype(int)
y = y_test[:,1].astype(int)

# %%
fig, (ax0,ax1) = plt.subplots(1,2, sharey=True, sharex=True, figsize=(12,5),)
plot_data(ax0,X_test,y,'тестовые')    
plot_data(ax1,X_test,p,'результат')    
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y,p))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       377
#            1       1.00      1.00      1.00       373
#
#     accuracy                           1.00       750
#    macro avg       1.00      1.00      1.00       750
# weighted avg       1.00      1.00      1.00       750

# %% [markdown]
# ## карта скоров

# %%
# строим сетку и определяем значения скора классификатора во всех узлах

n=500 # количество разбиений сетки

xx,yy = np.meshgrid(
    np.linspace( X_test[:,0].numpy().min()-.1, X_test[:,0].numpy().max()+.1, n), 
    np.linspace( X_test[:,1].numpy().min()-.1, X_test[:,1].numpy().max()+.1, n)
) # узлы сетки

xy = np.vstack([xx.flatten(),yy.flatten() ]).T # разворачиваем сетку 

# пакуем данные в формат TF
xy = tf.cast(xy,tf.float32)
s = model.predict(xy)[:,1]

plt.figure(figsize=(7,7))
plt.contourf(xx, yy, (1.-s).reshape(n,n), cmap=plt.cm.RdBu)
plt.scatter( x=X_test[:,0], y=X_test[:,1], c=y_test[:,1].astype(int), alpha=.5 )
plt.grid()
