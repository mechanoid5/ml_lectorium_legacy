# %% [markdown]
# **MLP классификатор (Keras Sequential model)**
#
# Евгений Борисов  <esborisov@sevsu.ru>

# %% [markdown]
# О методах обучения многослойных нейронных сетей прямого распространения.
# http://mechanoid.su/neural-net-backprop.html
# http://mechanoid.su/neural-net-backprop2.html

# %%
import numpy as np
from numpy import random as rng
import matplotlib.pyplot as plt

# %%
np.set_printoptions(precision=2)

# %% [markdown]
# ## генерируем данные

# %%
n_samples = 1500

# from sklearn.datasets import make_blobs
# X,target = make_blobs( n_samples=n_samples, centers=2,  cluster_std=[1.5, 1.8,] )

# from sklearn.datasets import make_moons
# X,target = make_moons(n_samples=n_samples, noise=.09)

from sklearn.datasets import make_circles
X,target = make_circles(n_samples=n_samples, shuffle=True, noise=.09, factor=.3)
# X = X+(np.random.rand(X.shape[0],X.shape[1])*0.6)


y = np.eye(len(target),2)[target] # [:,np.newaxis]

X.shape, y.shape
# Out:
# ((1500, 2), (1500, 2))

# %%
# нормируем данные
# from sklearn.preprocessing import MinMaxScaler
# X = MinMaxScaler([-1.0,1.0]).fit_transform(X)

# from sklearn.preprocessing   import StandardScaler
# X = StandardScaler().fit(X).transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.5)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((750, 2), (750, 2), (750, 2), (750, 2))

# %%
del X
del y
del target

# %%
def plot_data(ax,X,y,t):
    c = [ ['b','r','g','y'][j] for j in y.astype(int).flatten()  ]
    ax.set_title(t)
    ax.scatter( x=X[:,0], y=X[:,1], c=c,  alpha=0.5 )
    ax.grid()

fig, (ax0,ax1) = plt.subplots(1,2, sharey=True, sharex=True, figsize=(12,5),)
plot_data(ax0,X_train,y_train[:,0],'учебные')    
plot_data(ax1,X_test,y_test[:,0],'тестовые')    
plt.show()

# %% [markdown]
# ## модель

# %% [markdown]
# схема нейрона
#
# ![image.png](attachment:image.png)

# %% [markdown]
# схема MPL
#
# ![image.png](attachment:image.png)

# %%
import tensorflow as tf
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense 
from tensorflow.keras.activations import sigmoid

model = Sequential([
    Dense(units=X_train.shape[1]),
    Dense(units=10,activation=sigmoid),
    Dense(units=5,activation=sigmoid),
    Dense(units=y_train.shape[1],activation=sigmoid)
])

# %% [markdown]
# ## обучаем модель

# %% [markdown]
# функция потери средняя квадратичная ошибка
# $$L=MSQE(y,o)=\frac{1}{m}\sum\limits_{i=0}^m(o_i-y_i)^2$$

# %%
from tensorflow.keras.callbacks import Callback

class AccuracyCallback(Callback): 
    
    def on_epoch_end(self, epoch, logs={}): 
        min_acc=.98
        acc = logs.get('accuracy')
        if acc is not None:
            if(logs.get('accuracy') > min_acc):   
                print('\naccuracy threshold reached\n')
                self.model.stop_training = True

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=.1)
loss = tf.keras.losses.MeanSquaredError()
model.compile(loss=loss, optimizer=optimizer, metrics=['accuracy'])

# %%
from tensorflow.python.client import device_lib

devices = [ d.name for d in device_lib.list_local_devices() if d.device_type=='GPU' ]
device = devices[0] if len(devices)>0 else 'cpu'
device
# Out:
# '/device:GPU:0'

# %%
# %%time

result = model.fit(
    tf.cast(X_train,tf.float32),
    tf.cast(y_train,tf.float32),
    batch_size=len(y_train)//3, 
    epochs=135,
    callbacks=[AccuracyCallback()],
)
# Out:
# Epoch 1/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2730 - accuracy: 0.4982
# Epoch 2/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2645 - accuracy: 0.5038
# Epoch 3/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2542 - accuracy: 0.5322
# Epoch 4/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2536 - accuracy: 0.4992
# Epoch 5/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2519 - accuracy: 0.5022
# Epoch 6/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2521 - accuracy: 0.5008
# Epoch 7/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2506 - accuracy: 0.5108
# Epoch 8/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2500 - accuracy: 0.5178
# Epoch 9/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2512 - accuracy: 0.5588
# Epoch 10/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2488 - accuracy: 0.5528
# Epoch 11/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2463 - accuracy: 0.5565
# Epoch 12/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2402 - accuracy: 0.6350
# Epoch 13/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2273 - accuracy: 0.6840
# Epoch 14/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2124 - accuracy: 0.6930
# Epoch 15/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2017 - accuracy: 0.7035
# Epoch 16/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1950 - accuracy: 0.7022
# Epoch 17/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1904 - accuracy: 0.6982
# Epoch 18/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1933 - accuracy: 0.6945
# Epoch 19/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1867 - accuracy: 0.7060
# Epoch 20/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1919 - accuracy: 0.7007
# Epoch 21/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1898 - accuracy: 0.6988
# Epoch 22/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1925 - accuracy: 0.6910
# Epoch 23/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1933 - accuracy: 0.6863
# Epoch 24/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1898 - accuracy: 0.6933
# Epoch 25/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1924 - accuracy: 0.6962
# Epoch 26/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1833 - accuracy: 0.7152
# Epoch 27/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1910 - accuracy: 0.6913
# Epoch 28/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1945 - accuracy: 0.6888
# Epoch 29/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1914 - accuracy: 0.6967
# Epoch 30/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1915 - accuracy: 0.6938
# Epoch 31/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1872 - accuracy: 0.7028
# Epoch 32/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1917 - accuracy: 0.6792
# Epoch 33/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1852 - accuracy: 0.6897
# Epoch 34/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1753 - accuracy: 0.7143
# Epoch 35/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1726 - accuracy: 0.7158
# Epoch 36/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1780 - accuracy: 0.6840
# Epoch 37/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1685 - accuracy: 0.6945
# Epoch 38/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1598 - accuracy: 0.7355
# Epoch 39/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1510 - accuracy: 0.8352
# Epoch 40/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1457 - accuracy: 0.8472
# Epoch 41/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1427 - accuracy: 0.8407
# Epoch 42/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1358 - accuracy: 0.8442
# Epoch 43/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1290 - accuracy: 0.8438
# Epoch 44/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1249 - accuracy: 0.8522
# Epoch 45/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1203 - accuracy: 0.8533
# Epoch 46/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1233 - accuracy: 0.8455
# Epoch 47/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1261 - accuracy: 0.8347
# Epoch 48/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1173 - accuracy: 0.8532
# Epoch 49/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1168 - accuracy: 0.8527
# Epoch 50/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1227 - accuracy: 0.8437
# Epoch 51/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1211 - accuracy: 0.8417
# Epoch 52/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1210 - accuracy: 0.8372
# Epoch 53/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1149 - accuracy: 0.8592
# Epoch 54/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1196 - accuracy: 0.8480
# Epoch 55/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1183 - accuracy: 0.8448
# Epoch 56/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1136 - accuracy: 0.8555
# Epoch 57/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1137 - accuracy: 0.8485
# Epoch 58/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1151 - accuracy: 0.8498
# Epoch 59/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1141 - accuracy: 0.8493
# Epoch 60/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1134 - accuracy: 0.8455
# Epoch 61/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1078 - accuracy: 0.8558
# Epoch 62/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1041 - accuracy: 0.8565
# Epoch 63/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0944 - accuracy: 0.8863
# Epoch 64/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0788 - accuracy: 0.9075
# Epoch 65/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0715 - accuracy: 0.9223
# Epoch 66/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0420 - accuracy: 0.9558
# Epoch 67/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0189 - accuracy: 0.9953
#
# accuracy threshold reached
#
# CPU times: user 917 ms, sys: 143 ms, total: 1.06 s
# Wall time: 923 ms

# %%
# история изменения значений погрешности модели
plt.plot(result.history['accuracy'],label='max acc=%.3f'%(max(result.history['accuracy'])),c='r')
plt.grid()
plt.legend()

# %%
# история изменения значений ф-ции потери
plt.plot(result.history['loss'],label='min loss=%.3f'%(min(result.history['loss'])))
plt.grid()
plt.legend()

# %% [markdown]
# ## тестируем модель

# %%
s = model.predict(tf.cast(X_test,tf.float32))[:,1]

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

fpr, tpr, thresholds = roc_curve( y_test[:,1], s )
roc_auc = auc(fpr,tpr)

plt.figure(figsize=(7,7))
plt.grid(True)
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC AUC %0.2f' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# оптимальный порого скора 
#  максимальное количество True Positive при минимальном количестве False Positive
optimal_threshold = thresholds[ np.argmax( np.abs(tpr-fpr) )  ]
optimal_threshold
# Out:
# 0.5340395

# %%
p = (s>optimal_threshold).astype(int)
y = y_test[:,1].astype(int)

# %%
fig, (ax0,ax1) = plt.subplots(1,2, sharey=True, sharex=True, figsize=(12,5),)
plot_data(ax0,X_test,y,'тестовые')    
plot_data(ax1,X_test,p,'результат')    
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y,p))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       380
#            1       0.99      1.00      1.00       370
#
#     accuracy                           1.00       750
#    macro avg       1.00      1.00      1.00       750
# weighted avg       1.00      1.00      1.00       750

# %% [markdown]
# ## карта скоров

# %%
# строим сетку и определяем значения скора классификатора во всех узлах

n=500 # количество разбиений сетки

xx,yy = np.meshgrid(
    np.linspace( X_test[:,0].min()-.1, X_test[:,0].max()+.1, n), 
    np.linspace( X_test[:,1].min()-.1, X_test[:,1].max()+.1, n)
) # узлы сетки

xy = np.vstack([xx.flatten(),yy.flatten() ]).T # разворачиваем сетку 

# пакуем данные в формат TF
s = model.predict(tf.cast(xy,tf.float32))[:,1]

plt.figure(figsize=(7,7))
plt.contourf(xx, yy, (1.-s).reshape(n,n), cmap=plt.cm.RdBu)
plt.scatter( x=X_test[:,0], y=X_test[:,1], c=y_test[:,1].astype(int), alpha=.5 )
plt.grid()
