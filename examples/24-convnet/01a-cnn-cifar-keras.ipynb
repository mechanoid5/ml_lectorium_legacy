# %% [markdown]
# **классификатор изображений на основе свёрточной сети**
#
# Евгений Борисов <esborisov@sevsu.ru>

# %% [markdown]
# ---

# %% [markdown]
# Backpropagation applied to handwritten zip code recognition.
# LeCun Y., Boser B., Denker J.S., Henderson D., Howard R.E., Hubbard W., Jackel L.D.
# Neural Computation 1989 1(4):541-551.
#
# http://yann.lecun.com/exdb/publis/pdf/lecun-89e.pdf

# %% [markdown]
# ---

# %%
import numpy as np
import numpy.random as rng
from matplotlib import pyplot as plt

# %% [markdown]
# ## загружаем датасет

# %%
# from tensorflow.keras.datasets import fashion_mnist
# (image_train, target_train),(image_test, target_test) = fashion_mnist.load_data()
# image_train = image_train[:,:,:,np.newaxis]
# image_test = image_test[:,:,:,np.newaxis]
# target_train = target_train.flatten()
# target_test = target_test.flatten()

# %%
from tensorflow.keras.datasets import cifar10

(image_train, target_train),(image_test, target_test) = cifar10.load_data()

target_train = target_train.flatten()
target_test = target_test.flatten()

image_train.shape, image_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3))

# %%
n_show = 9

plt.figure(figsize=(16,4))
for n,i in enumerate(rng.permutation(len(image_train))[:n_show], start=1):
    img = image_train[i]
    plt.subplot(1,n_show,n)
    plt.axis(False)
    plt.imshow(img) # ,cmap='gray_r')

# %%
image_train.min(),image_train.max()
# Out:
# (0, 255)

# %% [markdown]
# ## подготовка данных

# %%
# масштабируем данные в [-1,1], добавляем ещё одну размерность (канал цвета)

im2ar = lambda im: (im-127.5)/127.5

x_train = im2ar(image_train).astype(np.float32)
x_test  = im2ar(image_test).astype(np.float32)

x_train.shape, x_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3))

# %%
x_train.min(),x_train.max()
# Out:
# (-1.0, 1.0)

# %%
# one hot encoding
y_train = np.eye(len(target_train),target_train.max()+1,dtype=np.float32)[target_train]
y_test = np.eye(len(target_test),target_train.max()+1,dtype=np.float32)[target_test]
y_train.shape, y_test.shape
# Out:
# ((50000, 10), (10000, 10))

# %% [markdown]
# ## Модель

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.8.0'

# %%
# from tensorflow.keras import Model
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D

from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.utils import plot_model

# %%
INPUT_SHAPE = x_train.shape[1:] # размер входного образа
N_CLASSES = y_train.shape[1] # размер выхода

# %%
model = Sequential()
model.add(Input( shape=INPUT_SHAPE, name='input1' ) )
model.add(Conv2D(32, kernel_size=3, padding='same', activation='relu', name='conv1', ))
model.add(MaxPooling2D(pool_size=2,strides=2, name='mpool1',))
model.add(Conv2D(64, kernel_size=3, padding='same', activation='relu', name='conv2', ))
model.add(Flatten(name='flatten1'))
model.add(Dense(512,activation='relu',name='hidden1',))
model.add(Dense(N_CLASSES, activation='softmax',name='out_softmax',))
# Out:
# 2022-04-20 12:36:49.336017: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-20 12:36:49.363034: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-20 12:36:49.363206: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-20 12:36:49.364015: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-20 12:36:49.364349: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-20 12:36:49.364528: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-20 12:36:49.364662: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-20 12:36:49.713305: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-20 12:36:49.713467: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-20 12:36:49.713586: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-20 12:36:49.713695: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4968 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1060 6GB, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
# model.summary()
plot_model(model,to_file='cnn.png', show_layer_names=True, show_shapes=True )

# %% [markdown]
# ## Обучение

# %%
# %%time

N_EPOCH = 20
BATCH_SIZE = 128
VERBOSE = 1
VALIDATION_SPLIT = .2
LEARNING_RATE = 2e-4

optimizer = tf.keras.optimizers.Adam(LEARNING_RATE)
model.compile(loss='binary_crossentropy', optimizer=optimizer,metrics=['accuracy'])

history = model.fit(x_train, y_train, 
                    batch_size=BATCH_SIZE, 
                    epochs=N_EPOCH, 
                    verbose=VERBOSE, 
                    validation_split=VALIDATION_SPLIT)
# Out:
# Epoch 1/20
# 2022-04-20 12:37:03.531579: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8300
# 313/313 [==============================] - 5s 12ms/step - loss: 0.2491 - accuracy: 0.4466 - val_loss: 0.2146 - val_accuracy: 0.5377
# Epoch 2/20
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1972 - accuracy: 0.5786 - val_loss: 0.1962 - val_accuracy: 0.5791
# Epoch 3/20
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1762 - accuracy: 0.6322 - val_loss: 0.1807 - val_accuracy: 0.6168
# Epoch 4/20
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1617 - accuracy: 0.6682 - val_loss: 0.1733 - val_accuracy: 0.6329
# Epoch 5/20
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1498 - accuracy: 0.6984 - val_loss: 0.1680 - val_accuracy: 0.6425
# Epoch 6/20
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1386 - accuracy: 0.7247 - val_loss: 0.1610 - val_accuracy: 0.6676
# Epoch 7/20
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1281 - accuracy: 0.7513 - val_loss: 0.1574 - val_accuracy: 0.6771
# Epoch 8/20
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1184 - accuracy: 0.7737 - val_loss: 0.1555 - val_accuracy: 0.6823
# Epoch 9/20
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1089 - accuracy: 0.7978 - val_loss: 0.1529 - val_accuracy: 0.6877
# Epoch 10/20
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0993 - accuracy: 0.8245 - val_loss: 0.1549 - val_accuracy: 0.6906
# Epoch 11/20
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0895 - accuracy: 0.8489 - val_loss: 0.1521 - val_accuracy: 0.7017
# Epoch 12/20
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0801 - accuracy: 0.8723 - val_loss: 0.1578 - val_accuracy: 0.6924
# Epoch 13/20
# 313/313 [==============================] - 4s 11ms/step - loss: 0.0711 - accuracy: 0.8942 - val_loss: 0.1593 - val_accuracy: 0.6996
# Epoch 14/20
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0630 - accuracy: 0.9114 - val_loss: 0.1688 - val_accuracy: 0.6895
# Epoch 15/20
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0537 - accuracy: 0.9337 - val_loss: 0.1649 - val_accuracy: 0.7003
# Epoch 16/20
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0455 - accuracy: 0.9496 - val_loss: 0.1694 - val_accuracy: 0.7044
# Epoch 17/20
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0375 - accuracy: 0.9645 - val_loss: 0.1786 - val_accuracy: 0.7063
# Epoch 18/20
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0308 - accuracy: 0.9760 - val_loss: 0.1901 - val_accuracy: 0.6970
# Epoch 19/20
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0251 - accuracy: 0.9831 - val_loss: 0.1927 - val_accuracy: 0.7061
# Epoch 20/20
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0199 - accuracy: 0.9895 - val_loss: 0.2076 - val_accuracy: 0.7035
# CPU times: user 1min 6s, sys: 3.33 s, total: 1min 10s
# Wall time: 1min 23s

# %% [markdown]
# ## Тестирование

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
score = model.evaluate(x_test, y_test, verbose=False)
print('Test accuracy:', score[1])
# Out:
# Test accuracy: 0.6973999738693237

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()

plt.show()

# %%
plt.clf()   # clear figure
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']

plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# ---

# %%
# %%time 

o_test = np.argmax( model.predict(x_test),axis=1)

class_names = [ 
'airplane',
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]
from sklearn.metrics import classification_report

print(classification_report(target_test, o_test, target_names=class_names) )
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.79      0.73      0.76      1000
#   automobile       0.78      0.82      0.80      1000
#         bird       0.55      0.61      0.58      1000
#          cat       0.53      0.49      0.51      1000
#         deer       0.66      0.60      0.63      1000
#          dog       0.60      0.59      0.60      1000
#         frog       0.77      0.77      0.77      1000
#        horse       0.72      0.79      0.75      1000
#         ship       0.79      0.83      0.81      1000
#        truck       0.79      0.75      0.77      1000
#
#     accuracy                           0.70     10000
#    macro avg       0.70      0.70      0.70     10000
# weighted avg       0.70      0.70      0.70     10000
#
# CPU times: user 993 ms, sys: 150 ms, total: 1.14 s
# Wall time: 997 ms

# %%
# матрица ошибок
import itertools
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(target_test,o_test)

classes=class_names
thresh = cm.max()/2.
tick_marks = np.arange(len(classes))

fig = plt.figure(figsize=(6,6))
plt.title('Confusion matrix')
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.xticks(tick_marks, classes, rotation=90)
plt.yticks(tick_marks, classes)

for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    c = 'white' if cm[i,j] > thresh else 'black'
    plt.text(j,i, f'{cm[i,j]}',horizontalalignment="center",color=c)

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
n_show, n_cols = 35, 7

n_rows = np.ceil(n_show/n_cols).astype(int)

plt.figure(figsize=(16,4*n_rows,))
for n,i in enumerate( rng.permutation(len(image_test))[:n_show] ):
    img = image_test[i]
    
    er = target_test[i]==o_test[i]
    t_mark = class_names[target_test[i]] 
    t_pred = class_names[o_test[i]] 
    t,c = (t_mark,'g') if er else (f'{t_pred}\n[{t_mark.upper()}]','r')
   
    plt.subplot(n_rows,n_cols,n+1)
    plt.axis(False)
    plt.title(t,color=c)
    plt.imshow(img,cmap='gray_r')
