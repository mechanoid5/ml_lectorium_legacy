# %% [markdown]
# **классификатор изображений на основе свёрточной сети**
#
# Евгений Борисов <esborisov@sevsu.ru>

# %% [markdown]
# ---

# %% [markdown]
# Backpropagation applied to handwritten zip code recognition.
# LeCun Y., Boser B., Denker J.S., Henderson D., Howard R.E., Hubbard W., Jackel L.D.
# Neural Computation 1989 1(4):541-551.
#
# http://yann.lecun.com/exdb/publis/pdf/lecun-89e.pdf

# %% [markdown]
# ---

# %%
import numpy as np
import numpy.random as rng
from matplotlib import pyplot as plt

# %% [markdown]
# ## загружаем датасет

# %%
# from tensorflow.keras.datasets import fashion_mnist
# (image_train, target_train),(image_test, target_test) = fashion_mnist.load_data()
# image_train = image_train[:,:,:,np.newaxis]
# image_test = image_test[:,:,:,np.newaxis]
# target_train = target_train.flatten()
# target_test = target_test.flatten()

# %%
from tensorflow.keras.datasets import cifar10

(image_train, target_train),(image_test, target_test) = cifar10.load_data()

target_train = target_train.flatten()
target_test = target_test.flatten()

image_train.shape, image_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3))

# %%
n_show = 9

plt.figure(figsize=(16,4))
for n,i in enumerate(rng.permutation(len(image_train))[:n_show], start=1):
    img = image_train[i]
    plt.subplot(1,n_show,n)
    plt.axis(False)
    plt.imshow(img) # ,cmap='gray_r')

# %%
image_train.min(),image_train.max()
# Out:
# (0, 255)

# %% [markdown]
# ## подготовка данных

# %%
# масштабируем данные в [-1,1], добавляем ещё одну размерность (канал цвета)

im2ar = lambda im: (im-127.5)/127.5

x_train = im2ar(image_train).astype(np.float32)
x_test  = im2ar(image_test).astype(np.float32)

x_train.shape, x_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3))

# %%
x_train.min(),x_train.max()
# Out:
# (-1.0, 1.0)

# %%
# # one hot encoding
# y_train = np.eye(len(target_train),target_train.max()+1,dtype=np.float32)[target_train]
# y_test = np.eye(len(target_test),target_train.max()+1,dtype=np.float32)[target_test]
# y_train.shape, y_test.shape

# %%
# one hot encoding
y_train = np.eye(target_train.max()+1,dtype=np.float32)[target_train]
y_test = np.eye(target_train.max()+1,dtype=np.float32)[target_test]
y_train.shape, y_test.shape
# Out:
# ((50000, 10), (10000, 10))

# %% [markdown]
# ## Модель

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.8.0'

# %%
# from tensorflow.keras import Model
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D

from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.utils import plot_model

# %%
INPUT_SHAPE = x_train.shape[1:] # размер входного образа
N_CLASSES = y_train.shape[1] # размер выхода

# %%
model = Sequential()
model.add(Input( shape=INPUT_SHAPE, name='input1' ) )
model.add(Conv2D(32, kernel_size=3, padding='same', activation='relu', name='conv1', ))
model.add(MaxPooling2D(pool_size=2,strides=2, name='mpool1',))
model.add(Conv2D(64, kernel_size=3, padding='same', activation='relu', name='conv2', ))
model.add(Flatten(name='flatten1'))
model.add(Dense(512,activation='relu',name='hidden1',))
model.add(Dense(N_CLASSES, activation='softmax',name='out_softmax',))
# Out:
# 2022-05-07 16:40:30.633192: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-07 16:40:31.343244: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-07 16:40:31.343985: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-07 16:40:31.360256: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-07 16:40:31.361632: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-07 16:40:31.362358: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-07 16:40:31.362962: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-07 16:40:35.082825: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-07 16:40:35.083280: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-07 16:40:35.083644: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-07 16:40:35.092962: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5369 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1060 6GB, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
# model.summary()
plot_model(model,to_file='cnn.png', show_layer_names=True, show_shapes=True )

# %% [markdown]
# ## Обучение

# %%
# %%time

N_EPOCH = 20
BATCH_SIZE = 128
VERBOSE = 1
VALIDATION_SPLIT = .2
LEARNING_RATE = 2e-4

optimizer = tf.keras.optimizers.Adam(LEARNING_RATE)
model.compile(loss='binary_crossentropy', optimizer=optimizer,metrics=['accuracy'])

history = model.fit(x_train, y_train, 
                    batch_size=BATCH_SIZE, 
                    epochs=N_EPOCH, 
                    verbose=VERBOSE, 
                    validation_split=VALIDATION_SPLIT)
# Out:
# Epoch 1/20
# 2022-05-07 16:40:45.124168: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8300
# 313/313 [==============================] - 21s 13ms/step - loss: 0.2526 - accuracy: 0.4327 - val_loss: 0.2228 - val_accuracy: 0.5084
# Epoch 2/20
# 313/313 [==============================] - 4s 12ms/step - loss: 0.2046 - accuracy: 0.5584 - val_loss: 0.1996 - val_accuracy: 0.5719
# Epoch 3/20
# 313/313 [==============================] - 4s 13ms/step - loss: 0.1840 - accuracy: 0.6113 - val_loss: 0.1858 - val_accuracy: 0.6072
# Epoch 4/20
# 313/313 [==============================] - 4s 13ms/step - loss: 0.1692 - accuracy: 0.6501 - val_loss: 0.1755 - val_accuracy: 0.6339
# Epoch 5/20
# 313/313 [==============================] - 4s 13ms/step - loss: 0.1565 - accuracy: 0.6801 - val_loss: 0.1702 - val_accuracy: 0.6475
# Epoch 6/20
# 313/313 [==============================] - 4s 13ms/step - loss: 0.1460 - accuracy: 0.7062 - val_loss: 0.1660 - val_accuracy: 0.6574
# Epoch 7/20
# 313/313 [==============================] - 4s 12ms/step - loss: 0.1354 - accuracy: 0.7351 - val_loss: 0.1628 - val_accuracy: 0.6586
# Epoch 8/20
# 313/313 [==============================] - 4s 13ms/step - loss: 0.1261 - accuracy: 0.7558 - val_loss: 0.1582 - val_accuracy: 0.6716
# Epoch 9/20
# 313/313 [==============================] - 4s 13ms/step - loss: 0.1169 - accuracy: 0.7791 - val_loss: 0.1565 - val_accuracy: 0.6776
# Epoch 10/20
# 313/313 [==============================] - 4s 13ms/step - loss: 0.1080 - accuracy: 0.8013 - val_loss: 0.1544 - val_accuracy: 0.6892
# Epoch 11/20
# 313/313 [==============================] - 4s 13ms/step - loss: 0.0991 - accuracy: 0.8259 - val_loss: 0.1549 - val_accuracy: 0.6960
# Epoch 12/20
# 313/313 [==============================] - 4s 13ms/step - loss: 0.0900 - accuracy: 0.8489 - val_loss: 0.1533 - val_accuracy: 0.6993
# Epoch 13/20
# 313/313 [==============================] - 4s 13ms/step - loss: 0.0813 - accuracy: 0.8674 - val_loss: 0.1570 - val_accuracy: 0.6925
# Epoch 14/20
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0730 - accuracy: 0.8885 - val_loss: 0.1585 - val_accuracy: 0.6985
# Epoch 15/20
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0639 - accuracy: 0.9108 - val_loss: 0.1622 - val_accuracy: 0.7019
# Epoch 16/20
# 313/313 [==============================] - 4s 13ms/step - loss: 0.0559 - accuracy: 0.9277 - val_loss: 0.1654 - val_accuracy: 0.7029
# Epoch 17/20
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0485 - accuracy: 0.9442 - val_loss: 0.1718 - val_accuracy: 0.7055
# Epoch 18/20
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0405 - accuracy: 0.9587 - val_loss: 0.1769 - val_accuracy: 0.7067
# Epoch 19/20
# 313/313 [==============================] - 5s 14ms/step - loss: 0.0338 - accuracy: 0.9703 - val_loss: 0.1860 - val_accuracy: 0.7066
# Epoch 20/20
# 313/313 [==============================] - 5s 15ms/step - loss: 0.0282 - accuracy: 0.9797 - val_loss: 0.1930 - val_accuracy: 0.7049
# CPU times: user 1min 38s, sys: 6.97 s, total: 1min 45s
# Wall time: 1min 41s

# %% [markdown]
# ## Тестирование

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
score = model.evaluate(x_test, y_test, verbose=False)
print('Test accuracy:', score[1])
# Out:
# Test accuracy: 0.6984000205993652

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()

plt.show()

# %%
plt.clf()   # clear figure
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']

plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# ---

# %%
# %%time 

o_test = np.argmax( model.predict(x_test),axis=1)

class_names = [ 
'airplane',
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]
from sklearn.metrics import classification_report

print(classification_report(target_test, o_test, target_names=class_names) )
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.72      0.75      0.73      1000
#   automobile       0.80      0.80      0.80      1000
#         bird       0.62      0.57      0.60      1000
#          cat       0.52      0.49      0.51      1000
#         deer       0.61      0.70      0.65      1000
#          dog       0.56      0.64      0.60      1000
#         frog       0.78      0.74      0.76      1000
#        horse       0.81      0.74      0.78      1000
#         ship       0.84      0.78      0.81      1000
#        truck       0.76      0.77      0.76      1000
#
#     accuracy                           0.70     10000
#    macro avg       0.70      0.70      0.70     10000
# weighted avg       0.70      0.70      0.70     10000
#
# CPU times: user 992 ms, sys: 155 ms, total: 1.15 s
# Wall time: 1.01 s

# %%
# матрица ошибок
import itertools
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(target_test,o_test)

classes=class_names
thresh = cm.max()/2.
tick_marks = np.arange(len(classes))

fig = plt.figure(figsize=(6,6))
plt.title('Confusion matrix')
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.xticks(tick_marks, classes, rotation=90)
plt.yticks(tick_marks, classes)

for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    c = 'white' if cm[i,j] > thresh else 'black'
    plt.text(j,i, f'{cm[i,j]}',horizontalalignment="center",color=c)

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
n_show, n_cols = 35, 7

n_rows = np.ceil(n_show/n_cols).astype(int)

plt.figure(figsize=(16,4*n_rows,))
for n,i in enumerate( rng.permutation(len(image_test))[:n_show] ):
    img = image_test[i]
    
    er = target_test[i]==o_test[i]
    t_mark = class_names[target_test[i]] 
    t_pred = class_names[o_test[i]] 
    t,c = (t_mark,'g') if er else (f'{t_pred}\n[{t_mark.upper()}]','r')
   
    plt.subplot(n_rows,n_cols,n+1)
    plt.axis(False)
    plt.title(t,color=c)
    plt.imshow(img,cmap='gray_r')
