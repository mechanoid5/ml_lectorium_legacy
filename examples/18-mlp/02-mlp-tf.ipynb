# %% [markdown]
# **MLP классификатор (TensorFlow)**
#
# Евгений Борисов  <esborisov@sevsu.ru>

# %% [markdown]
# О методах обучения многослойных нейронных сетей прямого распространения.
# http://mechanoid.su/neural-net-backprop.html
# http://mechanoid.su/neural-net-backprop2.html

# %%
import numpy as np
from numpy import random as rng
import matplotlib.pyplot as plt

# %%
np.set_printoptions(precision=2)

# %% [markdown]
# ## генерируем данные

# %%
n_samples = 1500

# from sklearn.datasets import make_blobs
# X,target = make_blobs( n_samples=n_samples, centers=2,  cluster_std=[1.5, 1.8,] )

# from sklearn.datasets import make_moons
# X,target = make_moons(n_samples=n_samples, noise=.09)

from sklearn.datasets import make_circles
X,target = make_circles(n_samples=n_samples, shuffle=True, noise=.09, factor=.3)
# X = X+(np.random.rand(X.shape[0],X.shape[1])*0.6)


y = np.eye(len(target),2)[target] # [:,np.newaxis]

X.shape, y.shape
# Out:
# ((1500, 2), (1500, 2))

# %%
# нормируем данные
# from sklearn.preprocessing import MinMaxScaler
# X = MinMaxScaler([-1.0,1.0]).fit_transform(X)

# from sklearn.preprocessing   import StandardScaler
# X = StandardScaler().fit(X).transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.5)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((750, 2), (750, 2), (750, 2), (750, 2))

# %%
del X
del y
del target

# %%
def plot_data(ax,X,y,t):
    c = [ ['b','r','g','y'][j] for j in y.astype(int).flatten()  ]
    ax.set_title(t)
    ax.scatter( x=X[:,0], y=X[:,1], c=c,  alpha=0.5 )
    ax.grid()

fig, (ax0,ax1) = plt.subplots(1,2, sharey=True, sharex=True, figsize=(12,5),)
plot_data(ax0,X_train,y_train[:,0],'учебные')    
plot_data(ax1,X_test,y_test[:,0],'тестовые')    
plt.show()

# %% [markdown]
# ## модель

# %% [markdown]
# схема нейрона
#
# ![image.png](attachment:image.png)

# %% [markdown]
# схема MPL
#
# ![image.png](attachment:image.png)

# %%
import tensorflow as tf
from tensorflow.keras import Model 
from tensorflow.keras.layers import Dense 

class MLP(Model):
    def __init__(self,input_size,output_size):
        super().__init__()
        self.dense0 = Dense(units=input_size) # нулевой - распределительный/входной слой
        self.dense1 = Dense(units=10) # первый - обрабатывающий/скрытый слой
        self.dense2 = Dense(units=5) # второй - обрабатывающий/скрытый слой
        self.dense3 = Dense(units=output_size) # третий - обрабатывающий/выходной слой

    def call(self, x): 
        o = self.dense0(x)
        
        o = self.dense1(o) 
        o = tf.nn.sigmoid(o)
        
        o = self.dense2(o) 
        o = tf.nn.sigmoid(o)
        
        o = self.dense3(o)
        o = tf.nn.sigmoid(o)
        return o

# %%
model = MLP( input_size=X_train.shape[1], output_size=y_train.shape[1], )
# model.predict(X_train)

# %% [markdown]
# ## обучаем модель

# %% [markdown]
# функция потери средняя квадратичная ошибка
# $$L=MSQE(y,o)=\frac{1}{m}\sum\limits_{i=0}^m(o_i-y_i)^2$$

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=.1)
loss = tf.keras.losses.MeanSquaredError()
model.compile(loss=loss, optimizer=optimizer, metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import Callback

class AccuracyCallback(Callback): 
    
    def on_epoch_end(self, epoch, logs={}): 
        min_acc=.98
        acc = logs.get('accuracy')
        if acc is not None:
            if(logs.get('accuracy') > min_acc):   
                print('\naccuracy threshold reached\n')
                self.model.stop_training = True

# %%
# %%time

result = model.fit(
    tf.cast(X_train,tf.float32),
    tf.cast(y_train,tf.float32),
    batch_size=len(y_train)//3, 
    epochs=135,
    callbacks=[AccuracyCallback()],
)
# Out:
# Epoch 1/135
# 3/3 [==============================] - 1s 2ms/step - loss: 0.2573 - accuracy: 0.4760
# Epoch 2/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2520 - accuracy: 0.5112
# Epoch 3/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2514 - accuracy: 0.4753
# Epoch 4/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2519 - accuracy: 0.4873
# Epoch 5/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2506 - accuracy: 0.4948
# Epoch 6/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2506 - accuracy: 0.4458
# Epoch 7/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2500 - accuracy: 0.5122
# Epoch 8/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2500 - accuracy: 0.5097
# Epoch 9/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2495 - accuracy: 0.5402
# Epoch 10/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2496 - accuracy: 0.5645
# Epoch 11/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2481 - accuracy: 0.5500
# Epoch 12/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2448 - accuracy: 0.5257
# Epoch 13/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2348 - accuracy: 0.6545
# Epoch 14/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2195 - accuracy: 0.6670
# Epoch 15/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2081 - accuracy: 0.6557
# Epoch 16/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1907 - accuracy: 0.6798
# Epoch 17/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1849 - accuracy: 0.7285
# Epoch 18/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1706 - accuracy: 0.8107
# Epoch 19/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1527 - accuracy: 0.8252
# Epoch 20/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1475 - accuracy: 0.8198
# Epoch 21/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1312 - accuracy: 0.8455
# Epoch 22/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1274 - accuracy: 0.8368
# Epoch 23/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1217 - accuracy: 0.8490
# Epoch 24/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1119 - accuracy: 0.8615
# Epoch 25/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1086 - accuracy: 0.8605
# Epoch 26/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1120 - accuracy: 0.8505
# Epoch 27/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1135 - accuracy: 0.8408
# Epoch 28/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1129 - accuracy: 0.8557
# Epoch 29/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1136 - accuracy: 0.8490
# Epoch 30/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1099 - accuracy: 0.8573
# Epoch 31/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1163 - accuracy: 0.8453
# Epoch 32/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1061 - accuracy: 0.8638
# Epoch 33/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1160 - accuracy: 0.8458
# Epoch 34/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1000 - accuracy: 0.8788
# Epoch 35/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1039 - accuracy: 0.8685
# Epoch 36/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1016 - accuracy: 0.8712
# Epoch 37/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1089 - accuracy: 0.8587
# Epoch 38/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1002 - accuracy: 0.8713
# Epoch 39/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1042 - accuracy: 0.8667
# Epoch 40/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1077 - accuracy: 0.8545
# Epoch 41/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1123 - accuracy: 0.8477
# Epoch 42/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1008 - accuracy: 0.8725
# Epoch 43/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1065 - accuracy: 0.8570
# Epoch 44/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1009 - accuracy: 0.8708
# Epoch 45/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1042 - accuracy: 0.8630
# Epoch 46/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1048 - accuracy: 0.8555
# Epoch 47/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1038 - accuracy: 0.8645
# Epoch 48/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1050 - accuracy: 0.8617
# Epoch 49/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1027 - accuracy: 0.8643
# Epoch 50/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1076 - accuracy: 0.8598
# Epoch 51/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1017 - accuracy: 0.8655
# Epoch 52/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0980 - accuracy: 0.8715
# Epoch 53/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1016 - accuracy: 0.8675
# Epoch 54/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1028 - accuracy: 0.8655
# Epoch 55/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1049 - accuracy: 0.8660
# Epoch 56/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1034 - accuracy: 0.8705
# Epoch 57/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0987 - accuracy: 0.8670
# Epoch 58/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1055 - accuracy: 0.8668
# Epoch 59/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0975 - accuracy: 0.8757
# Epoch 60/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0890 - accuracy: 0.8868
# Epoch 61/135
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0849 - accuracy: 0.8935
# Epoch 62/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0750 - accuracy: 0.9167
# Epoch 63/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0613 - accuracy: 0.9330
# Epoch 64/135
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0271 - accuracy: 0.9857
#
# accuracy threshold reached
#
# CPU times: user 1.05 s, sys: 70.9 ms, total: 1.13 s
# Wall time: 989 ms

# %%
# история изменения значений погрешности модели
plt.plot(result.history['accuracy'],label='max acc=%.3f'%(max(result.history['accuracy'])),c='r')
plt.grid()
plt.legend()

# %%
# история изменения значений ф-ции потери
plt.plot(result.history['loss'],label='min loss=%.3f'%(min(result.history['loss'])))
plt.grid()
plt.legend()

# %% [markdown]
# ## тестируем модель

# %%
s = model.predict( tf.cast(X_test,tf.float32) )[:,1]

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

fpr, tpr, thresholds = roc_curve( y_test[:,1], s )
roc_auc = auc(fpr,tpr)

plt.figure(figsize=(7,7))
plt.grid(True)
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC AUC %0.2f' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# оптимальный порого скора 
#  максимальное количество True Positive при минимальном количестве False Positive
optimal_threshold = thresholds[ np.argmax( np.abs(tpr-fpr) )  ]
optimal_threshold
# Out:
# 0.5491338

# %%
p = (s>optimal_threshold).astype(int)
y = y_test[:,1].astype(int)

# %%
fig, (ax0,ax1) = plt.subplots(1,2, sharey=True, sharex=True, figsize=(12,5),)
plot_data(ax0,X_test,y,'тестовые')    
plot_data(ax1,X_test,p,'результат')    
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y,p))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       371
#            1       0.99      0.99      0.99       379
#
#     accuracy                           0.99       750
#    macro avg       0.99      0.99      0.99       750
# weighted avg       0.99      0.99      0.99       750

# %% [markdown]
# ## карта скоров

# %%
# строим сетку и определяем значения скора классификатора во всех узлах

n=500 # количество разбиений сетки

xx,yy = np.meshgrid(
    np.linspace( X_test[:,0].min()-.1, X_test[:,0].max()+.1, n), 
    np.linspace( X_test[:,1].min()-.1, X_test[:,1].max()+.1, n)
) # узлы сетки

xy = np.vstack([xx.flatten(),yy.flatten() ]).T # разворачиваем сетку 

s = model.predict(tf.cast(xy,tf.float32))[:,1]

plt.figure(figsize=(7,7))
plt.contourf(xx, yy, (1.-s).reshape(n,n), cmap=plt.cm.RdBu)
plt.scatter( x=X_test[:,0], y=X_test[:,1], c=y_test[:,1].astype(int), alpha=.5 )
plt.grid()
