# %% [markdown]
# **извлечение признаков из текста на естественном языке**
#
# очистка текста и токенизация
#
# _Евгений Борисов <esborisov@sevsu.ru>_

# %% [markdown]
# ---

# %%
import re
# import numpy as np
# import numpy.random as rng
import pandas as pd
# from tqdm import tqdm
from tqdm.notebook import tqdm

# np.set_printoptions(precision=2) # вывод на печать чисел до 2 знака
pd.options.display.max_colwidth = 200 

tqdm.pandas()

# %% [markdown]
# ---

# %% [markdown]
# Проект Natasha. Набор качественных открытых инструментов для обработки естественного русского языка (NLP).
# https://habr.com/ru/post/516098/
#
# Corus — коллекция русскоязычных NLP-датасетов.
# https://natasha.github.io/corus/

# %% [markdown]
# ## текст

# %%
# загружаем текст
import gzip
with gzip.open('../data/dostoevsky-besy-p2.txt.gz','rt',encoding='utf-8') as f: text = f.read()     
# with gzip.open('../data/lobas-taxisty.txt.gz','rt',encoding='utf-8') as f: data = f.read()     
display(len(text))
print(text[85:1000])
# Out:
# 465595
# Прошло восемь дней. Теперь, когда уже все прошло, и я пишу хронику, мы уже знаем в чем дело; но тогда мы еще ничего не знали, и естественно, что нам представлялись странными разные вещи. По крайней мере мы со Степаном Трофимовичем в первое время заперлись и с испугом наблюдали издали. Я-то кой-куда еще выходил и по-прежнему приносил ему разные вести, без чего он и пробыть не мог.
#
# Нечего и говорить, что по городу пошли самые разнообразные слухи, то-есть насчет пощечины, обморока Лизаветы Николаевны и прочего случившегося в то воскресенье. Но удивительно нам было то: через кого это все могло так скоро и точно выйти наружу? Ни одно из присутствовавших тогда лиц не имело бы, кажется, ни нужды, ни выгоды нарушить секрет происшедшего. Прислуги тогда не было; один Лебядкин мог бы что-нибудь разболтать, не столько по злобе, потому что вышел тогда в крайнем испуге (а страх к врагу уничтожает и злобу к нему), а

# %% [markdown]
# ## простой токенайзер

# %%
# пробел - разделитель
text.split()
# Out:
# ['БЕСЫ',
#  'Федор',
#  'Михайлович',
#  'Достоевский',
#  'ЧАСТЬ',
#  'ВТОРАЯ',
#  'ГЛАВА',
#  'ПЕРВАЯ',
#  'Ночь',
#  'I',
#  'Прошло',
#  'восемь',
#  'дней.',
#  'Теперь,',
#  'когда',
#  'уже',
#  'все',
#  'прошло,',
#  'и',
#  'я',
#  'пишу',
#  'хронику,',
#  'мы',
#  'уже',
#  'знаем',
#  'в',
#  'чем',
#  'дело;',
#  'но',
#  'тогда',
#  'мы',
#  'еще',
#  'ничего',
#  'не',
#  'знали,',
#  'и',
#  'естественно,',
#  'что',
#  'нам',
#  'представлялись',
#  'странными',
#  'разные',
#  'вещи.',
#  'По',
#  'крайней',
#  'мере',
#  'мы',
#  'со',
#  'Степаном',
#  'Трофимовичем',
#  'в',
#  'первое',
#  'время',
#  'заперлись',
#  'и',
#  'с',
#  'испугом',
#  'наблюдали',
#  'издали.',
#  'Я-то',
#  'кой-куда',
#  'еще',
#  'выходил',
#  'и',
#  'по-прежнему',
#  'приносил',
#  'ему',
#  'разные',
#  'вести,',
#  'без',
#  'чего',
#  'он',
#  'и',
#  'пробыть',
#  'не',
#  'мог.',
#  'Нечего',
#  'и',
#  'говорить,',
#  'что',
#  'по',
#  'городу',
#  'пошли',
#  'самые',
#  'разнообразные',
#  'слухи,',
#  'то-есть',
#  'насчет',
#  'пощечины,',
#  'обморока',
#  'Лизаветы',
#  'Николаевны',
#  'и',
#  'прочего',
#  'случившегося',
#  'в',
#  'то',
#  'воскресенье.',
#  'Но',
#  'удивительно',
#  'нам',
#  'было',
#  'то:',
#  'через',
#  'кого',
#  'это',
#  'все',
#  'могло',
#  'так',
#  'скоро',
#  'и',
#  'точно',
#  'выйти',
#  'наружу?',
#  'Ни',
#  'одно',
#  'из',
#  'присутствовавших',
#  'тогда',
#  'лиц',
#  'не',
#  'имело',
#  'бы,',
#  'кажется,',
#  'ни',
#  'нужды,',
#  'ни',
#  'выгоды',
#  'нарушить',
#  'секрет',
#  'происшедшего.',
#  'Прислуги',
#  'тогда',
#  'не',
#  'было;',
#  'один',
#  'Лебядкин',
#  'мог',
#  'бы',
#  'что-нибудь',
#  'разболтать,',
#  'не',
#  'столько',
#  'по',
#  'злобе,',
#  'потому',
#  'что',
#  'вышел',
#  'тогда',
#  'в',
#  'крайнем',
#  'испуге',
#  '(а',
#  'страх',
#  'к',
#  'врагу',
#  'уничтожает',
#  'и',
#  'злобу',
#  'к',
#  'нему),',
#  'а',
#  'единственно',
#  'по',
#  'невоздержности.',
#  'Но',
#  'Лебядкин,',
#  'вместе',
#  'с',
#  'сестрицей,',
#  'на',
#  'другой',
#  'же',
#  'день',
#  'пропал',
#  'без',
#  'вести;',
#  'в',
#  'доме',
#  'Филиппова',
#  'его',
#  'не',
#  'оказалось,',
#  'он',
#  'переехал',
#  'неизвестно',
#  'куда',
#  'и',
#  'точно',
#  'сгинул.',
#  'Шатов,',
#  'у',
#  'которого',
#  'я',
#  'хотел',
#  'было',
#  'справиться',
#  'о',
#  'Марье',
#  'Тимофеевне,',
#  'заперся',
#  'и,',
#  'кажется,',
#  'все',
#  'эти',
#  'восемь',
#  'дней',
#  'просидел',
#  'у',
#  'себя',
#  'на',
#  'квартире,',
#  'даже',
#  'прервав',
#  'свои',
#  'занятия',
#  'в',
#  'городе.',
#  'Меня',
#  'он',
#  'не',
#  'принял.',
#  'Я',
#  'было',
#  'зашел',
#  'к',
#  'нему',
#  'во',
#  'вторник',
#  'и',
#  'стукнул',
#  'в',
#  'дверь.',
#  'Ответа',
#  'не',
#  'получил,',
#  'но',
#  'уверенный,',
#  'по',
#  'несомненным',
#  'данным,',
#  'что',
#  'он',
#  'дома,',
#  'постучался',
#  'в',
#  'другой',
#  'раз.',
#  'Тогда',
#  'он,',
#  'соскочив',
#  'по-видимому',
#  'с',
#  'постели,',
#  'подошел',
#  'крупными',
#  'шагами',
#  'к',
#  'дверям',
#  'и',
#  'крикнул',
#  'мне',
#  'во',
#  'весь',
#  'голос:',
#  '"Шатова',
#  'дома',
#  'нет".',
#  'Я',
#  'с',
#  'тем',
#  'и',
#  'ушел.',
#  'Мы',
#  'со',
#  'Степаном',
#  'Трофимовичем,',
#  'не',
#  'без',
#  'страха',
#  'за',
#  'смелость',
#  'предположения,',
#  'но',
#  'обоюдно',
#  'ободряя',
#  'друг',
#  'друга,',
#  'остановились',
#  'наконец',
#  'на',
#  'одной',
#  'мысли:',
#  'мы',
#  'решили,',
#  'что',
#  'виновником',
#  'разошедшихся',
#  'слухов',
#  'мог',
#  'быть',
#  'один',
#  'только',
#  'Петр',
#  'Степанович,',
#  'хотя',
#  'сам',
#  'он',
#  'некоторое',
#  'время',
#  'спустя,',
#  'в',
#  'разговоре',
#  'с',
#  'отцом,',
#  'уверял,',
#  'что',
#  'застал',
#  'уже',
#  'историю',
#  'во',
#  'всех',
#  'устах,',
#  'преимущественно',
#  'в',
#  'клубе,',
#  'и',
#  'совершенно',
#  'известною',
#  'до',
#  'мельчайших',
#  'подробностей',
#  'губернаторше',
#  'и',
#  'ее',
#  'супругу.',
#  'Вот',
#  'что',
#  'еще',
#  'замечательно:',
#  'на',
#  'второй',
#  'же',
#  'день,',
#  'в',
#  'понедельник',
#  'ввечеру,',
#  'я',
#  'встретил',
#  'Липутина,',
#  'и',
#  'он',
#  'уже',
#  'знал',
#  'все',
#  'до',
#  'последнего',
#  'слова,',
#  'стало',
#  'быть,',
#  'несомненно',
#  'узнал',
#  'из',
#  'первых.',
#  'Многие',
#  'из',
#  'дам',
#  '(и',
#  'из',
#  'самых',
#  'светских)',
#  'любопытствовали',
#  'и',
#  'о',
#  '"загадочной',
#  'хромоножке",',
#  'так',
#  'называли',
#  'Марью',
#  'Тимофеевну.',
#  'Нашлись',
#  'даже',
#  'пожелавшие',
#  'непременно',
#  'увидать',
#  'ее',
#  'лично',
#  'и',
#  'познакомиться,',
#  'так',
#  'что',
#  'господа,',
#  'поспешившие',
#  'припрятать',
#  'Лебядкиных,',
#  'очевидно',
#  'поступили',
#  'и',
#  'кстати.',
#  'Но',
#  'на',
#  'первом',
#  'плане',
#  'все-таки',
#  'стоял',
#  'обморок',
#  'Лизаветы',
#  'Николаевны,',
#  'и',
#  'этим',
#  'интересовался',
#  '"весь',
#  'свет",',
#  'уже',
#  'по',
#  'тому',
#  'одному,',
#  'что',
#  'дело',
#  'прямо',
#  'касалось',
#  'Юлии',
#  'Михайловны',
#  'как',
#  'родственницы',
#  'Лизаветы',
#  'Николаевны',
#  'и',
#  'ее',
#  'покровительницы.',
#  'И',
#  'чего-чего',
#  'ни',
#  'болтали!',
#  'Болтовне',
#  'способствовала',
#  'и',
#  'таинственность',
#  'обстановки:',
#  'оба',
#  'дома,',
#  'были',
#  'заперты',
#  'наглухо;',
#  'Лизавета',
#  'Николаевна,',
#  'как',
#  'рассказывали,',
#  'лежала',
#  'в',
#  'белой',
#  'горячке;',
#  'то',
#  'же',
#  'утверждали',
#  'и',
#  'о',
#  'Николае',
#  'Всеволодовиче,',
#  'с',
#  'отвратительными',
#  'подробностями',
#  'о',
#  'выбитом',
#  'будто',
#  'бы',
#  'зубе',
#  'и',
#  'о',
#  'распухшей',
#  'от',
#  'флюса',
#  'щеке',
#  'его.',
#  'Говорили',
#  'даже',
#  'по',
#  'уголкам,',
#  'что',
#  'у',
#  'нас',
#  'может',
#  'быть',
#  'будет',
#  'убийство,',
#  'что',
#  'Ставрогин',
#  'не',
#  'таков,',
#  'чтобы',
#  'снести',
#  'такую',
#  'обиду,',
#  'и',
#  'убьет',
#  'Шатова,',
#  'но',
#  'таинственно,',
#  'как',
#  'в',
#  'корсиканской',
#  'вендетте.',
#  'Мысль',
#  'эта',
#  'нравилась;',
#  'но',
#  'большинство',
#  'нашей',
#  'светской',
#  'молодежи',
#  'выслушивало',
#  'все',
#  'это',
#  'с',
#  'презрением',
#  'и',
#  'с',
#  'видом',
#  'самого',
#  'пренебрежительного',
#  'равнодушия,',
#  'разумеется,',
#  'напускного.',
#  'Вообще',
#  'древняя',
#  'враждебность',
#  'нашего',
#  'общества',
#  'к',
#  'Николаю',
#  'Всеволодовичу',
#  'обозначилась',
#  'ярко.',
#  'Даже',
#  'солидные',
#  'люди',
#  'стремились',
#  'обвинить',
#  'его,',
#  'хотя',
#  'и',
#  'сами',
#  'не',
#  'знали',
#  'в',
#  'чем.',
#  'Шепотом',
#  'рассказывали,',
#  'что',
#  'будто',
#  'бы',
#  'он',
#  'погубил',
#  'честь',
#  'Лизаветы',
#  'Николаевны,',
#  'и',
#  'что',
#  'между',
#  'ними',
#  'была',
#  'интрига',
#  'в',
#  'Швейцарии.',
#  'Конечно',
#  'осторожные',
#  'люди',
#  'сдерживались,',
#  'но',
#  'все',
#  'однако',
#  'же',
#  'слушали',
#  'с',
#  'аппетитом.',
#  'Были',
#  'и',
#  'другие',
#  'разговоры,',
#  'но',
#  'не',
#  'общие,',
#  'а',
#  'частные,',
#  'редкие',
#  'и',
#  'почти',
#  'закрытые,',
#  'чрезвычайно',
#  'странные',
#  'и',
#  'о',
#  'существовании',
#  'которых',
#  'я',
#  'упоминаю',
#  'лишь',
#  'для',
#  'предупреждения',
#  'читателей,',
#  'единственно',
#  'в',
#  'виду',
#  'дальнейших',
#  'событий',
#  'моего',
#  'рассказа.',
#  'Именно:',
#  'говорили',
#  'иные,',
#  'хмуря',
#  'брови',
#  'и',
#  'бог',
#  'знает',
#  'на',
#  'каком',
#  'основании,',
#  'что',
#  'Николай',
#  'Всеволодович',
#  'имеет',
#  'какое-то',
#  'особенное',
#  'дело',
#  'в',
#  'нашей',
#  'губернии,',
#  'что',
#  'он',
#  'чрез',
#  'графа',
#  'К.',
#  'вошел',
#  'в',
#  'Петербурге',
#  'в',
#  'какие-то',
#  'высшие',
#  'отношения,',
#  'что',
#  'он',
#  'даже,',
#  'может',
#  'быть,',
#  'служит',
#  'и',
#  'чуть',
#  'ли',
#  'не',
#  'снабжен',
#  'от',
#  'кого-то',
#  'какими-то',
#  'поручениями.',
#  'Когда',
#  'очень',
#  'уж',
#  'солидные',
#  'и',
#  'сдержанные',
#  'люди',
#  'на',
#  'этот',
#  'слух',
#  'улыбались,',
#  'благоразумно',
#  'замечая,',
#  'что',
#  'человек,',
#  'живущий',
#  'скандалами',
#  'и',
#  'начинающий',
#  'у',
#  'нас',
#  'с',
#  'флюса,',
#  'не',
#  'похож',
#  'на',
#  'чиновника,',
#  'то',
#  'им',
#  'шепотом',
#  'замечали,',
#  'что',
#  'служит',
#  'он',
#  'не',
#  'то',
#  'чтоб',
#  'оффициально,',
#  'а',
#  'так',
#  'сказать',
#  'конфиденциально,',
#  'и',
#  'что',
#  'в',
#  'таком',
#  'случае',
#  'самою',
#  'службой',
#  'требуется,',
#  'чтобы',
#  'служащий',
#  'как',
#  'можно',
#  'менее',
#  'походил',
#  'на',
#  'чиновника.',
#  'Такое',
#  'замечание',
#  'производило',
#  'эффект;',
#  'у',
#  'нас',
#  'известно',
#  'было,',
#  'что',
#  'на',
#  'земство',
#  'нашей',
#  'губернии',
#  'смотрят',
#  'в',
#  'столице',
#  'с',
#  'некоторым',
#  'особым',
#  'вниманием.',
#  'Повторю,',
#  'эти',
#  'слухи',
#  'только',
#  'мелькнули',
#  'и',
#  'исчезли',
#  'бесследно,',
#  'до',
#  'времени,',
#  'при',
#  'первом',
#  'появлении',
#  'Николая',
#  'Всеволодовича;',
#  'но',
#  'замечу,',
#  'что',
#  'причиной',
#  'многих',
#  'слухов',
#  'было',
#  'отчасти',
#  'несколько',
#  'кратких,',
#  'но',
#  'злобных',
#  'слов,',
#  'неясно',
#  'и',
#  'отрывисто',
#  'произнесенных',
#  'в',
#  'клубе',
#  'недавно',
#  'возвратившимся',
#  'из',
#  'Петербурга',
#  'отставным',
#  'капитаном',
#  'гвардии',
#  'Артемием',
#  'Павловичем',
#  'Гагановым,',
#  'весьма',
#  'крупным',
#  'помещиком',
#  'нашей',
#  'губернии',
#  'и',
#  'уезда,',
#  'столичным',
#  'светским',
#  'человеком',
#  'и',
#  'сыном',
#  'покойного',
#  'Павла',
#  'Павловича',
#  'Гаганова,',
#  'того',
#  'самого',
#  'почтенного',
#  'старшины,',
#  'с',
#  'которым',
#  'Николай',
#  'Всеволодович',
#  'имел,',
#  'четыре',
#  'слишком',
#  'года',
#  'тому',
#  'назад,',
#  'то',
#  'необычайное',
#  'по',
#  'своей',
#  'грубости',
#  'и',
#  'внезапности',
#  'столкновение,',
#  'о',
#  'котором',
#  'я',
#  'уже',
#  'упоминал',
#  'прежде,',
#  'в',
#  'начале',
#  'моего',
#  'рассказа.',
#  'Всем',
#  'тотчас',
#  'же',
#  'стало',
#  'известно,',
#  'что',
#  'Юлия',
#  'Михайловна',
#  'сделала',
#  'Варваре',
#  'Петровне',
#  'чрезвычайный',
#  'визит,',
#  'и',
#  'что',
#  'у',
#  'крыльца',
#  'дома',
#  'ей',
#  'объявили,',
#  'что',
#  '"по',
#  'нездоровью',
#  'не',
#  'могут',
#  'принять".',
#  'Также',
#  'и',
#  'то,',
#  'что',
#  'дня',
#  'через',
#  'два',
#  'после',
#  'своего',
#  'визита',
#  'Юлия',
#  'Михайловна',
#  'посылала',
#  'узнать',
#  'о',
#  'здоровье',
#  'Варвары',
#  'Петровны',
#  'нарочного.',
#  'Наконец',
#  'принялась',
#  'везде',
#  '"защищать"',
#  'Варвару',
#  'Петровну,',
#  'конечно',
#  'лишь',
#  'в',
#  'самом',
#  'высшем',
#  'смысле,',
#  'то',
#  '"есть',
#  'по',
#  'возможности',
#  'в',
#  'самом',
#  'неопределенном.',
#  'Все',
#  'же',
#  'первоначальные',
#  'торопливые',
#  'намеки',
#  'о',
#  'воскресной',
#  'истории',
#  'выслушала',
#  'строго',
#  'и',
#  'холодно,',
#  'так',
#  'что',
#  'в',
#  'последующие',
#  'дни,',
#  'в',
#  'ее',
#  'присутствии,',
#  'они',
#  'уже',
#  'не',
#  'возобновлялись.',
#  'Таким',
#  'образом',
#  'и',
#  'укрепилась',
#  'везде',
#  'мысль,',
#  'что',
#  'Юлии',
#  'Михайловне',
#  'известна',
#  'не',
#  'только',
#  'вся',
#  'эта',
#  'таинственная',
#  'история,',
#  'но',
#  'и',
#  'весь',
#  'ее',
#  'таинственный',
#  'смысл',
#  'до',
#  'мельчайших',
#  'подробностей,',
#  'и',
#  'не',
#  'как',
#  'посторонней,',
#  'а',
#  'как',
#  'соучастнице.',
#  'Замечу',
#  'кстати,',
#  'что',
#  'она',
#  'начала',
#  'уже',
#  'приобретать',
#  'у',
#  'нас,',
#  'помаленьку,',
#  'то',
#  'высшее',
#  'влияние,',
#  'которого',
#  'так',
#  'несомненно',
#  'добивалась',
#  'и',
#  'жаждала,',
#  'и',
#  'уже',
#  'начинала',
#  'видеть',
#  'себя',
#  '"окруженною".',
#  'Часть',
#  'общества',
#  'признала',
#  'за',
#  'нею',
#  'практический',
#  'ум',
#  'и',
#  'такт...',
#  'но',
#  'об',
#  'этом',
#  'после.',
#  'Ее',
#  'же',
#  'покровительством',
#  'объяснялись',
#  'отчасти',
#  'и',
#  'весьма',
#  'быстрые',
#  'успехи',
#  'Петра',
#  'Степановича',
#  'в',
#  'нашем',
#  'обществе,',
#  '-',
#  'успехи,',
#  'особенно',
#  ...]

# %% [markdown]
# __*такой метод режет строку только на слова, предложения не разделяет*__

# %%
# собираем словарь
words = sorted( set( text.split()) )
display(len(words))
words
# Out:
# 22386
# ['"Bonjour",',
#  '"Fils,',
#  '"Merci"',
#  '"Merci".',
#  '"Qu\'un',
#  '"Tout',
#  '"cette',
#  '"qu\'un',
#  '"В',
#  '"Ваше',
#  '"Вашего',
#  '"Ведь',
#  '"Вот,',
#  '"Вы',
#  '"Господи!"',
#  '"Да',
#  '"Днем',
#  '"Думы"',
#  '"Если',
#  '"Еще',
#  '"Еще,',
#  '"Знаете',
#  '"Знай,',
#  '"Ибо',
#  '"Искание',
#  '"Как-нибудь',
#  '"Лембка",',
#  '"Лембку"',
#  '"Лембку",',
#  '"Лембку".',
#  '"Либерал',
#  '"Милостивые',
#  '"Мы',
#  '"Мысль',
#  '"Мя,',
#  '"На',
#  '"Наплевать',
#  '"Нашего"',
#  '"Не',
#  '"Несчастные"',
#  '"Нет,',
#  '"Неужели',
#  '"Но...',
#  '"Нож,',
#  '"Ночью',
#  '"Ну',
#  '"Ну,',
#  '"Нужно',
#  '"Однако',
#  '"По',
#  '"Полон',
#  '"Поскорей,',
#  '"Правда,',
#  '"Припадает',
#  '"Пугает',
#  '"С',
#  '"Светлую',
#  '"Соловья',
#  '"Сто',
#  '"Такой',
#  '"Ты,',
#  '"Угрюмые',
#  '"Успеешь,',
#  '"Франко-прусская',
#  '"Хитрый"',
#  '"Чти',
#  '"Что',
#  '"Шатова',
#  '"Шигалевщина",',
#  '"Шпигулинские!"',
#  '"Шпигулинские".',
#  '"Экой',
#  '"Это',
#  '"Этот',
#  '"Я',
#  '"а',
#  '"а,',
#  '"атеист',
#  '"бездарности";',
#  '"беспардонный',
#  '"бесчисленными',
#  '"благородным"',
#  '"богоносец"',
#  '"богоносец",',
#  '"бунта",',
#  '"бунтовщиков"',
#  '"бунтовщиков",',
#  '"в',
#  '"вам,',
#  '"ваша',
#  '"ваше',
#  '"вдруг"',
#  '"весь',
#  '"взглянуть"',
#  '"видели,',
#  '"видите,',
#  '"визжавшими"',
#  '"водят',
#  '"возбуждавший"',
#  '"вольнее".',
#  '"все',
#  '"все,',
#  '"всем',
#  '"всякую',
#  '"вы',
#  '"выбрал"',
#  '"выпелась"',
#  '"высшей',
#  '"высшем"',
#  '"высшим',
#  '"гораздо',
#  '"двести',
#  '"дескать',
#  '"дешевкой".',
#  '"до',
#  '"домогаться"',
#  '"достойным',
#  '"дружеской"',
#  '"есть',
#  '"за',
#  '"загадочной',
#  '"запирайте',
#  '"заседание',
#  '"заседание",',
#  '"заседания".',
#  '"защищать"',
#  '"здоровый',
#  '"знаешь',
#  '"и',
#  '"изречете"',
#  '"иначе',
#  '"кавалькады",',
#  '"кадет",',
#  '"как',
#  '"какой-нибудь',
#  '"кару"',
#  '"катехизису"',
#  '"кибитки";',
#  '"кибитку"',
#  '"кстати',
#  '"кучка"',
#  '"лаской"',
#  '"любит',
#  '"машут',
#  '"миленький"',
#  '"молодого',
#  '"молодым',
#  '"мя"',
#  '"мя,',
#  '"на',
#  '"над',
#  '"надменно".',
#  '"нашим"!',
#  '"наших"?',
#  '"не',
#  '"нежа',
#  '"несомненным',
#  '"несчастных"',
#  '"нет,',
#  '"нечему',
#  '"ни',
#  '"никак',
#  '"новая',
#  '"нового',
#  '"новом',
#  '"новый',
#  '"нож,',
#  '"ну',
#  '"ну,',
#  '"один',
#  '"ожидают-с",',
#  '"окруженною".',
#  '"он',
#  '"они',
#  '"описали"',
#  '"описали".',
#  '"отвез',
#  '"отказались',
#  '"открываться",',
#  '"отрапортовали".',
#  '"очень',
#  '"очистить',
#  '"переменить",',
#  '"перешло',
#  '"по',
#  '"подвержен".',
#  '"поднять',
#  '"пора",',
#  '"после',
#  '"потому',
#  '"потребовать',
#  '"почти',
#  '"пошли',
#  '"права',
#  '"правом',
#  '"презирать".',
#  '"принять',
#  '"прокутил"',
#  '"простых",',
#  '"простят"!',
#  '"пятерку"',
#  '"пятерку",',
#  '"равенство"!',
#  '"равно',
#  '"раскаявшийся',
#  '"расстроен",',
#  '"реки',
#  '"с',
#  '"самим',
#  '"самому',
#  '"самый',
#  '"свеженькой',
#  '"светлая',
#  '"свой',
#  '"своя',
#  '"священное"',
#  '"сдавив',
#  '"скрывается",',
#  '"скрывается".',
#  '"скрывающийся".',
#  '"слишком',
#  '"со',
#  '"собственными"',
#  '"совершенных',
#  '"сообщениями"',
#  '"соперников",',
#  '"студент"',
#  '"студент",',
#  '"стук',
#  '"третья,',
#  '"три',
#  '"увлекся',
#  '"умнейшего',
#  '"фамильном',
#  '"франтящею"',
#  '"хитрил",',
#  '"хозяин',
#  '"хорош',
#  '"хотя',
#  '"человек',
#  '"человека',
#  '"что',
#  '"чтобы',
#  '"чувствуя',
#  '"чужих',
#  '"шпигулинская',
#  '"шутку"',
#  '"этот',
#  '"эх,',
#  '(К',
#  '(Николай',
#  '(Он',
#  '(Подбородок',
#  '(Послышался',
#  '(Смех',
#  '(а',
#  '(а,',
#  '(в',
#  '(видите,',
#  '(впрочем',
#  '(выражение',
#  '(грубейшею',
#  '(да,',
#  '(даже',
#  '(для',
#  '(замечу,',
#  '(и',
#  '(из',
#  '(именно',
#  '(иногда',
#  '(как',
#  '(которого',
#  '(которую',
#  '(милый',
#  '(несмотря',
#  '(но',
#  '(ну',
#  '(он',
#  '(она',
#  '(опять',
#  '(очевидно',
#  '(по',
#  '(понизил',
#  '(почти',
#  '(природой)',
#  '(продолжение)',
#  '(своими',
#  '(славы',
#  '(так',
#  '(то-есть',
#  '(у',
#  '(участвовавший',
#  '(чорт',
#  '(это',
#  '(я',
#  '-',
#  '...',
#  '...Должна',
#  '187...',
#  '19-го',
#  'Adieu,',
#  'Adieu.',
#  'Alea',
#  'Allons!',
#  'Augustin',
#  'Augustin,',
#  'Augustin.',
#  'Augustin:',
#  'Avis',
#  'Ax,',
#  "C'est",
#  "C'йtait",
#  'Candide.',
#  'Cela',
#  'Cette',
#  'Cher',
#  'Cher,',
#  'Chere',
#  'Chere,',
#  'Cozak',
#  'Don',
#  'Don,',
#  'Elle',
#  'Eloignez-la',
#  'Enfin',
#  'Enfin,',
#  'Et',
#  'Excellent',
#  'Fantichambre,',
#  'Fautre',
#  'He',
#  'I',
#  'II',
#  'III',
#  'IV',
#  'Il',
#  'Ils',
#  'Incognito".',
#  'Internationale',
#  'Internationale,',
#  'Internationale;',
#  "J'ai",
#  "J'йtais",
#  'Je',
#  'Karmazinoff,',
#  'Lembke.',
#  'Littre,',
#  'Maman',
#  'Mein',
#  'Merci',
#  'Merci.',
#  'Nicolas',
#  'Nicolas,',
#  'Oui,',
#  'Pardon,',
#  'Pas',
#  'Passons,',
#  'Passons.',
#  'Passons?',
#  'Pйtersbourg,',
#  "Qu'en",
#  'Quelque',
#  'Rosenthal.',
#  'Savez',
#  'Savez-vous,',
#  'Se',
#  'Tant',
#  'Teliatnikoff,',
#  'To-есть',
#  'Tous',
#  'V',
#  'VI',
#  'VII',
#  'Voilа',
#  'Voltaire,',
#  'Votre',
#  'Vous',
#  'Voyez-vous,',
#  'Voyez-vous:',
#  'a',
#  'abreuve',
#  'activitй',
#  'ami!',
#  'ami,',
#  'ami.',
#  'amie"',
#  'amis,',
#  'amis...',
#  'annйe',
#  'ans',
#  'arrкter,',
#  'au',
#  "aujourd'hui,",
#  'autour',
#  'avait',
#  'avec',
#  'bas',
#  'battre',
#  'beaucoup,',
#  'belle',
#  'belles',
#  'bien',
#  'bienfaisant...',
#  'bon',
#  'boudoir.',
#  'bourru',
#  'brisons-lа,',
#  'bruit',
#  'bкte',
#  'bкtise',
#  'bкtises,',
#  "c'est",
#  'cacha',
#  'calme',
#  'calme!',
#  'calme.',
#  'carriиre',
#  'ce',
#  'cela',
#  'cela,',
#  'ces',
#  'cette',
#  'chambre',
#  'chaque',
#  'charmant,',
#  'charmante',
#  'cher',
#  'cher,',
#  'cher...',
#  'chere,',
#  'chez',
#  'chose',
#  'choses!',
#  'choses-lа',
#  'choses;',
#  'chиre',
#  'chйri"',
#  'cochon',
#  'comme',
#  'commencerai',
#  'comment',
#  'comparaison',
#  'comprenez',
#  'comprenez?',
#  'compris.',
#  'connais.',
#  'connaissez?',
#  'consenti...',
#  'content',
#  'content.',
#  'convertir.',
#  'cozak',
#  'critiques',
#  'croire',
#  'croyez',
#  'croyez-vous?',
#  'cа',
#  "d'allemand",
#  "d'aveugle",
#  "d'hйbйtй",
#  'dans',
#  'date',
#  'de',
#  'dedans',
#  'des',
#  'deux',
#  'digne',
#  'digne,',
#  'dira-t-elle,',
#  'distance',
#  'dit',
#  'doit',
#  'drapeau',
#  'du',
#  'dйvorante',
#  'dйvorante,',
#  'dйvorante.',
#  'e',
#  'elle',
#  'employй',
#  'en',
#  'encore',
#  'enfin',
#  'ennemis...',
#  'entendra',
#  'esclandre.',
#  'esprits-forts',
#  'est',
#  'est!',
#  'est.',
#  'et',
#  'fair',
#  'faire',
#  'faites',
#  'faut',
#  'faзon',
#  'femmes...',
#  'ferai',
#  'figure,',
#  'fils',
#  'finie',
#  'finie.',
#  'fois',
#  'forteresses!',
#  'genre.',
#  'gens',
#  'gens-lа!',
#  'guenille,',
#  'hauteur',
#  'heure',
#  'historiques,',
#  'homme,',
#  'i.',
#  'il',
#  'immйdiatement',
#  'impuissance.',
#  'impur',
#  'impur...",',
#  'index,',
#  'invraisemblable...',
#  "j'ai",
#  'jacta',
#  'je',
#  'jure',
#  "l'assure.",
#  'la',
#  'le',
#  'lecteur!',
#  'lecteur.',
#  'les',
#  'lieber',
#  'louche.',
#  'lui',
#  'lа',
#  'lа-bas',
#  'lвchetй!',
#  "m'a",
#  "m'embкte.",
#  "m'en",
#  "m'y",
#  'm-me',
#  'm-r',
#  'ma',
#  'mais',
#  'manquй',
#  'me',
#  'meilleur',
#  'mes',
#  'mettez',
#  'mieux',
#  'mieux.',
#  'minimum',
#  'moi,',
#  'moines',
#  'moines,',
#  'moment...',
#  'mon',
#  'mondes',
#  'mot!',
#  'mot.',
#  "n'ai",
#  "n'est",
#  'ne',
#  'nom',
#  'nom,',
#  'nom.',
#  'nom...',
#  'non',
#  'nos',
#  'notre',
#  'on',
#  'oubliй',
#  'oubliй.',
#  'oui,',
#  'paraisse!',
#  'paresseux!',
#  'paresseux,',
#  'parlait,',
#  'parlait...',
#  'partout',
#  'pas',
#  'pas.',
#  'passant.',
#  'pauvre',
#  'pays,',
#  'permise.',
#  'petit',
#  'peut',
#  'physionomie.',
#  'pierre',
#  'plaisir',
#  'plus',
#  'plus,',
#  'plвtre.',
#  'politesse',
#  'politiques.',
#  'possibles".',
#  'pouce',
#  'pour',
#  'pourtant',
#  'procureur,',
#  'prononcй',
#  'propre',
#  'protegйe',
#  'prйpare.',
#  'prкt,',
#  'puis',
#  'puis,',
#  'puis...',
#  "qu'il",
#  "qu'on",
#  'quand',
#  'que',
#  'quelque',
#  'quelques',
#  'qui',
#  'quinze',
#  'quoi',
#  'raison,',
#  'rien',
#  'rit',
#  'rit.',
#  'roide',
#  'rossй',
#  'roubles',
#  "s'appelle",
#  'sa',
#  'sacrй...',
#  'sang',
#  'sans',
#  'sautait',
#  'savez-vous;',
#  'se',
#  'sens.',
#  'sent',
#  'serai',
#  'seul,',
#  'sillons!"',
#  'simplement',
#  'soit',
#  'son',
#  'sonnйe.',
#  'sont',
#  'soupзonnera',
#  'souviens,',
#  'suis',
#  'sur',
#  'surexcitй,',
#  'sйrieux.',
#  'sйvиre,',
#  'tas',
#  'tenait',
#  'terrain,',
#  'tombe.',
#  'tomberai',
#  'toujours.',
#  'tout',
#  'tout-а-fait',
#  'toute',
#  'trop',
#  'trop.',
#  'trouve',
#  'trиs',
#  'un',
#  'une',
#  'unes',
#  'vero.',
#  'vie...',
#  'vient',
#  'vingt',
#  'voulais',
#  'vous',
#  'vous,',
#  'vous.',
#  'voyez',
#  'voyez-vous,',
#  'voyez-vous...',
#  'xe-xe!',
#  'А',
#  'А!',
#  'А,',
#  'А-а!',
#  'А-а,',
#  'А-а-а!',
#  'А?',
#  'Авдотье',
#  'Агафья',
#  'Агентом',
#  'Адвокат,',
#  'Администраторы,',
#  'Акмолинский',
#  'Александрович,',
#  'Александровском',
#  'Алексей',
#  'Алексея',
#  'Алексея.',
#  'Алеша',
#  'Али',
#  'Амалией,',
#  'Амалию',
#  'Америка?',
#  'Америке',
#  'Америки',
#  'Америки.',
#  'Америки;',
#  'Америки?',
#  'Америку',
#  'Америку.',
#  'Америку...',
#  'Ан',
#  'Англии',
#  'Андреем',
#  'Андрей',
#  'Андрею',
#  'Андрея',
#  'Аничкова',
#  'Антонович',
#  'Антонович!',
#  'Антонович,',
#  'Антонович;',
#  'Антоновича',
#  'Антоновича,',
#  'Антоновича.',
#  'Антоновичем',
#  'Антоновичем!',
#  'Антоновичем,',
#  'Антоновичем.',
#  'Антоновичу',
#  'Антоновичу,',
#  'Антоновичу.',
#  'Антроповна,',
#  'Апокалипсис',
#  'Апокалипсис.',
#  'Апокалипсисе',
#  'Арина',
#  'Арине',
#  'Арины',
#  'Аристократ,',
#  'Артемием',
#  'Артемий',
#  'Артемия',
#  'Архангельск,',
#  'Ах',
#  'Ах,',
#  'Б-цах',
#  'БЕСЫ',
#  'Ба!',
#  'Ба,',
#  'Базаров',
#  'Байрон!..',
#  'Байроном,',
#  'Бальзака,',
#  'Барьер',
#  'Басни!',
#  'Батюшка!',
#  'Беда',
#  'Бедная',
#  'Бедный',
#  'Бедный,',
#  'Бедняжка',
#  'Бедняжка,',
#  'Без',
#  'Безумных',
#  'Белинский,',
#  'Белинского',
#  'Берлина',
#  'Берлине',
#  'Берут',
#  'Бешенство',
#  'Бисмарка',
#  'Блага-а-дарен,',
#  'Благодарю',
#  'Благодарю,',
#  'Благодарю.',
#  'Благодетель!',
#  'Благослови',
#  'Бледный',
#  'Близость',
#  'Блюм',
#  'Блюм!',
#  'Блюм,',
#  'Блюм.',
#  'Блюма',
#  'Блюма,',
#  'Блюма.',
#  'Блюмера',
#  'Блюмом,',
#  'Блюму,',
#  'Бог',
#  'Бога',
#  'Богородицы,',
#  'Богородский',
#  'Богородском',
#  'Богочеловек?',
#  'Богоявленская',
#  'Богоявленской',
#  'Богоявленскую',
#  'Боже',
#  'Боже!',
#  'Боже,',
#  'Боитесь?',
#  'Бойтесь',
#  'Бока',
#  'Болезненное',
#  'Болен',
#  'Болтовне',
#  'Больны',
#  'Боюсь',
#  'Боязливо',
#  'Боясь',
#  'Братство,',
#  'Бред,',
#  'Бродяга',
#  'Бросив',
#  'Брыкове,',
#  'Будет',
#  'Будто',
#  'Буду',
#  'Будьте',
#  'Бунт',
#  'Бунт?',
#  'Бунтуют',
#  'Бутылка',
#  'Бухгалтер!',
#  'Бывает',
#  'Быковой',
#  'Был',
#  'Был,',
#  'Была',
#  'Были',
#  'Было',
#  'Быстрому',
#  'Быть',
#  'Бьюсь',
#  'Бюхнера,',
#  'В',
#  'В...',
#  'ВОСЬМАЯ',
#  'ВТОРАЯ',
#  'Вавилон',
#  'Вам',
#  'Варвара',
#  'Варваре',
#  'Варварой',
#  'Варвару',
#  'Варвары',
#  'Вас',
#  'Вас?',
#  'Василий',
#  'Ваш',
#  'Ваша',
#  'Ваше',
#  'Вбежавший',
#  'Вдовицу',
#  'Вдруг',
#  'Ведь',
#  'Великий',
#  'Верен',
#  'Верите',
#  'Верно,',
#  'Вероятнее',
#  'Вероятно',
#  'Верхишиных',
#  'Верховенские,',
#  'Верховенский',
#  'Верховенский,',
#  'Верховенский.',
#  'Верховенский:',
#  'Верховенским',
#  'Верховенским,',
#  'Верховенского',
#  'Верховенского,',
#  'Верховенского.',
#  'Верховенском,',
#  'Верховенскому',
#  'Верховенскому).',
#  'Верховенскому,',
#  'Верховенскому.',
#  'Веселые',
#  'Веселым',
#  'Весь',
#  'Ветер',
#  'Ветром',
#  'Взгляд',
#  'Взгляды',
#  'Вздор',
#  'Вздор;',
#  'Взял',
#  'Взяли',
#  'Вид',
#  'Видал.',
#  'Видали',
#  'Видимо',
#  'Видимое',
#  'Видите',
#  'Видите,',
#  'Видите-с,',
#  'Видите-с.',
#  'Видите-с:',
#  'Видишь',
#  'Видно',
#  'Видно,',
#  'Вижу,',
#  'Визит',
#  'Виноват,',
#  'Виновата',
#  'Виргинская',
#  'Виргинская,',
#  'Виргинская.',
#  'Виргинские',
#  'Виргинский',
#  'Виргинский,',
#  'Виргинский.',
#  'Виргинским',
#  'Виргинского',
#  'Виргинского,',
#  'Виргинского.',
#  'Виргинской',
#  'Виргинской),',
#  'Виргинской,',
#  'Виргинской.',
#  'Виргинскому',
#  'Влюбленный',
#  'Вместе',
#  'Вникните',
#  'Во',
#  'Во-первых,',
#  'Водосточная,',
#  'Воды',
#  'Возбудил',
#  'Возвратясь',
#  'Возьмите',
#  'Возьмите,',
#  'Войдите',
#  'Волнение',
#  'Воля',
#  'Вон',
#  'Воображаю.',
#  'Вообразив',
#  'Вообразите,',
#  'Вообще',
#  'Вообще,',
#  'Вообще?',
#  'Вопрос,',
#  'Вопроса',
#  'Ворота',
#  'Воспитанники',
#  'Вот',
#  'Вот,',
#  'Вот-с',
#  'Вот-с!',
#  'Вот-с,',
#  'Вошедший',
#  'Вошел',
#  'Впечатление,',
#  'Впоследствии',
#  'Впрочем',
#  'Впрочем,',
#  'Враги,',
#  'Время',
#  'Врете',
#  'Все',
#  'Все,',
#  'Все-таки',
#  'Все.',
#  'Все?',
#  'Всеволодович',
#  'Всеволодович!',
#  'Всеволодович,',
#  'Всеволодович.',
#  'Всеволодович:',
#  'Всеволодович;',
#  'Всеволодович?',
#  'Всеволодовича',
#  'Всеволодовича),',
#  'Всеволодовича,',
#  'Всеволодовича.',
#  'Всеволодовича;',
#  'Всеволодовиче,',
#  'Всеволодовичем',
#  'Всеволодовичем.',
#  'Всеволодовичу',
#  'Всеволодовичу.',
#  'Всегда-то,',
#  'Всего',
#  'Всем',
#  'Всеобщее',
#  'Всех',
#  'Вспоминались',
#  'Вспомнили',
#  'Вспомните,',
#  'Вставайте,',
#  'Встаньте',
#  'Встреча',
#  'Вступая',
#  'Всю',
#  'Вся',
#  'Всякий',
#  'Втихомолку',
#  'Вход',
#  ...]

# %% [markdown]
# ## NLTK токенайзер

# %%
# NLTK токенайзер
from nltk.tokenize import sent_tokenize as nltk_sentence_split
from nltk.tokenize import word_tokenize as nltk_tokenize_word

text_ = [ 
    nltk_tokenize_word(s,language='russian') # разбиваем предложения на слова
    for s in nltk_sentence_split(text,language='russian') # режем текст на отдельные предложения
]

display( len(text_) )
text_
# Out:
# 5495
# [['БЕСЫ',
#   'Федор',
#   'Михайлович',
#   'Достоевский',
#   'ЧАСТЬ',
#   'ВТОРАЯ',
#   'ГЛАВА',
#   'ПЕРВАЯ',
#   'Ночь',
#   'I',
#   'Прошло',
#   'восемь',
#   'дней',
#   '.'],
#  ['Теперь',
#   ',',
#   'когда',
#   'уже',
#   'все',
#   'прошло',
#   ',',
#   'и',
#   'я',
#   'пишу',
#   'хронику',
#   ',',
#   'мы',
#   'уже',
#   'знаем',
#   'в',
#   'чем',
#   'дело',
#   ';',
#   'но',
#   'тогда',
#   'мы',
#   'еще',
#   'ничего',
#   'не',
#   'знали',
#   ',',
#   'и',
#   'естественно',
#   ',',
#   'что',
#   'нам',
#   'представлялись',
#   'странными',
#   'разные',
#   'вещи',
#   '.'],
#  ['По',
#   'крайней',
#   'мере',
#   'мы',
#   'со',
#   'Степаном',
#   'Трофимовичем',
#   'в',
#   'первое',
#   'время',
#   'заперлись',
#   'и',
#   'с',
#   'испугом',
#   'наблюдали',
#   'издали',
#   '.'],
#  ['Я-то',
#   'кой-куда',
#   'еще',
#   'выходил',
#   'и',
#   'по-прежнему',
#   'приносил',
#   'ему',
#   'разные',
#   'вести',
#   ',',
#   'без',
#   'чего',
#   'он',
#   'и',
#   'пробыть',
#   'не',
#   'мог',
#   '.'],
#  ['Нечего',
#   'и',
#   'говорить',
#   ',',
#   'что',
#   'по',
#   'городу',
#   'пошли',
#   'самые',
#   'разнообразные',
#   'слухи',
#   ',',
#   'то-есть',
#   'насчет',
#   'пощечины',
#   ',',
#   'обморока',
#   'Лизаветы',
#   'Николаевны',
#   'и',
#   'прочего',
#   'случившегося',
#   'в',
#   'то',
#   'воскресенье',
#   '.'],
#  ['Но',
#   'удивительно',
#   'нам',
#   'было',
#   'то',
#   ':',
#   'через',
#   'кого',
#   'это',
#   'все',
#   'могло',
#   'так',
#   'скоро',
#   'и',
#   'точно',
#   'выйти',
#   'наружу',
#   '?'],
#  ['Ни',
#   'одно',
#   'из',
#   'присутствовавших',
#   'тогда',
#   'лиц',
#   'не',
#   'имело',
#   'бы',
#   ',',
#   'кажется',
#   ',',
#   'ни',
#   'нужды',
#   ',',
#   'ни',
#   'выгоды',
#   'нарушить',
#   'секрет',
#   'происшедшего',
#   '.'],
#  ['Прислуги',
#   'тогда',
#   'не',
#   'было',
#   ';',
#   'один',
#   'Лебядкин',
#   'мог',
#   'бы',
#   'что-нибудь',
#   'разболтать',
#   ',',
#   'не',
#   'столько',
#   'по',
#   'злобе',
#   ',',
#   'потому',
#   'что',
#   'вышел',
#   'тогда',
#   'в',
#   'крайнем',
#   'испуге',
#   '(',
#   'а',
#   'страх',
#   'к',
#   'врагу',
#   'уничтожает',
#   'и',
#   'злобу',
#   'к',
#   'нему',
#   ')',
#   ',',
#   'а',
#   'единственно',
#   'по',
#   'невоздержности',
#   '.'],
#  ['Но',
#   'Лебядкин',
#   ',',
#   'вместе',
#   'с',
#   'сестрицей',
#   ',',
#   'на',
#   'другой',
#   'же',
#   'день',
#   'пропал',
#   'без',
#   'вести',
#   ';',
#   'в',
#   'доме',
#   'Филиппова',
#   'его',
#   'не',
#   'оказалось',
#   ',',
#   'он',
#   'переехал',
#   'неизвестно',
#   'куда',
#   'и',
#   'точно',
#   'сгинул',
#   '.'],
#  ['Шатов',
#   ',',
#   'у',
#   'которого',
#   'я',
#   'хотел',
#   'было',
#   'справиться',
#   'о',
#   'Марье',
#   'Тимофеевне',
#   ',',
#   'заперся',
#   'и',
#   ',',
#   'кажется',
#   ',',
#   'все',
#   'эти',
#   'восемь',
#   'дней',
#   'просидел',
#   'у',
#   'себя',
#   'на',
#   'квартире',
#   ',',
#   'даже',
#   'прервав',
#   'свои',
#   'занятия',
#   'в',
#   'городе',
#   '.'],
#  ['Меня', 'он', 'не', 'принял', '.'],
#  ['Я',
#   'было',
#   'зашел',
#   'к',
#   'нему',
#   'во',
#   'вторник',
#   'и',
#   'стукнул',
#   'в',
#   'дверь',
#   '.'],
#  ['Ответа',
#   'не',
#   'получил',
#   ',',
#   'но',
#   'уверенный',
#   ',',
#   'по',
#   'несомненным',
#   'данным',
#   ',',
#   'что',
#   'он',
#   'дома',
#   ',',
#   'постучался',
#   'в',
#   'другой',
#   'раз.',
#   'Тогда',
#   'он',
#   ',',
#   'соскочив',
#   'по-видимому',
#   'с',
#   'постели',
#   ',',
#   'подошел',
#   'крупными',
#   'шагами',
#   'к',
#   'дверям',
#   'и',
#   'крикнул',
#   'мне',
#   'во',
#   'весь',
#   'голос',
#   ':',
#   '``',
#   'Шатова',
#   'дома',
#   'нет',
#   "''",
#   '.'],
#  ['Я', 'с', 'тем', 'и', 'ушел', '.'],
#  ['Мы',
#   'со',
#   'Степаном',
#   'Трофимовичем',
#   ',',
#   'не',
#   'без',
#   'страха',
#   'за',
#   'смелость',
#   'предположения',
#   ',',
#   'но',
#   'обоюдно',
#   'ободряя',
#   'друг',
#   'друга',
#   ',',
#   'остановились',
#   'наконец',
#   'на',
#   'одной',
#   'мысли',
#   ':',
#   'мы',
#   'решили',
#   ',',
#   'что',
#   'виновником',
#   'разошедшихся',
#   'слухов',
#   'мог',
#   'быть',
#   'один',
#   'только',
#   'Петр',
#   'Степанович',
#   ',',
#   'хотя',
#   'сам',
#   'он',
#   'некоторое',
#   'время',
#   'спустя',
#   ',',
#   'в',
#   'разговоре',
#   'с',
#   'отцом',
#   ',',
#   'уверял',
#   ',',
#   'что',
#   'застал',
#   'уже',
#   'историю',
#   'во',
#   'всех',
#   'устах',
#   ',',
#   'преимущественно',
#   'в',
#   'клубе',
#   ',',
#   'и',
#   'совершенно',
#   'известною',
#   'до',
#   'мельчайших',
#   'подробностей',
#   'губернаторше',
#   'и',
#   'ее',
#   'супругу',
#   '.'],
#  ['Вот',
#   'что',
#   'еще',
#   'замечательно',
#   ':',
#   'на',
#   'второй',
#   'же',
#   'день',
#   ',',
#   'в',
#   'понедельник',
#   'ввечеру',
#   ',',
#   'я',
#   'встретил',
#   'Липутина',
#   ',',
#   'и',
#   'он',
#   'уже',
#   'знал',
#   'все',
#   'до',
#   'последнего',
#   'слова',
#   ',',
#   'стало',
#   'быть',
#   ',',
#   'несомненно',
#   'узнал',
#   'из',
#   'первых',
#   '.'],
#  ['Многие',
#   'из',
#   'дам',
#   '(',
#   'и',
#   'из',
#   'самых',
#   'светских',
#   ')',
#   'любопытствовали',
#   'и',
#   'о',
#   '``',
#   'загадочной',
#   'хромоножке',
#   "''",
#   ',',
#   'так',
#   'называли',
#   'Марью',
#   'Тимофеевну',
#   '.'],
#  ['Нашлись',
#   'даже',
#   'пожелавшие',
#   'непременно',
#   'увидать',
#   'ее',
#   'лично',
#   'и',
#   'познакомиться',
#   ',',
#   'так',
#   'что',
#   'господа',
#   ',',
#   'поспешившие',
#   'припрятать',
#   'Лебядкиных',
#   ',',
#   'очевидно',
#   'поступили',
#   'и',
#   'кстати',
#   '.'],
#  ['Но',
#   'на',
#   'первом',
#   'плане',
#   'все-таки',
#   'стоял',
#   'обморок',
#   'Лизаветы',
#   'Николаевны',
#   ',',
#   'и',
#   'этим',
#   'интересовался',
#   '``',
#   'весь',
#   'свет',
#   "''",
#   ',',
#   'уже',
#   'по',
#   'тому',
#   'одному',
#   ',',
#   'что',
#   'дело',
#   'прямо',
#   'касалось',
#   'Юлии',
#   'Михайловны',
#   'как',
#   'родственницы',
#   'Лизаветы',
#   'Николаевны',
#   'и',
#   'ее',
#   'покровительницы',
#   '.'],
#  ['И', 'чего-чего', 'ни', 'болтали', '!'],
#  ['Болтовне',
#   'способствовала',
#   'и',
#   'таинственность',
#   'обстановки',
#   ':',
#   'оба',
#   'дома',
#   ',',
#   'были',
#   'заперты',
#   'наглухо',
#   ';',
#   'Лизавета',
#   'Николаевна',
#   ',',
#   'как',
#   'рассказывали',
#   ',',
#   'лежала',
#   'в',
#   'белой',
#   'горячке',
#   ';',
#   'то',
#   'же',
#   'утверждали',
#   'и',
#   'о',
#   'Николае',
#   'Всеволодовиче',
#   ',',
#   'с',
#   'отвратительными',
#   'подробностями',
#   'о',
#   'выбитом',
#   'будто',
#   'бы',
#   'зубе',
#   'и',
#   'о',
#   'распухшей',
#   'от',
#   'флюса',
#   'щеке',
#   'его',
#   '.'],
#  ['Говорили',
#   'даже',
#   'по',
#   'уголкам',
#   ',',
#   'что',
#   'у',
#   'нас',
#   'может',
#   'быть',
#   'будет',
#   'убийство',
#   ',',
#   'что',
#   'Ставрогин',
#   'не',
#   'таков',
#   ',',
#   'чтобы',
#   'снести',
#   'такую',
#   'обиду',
#   ',',
#   'и',
#   'убьет',
#   'Шатова',
#   ',',
#   'но',
#   'таинственно',
#   ',',
#   'как',
#   'в',
#   'корсиканской',
#   'вендетте',
#   '.'],
#  ['Мысль',
#   'эта',
#   'нравилась',
#   ';',
#   'но',
#   'большинство',
#   'нашей',
#   'светской',
#   'молодежи',
#   'выслушивало',
#   'все',
#   'это',
#   'с',
#   'презрением',
#   'и',
#   'с',
#   'видом',
#   'самого',
#   'пренебрежительного',
#   'равнодушия',
#   ',',
#   'разумеется',
#   ',',
#   'напускного',
#   '.'],
#  ['Вообще',
#   'древняя',
#   'враждебность',
#   'нашего',
#   'общества',
#   'к',
#   'Николаю',
#   'Всеволодовичу',
#   'обозначилась',
#   'ярко',
#   '.'],
#  ['Даже',
#   'солидные',
#   'люди',
#   'стремились',
#   'обвинить',
#   'его',
#   ',',
#   'хотя',
#   'и',
#   'сами',
#   'не',
#   'знали',
#   'в',
#   'чем',
#   '.'],
#  ['Шепотом',
#   'рассказывали',
#   ',',
#   'что',
#   'будто',
#   'бы',
#   'он',
#   'погубил',
#   'честь',
#   'Лизаветы',
#   'Николаевны',
#   ',',
#   'и',
#   'что',
#   'между',
#   'ними',
#   'была',
#   'интрига',
#   'в',
#   'Швейцарии',
#   '.'],
#  ['Конечно',
#   'осторожные',
#   'люди',
#   'сдерживались',
#   ',',
#   'но',
#   'все',
#   'однако',
#   'же',
#   'слушали',
#   'с',
#   'аппетитом',
#   '.'],
#  ['Были',
#   'и',
#   'другие',
#   'разговоры',
#   ',',
#   'но',
#   'не',
#   'общие',
#   ',',
#   'а',
#   'частные',
#   ',',
#   'редкие',
#   'и',
#   'почти',
#   'закрытые',
#   ',',
#   'чрезвычайно',
#   'странные',
#   'и',
#   'о',
#   'существовании',
#   'которых',
#   'я',
#   'упоминаю',
#   'лишь',
#   'для',
#   'предупреждения',
#   'читателей',
#   ',',
#   'единственно',
#   'в',
#   'виду',
#   'дальнейших',
#   'событий',
#   'моего',
#   'рассказа',
#   '.'],
#  ['Именно',
#   ':',
#   'говорили',
#   'иные',
#   ',',
#   'хмуря',
#   'брови',
#   'и',
#   'бог',
#   'знает',
#   'на',
#   'каком',
#   'основании',
#   ',',
#   'что',
#   'Николай',
#   'Всеволодович',
#   'имеет',
#   'какое-то',
#   'особенное',
#   'дело',
#   'в',
#   'нашей',
#   'губернии',
#   ',',
#   'что',
#   'он',
#   'чрез',
#   'графа',
#   'К.',
#   'вошел',
#   'в',
#   'Петербурге',
#   'в',
#   'какие-то',
#   'высшие',
#   'отношения',
#   ',',
#   'что',
#   'он',
#   'даже',
#   ',',
#   'может',
#   'быть',
#   ',',
#   'служит',
#   'и',
#   'чуть',
#   'ли',
#   'не',
#   'снабжен',
#   'от',
#   'кого-то',
#   'какими-то',
#   'поручениями',
#   '.'],
#  ['Когда',
#   'очень',
#   'уж',
#   'солидные',
#   'и',
#   'сдержанные',
#   'люди',
#   'на',
#   'этот',
#   'слух',
#   'улыбались',
#   ',',
#   'благоразумно',
#   'замечая',
#   ',',
#   'что',
#   'человек',
#   ',',
#   'живущий',
#   'скандалами',
#   'и',
#   'начинающий',
#   'у',
#   'нас',
#   'с',
#   'флюса',
#   ',',
#   'не',
#   'похож',
#   'на',
#   'чиновника',
#   ',',
#   'то',
#   'им',
#   'шепотом',
#   'замечали',
#   ',',
#   'что',
#   'служит',
#   'он',
#   'не',
#   'то',
#   'чтоб',
#   'оффициально',
#   ',',
#   'а',
#   'так',
#   'сказать',
#   'конфиденциально',
#   ',',
#   'и',
#   'что',
#   'в',
#   'таком',
#   'случае',
#   'самою',
#   'службой',
#   'требуется',
#   ',',
#   'чтобы',
#   'служащий',
#   'как',
#   'можно',
#   'менее',
#   'походил',
#   'на',
#   'чиновника',
#   '.'],
#  ['Такое',
#   'замечание',
#   'производило',
#   'эффект',
#   ';',
#   'у',
#   'нас',
#   'известно',
#   'было',
#   ',',
#   'что',
#   'на',
#   'земство',
#   'нашей',
#   'губернии',
#   'смотрят',
#   'в',
#   'столице',
#   'с',
#   'некоторым',
#   'особым',
#   'вниманием',
#   '.'],
#  ['Повторю',
#   ',',
#   'эти',
#   'слухи',
#   'только',
#   'мелькнули',
#   'и',
#   'исчезли',
#   'бесследно',
#   ',',
#   'до',
#   'времени',
#   ',',
#   'при',
#   'первом',
#   'появлении',
#   'Николая',
#   'Всеволодовича',
#   ';',
#   'но',
#   'замечу',
#   ',',
#   'что',
#   'причиной',
#   'многих',
#   'слухов',
#   'было',
#   'отчасти',
#   'несколько',
#   'кратких',
#   ',',
#   'но',
#   'злобных',
#   'слов',
#   ',',
#   'неясно',
#   'и',
#   'отрывисто',
#   'произнесенных',
#   'в',
#   'клубе',
#   'недавно',
#   'возвратившимся',
#   'из',
#   'Петербурга',
#   'отставным',
#   'капитаном',
#   'гвардии',
#   'Артемием',
#   'Павловичем',
#   'Гагановым',
#   ',',
#   'весьма',
#   'крупным',
#   'помещиком',
#   'нашей',
#   'губернии',
#   'и',
#   'уезда',
#   ',',
#   'столичным',
#   'светским',
#   'человеком',
#   'и',
#   'сыном',
#   'покойного',
#   'Павла',
#   'Павловича',
#   'Гаганова',
#   ',',
#   'того',
#   'самого',
#   'почтенного',
#   'старшины',
#   ',',
#   'с',
#   'которым',
#   'Николай',
#   'Всеволодович',
#   'имел',
#   ',',
#   'четыре',
#   'слишком',
#   'года',
#   'тому',
#   'назад',
#   ',',
#   'то',
#   'необычайное',
#   'по',
#   'своей',
#   'грубости',
#   'и',
#   'внезапности',
#   'столкновение',
#   ',',
#   'о',
#   'котором',
#   'я',
#   'уже',
#   'упоминал',
#   'прежде',
#   ',',
#   'в',
#   'начале',
#   'моего',
#   'рассказа',
#   '.'],
#  ['Всем',
#   'тотчас',
#   'же',
#   'стало',
#   'известно',
#   ',',
#   'что',
#   'Юлия',
#   'Михайловна',
#   'сделала',
#   'Варваре',
#   'Петровне',
#   'чрезвычайный',
#   'визит',
#   ',',
#   'и',
#   'что',
#   'у',
#   'крыльца',
#   'дома',
#   'ей',
#   'объявили',
#   ',',
#   'что',
#   '``',
#   'по',
#   'нездоровью',
#   'не',
#   'могут',
#   'принять',
#   "''",
#   '.'],
#  ['Также',
#   'и',
#   'то',
#   ',',
#   'что',
#   'дня',
#   'через',
#   'два',
#   'после',
#   'своего',
#   'визита',
#   'Юлия',
#   'Михайловна',
#   'посылала',
#   'узнать',
#   'о',
#   'здоровье',
#   'Варвары',
#   'Петровны',
#   'нарочного',
#   '.'],
#  ['Наконец',
#   'принялась',
#   'везде',
#   '``',
#   'защищать',
#   "''",
#   'Варвару',
#   'Петровну',
#   ',',
#   'конечно',
#   'лишь',
#   'в',
#   'самом',
#   'высшем',
#   'смысле',
#   ',',
#   'то',
#   '``',
#   'есть',
#   'по',
#   'возможности',
#   'в',
#   'самом',
#   'неопределенном',
#   '.'],
#  ['Все',
#   'же',
#   'первоначальные',
#   'торопливые',
#   'намеки',
#   'о',
#   'воскресной',
#   'истории',
#   'выслушала',
#   'строго',
#   'и',
#   'холодно',
#   ',',
#   'так',
#   'что',
#   'в',
#   'последующие',
#   'дни',
#   ',',
#   'в',
#   'ее',
#   'присутствии',
#   ',',
#   'они',
#   'уже',
#   'не',
#   'возобновлялись',
#   '.'],
#  ['Таким',
#   'образом',
#   'и',
#   'укрепилась',
#   'везде',
#   'мысль',
#   ',',
#   'что',
#   'Юлии',
#   'Михайловне',
#   'известна',
#   'не',
#   'только',
#   'вся',
#   'эта',
#   'таинственная',
#   'история',
#   ',',
#   'но',
#   'и',
#   'весь',
#   'ее',
#   'таинственный',
#   'смысл',
#   'до',
#   'мельчайших',
#   'подробностей',
#   ',',
#   'и',
#   'не',
#   'как',
#   'посторонней',
#   ',',
#   'а',
#   'как',
#   'соучастнице',
#   '.'],
#  ['Замечу',
#   'кстати',
#   ',',
#   'что',
#   'она',
#   'начала',
#   'уже',
#   'приобретать',
#   'у',
#   'нас',
#   ',',
#   'помаленьку',
#   ',',
#   'то',
#   'высшее',
#   'влияние',
#   ',',
#   'которого',
#   'так',
#   'несомненно',
#   'добивалась',
#   'и',
#   'жаждала',
#   ',',
#   'и',
#   'уже',
#   'начинала',
#   'видеть',
#   'себя',
#   '``',
#   'окруженною',
#   "''",
#   '.'],
#  ['Часть',
#   'общества',
#   'признала',
#   'за',
#   'нею',
#   'практический',
#   'ум',
#   'и',
#   'такт',
#   '...',
#   'но',
#   'об',
#   'этом',
#   'после',
#   '.'],
#  ['Ее',
#   'же',
#   'покровительством',
#   'объяснялись',
#   'отчасти',
#   'и',
#   'весьма',
#   'быстрые',
#   'успехи',
#   'Петра',
#   'Степановича',
#   'в',
#   'нашем',
#   'обществе',
#   ',',
#   '-',
#   'успехи',
#   ',',
#   'особенно',
#   'поразившие',
#   'тогда',
#   'Степана',
#   'Трофимовича',
#   '.'],
#  ['Мы', 'с', 'ним', 'может', 'быть', 'и', 'преувеличивали', '.'],
#  ['Во-первых',
#   ',',
#   'Петр',
#   'Степанович',
#   'перезнакомился',
#   'почти',
#   'мгновенно',
#   'со',
#   'всем',
#   'городом',
#   ',',
#   'в',
#   'первые',
#   'же',
#   'четыре',
#   'дня',
#   'после',
#   'своего',
#   'появления',
#   '.'],
#  ['Появился',
#   'он',
#   'в',
#   'воскресенье',
#   ',',
#   'а',
#   'во',
#   'вторник',
#   'я',
#   'уже',
#   'встретил',
#   'его',
#   'в',
#   'коляске',
#   'с',
#   'Артемием',
#   'Павловичем',
#   'Гагановым',
#   ',',
#   'человеком',
#   'гордым',
#   ',',
#   'раздражительным',
#   'и',
#   'заносчивым',
#   ',',
#   'несмотря',
#   'на',
#   'всю',
#   'его',
#   'светскость',
#   ',',
#   'и',
#   'с',
#   'которым',
#   ',',
#   'по',
#   'характеру',
#   'его',
#   ',',
#   'довольно',
#   'трудно',
#   'было',
#   'ужиться',
#   '.'],
#  ['У',
#   'губернатора',
#   'Петр',
#   'Степанович',
#   'был',
#   'тоже',
#   'принят',
#   'прекрасно',
#   ',',
#   'до',
#   'того',
#   ',',
#   'что',
#   'тотчас',
#   'же',
#   'стал',
#   'в',
#   'положение',
#   'близкого',
#   'или',
#   'так-сказать',
#   'обласканного',
#   'молодого',
#   'человека',
#   ';',
#   'обедал',
#   'у',
#   'Юлии',
#   'Михайловны',
#   'почти',
#   'ежедневно',
#   '.'],
#  ['Познакомился',
#   'он',
#   'с',
#   'нею',
#   'еще',
#   'в',
#   'Швейцарии',
#   ',',
#   'но',
#   'в',
#   'быстром',
#   'успехе',
#   'его',
#   'в',
#   'доме',
#   'его',
#   'превосходительства',
#   'действительно',
#   'заключалось',
#   'нечто',
#   'любопытное',
#   '.'],
#  ['Все-таки',
#   'он',
#   'слыл',
#   'же',
#   'когда-то',
#   'заграничным',
#   'революционером',
#   ',',
#   'правда',
#   'ли',
#   ',',
#   'нет',
#   'ли',
#   ',',
#   'участвовал',
#   'в',
#   'каких-то',
#   'заграничных',
#   'изданиях',
#   'и',
#   'конгрессах',
#   ',',
#   '``',
#   'что',
#   'можно',
#   'даже',
#   'из',
#   'газет',
#   'доказать',
#   "''",
#   ',',
#   'как',
#   'злобно',
#   'выразился',
#   'мне',
#   'при',
#   'встрече',
#   'Алеша',
#   'Телятников',
#   ',',
#   'теперь',
#   ',',
#   'увы',
#   ',',
#   'отставной',
#   'чиновничек',
#   ',',
#   'а',
#   'прежде',
#   'тоже',
#   'обласканный',
#   'молодой',
#   'человек',
#   'в',
#   'доме',
#   'старого',
#   'губернатора',
#   '.'],
#  ['Но',
#   'тут',
#   'стоял',
#   'однако',
#   'же',
#   'факт',
#   ':',
#   'бывший',
#   'революционер',
#   'явился',
#   'в',
#   'любезном',
#   'отечестве',
#   'не',
#   'только',
#   'без',
#   'всякого',
#   'беспокойства',
#   ',',
#   'но',
#   'чуть',
#   'ли',
#   'не',
#   'с',
#   'поощрениями',
#   ';',
#   'стало',
#   'быть',
#   ',',
#   'ничего',
#   ',',
#   'может',
#   ',',
#   'и',
#   'не',
#   'было',
#   '.'],
#  ['Липутин',
#   'шепнул',
#   'мне',
#   'раз',
#   ',',
#   'что',
#   ',',
#   'по',
#   'слухам',
#   ',',
#   'Петр',
#   'Степанович',
#   'будто',
#   'бы',
#   'где-то',
#   'принес',
#   'покаяние',
#   'и',
#   'получил',
#   'отпущение',
#   ',',
#   'назвав',
#   'несколько',
#   'прочих',
#   'имен',
#   ',',
#   'и',
#   'таким',
#   'образом',
#   ',',
#   'может',
#   ',',
#   'и',
#   'успел',
#   'уже',
#   'заслужить',
#   'вину',
#   ',',
#   'обещая',
#   'и',
#   'впредь',
#   'быть',
#   'полезным',
#   'отечеству',
#   '.'],
#  ['Я',
#   'передал',
#   'эту',
#   'ядовитую',
#   'фразу',
#   'Степану',
#   'Трофимовичу',
#   ',',
#   'и',
#   'тот',
#   ',',
#   'несмотря',
#   'на',
#   'то',
#   ',',
#   'что',
#   'был',
#   'почти',
#   'не',
#   'в',
#   'состоянии',
#   'соображать',
#   ',',
#   'сильно',
#   'задумался',
#   '.'],
#  ['Впоследствии',
#   'обнаружилось',
#   ',',
#   'что',
#   'Петр',
#   'Степанович',
#   'приехал',
#   'к',
#   'нам',
#   'с',
#   'чрезвычайно',
#   'почтенными',
#   'рекомендательными',
#   'письмами',
#   ',',
#   'по',
#   'крайней',
#   'мере',
#   'привез',
#   'одно',
#   'к',
#   'губернаторше',
#   'от',
#   'одной',
#   'чрезвычайно',
#   'важной',
#   'петербургской',
#   'старушки',
#   ',',
#   'муж',
#   'которой',
#   'был',
#   'одним',
#   'из',
#   'самых',
#   'значительных',
#   'петербургских',
#   'старичков',
#   '.'],
#  ['Эта',
#   'старушка',
#   ',',
#   'крестная',
#   'мать',
#   'Юлии',
#   'Михайловны',
#   ',',
#   'упоминала',
#   'в',
#   'письме',
#   'своем',
#   ',',
#   'что',
#   'и',
#   'граф',
#   'К.',
#   'хорошо',
#   'знает',
#   'Петра',
#   'Степановича',
#   ',',
#   'чрез',
#   'Николая',
#   'Всеволодовича',
#   ',',
#   'обласкал',
#   'его',
#   'и',
#   'находит',
#   '``',
#   'достойным',
#   'молодым',
#   'человеком',
#   ',',
#   'несмотря',
#   'на',
#   'бывшие',
#   'заблуждения',
#   "''",
#   '.'],
#  ['Юлия',
#   'Михайловна',
#   'до',
#   'крайности',
#   'ценила',
#   'свои',
#   'скудные',
#   'и',
#   'с',
#   'таким',
#   'трудом',
#   'поддерживаемые',
#   'связи',
#   'с',
#   '``',
#   'высшим',
#   'миром',
#   "''",
#   'и',
#   'уж',
#   'конечно',
#   'была',
#   'рада',
#   'письму',
#   'важной',
#   'старушки',
#   ';',
#   'но',
#   'все-таки',
#   'оставалось',
#   'тут',
#   'нечто',
#   'как',
#   'бы',
#   'и',
#   'особенное',
#   '.'],
#  ['Даже',
#   'супруга',
#   'своего',
#   'поставила',
#   'к',
#   'Петру',
#   'Степановичу',
#   'в',
#   'отношения',
#   'почти',
#   'фамилиарные',
#   ',',
#   'так',
#   'что',
#   'г.',
#   'фон-Лембке',
#   'жаловался',
#   '...',
#   'но',
#   'об',
#   'этом',
#   'тоже',
#   'после',
#   '.'],
#  ['Замечу',
#   'тоже',
#   'для',
#   'памяти',
#   ',',
#   'что',
#   'и',
#   'великий',
#   'писатель',
#   'весьма',
#   'благосклонно',
#   'отнесся',
#   'к',
#   'Петру',
#   'Степановичу',
#   'и',
#   'тотчас',
#   'же',
#   'пригласил',
#   'его',
#   'к',
#   'себе',
#   '.'],
#  ['Такая',
#   'поспешность',
#   'такого',
#   'надутого',
#   'собою',
#   'человека',
#   'кольнула',
#   'Степана',
#   'Трофимовича',
#   'больнее',
#   'всего',
#   ';',
#   'но',
#   'я',
#   'объяснил',
#   'себе',
#   'иначе',
#   ':',
#   'зазывая',
#   'к',
#   'себе',
#   'нигилиста',
#   ',',
#   'г.',
#   'Кармазинов',
#   'уж',
#   'конечно',
#   'имел',
#   'в',
#   'виду',
#   'сношения',
#   'его',
#   'с',
#   'прогрессивными',
#   'юношами',
#   'обеих',
#   'столиц',
#   '.'],
#  ['Великий',
#   'писатель',
#   'болезненно',
#   'трепетал',
#   'пред',
#   'новейшею',
#   'революционною',
#   'молодежью',
#   'и',
#   ',',
#   'воображая',
#   ',',
#   'по',
#   'незнанию',
#   'дела',
#   ',',
#   'что',
#   'в',
#   'руках',
#   'ее',
#   'ключи',
#   'русской',
#   'будущности',
#   ',',
#   'унизительно',
#   'к',
#   'ним',
#   'подлизывался',
#   ',',
#   'главное',
#   'потому',
#   'что',
#   'они',
#   'не',
#   'обращали',
#   'на',
#   'него',
#   'никакого',
#   'внимания',
#   '.'],
#  ['II',
#   'Петр',
#   'Степанович',
#   'забежал',
#   'раза',
#   'два',
#   'и',
#   'к',
#   'родителю',
#   ',',
#   'и',
#   ',',
#   'к',
#   'несчастию',
#   'моему',
#   ',',
#   'оба',
#   'раза',
#   'в',
#   'мое',
#   'отсутствие',
#   '.'],
#  ['В',
#   'первый',
#   'раз',
#   'посетил',
#   'его',
#   'в',
#   'среду',
#   ',',
#   'то-есть',
#   'на',
#   'четвертый',
#   'лишь',
#   'день',
#   'после',
#   'той',
#   'первой',
#   'встречи',
#   ',',
#   'да',
#   'и',
#   'то',
#   'по',
#   'делу',
#   '.'],
#  ['Кстати',
#   ',',
#   'расчет',
#   'по',
#   'имению',
#   'окончился',
#   'у',
#   'них',
#   'как-то',
#   'неслышно',
#   'и',
#   'невидно',
#   '.'],
#  ['Варвара',
#   'Петровна',
#   'взяла',
#   'все',
#   'на',
#   'себя',
#   'и',
#   'все',
#   'выплатила',
#   ',',
#   'разумеется',
#   ',',
#   'приобретя',
#   'землицу',
#   ',',
#   'а',
#   'Степана',
#   'Трофимовича',
#   'только',
#   'уведомила',
#   'о',
#   'том',
#   ',',
#   'что',
#   'все',
#   'кончено',
#   ',',
#   'и',
#   'уполномоченный',
#   'Варвары',
#   'Петровны',
#   ',',
#   'камердинер',
#   'ее',
#   'Алексей',
#   'Егорович',
#   ',',
#   'поднес',
#   'ему',
#   'что-то',
#   'подписать',
#   ',',
#   'что',
#   'он',
#   'и',
#   'исполнил',
#   'молча',
#   'и',
#   'с',
#   'чрезвычайным',
#   'достоинством',
#   '.'],
#  ['Замечу',
#   'по',
#   'поводу',
#   'достоинства',
#   ',',
#   'что',
#   'я',
#   'почти',
#   'не',
#   'узнавал',
#   'нашего',
#   'прежнего',
#   'старички',
#   'в',
#   'эти',
#   'дни',
#   '.'],
#  ['Он',
#   'держал',
#   'себя',
#   'как',
#   'никогда',
#   'прежде',
#   ',',
#   'стал',
#   'удивительно',
#   'молчалив',
#   ',',
#   'даже',
#   'не',
#   'написал',
#   'ни',
#   'одного',
#   'письма',
#   'Варваре',
#   'Петровне',
#   'с',
#   'самого',
#   'воскресенья',
#   ',',
#   'что',
#   'я',
#   'счел',
#   'бы',
#   'чудом',
#   ',',
#   'а',
#   'главное',
#   'стал',
#   'спокоен',
#   '.'],
#  ['Он',
#   'укрепился',
#   'на',
#   'какой-то',
#   'окончательной',
#   'и',
#   'чрезвычайной',
#   'идее',
#   ',',
#   'придававшей',
#   'ему',
#   'спокойствие',
#   ',',
#   'это',
#   'было',
#   'видно',
#   '.'],
#  ['Он', 'нашел', 'эту', 'идею', ',', 'сидел', 'и', 'чего-то', 'ждал', '.'],
#  ['Сначала',
#   'впрочем',
#   'был',
#   'болен',
#   ',',
#   'особенно',
#   'в',
#   'понедельник',
#   ';',
#   'была',
#   'холерина',
#   '.'],
#  ['Тоже',
#   'и',
#   'без',
#   'вестей',
#   'пробыть',
#   'не',
#   'мог',
#   'во',
#   'все',
#   'время',
#   ';',
#   'но',
#   'лишь',
#   'только',
#   'я',
#   ',',
#   'оставляя',
#   'факты',
#   ',',
#   'переходил',
#   'к',
#   'сути',
#   'дела',
#   'и',
#   'высказывал',
#   'какие-нибудь',
#   'предположения',
#   ',',
#   'то',
#   'он',
#   'тотчас',
#   'же',
#   'начинал',
#   'махать',
#   'на',
#   'меня',
#   'руками',
#   ',',
#   'чтоб',
#   'я',
#   'перестал',
#   '.'],
#  ['Но',
#   'оба',
#   'свидания',
#   'с',
#   'сынком',
#   'все-таки',
#   'болезненно',
#   'на',
#   'него',
#   'подействовали',
#   ',',
#   'хотя',
#   'и',
#   'не',
#   'поколебали',
#   '.'],
#  ['В',
#   'оба',
#   'эти',
#   'дня',
#   ',',
#   'после',
#   'свиданий',
#   ',',
#   'он',
#   'лежал',
#   'на',
#   'диване',
#   ',',
#   'обмотав',
#   'голову',
#   'платком',
#   ',',
#   'намоченным',
#   'в',
#   'уксусе',
#   ';',
#   'но',
#   'в',
#   'высшем',
#   'смысле',
#   'продолжал',
#   'оставаться',
#   'спокойным',
#   '.'],
#  ['Иногда',
#   ',',
#   'впрочем',
#   ',',
#   'он',
#   'и',
#   'не',
#   'махал',
#   'на',
#   'меня',
#   'руками',
#   '.'],
#  ['Иногда',
#   'тоже',
#   'казалось',
#   'мне',
#   ',',
#   'что',
#   'принятая',
#   'таинственная',
#   'решимость',
#   'как',
#   'бы',
#   'оставляла',
#   'его',
#   ',',
#   'и',
#   'что',
#   'он',
#   'начинал',
#   'бороться',
#   'с',
#   'каким-то',
#   'новым',
#   'соблазнительным',
#   'наплывом',
#   'идей',
#   '.'],
#  ['Это', 'было', 'мгновениями', ',', 'но', 'я', 'отмечаю', 'их', '.'],
#  ['Я',
#   'подозревал',
#   ',',
#   'что',
#   'ему',
#   'очень',
#   'бы',
#   'хотелось',
#   'опять',
#   'заявить',
#   'себя',
#   ',',
#   'выйти',
#   'из',
#   'уединения',
#   ',',
#   'предложить',
#   'борьбу',
#   ',',
#   'задать',
#   'последнюю',
#   'битву',
#   '.'],
#  ['-', 'Cher', ',', 'я', 'бы', 'их', 'разгромил', '!'],
#  ['-',
#   'вырвалось',
#   'у',
#   'него',
#   'в',
#   'четверг',
#   'вечером',
#   ',',
#   'после',
#   'второго',
#   'свидания',
#   'с',
#   'Петром',
#   'Степановичем',
#   ',',
#   'когда',
#   'он',
#   'лежал',
#   ',',
#   'протянувшись',
#   'на',
#   'диване',
#   ',',
#   'с',
#   'головой',
#   ',',
#   'обернутою',
#   'полотенцем',
#   '.'],
#  ['До',
#   'этой',
#   'минуты',
#   'он',
#   'во',
#   'весь',
#   'день',
#   'еще',
#   'ни',
#   'слова',
#   'не',
#   'сказал',
#   'со',
#   'мной',
#   '.'],
#  ['-',
#   '``',
#   'Fils',
#   ',',
#   'fils',
#   'chйri',
#   "''",
#   'и',
#   'так',
#   'далее',
#   ',',
#   'я',
#   'согласен',
#   ',',
#   'что',
#   'все',
#   'эти',
#   'выражения',
#   'вздор',
#   ',',
#   'кухарочный',
#   'словарь',
#   ',',
#   'да',
#   'и',
#   'пусть',
#   'их',
#   ',',
#   'я',
#   'сам',
#   'теперь',
#   'вижу',
#   '.'],
#  ['Я',
#   'его',
#   'не',
#   'кормил',
#   'и',
#   'не',
#   'поил',
#   ',',
#   'я',
#   'отослал',
#   'его',
#   'из',
#   'Берлина',
#   'в',
#   'скую',
#   'губернию',
#   ',',
#   'грудного',
#   'ребенка',
#   ',',
#   'по',
#   'почте',
#   ',',
#   'ну',
#   'и',
#   'так',
#   'далее',
#   ',',
#   'я',
#   'согласен',
#   '...',
#   '``',
#   'Ты',
#   ',',
#   'говорит',
#   ',',
#   'меня',
#   'не',
#   'поил',
#   'и',
#   'по',
#   'почте',
#   'выслал',
#   ',',
#   'да',
#   'еще',
#   'здесь',
#   'ограбил',
#   "''",
#   '.'],
#  ['Но',
#   ',',
#   'несчастный',
#   ',',
#   'кричу',
#   'ему',
#   ',',
#   'ведь',
#   'болел',
#   'же',
#   'я',
#   'за',
#   'тебя',
#   'сердцем',
#   'всю',
#   'мою',
#   'жизнь',
#   ',',
#   'хотя',
#   'и',
#   'по',
#   'почте',
#   '!'],
#  ['Il', 'rit', '.'],
#  ['Но',
#   'я',
#   'согласен',
#   ',',
#   'согласен',
#   '...',
#   'пусть',
#   'по',
#   'почте',
#   ',',
#   '-',
#   'закончил',
#   'он',
#   'как',
#   'в',
#   'бреду',
#   '.'],
#  ['-',
#   'Passons',
#   ',',
#   '-',
#   'начал',
#   'он',
#   'опять',
#   'через',
#   'пять',
#   'минут',
#   '.'],
#  ['-', 'Я', 'не', 'понимаю', 'Тургенева', '.'],
#  ['У',
#   'него',
#   'Базаров',
#   'это',
#   'какое-то',
#   'фиктивное',
#   'лицо',
#   ',',
#   'не',
#   'существующее',
#   'вовсе',
#   ';',
#   'они',
#   'же',
#   'первые',
#   'и',
#   'отвергли',
#   'его',
#   'тогда',
#   ',',
#   'как',
#   'ни',
#   'на',
#   'что',
#   'не',
#   'похожее',
#   '.'],
#  ['Этот',
#   'Базаров',
#   'это',
#   'какая-то',
#   'неясная',
#   'смесь',
#   'Ноздрева',
#   'с',
#   'Байроном',
#   ',',
#   "c'est",
#   'le',
#   'mot',
#   '!'],
#  ['Посмотрите',
#   'на',
#   'них',
#   'внимательно',
#   ':',
#   'они',
#   'кувыркаются',
#   'и',
#   'визжат',
#   'от',
#   'радости',
#   'как',
#   'щенки',
#   'на',
#   'солнце',
#   ',',
#   'они',
#   'счастливы',
#   ',',
#   'они',
#   'победители',
#   '!'],
#  ['Какой', 'тут', 'Байрон', '!', '..'],
#  ['И', 'при', 'том', 'какие', 'будни', '!'],
#  ['Какая',
#   'кухарочная',
#   'раздражительность',
#   'самолюбия',
#   ',',
#   'какая',
#   'пошленькая',
#   'жаждишка',
#   'faire',
#   'du',
#   'bruit',
#   'autour',
#   'de',
#   'son',
#   'nom',
#   ',',
#   'не',
#   'замечая',
#   ',',
#   'что',
#   'son',
#   'nom',
#   '...',
#   'О',
#   ',',
#   'карикатура',
#   '!'],
#  ['Помилуй',
#   ',',
#   'кричу',
#   'ему',
#   ',',
#   'да',
#   'неужто',
#   'ты',
#   'себя',
#   'такого',
#   'как',
#   'есть',
#   'людям',
#   'взамен',
#   'Христа',
#   'предложить',
#   'желаешь',
#   '?'],
#  ['Il', 'rit', '.'],
#  ['Il', 'rit', 'beaucoup', ',', 'il', 'rit', 'trop', '.'],
#  ['У', 'него', 'какая-то', 'странная', 'улыбка', '.'],
#  ['У', 'его', 'матери', 'не', 'было', 'такой', 'улыбки', '.'],
#  ['Il', 'rit', 'toujours', '.'],
#  ['Опять', 'наступило', 'молчание', '.'],
#  ['-',
#   'Они',
#   'хитры',
#   ';',
#   'в',
#   'воскресенье',
#   'они',
#   'сговорились',
#   '...',
#   '-',
#   'брякнул',
#   'он',
#   'вдруг',
#   '.'],
#  ['-',
#   'О',
#   ',',
#   'без',
#   'сомнения',
#   ',',
#   '-',
#   'вскричал',
#   'я',
#   ',',
#   'навострив',
#   'уши',
#   ',',
#   '-',
#   'все',
#   'это',
#   'стачка',
#   'и',
#   'сшито',
#   'белыми',
#   'нитками',
#   ',',
#   'и',
#   'так',
#   'дурно',
#   'разыграно',
#   '.'],
#  ['-', 'Я', 'не', 'про', 'то', '.'],
#  ['Знаете',
#   'ли',
#   ',',
#   'что',
#   'все',
#   'это',
#   'было',
#   'нарочно',
#   'сшито',
#   'белыми',
#   'нитками',
#   ',',
#   'чтобы',
#   'заметили',
#   'те',
#   '...',
#   'кому',
#   'надо',
#   '.'],
#  ['Понимаете', 'это', '?'],
#  ['-', 'Нет', ',', 'не', 'понимаю', '.'],
#  ['-', 'Tant', 'mieux', '.'],
#  ['Passons', '.'],
#  ['Я', 'очень', 'раздражен', 'сегодня', '.'],
#  ['-',
#   'Да',
#   'зачем',
#   'же',
#   'вы',
#   'с',
#   'ним',
#   'спорили',
#   ',',
#   'Степан',
#   'Трофимович',
#   '?'],
#  ['-', 'проговорил', 'я', 'укоризненно', '.'],
#  ['-', 'Je', 'voulais', 'convertir', '.'],
#  ['Конечно', 'смейтесь', '.'],
#  ['Cette',
#   'pauvre',
#   'тетя',
#   ',',
#   'elle',
#   'entendra',
#   'de',
#   'belles',
#   'choses',
#   '!'],
#  ['О',
#   ',',
#   'друг',
#   'мой',
#   ',',
#   'поверите',
#   'ли',
#   ',',
#   'что',
#   'я',
#   'давеча',
#   'ощутил',
#   'себя',
#   'патриотом',
#   '!'],
#  ['Впрочем',
#   'я',
#   'всегда',
#   'сознавал',
#   'себя',
#   'русским',
#   '...',
#   'да',
#   'настоящий',
#   'русский',
#   'и',
#   'не',
#   'может',
#   'быть',
#   'иначе',
#   ',',
#   'как',
#   'мы',
#   'с',
#   'вами',
#   '.'],
#  ['Il',
#   'у',
#   'a',
#   'lа',
#   'dedans',
#   'quelque',
#   'chose',
#   "d'aveugle",
#   'et',
#   'de',
#   'louche',
#   '.'],
#  ['-', 'Непременно', ',', '-', 'ответил', 'я', '.'],
#  ['-',
#   'Друг',
#   'мой',
#   ',',
#   'настоящая',
#   'правда',
#   'всегда',
#   'не',
#   'правдоподобна',
#   ',',
#   'знаете',
#   'ли',
#   'вы',
#   'это',
#   '?'],
#  ['Чтобы',
#   'сделать',
#   'правду',
#   'правдоподобнее',
#   ',',
#   'нужно',
#   'непременно',
#   'подмешать',
#   'к',
#   'ней',
#   'лжи',
#   '.'],
#  ['Люди', 'всегда', 'так', 'и', 'поступали', '.'],
#  ['Может',
#   'быть',
#   ',',
#   'тут',
#   'есть',
#   ',',
#   'чего',
#   'мы',
#   'не',
#   'понимаем',
#   '.'],
#  ['Как',
#   'вы',
#   'думаете',
#   ',',
#   'есть',
#   'тут',
#   ',',
#   'чего',
#   'мы',
#   'не',
#   'понимаем',
#   'в',
#   'этом',
#   'победоносном',
#   'визге',
#   '?'],
#  ['Я', 'бы', 'желал', ',', 'чтобы', 'было', '.'],
#  ['Я', 'бы', 'желал', '.'],
#  ['Я', 'промолчал', '.'],
#  ['Он', 'тоже', 'очень', 'долго', 'молчал', '.'],
#  ['-',
#   'Говорят',
#   ',',
#   'французский',
#   'ум',
#   '...',
#   '-',
#   'залепетал',
#   'он',
#   'вдруг',
#   'точно',
#   'в',
#   'жару',
#   ',',
#   '-',
#   'это',
#   'ложь',
#   ',',
#   'это',
#   'всегда',
#   'так',
#   'и',
#   'было',
#   '.'],
#  ['Зачем', 'клеветать', 'на', 'французский', 'ум', '?'],
#  ['Тут',
#   'просто',
#   'русская',
#   'лень',
#   ',',
#   'наше',
#   'унизительное',
#   'бессилие',
#   'произвести',
#   'идею',
#   ',',
#   'наше',
#   'отвратительное',
#   'паразитство',
#   'в',
#   'ряду',
#   'народов',
#   '.'],
#  ['Ils',
#   'sont',
#   'tout',
#   'simplement',
#   'des',
#   'paresseux',
#   ',',
#   'а',
#   'не',
#   'французский',
#   'ум.',
#   'О',
#   ',',
#   'русские',
#   'должны',
#   'бы',
#   'быть',
#   'истреблены',
#   'для',
#   'блага',
#   'человечества',
#   'как',
#   'вредные',
#   'паразиты',
#   '!'],
#  ['Мы',
#   'вовсе',
#   ',',
#   'вовсе',
#   'не',
#   'к',
#   'тому',
#   'стремились',
#   ';',
#   'я',
#   'ничего',
#   'не',
#   'понимаю',
#   '.'],
#  ['Я', 'перестал', 'понимать', '!'],
#  ['Да',
#   'понимаешь',
#   'ли',
#   ',',
#   'кричу',
#   'ему',
#   ',',
#   'понимаешь',
#   'ли',
#   ',',
#   'что',
#   'если',
#   'у',
#   'вас',
#   'гильйотина',
#   'на',
#   'первом',
#   'плане',
#   'и',
#   'с',
#   'таким',
#   'восторгом',
#   ',',
#   'то',
#   'это',
#   'единственно',
#   'потому',
#   ',',
#   'что',
#   'рубить',
#   'головы',
#   'всего',
#   'легче',
#   ',',
#   'а',
#   'иметь',
#   'идею',
#   'всего',
#   'труднее',
#   '!'],
#  ['Vous', 'кtes', 'des', 'paresseux', '!'],
#  ['Votre',
#   'drapeau',
#   'est',
#   'une',
#   'guenille',
#   ',',
#   'une',
#   'impuissance',
#   '.'],
#  ['Эти',
#   'телеги',
#   ',',
#   'или',
#   'как',
#   'там',
#   ':',
#   '``',
#   'стук',
#   'телег',
#   ',',
#   'подвозящих',
#   'хлеб',
#   'человечеству',
#   "''",
#   ',',
#   'полезнее',
#   'Сикстинской',
#   'Мадонны',
#   ',',
#   'или',
#   'как',
#   'у',
#   'них',
#   'там',
#   '...',
#   'une',
#   'bкtise',
#   'dans',
#   'се',
#   'genre',
#   '.'],
#  ['Но',
#   'понимаешь',
#   'ли',
#   ',',
#   'кричу',
#   'ему',
#   ',',
#   'понимаешь',
#   'ли',
#   'ты',
#   ',',
#   'что',
#   'человеку',
#   'кроме',
#   'счастья',
#   'так',
#   'же',
#   'точно',
#   'и',
#   'совершенно',
#   'во',
#   'столько',
#   'же',
#   'необходимо',
#   'и',
#   'несчастие',
#   '!'],
#  ['Il', 'rit', '.'],
#  ['Ты',
#   ',',
#   'говорит',
#   ',',
#   'здесь',
#   'бонмо',
#   'отпускаешь',
#   ',',
#   '``',
#   'нежа',
#   'свои',
#   'члены',
#   '(',
#   'он',
#   'пакостнее',
#   'выразился',
#   ')',
#   'на',
#   'бархатном',
#   'диване',
#   "''",
#   '...',
#   'И',
#   'заметьте',
#   ',',
#   'эта',
#   'наша',
#   'привычка',
#   'на',
#   'ты',
#   'отца',
#   'с',
#   'сыном',
#   ';',
#   'хорошо',
#   ',',
#   'когда',
#   'оба',
#   'согласны',
#   ',',
#   'ну',
#   ',',
#   'а',
#   'если',
#   'ругаются',
#   '?'],
#  ['С', 'минуту', 'опять', 'помолчали', '.'],
#  ['-',
#   'Cher',
#   ',',
#   '-',
#   'заключил',
#   'он',
#   'вдруг',
#   ',',
#   'быстро',
#   'приподнявшись',
#   ',',
#   '-',
#   'знаете',
#   'ли',
#   ',',
#   'что',
#   'это',
#   'непременно',
#   'чем-нибудь',
#   'кончится',
#   '?'],
#  ['-', 'Уж', 'конечно', ',', '-', 'сказал', 'я', '.'],
#  ['-', 'Vous', 'ne', 'comprenez', 'pas', '.'],
#  ['Passons', '.'],
#  ['Но',
#   '...',
#   'обыкновенно',
#   'на',
#   'свете',
#   'кончается',
#   'ничем',
#   ',',
#   'но',
#   'здесь',
#   'будет',
#   'конец',
#   ',',
#   'непременно',
#   ',',
#   'непременно',
#   '!'],
#  ['Он',
#   'встал',
#   ',',
#   'прошелся',
#   'по',
#   'комнате',
#   'в',
#   'сильнейшем',
#   'волнении',
#   'и',
#   ',',
#   'дойдя',
#   'опять',
#   'до',
#   'дивана',
#   ',',
#   'бессильно',
#   'повалился',
#   'на',
#   'него',
#   '.'],
#  ['В',
#   'пятницу',
#   'утром',
#   'Петр',
#   'Степанович',
#   'уехал',
#   'куда-то',
#   'в',
#   'уезд',
#   'и',
#   'пробыл',
#   'до',
#   'понедельника',
#   '.'],
#  ['Об',
#   'отъезде',
#   'его',
#   'я',
#   'узнал',
#   'от',
#   'Липутина',
#   ',',
#   'и',
#   'тут',
#   'же',
#   ',',
#   'как-то',
#   'к',
#   'разговору',
#   ',',
#   'узнал',
#   'от',
#   'него',
#   ',',
#   'что',
#   'Лебядкины',
#   ',',
#   'братец',
#   'и',
#   'сестрица',
#   ',',
#   'оба',
#   'где-то',
#   'за',
#   'рекой',
#   ',',
#   'в',
#   'Горшечной',
#   'слободке',
#   '.'],
#  ['``',
#   'Я',
#   'же',
#   'и',
#   'перевозил',
#   "''",
#   ',',
#   'прибавил',
#   'Липутин',
#   ',',
#   'и',
#   ',',
#   'прервав',
#   'о',
#   'Лебядкиных',
#   ',',
#   'вдруг',
#   'возвестил',
#   'мне',
#   ',',
#   'что',
#   'Лизавета',
#   'Николаевна',
#   'выходит',
#   'за',
#   'Маврикия',
#   'Николаевича',
#   ',',
#   'и',
#   'хоть',
#   'это',
#   'и',
#   'не',
#   'объявлено',
#   ',',
#   'но',
#   'помолвка',
#   'была',
#   'и',
#   'дело',
#   'покончено',
#   '.'],
#  ['Назавтра',
#   'я',
#   'встретил',
#   'Лизавету',
#   'Николаевну',
#   'верхом',
#   'в',
#   'сопровождении',
#   'Маврикия',
#   'Николаевича',
#   ',',
#   'выехавшую',
#   'в',
#   'первый',
#   'раз',
#   'после',
#   'болезни',
#   '.'],
#  ['Она',
#   'сверкнула',
#   'на',
#   'меня',
#   'издали',
#   'глазами',
#   ',',
#   'засмеялась',
#   'и',
#   'очень',
#   'дружески',
#   'кивнула',
#   'головой',
#   '.'],
#  ['Все',
#   'это',
#   'я',
#   'передал',
#   'Степану',
#   'Трофимовичу',
#   ';',
#   'он',
#   'обратил',
#   'некоторое',
#   'внимание',
#   'лишь',
#   'на',
#   'известие',
#   'о',
#   'Лебядкиных',
#   '.'],
#  ['А',
#   'теперь',
#   ',',
#   'описав',
#   'наше',
#   'загадочное',
#   'положение',
#   'в',
#   'продолжение',
#   'этих',
#   'восьми',
#   'дней',
#   ',',
#   'когда',
#   'мы',
#   'еще',
#   'ничего',
#   'не',
#   'знали',
#   ',',
#   'приступлю',
#   'к',
#   'описанию',
#   'последующих',
#   'событий',
#   'моей',
#   'хроники',
#   ',',
#   'и',
#   'уже',
#   ',',
#   'так',
#   'сказать',
#   ',',
#   'с',
#   'знанием',
#   'дела',
#   ',',
#   'в',
#   'том',
#   'виде',
#   ',',
#   'как',
#   'все',
#   'это',
#   'открылось',
#   'и',
#   'объяснилось',
#   'теперь',
#   '.'],
#  ['Начну',
#   'именно',
#   'с',
#   'восьмого',
#   'дня',
#   'после',
#   'того',
#   'воскресенья',
#   ',',
#   'то-есть',
#   'с',
#   'понедельника',
#   'вечером',
#   '-',
#   'потому',
#   'что',
#   'в',
#   'сущности',
#   'с',
#   'этого',
#   'вечера',
#   'и',
#   'началась',
#   '``',
#   'новая',
#   'история',
#   "''",
#   '.'],
#  ['III', 'Было', 'семь', 'часов', 'вечера', '.'],
#  ['Николай',
#   'Всеволодович',
#   'сидел',
#   'один',
#   'в',
#   'своем',
#   'кабинете',
#   ',',
#   '-',
#   'комнате',
#   'им',
#   'еще',
#   'прежде',
#   'излюбленной',
#   ',',
#   'высокой',
#   ',',
#   'устланной',
#   'коврами',
#   ',',
#   'уставленной',
#   'несколько',
#   'тяжелою',
#   ',',
#   'старинного',
#   'фасона',
#   'мебелью',
#   '.'],
#  ['Он',
#   'сидел',
#   'в',
#   'углу',
#   'на',
#   'диване',
#   ',',
#   'одетый',
#   'как',
#   'бы',
#   'для',
#   'выхода',
#   ',',
#   'но',
#   ',',
#   'казалось',
#   ',',
#   'никуда',
#   'не',
#   'собирался',
#   ',',
#   'На',
#   'столе',
#   'пред',
#   'ним',
#   'стояла',
#   'лампа',
#   'с',
#   'абажуром',
#   '.'],
#  ['Бока', 'и', 'углы', 'большой', 'комнаты', 'оставались', 'в', 'тени', '.'],
#  ['Взгляд',
#   'его',
#   'был',
#   'задумчив',
#   'и',
#   'сосредоточен',
#   ',',
#   'не',
#   'совсем',
#   'спокоен',
#   ';',
#   'лицо',
#   'усталое',
#   'и',
#   'несколько',
#   'похудевшее',
#   '.'],
#  ['Болен',
#   'он',
#   'был',
#   'действительно',
#   'флюсом',
#   ';',
#   'но',
#   'слух',
#   'о',
#   'выбитом',
#   'зубе',
#   'был',
#   'преувеличен',
#   '.'],
#  ['Зуб',
#   'только',
#   'шатался',
#   ',',
#   'но',
#   'теперь',
#   'снова',
#   'окреп',
#   ';',
#   'была',
#   'тоже',
#   'рассечена',
#   'изнутри',
#   'верхняя',
#   'губа',
#   ',',
#   'но',
#   'и',
#   'это',
#   'зажило',
#   '.'],
#  ['Флюс',
#   'же',
#   'не',
#   'проходил',
#   'всю',
#   'неделю',
#   'лишь',
#   'потому',
#   ',',
#   'что',
#   'больной',
#   'не',
#   'хотел',
#   'принять',
#   'доктора',
#   'и',
#   'вовремя',
#   'дать',
#   'разрезать',
#   'опухоль',
#   ',',
#   'а',
#   'ждал',
#   ',',
#   'пока',
#   'нарыв',
#   'сам',
#   'прорвется',
#   '.'],
#  ['Он',
#   'не',
#   'только',
#   'доктора',
#   ',',
#   'но',
#   'и',
#   'мать',
#   'едва',
#   'допускал',
#   'к',
#   'себе',
#   ',',
#   'и',
#   'то',
#   'на',
#   'минуту',
#   ',',
#   'один',
#   'раз',
#   'на',
#   'дню',
#   'и',
#   'непременно',
#   'в',
#   'сумерки',
#   ',',
#   'когда',
#   'уже',
#   'становилось',
#   'темно',
#   ',',
#   'а',
#   'огня',
#   'еще',
#   'не',
#   'подавали',
#   '.'],
#  ['Не',
#   'принимал',
#   'он',
#   'тоже',
#   'и',
#   'Петра',
#   'Степановича',
#   ',',
#   'который',
#   'однако',
#   'же',
#   'по',
#   'два',
#   'и',
#   'по',
#   'три',
#   'раза',
#   'в',
#   'день',
#   'забегал',
#   'к',
#   'Варваре',
#   'Петровне',
#   ',',
#   'пока',
#   'оставался',
#   'в',
#   'городе',
#   '.'],
#  ['И',
#   'вот',
#   'наконец',
#   'в',
#   'понедельник',
#   ',',
#   'возвратясь',
#   'поутру',
#   'после',
#   'своей',
#   'трехдневной',
#   'отлучки',
#   ',',
#   'обегав',
#   'весь',
#   'город',
#   'и',
#   'отобедав',
#   'у',
#   'Юлии',
#   'Михайловны',
#   ',',
#   'Петр',
#   'Степанович',
#   'к',
#   'вечеру',
#   'явился',
#   'наконец',
#   'к',
#   'нетерпеливо',
#   'ожидавшей',
#   'его',
#   'Варваре',
#   'Петровне',
#   '.'],
#  ['Запрет', 'был', 'снят', ',', 'Николай', 'Всеволодович', 'принимал', '.'],
#  ['Варвара',
#   'Петровна',
#   'сама',
#   'подвела',
#   'гостя',
#   'к',
#   'дверям',
#   'кабинета',
#   ';',
#   'она',
#   'давно',
#   'желала',
#   'их',
#   'свиданья',
#   ',',
#   'а',
#   'Петр',
#   'Степанович',
#   'дал',
#   'ей',
#   'слово',
#   'забежать',
#   'к',
#   'ней',
#   'от',
#   'Nicolas',
#   'и',
#   'пересказать',
#   '.'],
#  ['Робко',
#   'постучалась',
#   'она',
#   'к',
#   'Николаю',
#   'Всеволодовичу',
#   'и',
#   ',',
#   'не',
#   'получая',
#   'ответа',
#   ',',
#   'осмелилась',
#   'приотворить',
#   'дверь',
#   'вершка',
#   'на',
#   'два',
#   '.'],
#  ['-',
#   'Nicolas',
#   ',',
#   'могу',
#   'я',
#   'ввести',
#   'к',
#   'тебе',
#   'Петра',
#   'Степановича',
#   '?'],
#  ['-',
#   'тихо',
#   'и',
#   'сдержанно',
#   'спросила',
#   'она',
#   ',',
#   'стараясь',
#   'разглядеть',
#   'Николая',
#   'Всеволодовича',
#   'из-за',
#   'лампы',
#   '.'],
#  ['-', 'Можно', ',', 'можно', ',', 'конечно', 'можно', '!'],
#  ['-',
#   'громко',
#   'и',
#   'весело',
#   'крикнул',
#   'сам',
#   'Петр',
#   'Степанович',
#   ',',
#   'отворил',
#   'дверь',
#   'своею',
#   'рукой',
#   'и',
#   'вошел',
#   '.'],
#  ['Николай',
#   'Всеволодович',
#   'не',
#   'слыхал',
#   'стука',
#   'в',
#   'дверь',
#   ',',
#   'а',
#   'расслышал',
#   'лишь',
#   'только',
#   'робкий',
#   'вопрос',
#   'мамаши',
#   ',',
#   'но',
#   'не',
#   'успел',
#   'на',
#   'него',
#   'ответить',
#   '.'],
#  ['Пред',
#   'ним',
#   'в',
#   'эту',
#   'минуту',
#   'лежало',
#   'только',
#   'что',
#   'прочитанное',
#   'им',
#   'письмо',
#   ',',
#   'над',
#   'которым',
#   'он',
#   'сильно',
#   'задумался',
#   '.'],
#  ['Он',
#   'вздрогнул',
#   ',',
#   'заслышав',
#   'внезапный',
#   'окрик',
#   'Петра',
#   'Степановича',
#   ',',
#   'и',
#   'поскорее',
#   'накрыл',
#   'письмо',
#   'попавшимся',
#   'под',
#   'руку',
#   'преспапье',
#   ',',
#   'но',
#   'не',
#   'совсем',
#   'удалось',
#   ':',
#   'угол',
#   'письма',
#   'и',
#   'почти',
#   'весь',
#   'конверт',
#   'выглядывали',
#   'наружу',
#   '.'],
#  ['-',
#   'Я',
#   'нарочно',
#   'крикнул',
#   'изо',
#   'всей',
#   'силы',
#   ',',
#   'чтобы',
#   'вы',
#   'успели',
#   'приготовиться',
#   ',',
#   '-',
#   'торопливо',
#   'с',
#   'удивительною',
#   'наивностью',
#   'прошептал',
#   'Петр',
#   'Степанович',
#   ',',
#   'подбегая',
#   'к',
#   'столу',
#   ',',
#   'и',
#   'мигом',
#   'уставился',
#   'на',
#   'преспапье',
#   'и',
#   'на',
#   'угол',
#   'письма',
#   '.'],
#  ['-',
#   'И',
#   'конечно',
#   'успели',
#   'подглядеть',
#   ',',
#   'как',
#   'я',
#   'прятал',
#   'от',
#   'вас',
#   'под',
#   'преспапье',
#   'только',
#   'что',
#   'полученное',
#   'мною',
#   'письмо',
#   ',',
#   '-',
#   'спокойно',
#   'проговорил',
#   'Николай',
#   'Всеволодович',
#   ',',
#   'не',
#   'трогаясь',
#   'с',
#   'места',
#   '.'],
#  ['-', 'Письмо', '?'],
#  ['Бог', 'с', 'вами', 'и', 'с', 'вашим', 'письмом', ',', 'мне', 'что', '!'],
#  ['-',
#   'воскликнул',
#   'гость',
#   ',',
#   '-',
#   'но',
#   '...',
#   'главное',
#   ',',
#   '-',
#   'зашептал',
#   'он',
#   'опять',
#   ',',
#   'обертываясь',
#   'к',
#   'двери',
#   ',',
#   'уже',
#   'запертой',
#   ',',
#   'и',
#   'кивая',
#   'в',
#   'ту',
#   'сторону',
#   'головой',
#   '.'],
#  ['-',
#   'Она',
#   'никогда',
#   'не',
#   'подслушивает',
#   ',',
#   '-',
#   'холодно',
#   'заметил',
#   'Николай',
#   'Всеволодович',
#   '.'],
#  ['-', 'То-есть', 'если', 'б', 'и', 'подслушивала', '!'],
#  ['-',
#   'мигом',
#   'подхватил',
#   ',',
#   'весело',
#   'возвышая',
#   'голос',
#   'и',
#   'усаживаясь',
#   'в',
#   'кресло',
#   ',',
#   'Петр',
#   'Степанович',
#   '.'],
#  ['-',
#   'Я',
#   'ничего',
#   'против',
#   'этого',
#   ',',
#   'я',
#   'только',
#   'теперь',
#   'бежал',
#   'поговорить',
#   'наедине',
#   '...',
#   'Ну',
#   ',',
#   'наконец-то',
#   'я',
#   'к',
#   'вам',
#   'добился',
#   '!'],
#  ['Прежде', 'всего', 'как', 'здоровье', '?'],
#  ['Вижу',
#   ',',
#   'что',
#   'прекрасно',
#   ',',
#   'и',
#   'завтра',
#   ',',
#   'может',
#   'быть',
#   ',',
#   'вы',
#   'явитесь',
#   ',',
#   '-',
#   'а',
#   '?'],
#  ['-', 'Может', 'быть', '.'],
#  ['-', 'Разрешите', 'их', 'наконец', ',', 'разрешите', 'меня', '!'],
#  ['-',
#   'неистово',
#   'зажестикулировал',
#   'он',
#   'с',
#   'шутливым',
#   'и',
#   'приятным',
#   'видом',
#   '.'],
#  ['-',
#   'Если',
#   'б',
#   'вы',
#   'знали',
#   ',',
#   'что',
#   'я',
#   'должен',
#   'был',
#   'им',
#   'наболтать',
#   '.'],
#  ['А', 'впрочем', 'вы', 'знаете', '.'],
#  ['-', 'Он', 'засмеялся', '.'],
#  ['-', 'Всего', 'не', 'знаю', '.'],
#  ['Я',
#   'слышал',
#   'только',
#   'от',
#   'матери',
#   ',',
#   'что',
#   'вы',
#   'очень',
#   '...',
#   'двигались',
#   '.'],
#  ['-',
#   'То-есть',
#   'я',
#   'ведь',
#   'ничего',
#   'определенного',
#   ',',
#   '-',
#   'вскинулся',
#   'вдруг',
#   'Петр',
#   'Степанович',
#   ',',
#   'как',
#   'бы',
#   'защищаясь',
#   'от',
#   'ужасного',
#   'нападения',
#   ',',
#   '-',
#   'знаете',
#   ',',
#   'я',
#   'пустил',
#   'в',
#   'ход',
#   'жену',
#   'Шатова',
#   ',',
#   'то-есть',
#   'слухи',
#   'о',
#   'ваших',
#   'связях',
#   'в',
#   'Париже',
#   ',',
#   'чем',
#   'и',
#   'объяснялся',
#   'конечно',
#   'тот',
#   'случай',
#   'в',
#   'воскресенье',
#   '...',
#   'вы',
#   'не',
#   'сердитесь',
#   '?'],
#  ['-', 'Убежден', ',', 'что', 'вы', 'очень', 'старались', '.'],
#  ['-', 'Ну', ',', 'я', 'только', 'этого', 'и', 'боялся', '.'],
#  ['А',
#   'впрочем',
#   'что',
#   'ж',
#   'это',
#   'значит',
#   ':',
#   '``',
#   'очень',
#   'старались',
#   "''",
#   '?'],
#  ['Это', 'ведь', 'упрек', '.'],
#  ['Впрочем',
#   'вы',
#   'прямо',
#   'ставите',
#   ',',
#   'я',
#   'всего',
#   'больше',
#   'боялся',
#   ',',
#   'идя',
#   'сюда',
#   ',',
#   'что',
#   'вы',
#   'не',
#   'захотите',
#   'прямо',
#   'поставить',
#   '.'],
#  ['-',
#   'Я',
#   'ничего',
#   'и',
#   'не',
#   'хочу',
#   'прямо',
#   'ставить',
#   ',',
#   '-',
#   'проговорил',
#   'Николай',
#   'Всеволодович',
#   'с',
#   'некоторым',
#   'раздражением',
#   ',',
#   'но',
#   'тотчас',
#   'же',
#   'усмехнулся',
#   '.'],
#  ['-',
#   'Я',
#   'не',
#   'про',
#   'то',
#   ';',
#   'не',
#   'про',
#   'то',
#   ',',
#   'не',
#   'ошибитесь',
#   ',',
#   'не',
#   'про',
#   'то',
#   '!'],
#  ['-',
#   'замахал',
#   'руками',
#   'Петр',
#   'Степанович',
#   ',',
#   'сыпля',
#   'словами',
#   'как',
#   'горохом',
#   'и',
#   'тотчас',
#   'же',
#   'обрадовавшись',
#   'раздражительности',
#   'хозяина',
#   '.'],
#  ['-',
#   'Я',
#   'не',
#   'стану',
#   'вас',
#   'раздражать',
#   'нашим',
#   'делом',
#   ',',
#   'особенно',
#   'в',
#   'вашем',
#   'теперешнем',
#   'положении',
#   '.'],
#  ['Я',
#   'прибежал',
#   'только',
#   'о',
#   'воскресном',
#   'случае',
#   ',',
#   'и',
#   'то',
#   'в',
#   'самую',
#   'необходимую',
#   'меру',
#   ',',
#   'потому',
#   'нельзя',
#   'же',
#   'ведь',
#   '.'],
#  ['Я',
#   'с',
#   'самыми',
#   'открытыми',
#   'объяснениями',
#   ',',
#   'в',
#   'которых',
#   'нуждаюсь',
#   'главное',
#   'я',
#   ',',
#   'а',
#   'не',
#   'вы',
#   ',',
#   '-',
#   'это',
#   'для',
#   'вашего',
#   'самолюбия',
#   ',',
#   'но',
#   'в',
#   'то',
#   'же',
#   'время',
#   'это',
#   'и',
#   'правда',
#   '.'],
#  ['Я',
#   'пришел',
#   ',',
#   'чтобы',
#   'быть',
#   'с',
#   'этих',
#   'пор',
#   'всегда',
#   'откровенным',
#   '.'],
#  ['-', 'Стало', 'быть', ',', 'прежде', 'были', 'неоткровенны', '?'],
#  ['-', 'И', 'вы', 'это', 'знаете', 'сами', '.'],
#  ['Я',
#   'хитрил',
#   'много',
#   'раз',
#   '...',
#   'вы',
#   'улыбнулись',
#   ',',
#   'очень',
#   'рад',
#   'улыбке',
#   ',',
#   'как',
#   'предлогу',
#   'для',
#   'разъяснения',
#   ';',
#   'я',
#   'ведь',
#   'нарочно',
#   'вызвал',
#   'улыбку',
#   'хвастливым',
#   'словом',
#   '``',
#   'хитрил',
#   "''",
#   ',',
#   'для',
#   'того',
#   ',',
#   'чтобы',
#   'вы',
#   'тотчас',
#   'же',
#   'и',
#   'рассердились',
#   ':',
#   'как',
#   'это',
#   'я',
#   'смел',
#   'подумать',
#   ',',
#   'что',
#   'могу',
#   'хитрить',
#   ',',
#   'а',
#   'мне',
#   ',',
#   'чтобы',
#   'сейчас',
#   'же',
#   'объясниться',
#   '.'],
#  ['Видите',
#   ',',
#   'видите',
#   ',',
#   'как',
#   'я',
#   'стал',
#   'теперь',
#   'откровенен',
#   '!'],
#  ['Ну-с', ',', 'угодно', 'вам', 'выслушать', '?'],
#  ['В',
#   'выражении',
#   'лица',
#   'Николая',
#   'Всеволодовича',
#   ',',
#   'презрительно',
#   'спокойном',
#   'и',
#   'даже',
#   'насмешливом',
#   ',',
#   'несмотря',
#   'на',
#   'все',
#   'очевидное',
#   'желание',
#   'гостя',
#   'раздражить',
#   'хозяина',
#   'нахальностию',
#   'своих',
#   'заранее',
#   'наготовленных',
#   'и',
#   'с',
#   'намерением',
#   'грубых',
#   'наивностей',
#   ',',
#   '-',
#   'выразилось',
#   'наконец',
#   'несколько',
#   'тревожное',
#   'любопытство',
#   '.'],
#  ['-',
#   'Слушайте',
#   'же',
#   ',',
#   '-',
#   'завертелся',
#   'Петр',
#   'Степанович',
#   'пуще',
#   'прежнего',
#   '.'],
#  ['-',
#   'Отправляясь',
#   'сюда',
#   ',',
#   'то-есть',
#   'вообще',
#   'сюда',
#   ',',
#   'в',
#   'этот',
#   'город',
#   ',',
#   'десять',
#   'дней',
#   'назад',
#   ',',
#   'я',
#   'конечно',
#   'решился',
#   'взять',
#   'роль',
#   '.'],
#  ['Самое',
#   'бы',
#   'лучшее',
#   'совсем',
#   'без',
#   'роли',
#   ',',
#   'свое',
#   'собственное',
#   'лицо',
#   ',',
#   'не',
#   'так',
#   'ли',
#   '?'],
#  ['Ничего',
#   'нет',
#   'хитрее',
#   ',',
#   'как',
#   'собственное',
#   'лицо',
#   ',',
#   'потому',
#   'что',
#   'никто',
#   'не',
#   'поверит',
#   '.'],
#  ['Я',
#   ',',
#   'признаться',
#   ',',
#   'хотел',
#   'было',
#   'взять',
#   'дурачка',
#   ',',
#   'потому',
#   'что',
#   'дурачек',
#   'легче',
#   ',',
#   'чем',
#   'собственное',
#   'лицо',
#   ';',
#   'но',
#   'так',
#   'как',
#   'дурачек',
#   'все-таки',
#   'крайность',
#   ',',
#   'а',
#   'крайность',
#   'возбуждает',
#   'любопытство',
#   ',',
#   'то',
#   'я',
#   'и',
#   'остановился',
#   'на',
#   'собственном',
#   'лице',
#   'окончательно',
#   '.'],
#  ['Ну-с', ',', 'какое', 'же', 'мое', 'собственное', 'лицо', '?'],
#  ['Золотая',
#   'средина',
#   ':',
#   'ни',
#   'глуп',
#   ',',
#   'ни',
#   'умен',
#   ',',
#   'довольно',
#   'бездарен',
#   'и',
#   'с',
#   'луны',
#   'соскочил',
#   ',',
#   'как',
#   'говорят',
#   'здесь',
#   'благоразумные',
#   'люди',
#   ',',
#   'не',
#   'так',
#   'ли',
#   '?'],
#  ['-',
#   'Что',
#   'ж',
#   ',',
#   'может',
#   'быть',
#   'и',
#   'так',
#   ',',
#   '-',
#   'чуть-чуть',
#   'улыбнулся',
#   'Николай',
#   'Всеволодович',
#   '.'],
#  ['-',
#   'А',
#   ',',
#   'вы',
#   'согласны',
#   '-',
#   'очень',
#   'рад',
#   ';',
#   'я',
#   'знал',
#   'вперед',
#   ',',
#   'что',
#   'это',
#   'ваши',
#   'собственные',
#   'мысли',
#   '...',
#   'Не',
#   'беспокойтесь',
#   ',',
#   'не',
#   'беспокойтесь',
#   ',',
#   'я',
#   'не',
#   'сержусь',
#   'и',
#   'вовсе',
#   'не',
#   'для',
#   'того',
#   'определил',
#   'себя',
#   'в',
#   'таком',
#   'виде',
#   ',',
#   'чтобы',
#   'вызвать',
#   'ваши',
#   'обратные',
#   'похвалы',
#   ':',
#   '``',
#   'нет',
#   ',',
#   'дескать',
#   ',',
#   'вы',
#   'не',
#   'бездарны',
#   ',',
#   'нет',
#   ',',
#   'дескать',
#   ',',
#   'вы',
#   'умны',
#   "''",
#   '...',
#   'А',
#   ',',
#   'вы',
#   'опять',
#   'улыбаетесь',
#   '!',
#   '..'],
#  ['Я', 'опять', 'попался', '.'],
#  ['Вы',
#   'не',
#   'сказали',
#   'бы',
#   ':',
#   '``',
#   'вы',
#   'умны',
#   "''",
#   ',',
#   'ну',
#   'и',
#   'положим',
#   ';',
#   'я',
#   'все',
#   'допускаю',
#   '.'],
#  ['Passons',
#   ',',
#   'как',
#   'говорит',
#   'папаша',
#   ',',
#   'и',
#   ',',
#   'в',
#   'скобках',
#   ',',
#   'не',
#   'сердитесь',
#   'на',
#   'мое',
#   'многословие',
#   '.'],
#  ['Кстати',
#   'вот',
#   'и',
#   'пример',
#   ':',
#   'я',
#   'всегда',
#   'говорю',
#   'много',
#   ',',
#   'то-есть',
#   'много',
#   'слов',
#   ',',
#   'и',
#   'тороплюсь',
#   ',',
#   'и',
#   'у',
#   'меня',
#   'всегда',
#   'не',
#   'выходит',
#   '.'],
#  ['А',
#   'почему',
#   'я',
#   'говорю',
#   'много',
#   'слов',
#   'и',
#   'у',
#   'меня',
#   'не',
#   'выходит',
#   '?'],
#  ['Потому', 'что', 'говорить', 'не', 'умею', '.'],
#  ['Те',
#   ',',
#   'которые',
#   'умеют',
#   'хорошо',
#   'говорить',
#   ',',
#   'те',
#   'коротко',
#   'говорят',
#   '.'],
#  ['Вот',
#   ',',
#   'стало',
#   'быть',
#   ',',
#   'у',
#   'меня',
#   'и',
#   'бездарность',
#   ',',
#   '-',
#   'не',
#   'правда',
#   'ли',
#   '?'],
#  ['Но',
#   'так',
#   'как',
#   'этот',
#   'дар',
#   'бездарности',
#   'у',
#   'меня',
#   'уже',
#   'есть',
#   'натуральный',
#   ',',
#   'так',
#   'почему',
#   'мне',
#   'им',
#   'не',
#   'воспользоваться',
#   'искусственно',
#   '?'],
#  ['Я', 'и', 'пользуюсь', '.'],
#  ['Правда',
#   ',',
#   'собираясь',
#   'сюда',
#   ',',
#   'я',
#   'было',
#   'подумал',
#   'сначала',
#   'молчать',
#   ';',
#   'но',
#   'ведь',
#   'молчать',
#   '-',
#   'большой',
#   'талант',
#   ',',
#   'и',
#   ',',
#   'стало',
#   'быть',
#   ',',
#   'мне',
#   'неприлично',
#   ',',
#   'а',
#   'во-вторых',
#   ',',
#   'молчать',
#   'все-таки',
#   'ведь',
#   'опасно',
#   ';',
#   'ну',
#   'я',
#   'и',
#   'решил',
#   'окончательно',
#   ',',
# ...
#   ',',
#   'Кириллова',
#   ',',
#   'ядом',
#   '...',
#   'Вы',
#   'утверждали',
#   'в',
#   'нем',
#   'ложь',
#   'и',
#   'клевету',
#   'и',
#   'довели',
#   'разум',
#   'его',
#   'до',
#   'исступления',
#   '...',
#   'Подите',
#   ',',
#   'взгляните',
#   'на',
#   'него',
#   'теперь',
#   ',',
#   'это',
#   'ваше',
#   'создание',
#   '...',
#   'Впрочем',
#   'вы',
#   'видели',
#   '.'],
#  ['-',
#   'Во-первых',
#   ',',
#   'замечу',
#   'вам',
#   ',',
#   'что',
#   'сам',
#   'Кириллов',
#   'сейчас',
#   'только',
#   'сказал',
#   'мне',
#   ',',
#   'что',
#   'он',
#   'счастлив',
#   'и',
#   'что',
#   'он',
#   'прекрасен',
#   '.'],
#  ['Ваше',
#   'предположение',
#   'о',
#   'том',
#   ',',
#   'что',
#   'все',
#   'это',
#   'произошло',
#   'в',
#   'одно',
#   'и',
#   'то',
#   'же',
#   'время',
#   ',',
#   'почти',
#   'верно',
#   ';',
#   'ну',
#   ',',
#   'и',
#   'что',
#   'же',
#   'из',
#   'всего',
#   'этого',
#   '?'],
#  ['Повторяю',
#   ',',
#   'я',
#   'вас',
#   'ни',
#   'того',
#   ',',
#   'ни',
#   'другого',
#   'не',
#   'обманывал',
#   '.'],
#  ['-', 'Вы', 'атеист', '?'],
#  ['Теперь', 'атеист', '?'],
#  ['-', 'Да', '.'],
#  ['-', 'А', 'тогда', '?'],
#  ['-', 'Точно', 'так', 'же', ',', 'как', 'и', 'тогда', '.'],
#  ['-',
#   'Я',
#   'не',
#   'к',
#   'себе',
#   'просил',
#   'у',
#   'вас',
#   'уважения',
#   ',',
#   'начиная',
#   'разговор',
#   ';',
#   'с',
#   'вашим',
#   'умом',
#   ',',
#   'вы',
#   'бы',
#   'могли',
#   'понять',
#   'это',
#   ',',
#   '-',
#   'в',
#   'негодовании',
#   'пробормотал',
#   'Шатов',
#   '.'],
#  ['-',
#   'Я',
#   'не',
#   'встал',
#   'с',
#   'первого',
#   'вашего',
#   'слова',
#   ',',
#   'не',
#   'закрыл',
#   'разговора',
#   ',',
#   'не',
#   'ушел',
#   'от',
#   'вас',
#   ',',
#   'а',
#   'сижу',
#   'до',
#   'сих',
#   'пор',
#   'и',
#   'смирно',
#   'отвечаю',
#   'на',
#   'ваши',
#   'вопросы',
#   'и',
#   '...',
#   'крики',
#   ',',
#   'стало',
#   'быть',
#   ',',
#   'не',
#   'нарушил',
#   'еще',
#   'к',
#   'вам',
#   'уважения',
#   '.'],
#  ['Шатов',
#   'прервал',
#   ',',
#   'махнув',
#   'рукой',
#   ':',
#   '-',
#   'Вы',
#   'помните',
#   'выражение',
#   'ваше',
#   ':',
#   '``',
#   'атеист',
#   'не',
#   'может',
#   'быть',
#   'русским',
#   "''",
#   ',',
#   '``',
#   'атеист',
#   'тотчас',
#   'же',
#   'перестает',
#   'быть',
#   'русским',
#   "''",
#   ',',
#   'помните',
#   'это',
#   '?'],
#  ['-', 'Да', '?'],
#  ['-', 'как', 'бы', 'переспросил', 'Николай', 'Всеволодович', '.'],
#  ['-', 'Вы', 'спрашиваете', '?'],
#  ['Вы', 'забыли', '?'],
#  ['А',
#   'между',
#   'тем',
#   'это',
#   'одно',
#   'из',
#   'самых',
#   'точнейших',
#   'указаний',
#   'на',
#   'одну',
#   'из',
#   'главнейших',
#   'особенностей',
#   'русского',
#   'духа',
#   ',',
#   'вами',
#   'угаданную',
#   '.'],
#  ['Не', 'могли', 'вы', 'этого', 'забыть', '?'],
#  ['Я',
#   'напомню',
#   'вам',
#   'больше',
#   ',',
#   '-',
#   'высказали',
#   'тогда',
#   'же',
#   ':',
#   '``',
#   'не',
#   'православный',
#   'не',
#   'может',
#   'быть',
#   'русским',
#   "''",
#   '.'],
#  ['-', 'Я', 'полагаю', ',', 'что', 'это', 'славянофильская', 'мысль', '.'],
#  ['-', 'Нет', ';', 'нынешние', 'славянофилы', 'от', 'нее', 'откажутся', '.'],
#  ['Нынче', 'народ', 'поумнел', '.'],
#  ['Но',
#   'вы',
#   'еще',
#   'дальше',
#   'шли',
#   ':',
#   'вы',
#   'веровали',
#   ',',
#   'что',
#   'римский',
#   'католицизм',
#   'уже',
#   'не',
#   'есть',
#   'христианство',
#   ';',
#   'вы',
#   'утверждали',
#   ',',
#   'что',
#   'Рим',
#   'провозгласил',
#   'Христа',
#   ',',
#   'поддавшегося',
#   'на',
#   'третье',
#   'дьяволово',
#   'искушение',
#   ',',
#   'и',
#   'что',
#   ',',
#   'возвестив',
#   'всему',
#   'свету',
#   ',',
#   'что',
#   'Христос',
#   'без',
#   'царства',
#   'земного',
#   'на',
#   'земле',
#   'устоять',
#   'не',
#   'может',
#   ',',
#   'католичество',
#   'тем',
#   'самым',
#   'провозгласило',
#   'антихриста',
#   'и',
#   'тем',
#   'погубило',
#   'весь',
#   'западный',
#   'мир.',
#   'Вы',
#   'именно',
#   'указывали',
#   ',',
#   'что',
#   'если',
#   'мучается',
#   'Франция',
#   ',',
#   'то',
#   'единственно',
#   'по',
#   'вине',
#   'католичества',
#   ',',
#   'ибо',
#   'отвергла',
#   'смрадного',
#   'бога',
#   'римского',
#   ',',
#   'а',
#   'нового',
#   'не',
#   'сыскала',
#   '.'],
#  ['Вот', 'что', 'вы', 'тогда', 'могли', 'говорить', '!'],
#  ['Я', 'помню', 'наши', 'разговоры', '.'],
#  ['-',
#   'Если',
#   'б',
#   'я',
#   'веровал',
#   ',',
#   'то',
#   ',',
#   'без',
#   'сомнения',
#   ',',
#   'повторил',
#   'бы',
#   'это',
#   'и',
#   'теперь',
#   ';',
#   'я',
#   'не',
#   'лгал',
#   ',',
#   'говоря',
#   'как',
#   'верующий',
#   ',',
#   '-',
#   'очень',
#   'серьезно',
#   'произнес',
#   'Николай',
#   'Всеволодович',
#   '.'],
#  ['-',
#   'Но',
#   'уверяю',
#   'вас',
#   ',',
#   'что',
#   'на',
#   'меня',
#   'производит',
#   'слишком',
#   'неприятное',
#   'впечатление',
#   'это',
#   'повторение',
#   'прошлых',
#   'мыслей',
#   'моих',
#   '.'],
#  ['Не', 'можете', 'ли', 'вы', 'перестать', '?'],
#  ['-', 'Если', 'бы', 'веровали', '?'],
#  ['-',
#   'вскричал',
#   'Шатов',
#   ',',
#   'не',
#   'обратив',
#   'ни',
#   'малейшего',
#   'внимания',
#   'на',
#   'просьбу',
#   '.'],
#  ['-',
#   'Но',
#   'не',
#   'вы',
#   'ли',
#   'говорили',
#   'мне',
#   ',',
#   'что',
#   'если',
#   'бы',
#   'математически',
#   'доказали',
#   'вам',
#   ',',
#   'что',
#   'истина',
#   'вне',
#   'Христа',
#   ',',
#   'то',
#   'вы',
#   'бы',
#   'согласились',
#   'лучше',
#   'остаться',
#   'со',
#   'Христом',
#   ',',
#   'нежели',
#   'с',
#   'истиной',
#   '?'],
#  ['Говорили', 'вы', 'это', '?'],
#  ['Говорили', '?'],
#  ['-',
#   'Но',
#   'позвольте',
#   'же',
#   'и',
#   'мне',
#   'наконец',
#   'спросить',
#   ',',
#   '-',
#   'возвысил',
#   'голос',
#   'Ставрогин',
#   ',',
#   '-',
#   'к',
#   'чему',
#   'ведет',
#   'весь',
#   'этот',
#   'нетерпеливый',
#   'и',
#   '...',
#   'злобный',
#   'экзамен',
#   '?'],
#  ['-',
#   'Этот',
#   'экзамен',
#   'пройдет',
#   'навеки',
#   'и',
#   'никогда',
#   'больше',
#   'не',
#   'напомнится',
#   'вам',
#   '.'],
#  ['-',
#   'Вы',
#   'все',
#   'настаиваете',
#   ',',
#   'что',
#   'мы',
#   'вне',
#   'пространства',
#   'и',
#   'времени',
#   '...',
#   '-',
#   'Молчите',
#   '!'],
#  ['-',
#   'вдруг',
#   'крикнул',
#   'Шатов',
#   ',',
#   '-',
#   'я',
#   'глуп',
#   'и',
#   'неловок',
#   ',',
#   'но',
#   'погибай',
#   'мое',
#   'имя',
#   'в',
#   'смешном',
#   '!'],
#  ['Дозволите',
#   'ли',
#   'вы',
#   'мне',
#   'повторить',
#   'пред',
#   'вами',
#   'всю',
#   'главную',
#   'вашу',
#   'тогдашнюю',
#   'мысль',
#   '...',
#   'О',
#   ',',
#   'только',
#   'десять',
#   'строк',
#   ',',
#   'одно',
#   'заключение',
#   '.'],
#  ['-',
#   'Повторите',
#   ',',
#   'если',
#   'только',
#   'одно',
#   'заключение',
#   '...',
#   'Ставрогин',
#   'сделал',
#   'было',
#   'движение',
#   'взглянуть',
#   'на',
#   'часы',
#   ',',
#   'но',
#   'удержался',
#   'и',
#   'не',
#   'взглянул',
#   '.'],
#  ['Шатов',
#   'принагнулся',
#   'опять',
#   'на',
#   'стуле',
#   'и',
#   ',',
#   'на',
#   'мгновение',
#   ',',
#   'даже',
#   'опять',
#   'было',
#   'поднял',
#   'палец',
#   '.'],
#  ['-',
#   'Ни',
#   'один',
#   'народ',
#   ',',
#   '-',
#   'начал',
#   'он',
#   ',',
#   'как',
#   'бы',
#   'читая',
#   'по',
#   'строкам',
#   'и',
#   'в',
#   'то',
#   'же',
#   'время',
#   'продолжая',
#   'грозно',
#   'смотреть',
#   'на',
#   'Ставрогина',
#   ',',
#   '-',
#   'ни',
#   'один',
#   'народ',
#   'еще',
#   'не',
#   'устраивался',
#   'на',
#   'началах',
#   'науки',
#   'и',
#   'разума',
#   ';',
#   'не',
#   'было',
#   'ни',
#   'разу',
#   'такого',
#   'примера',
#   ',',
#   'разве',
#   'на',
#   'одну',
#   'минуту',
#   ',',
#   'по',
#   'глупости',
#   '.'],
#  ['Социализм',
#   'по',
#   'существу',
#   'своему',
#   'уже',
#   'должен',
#   'быть',
#   'атеизмом',
#   ',',
#   'ибо',
#   'именно',
#   'провозгласил',
#   ',',
#   'с',
#   'самой',
#   'первой',
#   'строки',
#   ',',
#   'что',
#   'он',
#   'установление',
#   'атеистическое',
#   'и',
#   'намерен',
#   'устроиться',
#   'на',
#   'началах',
#   'науки',
#   'и',
#   'разума',
#   'исключительно',
#   '.'],
#  ['Разум',
#   'и',
#   'наука',
#   'в',
#   'жизни',
#   'народов',
#   'всегда',
#   ',',
#   'теперь',
#   'и',
#   'с',
#   'начала',
#   'веков',
#   ',',
#   'исполняли',
#   'лишь',
#   'должность',
#   'второстепенную',
#   'и',
#   'служебную',
#   ';',
#   'так',
#   'и',
#   'будут',
#   'исполнять',
#   'до',
#   'конца',
#   'веков',
#   '.'],
#  ['Народы',
#   'слагаются',
#   'и',
#   'движутся',
#   'силой',
#   'иною',
#   ',',
#   'повелевающею',
#   'и',
#   'господствующею',
#   ',',
#   'но',
#   'происхождение',
#   'которой',
#   'неизвестно',
#   'и',
#   'необъяснимо',
#   '.'],
#  ['Эта',
#   'сила',
#   'есть',
#   'сила',
#   'неутолимого',
#   'желания',
#   'дойти',
#   'до',
#   'конца',
#   'и',
#   'в',
#   'то',
#   'же',
#   'время',
#   'конец',
#   'отрицающая',
#   '.'],
#  ['Это',
#   'есть',
#   'сила',
#   'беспрерывного',
#   'и',
#   'неустанного',
#   'подтверждения',
#   'своего',
#   'бытия',
#   'и',
#   'отрицания',
#   'смерти',
#   '.'],
#  ['Дух',
#   'жизни',
#   ',',
#   'как',
#   'говорит',
#   'писание',
#   ',',
#   '``',
#   'реки',
#   'воды',
#   'живой',
#   "''",
#   ',',
#   'иссякновением',
#   'которых',
#   'так',
#   'угрожает',
#   'Апокалипсис',
#   '.'],
#  ['Начало',
#   'эстетическое',
#   ',',
#   'как',
#   'говорят',
#   'философы',
#   ',',
#   'начало',
#   'нравственное',
#   ',',
#   'как',
#   'отожествляют',
#   'они',
#   'же',
#   '.'],
#  ['``',
#   'Искание',
#   'бога',
#   "''",
#   ',',
#   'как',
#   'называю',
#   'я',
#   'всего',
#   'проще',
#   '.'],
#  ['Цель',
#   'всего',
#   'движения',
#   'народного',
#   ',',
#   'во',
#   'всяком',
#   'народе',
#   'и',
#   'во',
#   'всякий',
#   'период',
#   'его',
#   'бытия',
#   ',',
#   'есть',
#   'единственно',
#   'лишь',
#   'искание',
#   'бога',
#   ',',
#   'бога',
#   'своего',
#   ',',
#   'непременно',
#   'собственного',
#   ',',
#   'и',
#   'вера',
#   'в',
#   'него',
#   'как',
#   'в',
#   'единого',
#   'истинного',
#   '.'],
#  ['Бог',
#   'есть',
#   'синтетическая',
#   'личность',
#   'всего',
#   'народа',
#   ',',
#   'взятого',
#   'с',
#   'начала',
#   'его',
#   'и',
#   'до',
#   'конца',
#   '.'],
#  ['Никогда',
#   'еще',
#   'не',
#   'было',
#   ',',
#   'чтоб',
#   'у',
#   'всех',
#   'или',
#   'у',
#   'многих',
#   'народов',
#   'был',
#   'один',
#   'общий',
#   'бог',
#   ',',
#   'но',
#   'всегда',
#   'и',
#   'у',
#   'каждого',
#   'был',
#   'особый',
#   '.'],
#  ['Признак',
#   'уничтожения',
#   'народностей',
#   ',',
#   'когда',
#   'боги',
#   'начинают',
#   'становиться',
#   'общими',
#   '.'],
#  ['Когда',
#   'боги',
#   'становятся',
#   'общими',
#   ',',
#   'то',
#   'умирают',
#   'боги',
#   'и',
#   'вера',
#   'в',
#   'них',
#   'вместе',
#   'с',
#   'самими',
#   'народами',
#   '.'],
#  ['Чем', 'сильнее', 'народ', ',', 'тем', 'особливее', 'его', 'бог', '.'],
#  ['Никогда',
#   'еще',
#   'не',
#   'было',
#   'народа',
#   'без',
#   'религии',
#   ',',
#   'то-есть',
#   'без',
#   'понятия',
#   'о',
#   'зле',
#   'и',
#   'добре',
#   '.'],
#  ['У',
#   'всякого',
#   'народа',
#   'свое',
#   'собственное',
#   'понятие',
#   'о',
#   'зле',
#   'и',
#   'добре',
#   'и',
#   'свое',
#   'собственное',
#   'зло',
#   'и',
#   'добро',
#   '.'],
#  ['Когда',
#   'начинают',
#   'у',
#   'многих',
#   'народов',
#   'становиться',
#   'общими',
#   'понятия',
#   'о',
#   'зле',
#   'и',
#   'добре',
#   ',',
#   'тогда',
#   'вымирают',
#   'народы',
#   ',',
#   'и',
#   'тогда',
#   'самое',
#   'различие',
#   'между',
#   'злом',
#   'и',
#   'добром',
#   'начинает',
#   'стираться',
#   'и',
#   'исчезать',
#   '.'],
#  ['Никогда',
#   'разум',
#   'не',
#   'в',
#   'силах',
#   'был',
#   'определить',
#   'зло',
#   'и',
#   'добро',
#   ',',
#   'или',
#   'даже',
#   'отделить',
#   'зло',
#   'от',
#   'добра',
#   ',',
#   'хотя',
#   'приблизительно',
#   ';',
#   'напротив',
#   ',',
#   'всегда',
#   'позорно',
#   'и',
#   'жалко',
#   'смешивал',
#   ';',
#   'наука',
#   'же',
#   'давала',
#   'разрешения',
#   'кулачные',
#   '.'],
#  ['В',
#   'особенности',
#   'этим',
#   'отличалась',
#   'полунаука',
#   ',',
#   'самый',
#   'страшный',
#   'бич',
#   'человечества',
#   ',',
#   'хуже',
#   'мора',
#   ',',
#   'голода',
#   'и',
#   'войны',
#   ',',
#   'не',
#   'известный',
#   'до',
#   'нынешнего',
#   'столетия',
#   '.'],
#  ['Полунаука',
#   '-',
#   'это',
#   'деспот',
#   ',',
#   'каких',
#   'еще',
#   'не',
#   'приходило',
#   'до',
#   'сих',
#   'пор',
#   'никогда',
#   '.'],
#  ['Деспот',
#   ',',
#   'имеющий',
#   'своих',
#   'жрецов',
#   'и',
#   'рабов',
#   ',',
#   'деспот',
#   ',',
#   'пред',
#   'которым',
#   'все',
#   'преклонилось',
#   'с',
#   'любовью',
#   'и',
#   'суеверием',
#   ',',
#   'до',
#   'сих',
#   'пор',
#   'немыслимым',
#   ',',
#   'пред',
#   'которым',
#   'трепещет',
#   'даже',
#   'сама',
#   'наука',
#   'и',
#   'постыдно',
#   'потакает',
#   'ему',
#   '.'],
#  ['Все',
#   'это',
#   'ваши',
#   'собственные',
#   'слова',
#   ',',
#   'Ставрогин',
#   ',',
#   'кроме',
#   'только',
#   'слов',
#   'о',
#   'полунауке',
#   ';',
#   'эти',
#   'мои',
#   ',',
#   'потому',
#   'что',
#   'я',
#   'сам',
#   'только',
#   'полунаука',
#   ',',
#   'а',
#   'стало',
#   'быть',
#   ',',
#   'особенно',
#   'ненавижу',
#   'ее',
#   '.'],
#  ['В',
#   'ваших',
#   'же',
#   'мыслях',
#   'и',
#   'даже',
#   'в',
#   'самых',
#   'словах',
#   'я',
#   'не',
#   'изменил',
#   'ничего',
#   ',',
#   'ни',
#   'единого',
#   'слова',
#   '.'],
#  ['-',
#   'Не',
#   'думаю',
#   ',',
#   'чтобы',
#   'не',
#   'изменили',
#   ',',
#   '-',
#   'осторожно',
#   'заметил',
#   'Ставрогин',
#   ';',
#   '-',
#   'вы',
#   'пламенно',
#   'приняли',
#   'и',
#   'пламенно',
#   'переиначили',
#   ',',
#   'не',
#   'замечая',
#   'того',
#   '.'],
#  ['Уж',
#   'одно',
#   'то',
#   ',',
#   'что',
#   'вы',
#   'бога',
#   'низводите',
#   'до',
#   'простого',
#   'аттрибута',
#   'народности',
#   '...',
#   'Он',
#   'с',
#   'усиленным',
#   'и',
#   'особливым',
#   'вниманием',
#   'начал',
#   'вдруг',
#   'следить',
#   'за',
#   'Шатовым',
#   ',',
#   'и',
#   'не',
#   'столько',
#   'за',
#   'словами',
#   'его',
#   ',',
#   'сколько',
#   'за',
#   'ним',
#   'самим',
#   '.'],
#  ['-', 'Низвожу', 'бога', 'до', 'аттрибута', 'народности', '?'],
#  ['-',
#   'вскричал',
#   'Шатов',
#   ',',
#   '-',
#   'напротив',
#   ',',
#   'народ',
#   'возношу',
#   'до',
#   'бога',
#   '.'],
#  ['Да', 'и', 'было', 'ли', 'когда-нибудь', 'иначе', '?'],
#  ['Народ', '-', 'это', 'тело', 'божие', '.'],
#  ['Всякий',
#   'народ',
#   'до',
#   'тех',
#   'только',
#   'пор',
#   'и',
#   'народ',
#   ',',
#   'пока',
#   'имеет',
#   'своего',
#   'бога',
#   'особого',
#   ',',
#   'а',
#   'всех',
#   'остальных',
#   'на',
#   'свете',
#   'богов',
#   'исключает',
#   'безо',
#   'всякого',
#   'примирения',
#   ';',
#   'пока',
#   'верует',
#   'в',
#   'то',
#   ',',
#   'что',
#   'своим',
#   'богом',
#   'победит',
#   'и',
#   'изгонит',
#   'из',
#   'мира',
#   'всех',
#   'остальных',
#   'богов',
#   '.'],
#  ['Так',
#   'веровали',
#   'все',
#   'с',
#   'начала',
#   'веков',
#   ',',
#   'все',
#   'великие',
#   'народы',
#   'по',
#   'крайней',
#   'мере',
#   ',',
#   'все',
#   'сколько-нибудь',
#   'отмеченные',
#   ',',
#   'все',
#   'стоявшие',
#   'во',
#   'главе',
#   'человечества',
#   '.'],
#  ['Против', 'факта', 'идти', 'нельзя', '.'],
#  ['Евреи',
#   'жили',
#   'лишь',
#   'для',
#   'того',
#   ',',
#   'чтобы',
#   'дождаться',
#   'бога',
#   'истинного',
#   ',',
#   'и',
#   'оставили',
#   'миру',
#   'бога',
#   'истинного',
#   '.'],
#  ['Греки',
#   'боготворили',
#   'природу',
#   'и',
#   'завещали',
#   'миру',
#   'свою',
#   'религию',
#   ',',
#   'то-есть',
#   'философию',
#   'и',
#   'искусство',
#   '.'],
#  ['Рим',
#   'обоготворил',
#   'народ',
#   'в',
#   'государстве',
#   'и',
#   'завещал',
#   'народам',
#   'государство',
#   '.'],
#  ['Франция',
#   'в',
#   'продолжение',
#   'всей',
#   'своей',
#   'длинной',
#   'истории',
#   'была',
#   'одним',
#   'лишь',
#   'воплощением',
#   'и',
#   'развитием',
#   'идеи',
#   'римского',
#   'бога',
#   ',',
#   'и',
#   'если',
#   'сбросила',
#   'наконец',
#   'в',
#   'бездну',
#   'своего',
#   'римского',
#   'бога',
#   'и',
#   'ударилась',
#   'в',
#   'атеизм',
#   ',',
#   'который',
#   'называется',
#   'у',
#   'них',
#   'покамест',
#   'социализмом',
#   ',',
#   'то',
#   'единственно',
#   'потому',
#   'лишь',
#   ',',
#   'что',
#   'атеизм',
#   'все-таки',
#   'здоровее',
#   'римского',
#   'католичества',
#   '.'],
#  ['Если',
#   'великий',
#   'народ',
#   'не',
#   'верует',
#   ',',
#   'что',
#   'в',
#   'нем',
#   'одном',
#   'истина',
#   '(',
#   'именно',
#   'в',
#   'одном',
#   'и',
#   'именно',
#   'исключительно',
#   ')',
#   ',',
#   'если',
#   'не',
#   'верует',
#   ',',
#   'что',
#   'он',
#   'один',
#   'способен',
#   'и',
#   'призван',
#   'всех',
#   'воскресить',
#   'и',
#   'спасти',
#   'своею',
#   'истиной',
#   ',',
#   'то',
#   'он',
#   'тотчас',
#   'же',
#   'перестает',
#   'быть',
#   'великим',
#   'народом',
#   'и',
#   'тотчас',
#   'же',
#   'обращается',
#   'в',
#   'этнографический',
#   'материал',
#   ',',
#   'а',
#   'не',
#   'в',
#   'великий',
#   'народ',
#   '.'],
#  ['Истинный',
#   'великий',
#   'народ',
#   'никогда',
#   'не',
#   'может',
#   'примириться',
#   'со',
#   'второстепенною',
#   'ролью',
#   'в',
#   'человечестве',
#   ',',
#   'или',
#   'даже',
#   'с',
#   'первостепенною',
#   ',',
#   'а',
#   'непременно',
#   'и',
#   'исключительно',
#   'с',
#   'первою',
#   '.'],
#  ['Кто', 'теряет', 'эту', 'веру', ',', 'тот', 'уже', 'не', 'народ', '.'],
#  ['Но',
#   'истина',
#   'одна',
#   ',',
#   'а',
#   ',',
#   'стало',
#   'быть',
#   ',',
#   'только',
#   'единый',
#   'из',
#   'народов',
#   'и',
#   'может',
#   'иметь',
#   'бога',
#   'истинного',
#   ',',
#   'хотя',
#   'бы',
#   'остальные',
#   'народы',
#   'и',
#   'имели',
#   'своих',
#   'особых',
#   'и',
#   'великих',
#   'богов',
#   '.'],
#  ...]

# %%
# собираем словарь
words = sorted( set.union( *[ set(s) for s in text_ ] ) )
display(len(words))
words
# Out:
# 16658
# ['!',
#  "'",
#  "''",
#  '(',
#  ')',
#  ',',
#  '-',
#  '.',
#  '..',
#  '...',
#  '187',
#  '19-го',
#  ':',
#  ';',
#  '?',
#  'Adieu',
#  'Alea',
#  'Allons',
#  'Augustin',
#  'Avis',
#  'Ax',
#  'Bonjour',
#  "C'est",
#  "C'йtait",
#  'Candide',
#  'Cela',
#  'Cette',
#  'Cher',
#  'Chere',
#  'Cozak',
#  'Don',
#  'Elle',
#  'Eloignez-la',
#  'Enfin',
#  'Et',
#  'Excellent',
#  'Fantichambre',
#  'Fautre',
#  'Fils',
#  'He',
#  'I',
#  'II',
#  'III',
#  'IV',
#  'Il',
#  'Ils',
#  'Incognito',
#  'Internationale',
#  "J'ai",
#  "J'йtais",
#  'Je',
#  'Karmazinoff',
#  'Lembke',
#  'Littre',
#  'Maman',
#  'Mein',
#  'Merci',
#  'Nicolas',
#  'Oui',
#  'Pardon',
#  'Pas',
#  'Passons',
#  'Pйtersbourg',
#  "Qu'en",
#  "Qu'un",
#  'Quelque',
#  'Rosenthal',
#  'Savez',
#  'Savez-vous',
#  'Se',
#  'Tant',
#  'Teliatnikoff',
#  'To-есть',
#  'Tous',
#  'Tout',
#  'V',
#  'VI',
#  'VII',
#  'Voilа',
#  'Voltaire',
#  'Votre',
#  'Vous',
#  'Voyez-vous',
#  '``',
#  'a',
#  'abreuve',
#  'activitй',
#  'ami',
#  'amie',
#  'amis',
#  'annйe',
#  'ans',
#  'arrкter',
#  'au',
#  "aujourd'hui",
#  'autour',
#  'avait',
#  'avec',
#  'bas',
#  'battre',
#  'beaucoup',
#  'belle',
#  'belles',
#  'bien',
#  'bienfaisant',
#  'bon',
#  'boudoir',
#  'bourru',
#  'brisons-lа',
#  'bruit',
#  'bкte',
#  'bкtise',
#  'bкtises',
#  "c'est",
#  'cacha',
#  'calme',
#  'carriиre',
#  'ce',
#  'cela',
#  'ces',
#  'cette',
#  'chambre',
#  'chaque',
#  'charmant',
#  'charmante',
#  'cher',
#  'chere',
#  'chez',
#  'chose',
#  'choses',
#  'choses-lа',
#  'chиre',
#  'chйri',
#  'cochon',
#  'comme',
#  'commencerai',
#  'comment',
#  'comparaison',
#  'comprenez',
#  'compris',
#  'connais',
#  'connaissez',
#  'consenti',
#  'content',
#  'convertir',
#  'cozak',
#  'critiques',
#  'croire',
#  'croyez',
#  'croyez-vous',
#  'cа',
#  "d'allemand",
#  "d'aveugle",
#  "d'hйbйtй",
#  'dans',
#  'date',
#  'de',
#  'dedans',
#  'des',
#  'deux',
#  'digne',
#  'dira-t-elle',
#  'distance',
#  'dit',
#  'doit',
#  'drapeau',
#  'du',
#  'dйvorante',
#  'e',
#  'elle',
#  'employй',
#  'en',
#  'encore',
#  'enfin',
#  'ennemis',
#  'entendra',
#  'esclandre',
#  'esprits-forts',
#  'est',
#  'et',
#  'fair',
#  'faire',
#  'faites',
#  'faut',
#  'faзon',
#  'femmes',
#  'ferai',
#  'figure',
#  'fils',
#  'finie',
#  'fois',
#  'forteresses',
#  'genre',
#  'gens',
#  'gens-lа',
#  'guenille',
#  'hauteur',
#  'heure',
#  'historiques',
#  'homme',
#  'i.',
#  'il',
#  'immйdiatement',
#  'impuissance',
#  'impur',
#  'index',
#  'invraisemblable',
#  "j'ai",
#  'jacta',
#  'je',
#  'jure',
#  "l'assure",
#  'la',
#  'le',
#  'lecteur',
#  'les',
#  'lieber',
#  'louche',
#  'lui',
#  'lа',
#  'lа-bas',
#  'lвchetй',
#  'm',
#  "m'embкte",
#  "m'en",
#  'm-me',
#  'm-r',
#  'ma',
#  'mais',
#  'manquй',
#  'me',
#  'meilleur',
#  'mes',
#  'mettez',
#  'mieux',
#  'minimum',
#  'moi',
#  'moines',
#  'moment',
#  'mon',
#  'mondes',
#  'mot',
#  "n'ai",
#  "n'est",
#  'ne',
#  'nom',
#  'non',
#  'nos',
#  'notre',
#  'on',
#  'oubliй',
#  'oui',
#  'paraisse',
#  'paresseux',
#  'parlait',
#  'partout',
#  'pas',
#  'passant',
#  'pauvre',
#  'pays',
#  'permise',
#  'petit',
#  'peut',
#  'physionomie',
#  'pierre',
#  'plaisir',
#  'plus',
#  'plвtre',
#  'politesse',
#  'politiques',
#  'possibles',
#  'pouce',
#  'pour',
#  'pourtant',
#  'procureur',
#  'prononcй',
#  'propre',
#  'protegйe',
#  'prйpare',
#  'prкt',
#  'puis',
#  "qu'il",
#  "qu'on",
#  "qu'un",
#  'quand',
#  'que',
#  'quelque',
#  'quelques',
#  'qui',
#  'quinze',
#  'quoi',
#  'raison',
#  'rien',
#  'rit',
#  'roide',
#  'rossй',
#  'roubles',
#  "s'appelle",
#  'sa',
#  'sacrй',
#  'sang',
#  'sans',
#  'sautait',
#  'savez-vous',
#  'se',
#  'sens',
#  'sent',
#  'serai',
#  'seul',
#  'sillons',
#  'simplement',
#  'soit',
#  'son',
#  'sonnйe',
#  'sont',
#  'soupзonnera',
#  'souviens',
#  'suis',
#  'sur',
#  'surexcitй',
#  'sйrieux',
#  'sйvиre',
#  'tas',
#  'tenait',
#  'terrain',
#  'tombe',
#  'tomberai',
#  'toujours',
#  'tout',
#  'tout-а-fait',
#  'toute',
#  'trop',
#  'trouve',
#  'trиs',
#  'un',
#  'une',
#  'unes',
#  'vero',
#  'vie',
#  'vient',
#  'vingt',
#  'voulais',
#  'vous',
#  'voyez',
#  'voyez-vous',
#  'xe-xe',
#  'y',
#  'А',
#  'А-а',
#  'А-а-а',
#  'Авдотье',
#  'Агафья',
#  'Агентом',
#  'Адвокат',
#  'Администраторы',
#  'Акмолинский',
#  'Александрович',
#  'Александровском',
#  'Алексей',
#  'Алексея',
#  'Алеша',
#  'Али',
#  'Амалией',
#  'Амалию',
#  'Америка',
#  'Америке',
#  'Америки',
#  'Америку',
#  'Ан',
#  'Англии',
#  'Андреем',
#  'Андрей',
#  'Андрею',
#  'Андрея',
#  'Аничкова',
#  'Антонович',
#  'Антоновича',
#  'Антоновичем',
#  'Антоновичу',
#  'Антроповна',
#  'Апокалипсис',
#  'Апокалипсисе',
#  'Арина',
#  'Арине',
#  'Арины',
#  'Аристократ',
#  'Артемием',
#  'Артемий',
#  'Артемия',
#  'Архангельск',
#  'Ах',
#  'Б-цах',
#  'БЕСЫ',
#  'Ба',
#  'Базаров',
#  'Байрон',
#  'Байроном',
#  'Бальзака',
#  'Барьер',
#  'Басни',
#  'Батюшка',
#  'Беда',
#  'Бедная',
#  'Бедный',
#  'Бедняжка',
#  'Без',
#  'Безумных',
#  'Белинский',
#  'Белинского',
#  'Берлина',
#  'Берлине',
#  'Берут',
#  'Бешенство',
#  'Бисмарка',
#  'Блага-а-дарен',
#  'Благодарю',
#  'Благодетель',
#  'Благослови',
#  'Бледный',
#  'Близость',
#  'Блюм',
#  'Блюма',
#  'Блюмера',
#  'Блюмом',
#  'Блюму',
#  'Бог',
#  'Бога',
#  'Богородицы',
#  'Богородский',
#  'Богородском',
#  'Богочеловек',
#  'Богоявленская',
#  'Богоявленской',
#  'Богоявленскую',
#  'Боже',
#  'Боитесь',
#  'Бойтесь',
#  'Бока',
#  'Болезненное',
#  'Болен',
#  'Болтовне',
#  'Больны',
#  'Боюсь',
#  'Боязливо',
#  'Боясь',
#  'Братство',
#  'Бред',
#  'Бродяга',
#  'Бросив',
#  'Брыкове',
#  'Будет',
#  'Будто',
#  'Буду',
#  'Будьте',
#  'Бунт',
#  'Бунтуют',
#  'Бутылка',
#  'Бухгалтер',
#  'Бывает',
#  'Быковой',
#  'Был',
#  'Была',
#  'Были',
#  'Было',
#  'Быстрому',
#  'Быть',
#  'Бьюсь',
#  'Бюхнера',
#  'В',
#  'ВОСЬМАЯ',
#  'ВТОРАЯ',
#  'Вавилон',
#  'Вам',
#  'Варвара',
#  'Варваре',
#  'Варварой',
#  'Варвару',
#  'Варвары',
#  'Вас',
#  'Василий',
#  'Ваш',
#  'Ваша',
#  'Ваше',
#  'Вашего',
#  'Вбежавший',
#  'Вдовицу',
#  'Вдруг',
#  'Ведь',
#  'Великий',
#  'Верен',
#  'Верите',
#  'Верно',
#  'Вероятнее',
#  'Вероятно',
#  'Верхишиных',
#  'Верховенские',
#  'Верховенский',
#  'Верховенским',
#  'Верховенского',
#  'Верховенском',
#  'Верховенскому',
#  'Веселые',
#  'Веселым',
#  'Весь',
#  'Ветер',
#  'Ветром',
#  'Взгляд',
#  'Взгляды',
#  'Вздор',
#  'Взял',
#  'Взяли',
#  'Вид',
#  'Видал',
#  'Видали',
#  'Видимо',
#  'Видимое',
#  'Видите',
#  'Видите-с',
#  'Видите-с.',
#  'Видишь',
#  'Видно',
#  'Вижу',
#  'Визит',
#  'Виноват',
#  'Виновата',
#  'Виргинская',
#  'Виргинские',
#  'Виргинский',
#  'Виргинским',
#  'Виргинского',
#  'Виргинской',
#  'Виргинскому',
#  'Влюбленный',
#  'Вместе',
#  'Вникните',
#  'Во',
#  'Во-первых',
#  'Водосточная',
#  'Воды',
#  'Возбудил',
#  'Возвратясь',
#  'Возьмите',
#  'Войдите',
#  'Волнение',
#  'Воля',
#  'Вон',
#  'Воображаю',
#  'Вообразив',
#  'Вообразите',
#  'Вообще',
#  'Вопрос',
#  'Вопроса',
#  'Ворота',
#  'Воспитанники',
#  'Вот',
#  'Вот-с',
#  'Вошедший',
#  'Вошел',
#  'Впечатление',
#  'Впоследствии',
#  'Впрочем',
#  'Враги',
#  'Время',
#  'Врете',
#  'Все',
#  'Все-таки',
#  'Всеволодович',
#  'Всеволодовича',
#  'Всеволодовиче',
#  'Всеволодовичем',
#  'Всеволодовичу',
#  'Всегда-то',
#  'Всего',
#  'Всем',
#  'Всеобщее',
#  'Всех',
#  'Вспоминались',
#  'Вспомнили',
#  'Вспомните',
#  'Вставайте',
#  'Встаньте',
#  'Встреча',
#  'Вступая',
#  'Всю',
#  'Вся',
#  'Всякий',
#  'Втихомолку',
#  'Вход',
#  'Входили',
#  'Входите',
#  'Вчера',
#  'Вчерашний',
#  'Въехали',
#  'Вы',
#  'Вы-с',
#  'Вы-то',
#  'Выбросил',
#  'Вызов',
#  'Выйдет',
#  'Высекут',
#  'Высокая',
#  'Высокие',
#  'Высокий',
#  'Высоцкого',
#  'Выстрел',
#  'Высшие',
#  'Высылкой',
#  'Выходит',
#  'Выходя',
#  'Вышло',
#  'Г.',
#  'ГЛАВА',
#  'Гаганов',
#  'Гаганова',
#  'Гаганову',
#  'Гагановым',
#  'Гамбурга',
#  'Гамбурге',
#  'Где',
#  'Гекерну',
#  'Генерал',
#  'Генеральша',
#  'Гениального',
#  'Герцен',
#  'Герцена',
#  'Гимназист',
#  'Гимназистов',
#  'Главное',
#  'Главною',
#  'Глаза',
#  'Глупейшим',
#  'Глупов',
#  'Глупость',
#  'Гм',
#  'Говори',
#  'Говорил',
#  'Говорили',
#  'Говорите',
#  'Говорить',
#  'Говорю',
#  'Говоря',
#  'Говорят',
#  'Гоголь',
#  'Гони',
#  'Город',
#  'Горшечной',
#  'Горячий',
#  'Господа',
#  'Господи',
#  'Господин',
#  'Гостиного',
#  'Гостином',
#  'Гость',
#  'Грабительство',
#  'Грановского',
#  'Графиня',
#  'Греки',
#  'Гривен',
#  'Гришка',
#  'Гришку',
#  'ДЕВЯТАЯ',
#  'ДЕСЯТАЯ',
#  'Да',
#  'Да-с',
#  'Давайте',
#  'Давешней',
#  'Давно',
#  'Даже',
#  'Дайте',
#  'Далась',
#  'Дались',
#  'Дама',
#  'Дарьей',
#  'Дарьи',
#  'Дарья',
#  'Дать',
#  'Даша',
#  'Даю',
#  'Два',
#  'Двадцать',
#  'Две',
#  'Двери',
#  'Дверь',
#  'Девочка',
#  'Действительно',
#  'Делайте',
#  'Делался',
#  'Дело',
#  'Денег',
#  'Денежные',
#  'День',
#  'Державина',
#  'Деспот',
#  'Десять',
#  'Дикая',
#  'Длинное',
#  'Длинному',
#  'Длинноухий',
#  'Для',
#  'Дмитрия',
#  'Днем',
#  'До',
#  'Довольно',
#  'Довольны',
#  'Догадавшись',
#  'Договаривайте',
#  'Дозволите',
#  'Дозвольте',
#  'Доктор',
#  'Долгое',
#  'Должна',
#  'Должно',
#  'Долой',
#  'Дом',
#  'Дома',
#  'Домой',
#  'Донесет',
#  'Донесли',
#  'Дорогой',
#  'Достоевский',
#  'Дрезден',
#  'Дроздова',
#  'Дроздовы',
#  'Друг',
#  'Другие',
#  'Другого',
#  'Другое',
#  'Думаю',
#  'Думы',
#  'Дураки',
#  'Дурында',
#  'Дух',
#  'Духове',
#  'Духово',
#  'Душа',
#  'Дуэль',
#  'Дяденька',
#  'Евангелие',
#  'Евреи',
#  'Европе',
#  'Европы',
#  'Его',
#  'Егорович',
#  'Егоровича',
#  'Егорыч',
#  'Едва',
#  'Единственно',
#  'Единый',
#  'Ее',
#  'Ей',
#  'Елей',
#  'Ему',
#  'Если',
#  'Есть',
#  'Ефимьевском',
#  'Еще',
#  'Жажда',
#  'Жаль',
#  'Жаль-с',
#  'Ждал',
#  'Ждали',
#  'Жду',
#  'Желание',
#  'Женился',
#  'Женщины',
#  'Жив',
#  'Жизнь',
#  'Жребий',
#  'Жюль',
#  'За',
#  'Забывать',
#  'Забыл',
#  'Заволновались',
#  'Завтра',
#  'Загадочный',
#  'Заговорите',
#  'Задатку',
#  'Заколодило',
#  'Заметив',
#  'Заметьте',
#  'Замечание',
#  'Замечательно',
#  'Замечательные',
#  'Замечу',
#  'Заперлись',
#  'Запнулся',
#  'Запрет',
#  'Заседание',
#  'Заслышав',
#  'Застрелитесь',
#  'Затверженные',
#  'Затем',
#  'Зато',
#  'Затуманится',
#  'Заходил',
#  'Зачем',
#  'Звонко',
#  'Звуки',
#  'Здесь',
#  'Здорова',
#  'Здоровье',
#  'Здравствуйте',
#  'Злато',
#  'Злится',
#  'Злобной',
#  'Злость',
#  'Знаем',
#  'Знаете',
#  'Знай',
#  'Знайте',
#  'Знаком',
#  'Знаменит',
#  'Значит',
#  'Знаю',
#  'Знаю-с',
#  'Золотая',
#  'Золотые',
#  'Зонтик',
#  'Зонтика',
#  'Зосимой',
#  'Зуб',
#  'И',
#  'Ибо',
#  'Ив',
#  'Иван',
#  'Иван-царевич',
#  'Ивана',
#  'Ивана-царевича',
#  'Иванович',
#  'Игренева',
#  'Идем',
#  'Идет',
#  'Идея',
#  'Идите',
#  'Иду',
#  'Из',
#  'Из-под',
#  'Изверг',
#  'Известие',
#  'Известна',
#  'Извините',
#  'Извольте',
#  'Изредка',
#  'Изреки',
#  'Или',
#  'Илье',
#  'Ильич',
#  'Ильичу',
#  'Илья',
#  'Имеете',
#  'Именно',
#  'Имею',
#  'Имеются',
#  'Имя',
#  'Иногда',
#  'Интересно',
#  'Интонация',
#  'Искали',
#  'Искание',
#  'Исполнили',
#  'Исступление',
#  'Истина',
#  'Истинный',
#  'Итак',
#  'Их',
#  'Ищу',
#  'К',
#  'К.',
#  'Кабета',
#  'Кабеты',
#  'Кавказ',
#  'Каждое',
#  'Каждый',
#  'Кажется',
#  'Казалось',
#  'Казням',
#  'Как',
#  'Как-нибудь',
#  'Какая',
#  'Какие',
#  'Каким',
#  'Какого',
#  'Какое',
#  'Какой',
#  'Какой-то',
#  'Какую',
#  'Капитан',
#  'Капитон',
#  'Капфиг',
#  'Карлсбаде',
#  'Карльсруэ',
#  'Кармазинов',
#  'Кармазинова',
#  'Кармазинову',
#  'Карьера',
#  'Каторжный',
#  'Кириллов',
#  'Кириллова',
#  'Кириллову',
#  'Кирилловым',
#  'Кладу',
#  'Клянусь',
#  'Книгоношу',
#  'Книжки',
#  'Когда',
#  'Когда-то',
#  'Кого',
#  'Кого-о',
#  'Коли',
#  'Колокола',
#  'Колпак',
#  'Колумб',
#  'Комната',
#  'Кондукторы',
#  'Конечно',
#  'Конечно-с',
#  'Кончив',
#  'Кончилось',
#  'Кончится',
#  'Копернику',
#  'Короваев',
#  'Короваеву',
#  'Краса',
#  'Крестили',
#  'Кричат',
#  'Крови',
#  'Кроме',
#  'Круг',
#  'Крыльцо',
#  'Кстати',
#  'Кто',
#  'Кто-то',
#  'Куда',
#  'Кукольник',
#  'Купец',
#  'Кучер',
#  'Кучки-то',
#  'Кушал',
#  'ЛИЧНОСТЬ',
#  'Лакей',
#  'Ласковое',
#  'Лебядкин',
#  'Лебядкина',
#  'Лебядкина-с',
#  'Лебядкиной',
#  'Лебядкину',
#  'Лебядкины',
#  'Лебядкиным',
#  'Лебядкиных',
#  'Лежит',
#  'Лекций',
#  'Лембка',
#  'Лембками',
#  'Лембке',
#  'Лембку',
#  'Лентяи',
#  'Лень',
#  'Лет',
#  'Либерал',
#  'Лиза',
#  'Лизавета',
#  'Лизавете',
#  'Лизаветой',
#  'Лизавету',
#  'Лизаветы',
#  'Лизу',
#  'Лизы',
#  'Липутин',
#  'Липутина',
#  'Липутину',
#  'Лист',
#  'Лихорадка',
#  'Лицо',
#  'Личности',
#  'Личность',
#  'Лучше',
#  'Люблю',
#  'Любопытно',
#  'Люди',
#  'Лягте',
#  'Лямшин',
#  'Лямшина',
#  'Лямшине',
#  'Лямшину',
#  'Лямшиным',
#  'Ма',
#  'Маврикием',
#  'Маврикий',
#  'Маврикию',
#  'Маврикия',
#  'Мадонна',
#  'Мадонне',
#  'Мадонной',
#  'Мадонны',
#  'Майор',
#  'Максимович',
#  'Мало',
#  'Мальчик',
#  'Мальчишка',
#  'Манера',
#  ...]

# %% [markdown]
# количество слов 16 658
# против 22 386 в случае "простого" разделения по пробелу
#
# NLTK обеспечивает разделение на отдельные предложения
# и более качественную токенизацию
# разделяя конструкции типа '(Послышался'

# %% [markdown]
# ## токенайзер для русского языка из пакета  Natasha

# %%
from razdel import sentenize
from razdel import tokenize

text_ = [ [ t.text for t in tokenize(s.text) ] for s in sentenize(text) ]
text_
# Out:
# [['БЕСЫ',
#   'Федор',
#   'Михайлович',
#   'Достоевский',
#   'ЧАСТЬ',
#   'ВТОРАЯ',
#   'ГЛАВА',
#   'ПЕРВАЯ',
#   'Ночь',
#   'I',
#   'Прошло',
#   'восемь',
#   'дней',
#   '.'],
#  ['Теперь',
#   ',',
#   'когда',
#   'уже',
#   'все',
#   'прошло',
#   ',',
#   'и',
#   'я',
#   'пишу',
#   'хронику',
#   ',',
#   'мы',
#   'уже',
#   'знаем',
#   'в',
#   'чем',
#   'дело',
#   ';',
#   'но',
#   'тогда',
#   'мы',
#   'еще',
#   'ничего',
#   'не',
#   'знали',
#   ',',
#   'и',
#   'естественно',
#   ',',
#   'что',
#   'нам',
#   'представлялись',
#   'странными',
#   'разные',
#   'вещи',
#   '.'],
#  ['По',
#   'крайней',
#   'мере',
#   'мы',
#   'со',
#   'Степаном',
#   'Трофимовичем',
#   'в',
#   'первое',
#   'время',
#   'заперлись',
#   'и',
#   'с',
#   'испугом',
#   'наблюдали',
#   'издали',
#   '.'],
#  ['Я-то',
#   'кой-куда',
#   'еще',
#   'выходил',
#   'и',
#   'по-прежнему',
#   'приносил',
#   'ему',
#   'разные',
#   'вести',
#   ',',
#   'без',
#   'чего',
#   'он',
#   'и',
#   'пробыть',
#   'не',
#   'мог',
#   '.'],
#  ['Нечего',
#   'и',
#   'говорить',
#   ',',
#   'что',
#   'по',
#   'городу',
#   'пошли',
#   'самые',
#   'разнообразные',
#   'слухи',
#   ',',
#   'то-есть',
#   'насчет',
#   'пощечины',
#   ',',
#   'обморока',
#   'Лизаветы',
#   'Николаевны',
#   'и',
#   'прочего',
#   'случившегося',
#   'в',
#   'то',
#   'воскресенье',
#   '.'],
#  ['Но',
#   'удивительно',
#   'нам',
#   'было',
#   'то',
#   ':',
#   'через',
#   'кого',
#   'это',
#   'все',
#   'могло',
#   'так',
#   'скоро',
#   'и',
#   'точно',
#   'выйти',
#   'наружу',
#   '?'],
#  ['Ни',
#   'одно',
#   'из',
#   'присутствовавших',
#   'тогда',
#   'лиц',
#   'не',
#   'имело',
#   'бы',
#   ',',
#   'кажется',
#   ',',
#   'ни',
#   'нужды',
#   ',',
#   'ни',
#   'выгоды',
#   'нарушить',
#   'секрет',
#   'происшедшего',
#   '.'],
#  ['Прислуги',
#   'тогда',
#   'не',
#   'было',
#   ';',
#   'один',
#   'Лебядкин',
#   'мог',
#   'бы',
#   'что-нибудь',
#   'разболтать',
#   ',',
#   'не',
#   'столько',
#   'по',
#   'злобе',
#   ',',
#   'потому',
#   'что',
#   'вышел',
#   'тогда',
#   'в',
#   'крайнем',
#   'испуге',
#   '(',
#   'а',
#   'страх',
#   'к',
#   'врагу',
#   'уничтожает',
#   'и',
#   'злобу',
#   'к',
#   'нему',
#   ')',
#   ',',
#   'а',
#   'единственно',
#   'по',
#   'невоздержности',
#   '.'],
#  ['Но',
#   'Лебядкин',
#   ',',
#   'вместе',
#   'с',
#   'сестрицей',
#   ',',
#   'на',
#   'другой',
#   'же',
#   'день',
#   'пропал',
#   'без',
#   'вести',
#   ';',
#   'в',
#   'доме',
#   'Филиппова',
#   'его',
#   'не',
#   'оказалось',
#   ',',
#   'он',
#   'переехал',
#   'неизвестно',
#   'куда',
#   'и',
#   'точно',
#   'сгинул',
#   '.'],
#  ['Шатов',
#   ',',
#   'у',
#   'которого',
#   'я',
#   'хотел',
#   'было',
#   'справиться',
#   'о',
#   'Марье',
#   'Тимофеевне',
#   ',',
#   'заперся',
#   'и',
#   ',',
#   'кажется',
#   ',',
#   'все',
#   'эти',
#   'восемь',
#   'дней',
#   'просидел',
#   'у',
#   'себя',
#   'на',
#   'квартире',
#   ',',
#   'даже',
#   'прервав',
#   'свои',
#   'занятия',
#   'в',
#   'городе',
#   '.'],
#  ['Меня', 'он', 'не', 'принял', '.'],
#  ['Я',
#   'было',
#   'зашел',
#   'к',
#   'нему',
#   'во',
#   'вторник',
#   'и',
#   'стукнул',
#   'в',
#   'дверь',
#   '.'],
#  ['Ответа',
#   'не',
#   'получил',
#   ',',
#   'но',
#   'уверенный',
#   ',',
#   'по',
#   'несомненным',
#   'данным',
#   ',',
#   'что',
#   'он',
#   'дома',
#   ',',
#   'постучался',
#   'в',
#   'другой',
#   'раз',
#   '.'],
#  ['Тогда',
#   'он',
#   ',',
#   'соскочив',
#   'по-видимому',
#   'с',
#   'постели',
#   ',',
#   'подошел',
#   'крупными',
#   'шагами',
#   'к',
#   'дверям',
#   'и',
#   'крикнул',
#   'мне',
#   'во',
#   'весь',
#   'голос',
#   ':',
#   '"',
#   'Шатова',
#   'дома',
#   'нет',
#   '"',
#   '.'],
#  ['Я', 'с', 'тем', 'и', 'ушел', '.'],
#  ['Мы',
#   'со',
#   'Степаном',
#   'Трофимовичем',
#   ',',
#   'не',
#   'без',
#   'страха',
#   'за',
#   'смелость',
#   'предположения',
#   ',',
#   'но',
#   'обоюдно',
#   'ободряя',
#   'друг',
#   'друга',
#   ',',
#   'остановились',
#   'наконец',
#   'на',
#   'одной',
#   'мысли',
#   ':',
#   'мы',
#   'решили',
#   ',',
#   'что',
#   'виновником',
#   'разошедшихся',
#   'слухов',
#   'мог',
#   'быть',
#   'один',
#   'только',
#   'Петр',
#   'Степанович',
#   ',',
#   'хотя',
#   'сам',
#   'он',
#   'некоторое',
#   'время',
#   'спустя',
#   ',',
#   'в',
#   'разговоре',
#   'с',
#   'отцом',
#   ',',
#   'уверял',
#   ',',
#   'что',
#   'застал',
#   'уже',
#   'историю',
#   'во',
#   'всех',
#   'устах',
#   ',',
#   'преимущественно',
#   'в',
#   'клубе',
#   ',',
#   'и',
#   'совершенно',
#   'известною',
#   'до',
#   'мельчайших',
#   'подробностей',
#   'губернаторше',
#   'и',
#   'ее',
#   'супругу',
#   '.'],
#  ['Вот',
#   'что',
#   'еще',
#   'замечательно',
#   ':',
#   'на',
#   'второй',
#   'же',
#   'день',
#   ',',
#   'в',
#   'понедельник',
#   'ввечеру',
#   ',',
#   'я',
#   'встретил',
#   'Липутина',
#   ',',
#   'и',
#   'он',
#   'уже',
#   'знал',
#   'все',
#   'до',
#   'последнего',
#   'слова',
#   ',',
#   'стало',
#   'быть',
#   ',',
#   'несомненно',
#   'узнал',
#   'из',
#   'первых',
#   '.'],
#  ['Многие',
#   'из',
#   'дам',
#   '(',
#   'и',
#   'из',
#   'самых',
#   'светских',
#   ')',
#   'любопытствовали',
#   'и',
#   'о',
#   '"',
#   'загадочной',
#   'хромоножке',
#   '"',
#   ',',
#   'так',
#   'называли',
#   'Марью',
#   'Тимофеевну',
#   '.'],
#  ['Нашлись',
#   'даже',
#   'пожелавшие',
#   'непременно',
#   'увидать',
#   'ее',
#   'лично',
#   'и',
#   'познакомиться',
#   ',',
#   'так',
#   'что',
#   'господа',
#   ',',
#   'поспешившие',
#   'припрятать',
#   'Лебядкиных',
#   ',',
#   'очевидно',
#   'поступили',
#   'и',
#   'кстати',
#   '.'],
#  ['Но',
#   'на',
#   'первом',
#   'плане',
#   'все-таки',
#   'стоял',
#   'обморок',
#   'Лизаветы',
#   'Николаевны',
#   ',',
#   'и',
#   'этим',
#   'интересовался',
#   '"',
#   'весь',
#   'свет',
#   '"',
#   ',',
#   'уже',
#   'по',
#   'тому',
#   'одному',
#   ',',
#   'что',
#   'дело',
#   'прямо',
#   'касалось',
#   'Юлии',
#   'Михайловны',
#   'как',
#   'родственницы',
#   'Лизаветы',
#   'Николаевны',
#   'и',
#   'ее',
#   'покровительницы',
#   '.'],
#  ['И', 'чего-чего', 'ни', 'болтали', '!'],
#  ['Болтовне',
#   'способствовала',
#   'и',
#   'таинственность',
#   'обстановки',
#   ':',
#   'оба',
#   'дома',
#   ',',
#   'были',
#   'заперты',
#   'наглухо',
#   ';'],
#  ['Лизавета',
#   'Николаевна',
#   ',',
#   'как',
#   'рассказывали',
#   ',',
#   'лежала',
#   'в',
#   'белой',
#   'горячке',
#   ';',
#   'то',
#   'же',
#   'утверждали',
#   'и',
#   'о',
#   'Николае',
#   'Всеволодовиче',
#   ',',
#   'с',
#   'отвратительными',
#   'подробностями',
#   'о',
#   'выбитом',
#   'будто',
#   'бы',
#   'зубе',
#   'и',
#   'о',
#   'распухшей',
#   'от',
#   'флюса',
#   'щеке',
#   'его',
#   '.'],
#  ['Говорили',
#   'даже',
#   'по',
#   'уголкам',
#   ',',
#   'что',
#   'у',
#   'нас',
#   'может',
#   'быть',
#   'будет',
#   'убийство',
#   ',',
#   'что',
#   'Ставрогин',
#   'не',
#   'таков',
#   ',',
#   'чтобы',
#   'снести',
#   'такую',
#   'обиду',
#   ',',
#   'и',
#   'убьет',
#   'Шатова',
#   ',',
#   'но',
#   'таинственно',
#   ',',
#   'как',
#   'в',
#   'корсиканской',
#   'вендетте',
#   '.'],
#  ['Мысль',
#   'эта',
#   'нравилась',
#   ';',
#   'но',
#   'большинство',
#   'нашей',
#   'светской',
#   'молодежи',
#   'выслушивало',
#   'все',
#   'это',
#   'с',
#   'презрением',
#   'и',
#   'с',
#   'видом',
#   'самого',
#   'пренебрежительного',
#   'равнодушия',
#   ',',
#   'разумеется',
#   ',',
#   'напускного',
#   '.'],
#  ['Вообще',
#   'древняя',
#   'враждебность',
#   'нашего',
#   'общества',
#   'к',
#   'Николаю',
#   'Всеволодовичу',
#   'обозначилась',
#   'ярко',
#   '.'],
#  ['Даже',
#   'солидные',
#   'люди',
#   'стремились',
#   'обвинить',
#   'его',
#   ',',
#   'хотя',
#   'и',
#   'сами',
#   'не',
#   'знали',
#   'в',
#   'чем',
#   '.'],
#  ['Шепотом',
#   'рассказывали',
#   ',',
#   'что',
#   'будто',
#   'бы',
#   'он',
#   'погубил',
#   'честь',
#   'Лизаветы',
#   'Николаевны',
#   ',',
#   'и',
#   'что',
#   'между',
#   'ними',
#   'была',
#   'интрига',
#   'в',
#   'Швейцарии',
#   '.'],
#  ['Конечно',
#   'осторожные',
#   'люди',
#   'сдерживались',
#   ',',
#   'но',
#   'все',
#   'однако',
#   'же',
#   'слушали',
#   'с',
#   'аппетитом',
#   '.'],
#  ['Были',
#   'и',
#   'другие',
#   'разговоры',
#   ',',
#   'но',
#   'не',
#   'общие',
#   ',',
#   'а',
#   'частные',
#   ',',
#   'редкие',
#   'и',
#   'почти',
#   'закрытые',
#   ',',
#   'чрезвычайно',
#   'странные',
#   'и',
#   'о',
#   'существовании',
#   'которых',
#   'я',
#   'упоминаю',
#   'лишь',
#   'для',
#   'предупреждения',
#   'читателей',
#   ',',
#   'единственно',
#   'в',
#   'виду',
#   'дальнейших',
#   'событий',
#   'моего',
#   'рассказа',
#   '.'],
#  ['Именно',
#   ':',
#   'говорили',
#   'иные',
#   ',',
#   'хмуря',
#   'брови',
#   'и',
#   'бог',
#   'знает',
#   'на',
#   'каком',
#   'основании',
#   ',',
#   'что',
#   'Николай',
#   'Всеволодович',
#   'имеет',
#   'какое-то',
#   'особенное',
#   'дело',
#   'в',
#   'нашей',
#   'губернии',
#   ',',
#   'что',
#   'он',
#   'чрез',
#   'графа',
#   'К',
#   '.',
#   'вошел',
#   'в',
#   'Петербурге',
#   'в',
#   'какие-то',
#   'высшие',
#   'отношения',
#   ',',
#   'что',
#   'он',
#   'даже',
#   ',',
#   'может',
#   'быть',
#   ',',
#   'служит',
#   'и',
#   'чуть',
#   'ли',
#   'не',
#   'снабжен',
#   'от',
#   'кого-то',
#   'какими-то',
#   'поручениями',
#   '.'],
#  ['Когда',
#   'очень',
#   'уж',
#   'солидные',
#   'и',
#   'сдержанные',
#   'люди',
#   'на',
#   'этот',
#   'слух',
#   'улыбались',
#   ',',
#   'благоразумно',
#   'замечая',
#   ',',
#   'что',
#   'человек',
#   ',',
#   'живущий',
#   'скандалами',
#   'и',
#   'начинающий',
#   'у',
#   'нас',
#   'с',
#   'флюса',
#   ',',
#   'не',
#   'похож',
#   'на',
#   'чиновника',
#   ',',
#   'то',
#   'им',
#   'шепотом',
#   'замечали',
#   ',',
#   'что',
#   'служит',
#   'он',
#   'не',
#   'то',
#   'чтоб',
#   'оффициально',
#   ',',
#   'а',
#   'так',
#   'сказать',
#   'конфиденциально',
#   ',',
#   'и',
#   'что',
#   'в',
#   'таком',
#   'случае',
#   'самою',
#   'службой',
#   'требуется',
#   ',',
#   'чтобы',
#   'служащий',
#   'как',
#   'можно',
#   'менее',
#   'походил',
#   'на',
#   'чиновника',
#   '.'],
#  ['Такое',
#   'замечание',
#   'производило',
#   'эффект',
#   ';',
#   'у',
#   'нас',
#   'известно',
#   'было',
#   ',',
#   'что',
#   'на',
#   'земство',
#   'нашей',
#   'губернии',
#   'смотрят',
#   'в',
#   'столице',
#   'с',
#   'некоторым',
#   'особым',
#   'вниманием',
#   '.'],
#  ['Повторю',
#   ',',
#   'эти',
#   'слухи',
#   'только',
#   'мелькнули',
#   'и',
#   'исчезли',
#   'бесследно',
#   ',',
#   'до',
#   'времени',
#   ',',
#   'при',
#   'первом',
#   'появлении',
#   'Николая',
#   'Всеволодовича',
#   ';',
#   'но',
#   'замечу',
#   ',',
#   'что',
#   'причиной',
#   'многих',
#   'слухов',
#   'было',
#   'отчасти',
#   'несколько',
#   'кратких',
#   ',',
#   'но',
#   'злобных',
#   'слов',
#   ',',
#   'неясно',
#   'и',
#   'отрывисто',
#   'произнесенных',
#   'в',
#   'клубе',
#   'недавно',
#   'возвратившимся',
#   'из',
#   'Петербурга',
#   'отставным',
#   'капитаном',
#   'гвардии',
#   'Артемием',
#   'Павловичем',
#   'Гагановым',
#   ',',
#   'весьма',
#   'крупным',
#   'помещиком',
#   'нашей',
#   'губернии',
#   'и',
#   'уезда',
#   ',',
#   'столичным',
#   'светским',
#   'человеком',
#   'и',
#   'сыном',
#   'покойного',
#   'Павла',
#   'Павловича',
#   'Гаганова',
#   ',',
#   'того',
#   'самого',
#   'почтенного',
#   'старшины',
#   ',',
#   'с',
#   'которым',
#   'Николай',
#   'Всеволодович',
#   'имел',
#   ',',
#   'четыре',
#   'слишком',
#   'года',
#   'тому',
#   'назад',
#   ',',
#   'то',
#   'необычайное',
#   'по',
#   'своей',
#   'грубости',
#   'и',
#   'внезапности',
#   'столкновение',
#   ',',
#   'о',
#   'котором',
#   'я',
#   'уже',
#   'упоминал',
#   'прежде',
#   ',',
#   'в',
#   'начале',
#   'моего',
#   'рассказа',
#   '.'],
#  ['Всем',
#   'тотчас',
#   'же',
#   'стало',
#   'известно',
#   ',',
#   'что',
#   'Юлия',
#   'Михайловна',
#   'сделала',
#   'Варваре',
#   'Петровне',
#   'чрезвычайный',
#   'визит',
#   ',',
#   'и',
#   'что',
#   'у',
#   'крыльца',
#   'дома',
#   'ей',
#   'объявили',
#   ',',
#   'что',
#   '"',
#   'по',
#   'нездоровью',
#   'не',
#   'могут',
#   'принять',
#   '"',
#   '.'],
#  ['Также',
#   'и',
#   'то',
#   ',',
#   'что',
#   'дня',
#   'через',
#   'два',
#   'после',
#   'своего',
#   'визита',
#   'Юлия',
#   'Михайловна',
#   'посылала',
#   'узнать',
#   'о',
#   'здоровье',
#   'Варвары',
#   'Петровны',
#   'нарочного',
#   '.'],
#  ['Наконец',
#   'принялась',
#   'везде',
#   '"',
#   'защищать',
#   '"',
#   'Варвару',
#   'Петровну',
#   ',',
#   'конечно',
#   'лишь',
#   'в',
#   'самом',
#   'высшем',
#   'смысле',
#   ',',
#   'то',
#   '"',
#   'есть',
#   'по',
#   'возможности',
#   'в',
#   'самом',
#   'неопределенном',
#   '.'],
#  ['Все',
#   'же',
#   'первоначальные',
#   'торопливые',
#   'намеки',
#   'о',
#   'воскресной',
#   'истории',
#   'выслушала',
#   'строго',
#   'и',
#   'холодно',
#   ',',
#   'так',
#   'что',
#   'в',
#   'последующие',
#   'дни',
#   ',',
#   'в',
#   'ее',
#   'присутствии',
#   ',',
#   'они',
#   'уже',
#   'не',
#   'возобновлялись',
#   '.'],
#  ['Таким',
#   'образом',
#   'и',
#   'укрепилась',
#   'везде',
#   'мысль',
#   ',',
#   'что',
#   'Юлии',
#   'Михайловне',
#   'известна',
#   'не',
#   'только',
#   'вся',
#   'эта',
#   'таинственная',
#   'история',
#   ',',
#   'но',
#   'и',
#   'весь',
#   'ее',
#   'таинственный',
#   'смысл',
#   'до',
#   'мельчайших',
#   'подробностей',
#   ',',
#   'и',
#   'не',
#   'как',
#   'посторонней',
#   ',',
#   'а',
#   'как',
#   'соучастнице',
#   '.'],
#  ['Замечу',
#   'кстати',
#   ',',
#   'что',
#   'она',
#   'начала',
#   'уже',
#   'приобретать',
#   'у',
#   'нас',
#   ',',
#   'помаленьку',
#   ',',
#   'то',
#   'высшее',
#   'влияние',
#   ',',
#   'которого',
#   'так',
#   'несомненно',
#   'добивалась',
#   'и',
#   'жаждала',
#   ',',
#   'и',
#   'уже',
#   'начинала',
#   'видеть',
#   'себя',
#   '"',
#   'окруженною',
#   '"',
#   '.'],
#  ['Часть',
#   'общества',
#   'признала',
#   'за',
#   'нею',
#   'практический',
#   'ум',
#   'и',
#   'такт',
#   '...',
#   'но',
#   'об',
#   'этом',
#   'после',
#   '.'],
#  ['Ее',
#   'же',
#   'покровительством',
#   'объяснялись',
#   'отчасти',
#   'и',
#   'весьма',
#   'быстрые',
#   'успехи',
#   'Петра',
#   'Степановича',
#   'в',
#   'нашем',
#   'обществе',
#   ',',
#   '-',
#   'успехи',
#   ',',
#   'особенно',
#   'поразившие',
#   'тогда',
#   'Степана',
#   'Трофимовича',
#   '.'],
#  ['Мы', 'с', 'ним', 'может', 'быть', 'и', 'преувеличивали', '.'],
#  ['Во-первых',
#   ',',
#   'Петр',
#   'Степанович',
#   'перезнакомился',
#   'почти',
#   'мгновенно',
#   'со',
#   'всем',
#   'городом',
#   ',',
#   'в',
#   'первые',
#   'же',
#   'четыре',
#   'дня',
#   'после',
#   'своего',
#   'появления',
#   '.'],
#  ['Появился',
#   'он',
#   'в',
#   'воскресенье',
#   ',',
#   'а',
#   'во',
#   'вторник',
#   'я',
#   'уже',
#   'встретил',
#   'его',
#   'в',
#   'коляске',
#   'с',
#   'Артемием',
#   'Павловичем',
#   'Гагановым',
#   ',',
#   'человеком',
#   'гордым',
#   ',',
#   'раздражительным',
#   'и',
#   'заносчивым',
#   ',',
#   'несмотря',
#   'на',
#   'всю',
#   'его',
#   'светскость',
#   ',',
#   'и',
#   'с',
#   'которым',
#   ',',
#   'по',
#   'характеру',
#   'его',
#   ',',
#   'довольно',
#   'трудно',
#   'было',
#   'ужиться',
#   '.'],
#  ['У',
#   'губернатора',
#   'Петр',
#   'Степанович',
#   'был',
#   'тоже',
#   'принят',
#   'прекрасно',
#   ',',
#   'до',
#   'того',
#   ',',
#   'что',
#   'тотчас',
#   'же',
#   'стал',
#   'в',
#   'положение',
#   'близкого',
#   'или',
#   'так-сказать',
#   'обласканного',
#   'молодого',
#   'человека',
#   ';',
#   'обедал',
#   'у',
#   'Юлии',
#   'Михайловны',
#   'почти',
#   'ежедневно',
#   '.'],
#  ['Познакомился',
#   'он',
#   'с',
#   'нею',
#   'еще',
#   'в',
#   'Швейцарии',
#   ',',
#   'но',
#   'в',
#   'быстром',
#   'успехе',
#   'его',
#   'в',
#   'доме',
#   'его',
#   'превосходительства',
#   'действительно',
#   'заключалось',
#   'нечто',
#   'любопытное',
#   '.'],
#  ['Все-таки',
#   'он',
#   'слыл',
#   'же',
#   'когда-то',
#   'заграничным',
#   'революционером',
#   ',',
#   'правда',
#   'ли',
#   ',',
#   'нет',
#   'ли',
#   ',',
#   'участвовал',
#   'в',
#   'каких-то',
#   'заграничных',
#   'изданиях',
#   'и',
#   'конгрессах',
#   ',',
#   '"',
#   'что',
#   'можно',
#   'даже',
#   'из',
#   'газет',
#   'доказать',
#   '"',
#   ',',
#   'как',
#   'злобно',
#   'выразился',
#   'мне',
#   'при',
#   'встрече',
#   'Алеша',
#   'Телятников',
#   ',',
#   'теперь',
#   ',',
#   'увы',
#   ',',
#   'отставной',
#   'чиновничек',
#   ',',
#   'а',
#   'прежде',
#   'тоже',
#   'обласканный',
#   'молодой',
#   'человек',
#   'в',
#   'доме',
#   'старого',
#   'губернатора',
#   '.'],
#  ['Но',
#   'тут',
#   'стоял',
#   'однако',
#   'же',
#   'факт',
#   ':',
#   'бывший',
#   'революционер',
#   'явился',
#   'в',
#   'любезном',
#   'отечестве',
#   'не',
#   'только',
#   'без',
#   'всякого',
#   'беспокойства',
#   ',',
#   'но',
#   'чуть',
#   'ли',
#   'не',
#   'с',
#   'поощрениями',
#   ';',
#   'стало',
#   'быть',
#   ',',
#   'ничего',
#   ',',
#   'может',
#   ',',
#   'и',
#   'не',
#   'было',
#   '.'],
#  ['Липутин',
#   'шепнул',
#   'мне',
#   'раз',
#   ',',
#   'что',
#   ',',
#   'по',
#   'слухам',
#   ',',
#   'Петр',
#   'Степанович',
#   'будто',
#   'бы',
#   'где-то',
#   'принес',
#   'покаяние',
#   'и',
#   'получил',
#   'отпущение',
#   ',',
#   'назвав',
#   'несколько',
#   'прочих',
#   'имен',
#   ',',
#   'и',
#   'таким',
#   'образом',
#   ',',
#   'может',
#   ',',
#   'и',
#   'успел',
#   'уже',
#   'заслужить',
#   'вину',
#   ',',
#   'обещая',
#   'и',
#   'впредь',
#   'быть',
#   'полезным',
#   'отечеству',
#   '.'],
#  ['Я',
#   'передал',
#   'эту',
#   'ядовитую',
#   'фразу',
#   'Степану',
#   'Трофимовичу',
#   ',',
#   'и',
#   'тот',
#   ',',
#   'несмотря',
#   'на',
#   'то',
#   ',',
#   'что',
#   'был',
#   'почти',
#   'не',
#   'в',
#   'состоянии',
#   'соображать',
#   ',',
#   'сильно',
#   'задумался',
#   '.'],
#  ['Впоследствии',
#   'обнаружилось',
#   ',',
#   'что',
#   'Петр',
#   'Степанович',
#   'приехал',
#   'к',
#   'нам',
#   'с',
#   'чрезвычайно',
#   'почтенными',
#   'рекомендательными',
#   'письмами',
#   ',',
#   'по',
#   'крайней',
#   'мере',
#   'привез',
#   'одно',
#   'к',
#   'губернаторше',
#   'от',
#   'одной',
#   'чрезвычайно',
#   'важной',
#   'петербургской',
#   'старушки',
#   ',',
#   'муж',
#   'которой',
#   'был',
#   'одним',
#   'из',
#   'самых',
#   'значительных',
#   'петербургских',
#   'старичков',
#   '.'],
#  ['Эта',
#   'старушка',
#   ',',
#   'крестная',
#   'мать',
#   'Юлии',
#   'Михайловны',
#   ',',
#   'упоминала',
#   'в',
#   'письме',
#   'своем',
#   ',',
#   'что',
#   'и',
#   'граф',
#   'К',
#   '.',
#   'хорошо',
#   'знает',
#   'Петра',
#   'Степановича',
#   ',',
#   'чрез',
#   'Николая',
#   'Всеволодовича',
#   ',',
#   'обласкал',
#   'его',
#   'и',
#   'находит',
#   '"',
#   'достойным',
#   'молодым',
#   'человеком',
#   ',',
#   'несмотря',
#   'на',
#   'бывшие',
#   'заблуждения',
#   '"',
#   '.'],
#  ['Юлия',
#   'Михайловна',
#   'до',
#   'крайности',
#   'ценила',
#   'свои',
#   'скудные',
#   'и',
#   'с',
#   'таким',
#   'трудом',
#   'поддерживаемые',
#   'связи',
#   'с',
#   '"',
#   'высшим',
#   'миром',
#   '"',
#   'и',
#   'уж',
#   'конечно',
#   'была',
#   'рада',
#   'письму',
#   'важной',
#   'старушки',
#   ';',
#   'но',
#   'все-таки',
#   'оставалось',
#   'тут',
#   'нечто',
#   'как',
#   'бы',
#   'и',
#   'особенное',
#   '.'],
#  ['Даже',
#   'супруга',
#   'своего',
#   'поставила',
#   'к',
#   'Петру',
#   'Степановичу',
#   'в',
#   'отношения',
#   'почти',
#   'фамилиарные',
#   ',',
#   'так',
#   'что',
#   'г',
#   '.',
#   'фон-Лембке',
#   'жаловался',
#   '...',
#   'но',
#   'об',
#   'этом',
#   'тоже',
#   'после',
#   '.'],
#  ['Замечу',
#   'тоже',
#   'для',
#   'памяти',
#   ',',
#   'что',
#   'и',
#   'великий',
#   'писатель',
#   'весьма',
#   'благосклонно',
#   'отнесся',
#   'к',
#   'Петру',
#   'Степановичу',
#   'и',
#   'тотчас',
#   'же',
#   'пригласил',
#   'его',
#   'к',
#   'себе',
#   '.'],
#  ['Такая',
#   'поспешность',
#   'такого',
#   'надутого',
#   'собою',
#   'человека',
#   'кольнула',
#   'Степана',
#   'Трофимовича',
#   'больнее',
#   'всего',
#   ';',
#   'но',
#   'я',
#   'объяснил',
#   'себе',
#   'иначе',
#   ':',
#   'зазывая',
#   'к',
#   'себе',
#   'нигилиста',
#   ',',
#   'г',
#   '.',
#   'Кармазинов',
#   'уж',
#   'конечно',
#   'имел',
#   'в',
#   'виду',
#   'сношения',
#   'его',
#   'с',
#   'прогрессивными',
#   'юношами',
#   'обеих',
#   'столиц',
#   '.'],
#  ['Великий',
#   'писатель',
#   'болезненно',
#   'трепетал',
#   'пред',
#   'новейшею',
#   'революционною',
#   'молодежью',
#   'и',
#   ',',
#   'воображая',
#   ',',
#   'по',
#   'незнанию',
#   'дела',
#   ',',
#   'что',
#   'в',
#   'руках',
#   'ее',
#   'ключи',
#   'русской',
#   'будущности',
#   ',',
#   'унизительно',
#   'к',
#   'ним',
#   'подлизывался',
#   ',',
#   'главное',
#   'потому',
#   'что',
#   'они',
#   'не',
#   'обращали',
#   'на',
#   'него',
#   'никакого',
#   'внимания',
#   '.'],
#  ['II',
#   'Петр',
#   'Степанович',
#   'забежал',
#   'раза',
#   'два',
#   'и',
#   'к',
#   'родителю',
#   ',',
#   'и',
#   ',',
#   'к',
#   'несчастию',
#   'моему',
#   ',',
#   'оба',
#   'раза',
#   'в',
#   'мое',
#   'отсутствие',
#   '.'],
#  ['В',
#   'первый',
#   'раз',
#   'посетил',
#   'его',
#   'в',
#   'среду',
#   ',',
#   'то-есть',
#   'на',
#   'четвертый',
#   'лишь',
#   'день',
#   'после',
#   'той',
#   'первой',
#   'встречи',
#   ',',
#   'да',
#   'и',
#   'то',
#   'по',
#   'делу',
#   '.'],
#  ['Кстати',
#   ',',
#   'расчет',
#   'по',
#   'имению',
#   'окончился',
#   'у',
#   'них',
#   'как-то',
#   'неслышно',
#   'и',
#   'невидно',
#   '.'],
#  ['Варвара',
#   'Петровна',
#   'взяла',
#   'все',
#   'на',
#   'себя',
#   'и',
#   'все',
#   'выплатила',
#   ',',
#   'разумеется',
#   ',',
#   'приобретя',
#   'землицу',
#   ',',
#   'а',
#   'Степана',
#   'Трофимовича',
#   'только',
#   'уведомила',
#   'о',
#   'том',
#   ',',
#   'что',
#   'все',
#   'кончено',
#   ',',
#   'и',
#   'уполномоченный',
#   'Варвары',
#   'Петровны',
#   ',',
#   'камердинер',
#   'ее',
#   'Алексей',
#   'Егорович',
#   ',',
#   'поднес',
#   'ему',
#   'что-то',
#   'подписать',
#   ',',
#   'что',
#   'он',
#   'и',
#   'исполнил',
#   'молча',
#   'и',
#   'с',
#   'чрезвычайным',
#   'достоинством',
#   '.'],
#  ['Замечу',
#   'по',
#   'поводу',
#   'достоинства',
#   ',',
#   'что',
#   'я',
#   'почти',
#   'не',
#   'узнавал',
#   'нашего',
#   'прежнего',
#   'старички',
#   'в',
#   'эти',
#   'дни',
#   '.'],
#  ['Он',
#   'держал',
#   'себя',
#   'как',
#   'никогда',
#   'прежде',
#   ',',
#   'стал',
#   'удивительно',
#   'молчалив',
#   ',',
#   'даже',
#   'не',
#   'написал',
#   'ни',
#   'одного',
#   'письма',
#   'Варваре',
#   'Петровне',
#   'с',
#   'самого',
#   'воскресенья',
#   ',',
#   'что',
#   'я',
#   'счел',
#   'бы',
#   'чудом',
#   ',',
#   'а',
#   'главное',
#   'стал',
#   'спокоен',
#   '.'],
#  ['Он',
#   'укрепился',
#   'на',
#   'какой-то',
#   'окончательной',
#   'и',
#   'чрезвычайной',
#   'идее',
#   ',',
#   'придававшей',
#   'ему',
#   'спокойствие',
#   ',',
#   'это',
#   'было',
#   'видно',
#   '.'],
#  ['Он', 'нашел', 'эту', 'идею', ',', 'сидел', 'и', 'чего-то', 'ждал', '.'],
#  ['Сначала',
#   'впрочем',
#   'был',
#   'болен',
#   ',',
#   'особенно',
#   'в',
#   'понедельник',
#   ';',
#   'была',
#   'холерина',
#   '.'],
#  ['Тоже',
#   'и',
#   'без',
#   'вестей',
#   'пробыть',
#   'не',
#   'мог',
#   'во',
#   'все',
#   'время',
#   ';',
#   'но',
#   'лишь',
#   'только',
#   'я',
#   ',',
#   'оставляя',
#   'факты',
#   ',',
#   'переходил',
#   'к',
#   'сути',
#   'дела',
#   'и',
#   'высказывал',
#   'какие-нибудь',
#   'предположения',
#   ',',
#   'то',
#   'он',
#   'тотчас',
#   'же',
#   'начинал',
#   'махать',
#   'на',
#   'меня',
#   'руками',
#   ',',
#   'чтоб',
#   'я',
#   'перестал',
#   '.'],
#  ['Но',
#   'оба',
#   'свидания',
#   'с',
#   'сынком',
#   'все-таки',
#   'болезненно',
#   'на',
#   'него',
#   'подействовали',
#   ',',
#   'хотя',
#   'и',
#   'не',
#   'поколебали',
#   '.'],
#  ['В',
#   'оба',
#   'эти',
#   'дня',
#   ',',
#   'после',
#   'свиданий',
#   ',',
#   'он',
#   'лежал',
#   'на',
#   'диване',
#   ',',
#   'обмотав',
#   'голову',
#   'платком',
#   ',',
#   'намоченным',
#   'в',
#   'уксусе',
#   ';',
#   'но',
#   'в',
#   'высшем',
#   'смысле',
#   'продолжал',
#   'оставаться',
#   'спокойным',
#   '.'],
#  ['Иногда',
#   ',',
#   'впрочем',
#   ',',
#   'он',
#   'и',
#   'не',
#   'махал',
#   'на',
#   'меня',
#   'руками',
#   '.'],
#  ['Иногда',
#   'тоже',
#   'казалось',
#   'мне',
#   ',',
#   'что',
#   'принятая',
#   'таинственная',
#   'решимость',
#   'как',
#   'бы',
#   'оставляла',
#   'его',
#   ',',
#   'и',
#   'что',
#   'он',
#   'начинал',
#   'бороться',
#   'с',
#   'каким-то',
#   'новым',
#   'соблазнительным',
#   'наплывом',
#   'идей',
#   '.'],
#  ['Это', 'было', 'мгновениями', ',', 'но', 'я', 'отмечаю', 'их', '.'],
#  ['Я',
#   'подозревал',
#   ',',
#   'что',
#   'ему',
#   'очень',
#   'бы',
#   'хотелось',
#   'опять',
#   'заявить',
#   'себя',
#   ',',
#   'выйти',
#   'из',
#   'уединения',
#   ',',
#   'предложить',
#   'борьбу',
#   ',',
#   'задать',
#   'последнюю',
#   'битву',
#   '.'],
#  ['-',
#   'Cher',
#   ',',
#   'я',
#   'бы',
#   'их',
#   'разгромил',
#   '!',
#   '-',
#   'вырвалось',
#   'у',
#   'него',
#   'в',
#   'четверг',
#   'вечером',
#   ',',
#   'после',
#   'второго',
#   'свидания',
#   'с',
#   'Петром',
#   'Степановичем',
#   ',',
#   'когда',
#   'он',
#   'лежал',
#   ',',
#   'протянувшись',
#   'на',
#   'диване',
#   ',',
#   'с',
#   'головой',
#   ',',
#   'обернутою',
#   'полотенцем',
#   '.'],
#  ['До',
#   'этой',
#   'минуты',
#   'он',
#   'во',
#   'весь',
#   'день',
#   'еще',
#   'ни',
#   'слова',
#   'не',
#   'сказал',
#   'со',
#   'мной',
#   '.'],
#  ['-',
#   '"',
#   'Fils',
#   ',',
#   'fils',
#   'ch',
#   'й',
#   'ri',
#   '"',
#   'и',
#   'так',
#   'далее',
#   ',',
#   'я',
#   'согласен',
#   ',',
#   'что',
#   'все',
#   'эти',
#   'выражения',
#   'вздор',
#   ',',
#   'кухарочный',
#   'словарь',
#   ',',
#   'да',
#   'и',
#   'пусть',
#   'их',
#   ',',
#   'я',
#   'сам',
#   'теперь',
#   'вижу',
#   '.'],
#  ['Я',
#   'его',
#   'не',
#   'кормил',
#   'и',
#   'не',
#   'поил',
#   ',',
#   'я',
#   'отослал',
#   'его',
#   'из',
#   'Берлина',
#   'в',
#   'скую',
#   'губернию',
#   ',',
#   'грудного',
#   'ребенка',
#   ',',
#   'по',
#   'почте',
#   ',',
#   'ну',
#   'и',
#   'так',
#   'далее',
#   ',',
#   'я',
#   'согласен',
#   '...'],
#  ['"',
#   'Ты',
#   ',',
#   'говорит',
#   ',',
#   'меня',
#   'не',
#   'поил',
#   'и',
#   'по',
#   'почте',
#   'выслал',
#   ',',
#   'да',
#   'еще',
#   'здесь',
#   'ограбил',
#   '"',
#   '.'],
#  ['Но',
#   ',',
#   'несчастный',
#   ',',
#   'кричу',
#   'ему',
#   ',',
#   'ведь',
#   'болел',
#   'же',
#   'я',
#   'за',
#   'тебя',
#   'сердцем',
#   'всю',
#   'мою',
#   'жизнь',
#   ',',
#   'хотя',
#   'и',
#   'по',
#   'почте',
#   '!'],
#  ['Il', 'rit', '.'],
#  ['Но',
#   'я',
#   'согласен',
#   ',',
#   'согласен',
#   '...',
#   'пусть',
#   'по',
#   'почте',
#   ',',
#   '-',
#   'закончил',
#   'он',
#   'как',
#   'в',
#   'бреду',
#   '.'],
#  ['-',
#   'Passons',
#   ',',
#   '-',
#   'начал',
#   'он',
#   'опять',
#   'через',
#   'пять',
#   'минут',
#   '.'],
#  ['-', 'Я', 'не', 'понимаю', 'Тургенева', '.'],
#  ['У',
#   'него',
#   'Базаров',
#   'это',
#   'какое-то',
#   'фиктивное',
#   'лицо',
#   ',',
#   'не',
#   'существующее',
#   'вовсе',
#   ';',
#   'они',
#   'же',
#   'первые',
#   'и',
#   'отвергли',
#   'его',
#   'тогда',
#   ',',
#   'как',
#   'ни',
#   'на',
#   'что',
#   'не',
#   'похожее',
#   '.'],
#  ['Этот',
#   'Базаров',
#   'это',
#   'какая-то',
#   'неясная',
#   'смесь',
#   'Ноздрева',
#   'с',
#   'Байроном',
#   ',',
#   'c',
#   "'",
#   'est',
#   'le',
#   'mot',
#   '!'],
#  ['Посмотрите',
#   'на',
#   'них',
#   'внимательно',
#   ':',
#   'они',
#   'кувыркаются',
#   'и',
#   'визжат',
#   'от',
#   'радости',
#   'как',
#   'щенки',
#   'на',
#   'солнце',
#   ',',
#   'они',
#   'счастливы',
#   ',',
#   'они',
#   'победители',
#   '!'],
#  ['Какой', 'тут', 'Байрон', '!..'],
#  ['И', 'при', 'том', 'какие', 'будни', '!'],
#  ['Какая',
#   'кухарочная',
#   'раздражительность',
#   'самолюбия',
#   ',',
#   'какая',
#   'пошленькая',
#   'жаждишка',
#   'faire',
#   'du',
#   'bruit',
#   'autour',
#   'de',
#   'son',
#   'nom',
#   ',',
#   'не',
#   'замечая',
#   ',',
#   'что',
#   'son',
#   'nom',
#   '...'],
#  ['О', ',', 'карикатура', '!'],
#  ['Помилуй',
#   ',',
#   'кричу',
#   'ему',
#   ',',
#   'да',
#   'неужто',
#   'ты',
#   'себя',
#   'такого',
#   'как',
#   'есть',
#   'людям',
#   'взамен',
#   'Христа',
#   'предложить',
#   'желаешь',
#   '?'],
#  ['Il', 'rit', '.'],
#  ['Il', 'rit', 'beaucoup', ',', 'il', 'rit', 'trop', '.'],
#  ['У', 'него', 'какая-то', 'странная', 'улыбка', '.'],
#  ['У', 'его', 'матери', 'не', 'было', 'такой', 'улыбки', '.'],
#  ['Il', 'rit', 'toujours', '.'],
#  ['Опять', 'наступило', 'молчание', '.'],
#  ['-',
#   'Они',
#   'хитры',
#   ';',
#   'в',
#   'воскресенье',
#   'они',
#   'сговорились',
#   '...',
#   '-',
#   'брякнул',
#   'он',
#   'вдруг',
#   '.'],
#  ['-',
#   'О',
#   ',',
#   'без',
#   'сомнения',
#   ',',
#   '-',
#   'вскричал',
#   'я',
#   ',',
#   'навострив',
#   'уши',
#   ',',
#   '-',
#   'все',
#   'это',
#   'стачка',
#   'и',
#   'сшито',
#   'белыми',
#   'нитками',
#   ',',
#   'и',
#   'так',
#   'дурно',
#   'разыграно',
#   '.'],
#  ['-', 'Я', 'не', 'про', 'то', '.'],
#  ['Знаете',
#   'ли',
#   ',',
#   'что',
#   'все',
#   'это',
#   'было',
#   'нарочно',
#   'сшито',
#   'белыми',
#   'нитками',
#   ',',
#   'чтобы',
#   'заметили',
#   'те',
#   '...',
#   'кому',
#   'надо',
#   '.'],
#  ['Понимаете', 'это', '?'],
#  ['-', 'Нет', ',', 'не', 'понимаю', '.'],
#  ['-', 'Tant', 'mieux', '.'],
#  ['Passons', '.'],
#  ['Я', 'очень', 'раздражен', 'сегодня', '.'],
#  ['-',
#   'Да',
#   'зачем',
#   'же',
#   'вы',
#   'с',
#   'ним',
#   'спорили',
#   ',',
#   'Степан',
#   'Трофимович',
#   '?',
#   '-',
#   'проговорил',
#   'я',
#   'укоризненно',
#   '.'],
#  ['-', 'Je', 'voulais', 'convertir', '.'],
#  ['Конечно', 'смейтесь', '.'],
#  ['Cette',
#   'pauvre',
#   'тетя',
#   ',',
#   'elle',
#   'entendra',
#   'de',
#   'belles',
#   'choses',
#   '!'],
#  ['О',
#   ',',
#   'друг',
#   'мой',
#   ',',
#   'поверите',
#   'ли',
#   ',',
#   'что',
#   'я',
#   'давеча',
#   'ощутил',
#   'себя',
#   'патриотом',
#   '!'],
#  ['Впрочем',
#   'я',
#   'всегда',
#   'сознавал',
#   'себя',
#   'русским',
#   '...',
#   'да',
#   'настоящий',
#   'русский',
#   'и',
#   'не',
#   'может',
#   'быть',
#   'иначе',
#   ',',
#   'как',
#   'мы',
#   'с',
#   'вами',
#   '.'],
#  ['Il',
#   'у',
#   'a',
#   'l',
#   'а',
#   'dedans',
#   'quelque',
#   'chose',
#   'd',
#   "'",
#   'aveugle',
#   'et',
#   'de',
#   'louche',
#   '.'],
#  ['-', 'Непременно', ',', '-', 'ответил', 'я', '.'],
#  ['-',
#   'Друг',
#   'мой',
#   ',',
#   'настоящая',
#   'правда',
#   'всегда',
#   'не',
#   'правдоподобна',
#   ',',
#   'знаете',
#   'ли',
#   'вы',
#   'это',
#   '?'],
#  ['Чтобы',
#   'сделать',
#   'правду',
#   'правдоподобнее',
#   ',',
#   'нужно',
#   'непременно',
#   'подмешать',
#   'к',
#   'ней',
#   'лжи',
#   '.'],
#  ['Люди', 'всегда', 'так', 'и', 'поступали', '.'],
#  ['Может',
#   'быть',
#   ',',
#   'тут',
#   'есть',
#   ',',
#   'чего',
#   'мы',
#   'не',
#   'понимаем',
#   '.'],
#  ['Как',
#   'вы',
#   'думаете',
#   ',',
#   'есть',
#   'тут',
#   ',',
#   'чего',
#   'мы',
#   'не',
#   'понимаем',
#   'в',
#   'этом',
#   'победоносном',
#   'визге',
#   '?'],
#  ['Я', 'бы', 'желал', ',', 'чтобы', 'было', '.'],
#  ['Я', 'бы', 'желал', '.'],
#  ['Я', 'промолчал', '.'],
#  ['Он', 'тоже', 'очень', 'долго', 'молчал', '.'],
#  ['-',
#   'Говорят',
#   ',',
#   'французский',
#   'ум',
#   '...',
#   '-',
#   'залепетал',
#   'он',
#   'вдруг',
#   'точно',
#   'в',
#   'жару',
#   ',',
#   '-',
#   'это',
#   'ложь',
#   ',',
#   'это',
#   'всегда',
#   'так',
#   'и',
#   'было',
#   '.'],
#  ['Зачем', 'клеветать', 'на', 'французский', 'ум', '?'],
#  ['Тут',
#   'просто',
#   'русская',
#   'лень',
#   ',',
#   'наше',
#   'унизительное',
#   'бессилие',
#   'произвести',
#   'идею',
#   ',',
#   'наше',
#   'отвратительное',
#   'паразитство',
#   'в',
#   'ряду',
#   'народов',
#   '.'],
#  ['Ils',
#   'sont',
#   'tout',
#   'simplement',
#   'des',
#   'paresseux',
#   ',',
#   'а',
#   'не',
#   'французский',
#   'ум',
#   '.',
#   'О',
#   ',',
#   'русские',
#   'должны',
#   'бы',
#   'быть',
#   'истреблены',
#   'для',
#   'блага',
#   'человечества',
#   'как',
#   'вредные',
#   'паразиты',
#   '!'],
#  ['Мы',
#   'вовсе',
#   ',',
#   'вовсе',
#   'не',
#   'к',
#   'тому',
#   'стремились',
#   ';',
#   'я',
#   'ничего',
#   'не',
#   'понимаю',
#   '.'],
#  ['Я', 'перестал', 'понимать', '!'],
#  ['Да',
#   'понимаешь',
#   'ли',
#   ',',
#   'кричу',
#   'ему',
#   ',',
#   'понимаешь',
#   'ли',
#   ',',
#   'что',
#   'если',
#   'у',
#   'вас',
#   'гильйотина',
#   'на',
#   'первом',
#   'плане',
#   'и',
#   'с',
#   'таким',
#   'восторгом',
#   ',',
#   'то',
#   'это',
#   'единственно',
#   'потому',
#   ',',
#   'что',
#   'рубить',
#   'головы',
#   'всего',
#   'легче',
#   ',',
#   'а',
#   'иметь',
#   'идею',
#   'всего',
#   'труднее',
#   '!'],
#  ['Vous', 'к', 'tes', 'des', 'paresseux', '!'],
#  ['Votre',
#   'drapeau',
#   'est',
#   'une',
#   'guenille',
#   ',',
#   'une',
#   'impuissance',
#   '.'],
#  ['Эти',
#   'телеги',
#   ',',
#   'или',
#   'как',
#   'там',
#   ':',
#   '"',
#   'стук',
#   'телег',
#   ',',
#   'подвозящих',
#   'хлеб',
#   'человечеству',
#   '"',
#   ',',
#   'полезнее',
#   'Сикстинской',
#   'Мадонны',
#   ',',
#   'или',
#   'как',
#   'у',
#   'них',
#   'там',
#   '...',
#   'une',
#   'b',
#   'к',
#   'tise',
#   'dans',
#   'се',
#   'genre',
#   '.'],
#  ['Но',
#   'понимаешь',
#   'ли',
#   ',',
#   'кричу',
#   'ему',
#   ',',
#   'понимаешь',
#   'ли',
#   'ты',
#   ',',
#   'что',
#   'человеку',
#   'кроме',
#   'счастья',
#   'так',
#   'же',
#   'точно',
#   'и',
#   'совершенно',
#   'во',
#   'столько',
#   'же',
#   'необходимо',
#   'и',
#   'несчастие',
#   '!'],
#  ['Il', 'rit', '.'],
#  ['Ты',
#   ',',
#   'говорит',
#   ',',
#   'здесь',
#   'бонмо',
#   'отпускаешь',
#   ',',
#   '"',
#   'нежа',
#   'свои',
#   'члены',
#   '(',
#   'он',
#   'пакостнее',
#   'выразился',
#   ')',
#   'на',
#   'бархатном',
#   'диване',
#   '"',
#   '...'],
#  ['И',
#   'заметьте',
#   ',',
#   'эта',
#   'наша',
#   'привычка',
#   'на',
#   'ты',
#   'отца',
#   'с',
#   'сыном',
#   ';',
#   'хорошо',
#   ',',
#   'когда',
#   'оба',
#   'согласны',
#   ',',
#   'ну',
#   ',',
#   'а',
#   'если',
#   'ругаются',
#   '?'],
#  ['С', 'минуту', 'опять', 'помолчали', '.'],
#  ['-',
#   'Cher',
#   ',',
#   '-',
#   'заключил',
#   'он',
#   'вдруг',
#   ',',
#   'быстро',
#   'приподнявшись',
#   ',',
#   '-',
#   'знаете',
#   'ли',
#   ',',
#   'что',
#   'это',
#   'непременно',
#   'чем-нибудь',
#   'кончится',
#   '?'],
#  ['-', 'Уж', 'конечно', ',', '-', 'сказал', 'я', '.'],
#  ['-', 'Vous', 'ne', 'comprenez', 'pas', '.'],
#  ['Passons', '.'],
#  ['Но',
#   '...',
#   'обыкновенно',
#   'на',
#   'свете',
#   'кончается',
#   'ничем',
#   ',',
#   'но',
#   'здесь',
#   'будет',
#   'конец',
#   ',',
#   'непременно',
#   ',',
#   'непременно',
#   '!'],
#  ['Он',
#   'встал',
#   ',',
#   'прошелся',
#   'по',
#   'комнате',
#   'в',
#   'сильнейшем',
#   'волнении',
#   'и',
#   ',',
#   'дойдя',
#   'опять',
#   'до',
#   'дивана',
#   ',',
#   'бессильно',
#   'повалился',
#   'на',
#   'него',
#   '.'],
#  ['В',
#   'пятницу',
#   'утром',
#   'Петр',
#   'Степанович',
#   'уехал',
#   'куда-то',
#   'в',
#   'уезд',
#   'и',
#   'пробыл',
#   'до',
#   'понедельника',
#   '.'],
#  ['Об',
#   'отъезде',
#   'его',
#   'я',
#   'узнал',
#   'от',
#   'Липутина',
#   ',',
#   'и',
#   'тут',
#   'же',
#   ',',
#   'как-то',
#   'к',
#   'разговору',
#   ',',
#   'узнал',
#   'от',
#   'него',
#   ',',
#   'что',
#   'Лебядкины',
#   ',',
#   'братец',
#   'и',
#   'сестрица',
#   ',',
#   'оба',
#   'где-то',
#   'за',
#   'рекой',
#   ',',
#   'в',
#   'Горшечной',
#   'слободке',
#   '.'],
#  ['"',
#   'Я',
#   'же',
#   'и',
#   'перевозил',
#   '"',
#   ',',
#   'прибавил',
#   'Липутин',
#   ',',
#   'и',
#   ',',
#   'прервав',
#   'о',
#   'Лебядкиных',
#   ',',
#   'вдруг',
#   'возвестил',
#   'мне',
#   ',',
#   'что',
#   'Лизавета',
#   'Николаевна',
#   'выходит',
#   'за',
#   'Маврикия',
#   'Николаевича',
#   ',',
#   'и',
#   'хоть',
#   'это',
#   'и',
#   'не',
#   'объявлено',
#   ',',
#   'но',
#   'помолвка',
#   'была',
#   'и',
#   'дело',
#   'покончено',
#   '.'],
#  ['Назавтра',
#   'я',
#   'встретил',
#   'Лизавету',
#   'Николаевну',
#   'верхом',
#   'в',
#   'сопровождении',
#   'Маврикия',
#   'Николаевича',
#   ',',
#   'выехавшую',
#   'в',
#   'первый',
#   'раз',
#   'после',
#   'болезни',
#   '.'],
#  ['Она',
#   'сверкнула',
#   'на',
#   'меня',
#   'издали',
#   'глазами',
#   ',',
#   'засмеялась',
#   'и',
#   'очень',
#   'дружески',
#   'кивнула',
#   'головой',
#   '.'],
#  ['Все',
#   'это',
#   'я',
#   'передал',
#   'Степану',
#   'Трофимовичу',
#   ';',
#   'он',
#   'обратил',
#   'некоторое',
#   'внимание',
#   'лишь',
#   'на',
#   'известие',
#   'о',
#   'Лебядкиных',
#   '.'],
#  ['А',
#   'теперь',
#   ',',
#   'описав',
#   'наше',
#   'загадочное',
#   'положение',
#   'в',
#   'продолжение',
#   'этих',
#   'восьми',
#   'дней',
#   ',',
#   'когда',
#   'мы',
#   'еще',
#   'ничего',
#   'не',
#   'знали',
#   ',',
#   'приступлю',
#   'к',
#   'описанию',
#   'последующих',
#   'событий',
#   'моей',
#   'хроники',
#   ',',
#   'и',
#   'уже',
#   ',',
#   'так',
#   'сказать',
#   ',',
#   'с',
#   'знанием',
#   'дела',
#   ',',
#   'в',
#   'том',
#   'виде',
#   ',',
#   'как',
#   'все',
#   'это',
#   'открылось',
#   'и',
#   'объяснилось',
#   'теперь',
#   '.'],
#  ['Начну',
#   'именно',
#   'с',
#   'восьмого',
#   'дня',
#   'после',
#   'того',
#   'воскресенья',
#   ',',
#   'то-есть',
#   'с',
#   'понедельника',
#   'вечером',
#   '-',
#   'потому',
#   'что',
#   'в',
#   'сущности',
#   'с',
#   'этого',
#   'вечера',
#   'и',
#   'началась',
#   '"',
#   'новая',
#   'история',
#   '"',
#   '.'],
#  ['III', 'Было', 'семь', 'часов', 'вечера', '.'],
#  ['Николай',
#   'Всеволодович',
#   'сидел',
#   'один',
#   'в',
#   'своем',
#   'кабинете',
#   ',',
#   '-',
#   'комнате',
#   'им',
#   'еще',
#   'прежде',
#   'излюбленной',
#   ',',
#   'высокой',
#   ',',
#   'устланной',
#   'коврами',
#   ',',
#   'уставленной',
#   'несколько',
#   'тяжелою',
#   ',',
#   'старинного',
#   'фасона',
#   'мебелью',
#   '.'],
#  ['Он',
#   'сидел',
#   'в',
#   'углу',
#   'на',
#   'диване',
#   ',',
#   'одетый',
#   'как',
#   'бы',
#   'для',
#   'выхода',
#   ',',
#   'но',
#   ',',
#   'казалось',
#   ',',
#   'никуда',
#   'не',
#   'собирался',
#   ',',
#   'На',
#   'столе',
#   'пред',
#   'ним',
#   'стояла',
#   'лампа',
#   'с',
#   'абажуром',
#   '.'],
#  ['Бока', 'и', 'углы', 'большой', 'комнаты', 'оставались', 'в', 'тени', '.'],
#  ['Взгляд',
#   'его',
#   'был',
#   'задумчив',
#   'и',
#   'сосредоточен',
#   ',',
#   'не',
#   'совсем',
#   'спокоен',
#   ';',
#   'лицо',
#   'усталое',
#   'и',
#   'несколько',
#   'похудевшее',
#   '.'],
#  ['Болен',
#   'он',
#   'был',
#   'действительно',
#   'флюсом',
#   ';',
#   'но',
#   'слух',
#   'о',
#   'выбитом',
#   'зубе',
#   'был',
#   'преувеличен',
#   '.'],
#  ['Зуб',
#   'только',
#   'шатался',
#   ',',
#   'но',
#   'теперь',
#   'снова',
#   'окреп',
#   ';',
#   'была',
#   'тоже',
#   'рассечена',
#   'изнутри',
#   'верхняя',
#   'губа',
#   ',',
#   'но',
#   'и',
#   'это',
#   'зажило',
#   '.'],
#  ['Флюс',
#   'же',
#   'не',
#   'проходил',
#   'всю',
#   'неделю',
#   'лишь',
#   'потому',
#   ',',
#   'что',
#   'больной',
#   'не',
#   'хотел',
#   'принять',
#   'доктора',
#   'и',
#   'вовремя',
#   'дать',
#   'разрезать',
#   'опухоль',
#   ',',
#   'а',
#   'ждал',
#   ',',
#   'пока',
#   'нарыв',
#   'сам',
#   'прорвется',
#   '.'],
#  ['Он',
#   'не',
#   'только',
#   'доктора',
#   ',',
#   'но',
#   'и',
#   'мать',
#   'едва',
#   'допускал',
#   'к',
#   'себе',
#   ',',
#   'и',
#   'то',
#   'на',
#   'минуту',
#   ',',
#   'один',
#   'раз',
#   'на',
#   'дню',
#   'и',
#   'непременно',
#   'в',
#   'сумерки',
#   ',',
#   'когда',
#   'уже',
#   'становилось',
#   'темно',
#   ',',
#   'а',
#   'огня',
#   'еще',
#   'не',
#   'подавали',
#   '.'],
#  ['Не',
#   'принимал',
#   'он',
#   'тоже',
#   'и',
#   'Петра',
#   'Степановича',
#   ',',
#   'который',
#   'однако',
#   'же',
#   'по',
#   'два',
#   'и',
#   'по',
#   'три',
#   'раза',
#   'в',
#   'день',
#   'забегал',
#   'к',
#   'Варваре',
#   'Петровне',
#   ',',
#   'пока',
#   'оставался',
#   'в',
#   'городе',
#   '.'],
#  ['И',
#   'вот',
#   'наконец',
#   'в',
#   'понедельник',
#   ',',
#   'возвратясь',
#   'поутру',
#   'после',
#   'своей',
#   'трехдневной',
#   'отлучки',
#   ',',
#   'обегав',
#   'весь',
#   'город',
#   'и',
#   'отобедав',
#   'у',
#   'Юлии',
#   'Михайловны',
#   ',',
#   'Петр',
#   'Степанович',
#   'к',
#   'вечеру',
#   'явился',
#   'наконец',
#   'к',
#   'нетерпеливо',
#   'ожидавшей',
#   'его',
#   'Варваре',
#   'Петровне',
#   '.'],
#  ['Запрет', 'был', 'снят', ',', 'Николай', 'Всеволодович', 'принимал', '.'],
#  ['Варвара',
#   'Петровна',
#   'сама',
#   'подвела',
#   'гостя',
#   'к',
#   'дверям',
#   'кабинета',
#   ';',
#   'она',
#   'давно',
#   'желала',
#   'их',
#   'свиданья',
#   ',',
#   'а',
#   'Петр',
#   'Степанович',
#   'дал',
#   'ей',
#   'слово',
#   'забежать',
#   'к',
#   'ней',
#   'от',
#   'Nicolas',
#   'и',
#   'пересказать',
#   '.'],
#  ['Робко',
#   'постучалась',
#   'она',
#   'к',
#   'Николаю',
#   'Всеволодовичу',
#   'и',
#   ',',
#   'не',
#   'получая',
#   'ответа',
#   ',',
#   'осмелилась',
#   'приотворить',
#   'дверь',
#   'вершка',
#   'на',
#   'два',
#   '.'],
#  ['-',
#   'Nicolas',
#   ',',
#   'могу',
#   'я',
#   'ввести',
#   'к',
#   'тебе',
#   'Петра',
#   'Степановича',
#   '?',
#   '-',
#   'тихо',
#   'и',
#   'сдержанно',
#   'спросила',
#   'она',
#   ',',
#   'стараясь',
#   'разглядеть',
#   'Николая',
#   'Всеволодовича',
#   'из-за',
#   'лампы',
#   '.'],
#  ['-',
#   'Можно',
#   ',',
#   'можно',
#   ',',
#   'конечно',
#   'можно',
#   '!',
#   '-',
#   'громко',
#   'и',
#   'весело',
#   'крикнул',
#   'сам',
#   'Петр',
#   'Степанович',
#   ',',
#   'отворил',
#   'дверь',
#   'своею',
#   'рукой',
#   'и',
#   'вошел',
#   '.'],
#  ['Николай',
#   'Всеволодович',
#   'не',
#   'слыхал',
#   'стука',
#   'в',
#   'дверь',
#   ',',
#   'а',
#   'расслышал',
#   'лишь',
#   'только',
#   'робкий',
#   'вопрос',
#   'мамаши',
#   ',',
#   'но',
#   'не',
#   'успел',
#   'на',
#   'него',
#   'ответить',
#   '.'],
#  ['Пред',
#   'ним',
#   'в',
#   'эту',
#   'минуту',
#   'лежало',
#   'только',
#   'что',
#   'прочитанное',
#   'им',
#   'письмо',
#   ',',
#   'над',
#   'которым',
#   'он',
#   'сильно',
#   'задумался',
#   '.'],
#  ['Он',
#   'вздрогнул',
#   ',',
#   'заслышав',
#   'внезапный',
#   'окрик',
#   'Петра',
#   'Степановича',
#   ',',
#   'и',
#   'поскорее',
#   'накрыл',
#   'письмо',
#   'попавшимся',
#   'под',
#   'руку',
#   'преспапье',
#   ',',
#   'но',
#   'не',
#   'совсем',
#   'удалось',
#   ':',
#   'угол',
#   'письма',
#   'и',
#   'почти',
#   'весь',
#   'конверт',
#   'выглядывали',
#   'наружу',
#   '.'],
#  ['-',
#   'Я',
#   'нарочно',
#   'крикнул',
#   'изо',
#   'всей',
#   'силы',
#   ',',
#   'чтобы',
#   'вы',
#   'успели',
#   'приготовиться',
#   ',',
#   '-',
#   'торопливо',
#   'с',
#   'удивительною',
#   'наивностью',
#   'прошептал',
#   'Петр',
#   'Степанович',
#   ',',
#   'подбегая',
#   'к',
#   'столу',
#   ',',
#   'и',
#   'мигом',
#   'уставился',
#   'на',
#   'преспапье',
#   'и',
#   'на',
#   'угол',
#   'письма',
#   '.'],
#  ['-',
#   'И',
#   'конечно',
#   'успели',
#   'подглядеть',
#   ',',
#   'как',
#   'я',
#   'прятал',
#   'от',
#   'вас',
#   'под',
#   'преспапье',
#   'только',
#   'что',
#   'полученное',
#   'мною',
#   'письмо',
#   ',',
#   '-',
#   'спокойно',
#   'проговорил',
#   'Николай',
#   'Всеволодович',
#   ',',
#   'не',
#   'трогаясь',
#   'с',
#   'места',
#   '.'],
#  ['-', 'Письмо', '?'],
#  ['Бог',
#   'с',
#   'вами',
#   'и',
#   'с',
#   'вашим',
#   'письмом',
#   ',',
#   'мне',
#   'что',
#   '!',
#   '-',
#   'воскликнул',
#   'гость',
#   ',',
#   '-',
#   'но',
#   '...',
#   'главное',
#   ',',
#   '-',
#   'зашептал',
#   'он',
#   'опять',
#   ',',
#   'обертываясь',
#   'к',
#   'двери',
#   ',',
#   'уже',
#   'запертой',
#   ',',
#   'и',
#   'кивая',
#   'в',
#   'ту',
#   'сторону',
#   'головой',
#   '.'],
#  ['-',
#   'Она',
#   'никогда',
#   'не',
#   'подслушивает',
#   ',',
#   '-',
#   'холодно',
#   'заметил',
#   'Николай',
#   'Всеволодович',
#   '.'],
#  ['-',
#   'То-есть',
#   'если',
#   'б',
#   'и',
#   'подслушивала',
#   '!',
#   '-',
#   'мигом',
#   'подхватил',
#   ',',
#   'весело',
#   'возвышая',
#   'голос',
#   'и',
#   'усаживаясь',
#   'в',
#   'кресло',
#   ',',
#   'Петр',
#   'Степанович',
#   '.'],
#  ['-',
#   'Я',
#   'ничего',
#   'против',
#   'этого',
#   ',',
#   'я',
#   'только',
#   'теперь',
#   'бежал',
#   'поговорить',
#   'наедине',
#   '...'],
#  ['Ну', ',', 'наконец-то', 'я', 'к', 'вам', 'добился', '!'],
#  ['Прежде', 'всего', 'как', 'здоровье', '?'],
#  ['Вижу',
#   ',',
#   'что',
#   'прекрасно',
#   ',',
#   'и',
#   'завтра',
#   ',',
#   'может',
#   'быть',
#   ',',
#   'вы',
#   'явитесь',
#   ',',
#   '-',
#   'а',
#   '?'],
#  ['-', 'Может', 'быть', '.'],
#  ['-',
#   'Разрешите',
#   'их',
#   'наконец',
#   ',',
#   'разрешите',
#   'меня',
#   '!',
#   '-',
#   'неистово',
#   'зажестикулировал',
#   'он',
#   'с',
#   'шутливым',
#   'и',
#   'приятным',
#   'видом',
#   '.'],
#  ['-',
#   'Если',
#   'б',
#   'вы',
#   'знали',
#   ',',
#   'что',
#   'я',
#   'должен',
#   'был',
#   'им',
#   'наболтать',
#   '.'],
#  ['А', 'впрочем', 'вы', 'знаете', '.'],
#  ['-', 'Он', 'засмеялся', '.'],
#  ['-', 'Всего', 'не', 'знаю', '.'],
#  ['Я',
#   'слышал',
#   'только',
#   'от',
#   'матери',
#   ',',
#   'что',
#   'вы',
#   'очень',
#   '...',
#   'двигались',
#   '.'],
#  ['-',
#   'То-есть',
#   'я',
#   'ведь',
#   'ничего',
#   'определенного',
#   ',',
#   '-',
#   'вскинулся',
#   'вдруг',
#   'Петр',
#   'Степанович',
#   ',',
#   'как',
#   'бы',
#   'защищаясь',
#   'от',
#   'ужасного',
#   'нападения',
#   ',',
#   '-',
#   'знаете',
#   ',',
#   'я',
#   'пустил',
#   'в',
#   'ход',
#   'жену',
#   'Шатова',
#   ',',
#   'то-есть',
#   'слухи',
#   'о',
#   'ваших',
#   'связях',
#   'в',
#   'Париже',
#   ',',
#   'чем',
#   'и',
#   'объяснялся',
#   'конечно',
#   'тот',
#   'случай',
#   'в',
#   'воскресенье',
#   '...',
#   'вы',
#   'не',
#   'сердитесь',
#   '?'],
#  ['-', 'Убежден', ',', 'что', 'вы', 'очень', 'старались', '.'],
#  ['-', 'Ну', ',', 'я', 'только', 'этого', 'и', 'боялся', '.'],
#  ['А',
#   'впрочем',
#   'что',
#   'ж',
#   'это',
#   'значит',
#   ':',
#   '"',
#   'очень',
#   'старались',
#   '"',
#   '?'],
#  ['Это', 'ведь', 'упрек', '.'],
#  ['Впрочем',
#   'вы',
#   'прямо',
#   'ставите',
#   ',',
#   'я',
#   'всего',
#   'больше',
#   'боялся',
#   ',',
#   'идя',
#   'сюда',
#   ',',
#   'что',
#   'вы',
#   'не',
#   'захотите',
#   'прямо',
#   'поставить',
#   '.'],
#  ['-',
#   'Я',
#   'ничего',
#   'и',
#   'не',
#   'хочу',
#   'прямо',
#   'ставить',
#   ',',
#   '-',
#   'проговорил',
#   'Николай',
#   'Всеволодович',
#   'с',
#   'некоторым',
#   'раздражением',
#   ',',
#   'но',
#   'тотчас',
#   'же',
#   'усмехнулся',
#   '.'],
#  ['-',
#   'Я',
#   'не',
#   'про',
#   'то',
#   ';',
#   'не',
#   'про',
#   'то',
#   ',',
#   'не',
#   'ошибитесь',
#   ',',
#   'не',
#   'про',
#   'то',
#   '!',
#   '-',
#   'замахал',
#   'руками',
#   'Петр',
#   'Степанович',
#   ',',
#   'сыпля',
#   'словами',
#   'как',
#   'горохом',
#   'и',
#   'тотчас',
#   'же',
#   'обрадовавшись',
#   'раздражительности',
#   'хозяина',
#   '.'],
#  ['-',
#   'Я',
#   'не',
#   'стану',
#   'вас',
#   'раздражать',
#   'нашим',
#   'делом',
#   ',',
#   'особенно',
#   'в',
#   'вашем',
#   'теперешнем',
#   'положении',
#   '.'],
#  ['Я',
#   'прибежал',
#   'только',
#   'о',
#   'воскресном',
#   'случае',
#   ',',
#   'и',
#   'то',
#   'в',
#   'самую',
#   'необходимую',
#   'меру',
#   ',',
#   'потому',
#   'нельзя',
#   'же',
#   'ведь',
#   '.'],
#  ['Я',
#   'с',
#   'самыми',
#   'открытыми',
#   'объяснениями',
#   ',',
#   'в',
#   'которых',
#   'нуждаюсь',
#   'главное',
#   'я',
#   ',',
#   'а',
#   'не',
#   'вы',
#   ',',
#   '-',
#   'это',
#   'для',
#   'вашего',
#   'самолюбия',
#   ',',
#   'но',
#   'в',
#   'то',
#   'же',
#   'время',
#   'это',
#   'и',
#   'правда',
#   '.'],
#  ['Я',
#   'пришел',
#   ',',
#   'чтобы',
#   'быть',
#   'с',
#   'этих',
#   'пор',
#   'всегда',
#   'откровенным',
#   '.'],
#  ['-', 'Стало', 'быть', ',', 'прежде', 'были', 'неоткровенны', '?'],
#  ['-', 'И', 'вы', 'это', 'знаете', 'сами', '.'],
#  ['Я',
#   'хитрил',
#   'много',
#   'раз',
#   '...',
#   'вы',
#   'улыбнулись',
#   ',',
#   'очень',
#   'рад',
#   'улыбке',
#   ',',
#   'как',
#   'предлогу',
#   'для',
#   'разъяснения',
#   ';',
#   'я',
#   'ведь',
#   'нарочно',
#   'вызвал',
#   'улыбку',
#   'хвастливым',
#   'словом',
#   '"',
#   'хитрил',
#   '"',
#   ',',
#   'для',
#   'того',
#   ',',
#   'чтобы',
#   'вы',
#   'тотчас',
#   'же',
#   'и',
#   'рассердились',
#   ':',
#   'как',
#   'это',
#   'я',
#   'смел',
#   'подумать',
#   ',',
#   'что',
#   'могу',
#   'хитрить',
#   ',',
#   'а',
#   'мне',
#   ',',
#   'чтобы',
#   'сейчас',
#   'же',
#   'объясниться',
#   '.'],
#  ['Видите',
#   ',',
#   'видите',
#   ',',
#   'как',
#   'я',
#   'стал',
#   'теперь',
#   'откровенен',
#   '!'],
#  ['Ну-с', ',', 'угодно', 'вам', 'выслушать', '?'],
#  ['В',
#   'выражении',
#   'лица',
#   'Николая',
#   'Всеволодовича',
#   ',',
#   'презрительно',
#   'спокойном',
#   'и',
#   'даже',
#   'насмешливом',
#   ',',
#   'несмотря',
#   'на',
#   'все',
#   'очевидное',
#   'желание',
#   'гостя',
#   'раздражить',
#   'хозяина',
#   'нахальностию',
#   'своих',
#   'заранее',
#   'наготовленных',
#   'и',
#   'с',
#   'намерением',
#   'грубых',
#   'наивностей',
#   ',',
#   '-',
#   'выразилось',
#   'наконец',
#   'несколько',
#   'тревожное',
#   'любопытство',
#   '.'],
#  ['-',
#   'Слушайте',
#   'же',
#   ',',
#   '-',
#   'завертелся',
#   'Петр',
#   'Степанович',
#   'пуще',
#   'прежнего',
#   '.'],
#  ['-',
#   'Отправляясь',
#   'сюда',
#   ',',
#   'то-есть',
#   'вообще',
#   'сюда',
#   ',',
#   'в',
#   'этот',
#   'город',
#   ',',
#   'десять',
#   'дней',
#   'назад',
#   ',',
#   'я',
#   'конечно',
#   'решился',
#   'взять',
#   'роль',
#   '.'],
#  ['Самое',
#   'бы',
#   'лучшее',
#   'совсем',
#   'без',
#   'роли',
#   ',',
#   'свое',
#   'собственное',
#   'лицо',
#   ',',
#   'не',
#   'так',
#   'ли',
#   '?'],
#  ['Ничего',
#   'нет',
#   'хитрее',
#   ',',
#   'как',
#   'собственное',
#   'лицо',
#   ',',
#   'потому',
#   'что',
#   'никто',
#   'не',
#   'поверит',
#   '.'],
#  ['Я',
#   ',',
#   'признаться',
#   ',',
#   'хотел',
#   'было',
#   'взять',
#   'дурачка',
#   ',',
#   'потому',
#   'что',
#   'дурачек',
#   'легче',
#   ',',
#   'чем',
#   'собственное',
#   'лицо',
#   ';',
#   'но',
#   'так',
#   'как',
#   'дурачек',
#   'все-таки',
#   'крайность',
#   ',',
#   'а',
#   'крайность',
#   'возбуждает',
#   'любопытство',
#   ',',
#   'то',
#   'я',
#   'и',
#   'остановился',
#   'на',
#   'собственном',
#   'лице',
#   'окончательно',
#   '.'],
#  ['Ну-с', ',', 'какое', 'же', 'мое', 'собственное', 'лицо', '?'],
#  ['Золотая',
#   'средина',
#   ':',
#   'ни',
#   'глуп',
#   ',',
#   'ни',
#   'умен',
#   ',',
#   'довольно',
#   'бездарен',
#   'и',
#   'с',
#   'луны',
#   'соскочил',
#   ',',
#   'как',
#   'говорят',
#   'здесь',
#   'благоразумные',
#   'люди',
#   ',',
#   'не',
#   'так',
#   'ли',
#   '?'],
#  ['-',
#   'Что',
#   'ж',
#   ',',
#   'может',
#   'быть',
#   'и',
#   'так',
#   ',',
#   '-',
#   'чуть-чуть',
#   'улыбнулся',
#   'Николай',
#   'Всеволодович',
#   '.'],
#  ['-',
#   'А',
#   ',',
#   'вы',
#   'согласны',
#   '-',
#   'очень',
#   'рад',
#   ';',
#   'я',
#   'знал',
#   'вперед',
#   ',',
#   'что',
#   'это',
#   'ваши',
#   'собственные',
#   'мысли',
#   '...'],
#  ['Не',
#   'беспокойтесь',
#   ',',
#   'не',
#   'беспокойтесь',
#   ',',
#   'я',
#   'не',
#   'сержусь',
#   'и',
#   'вовсе',
#   'не',
#   'для',
#   'того',
#   'определил',
#   'себя',
#   'в',
#   'таком',
#   'виде',
#   ',',
#   'чтобы',
#   'вызвать',
#   'ваши',
#   'обратные',
#   'похвалы',
#   ':',
#   '"',
#   'нет',
#   ',',
#   'дескать',
#   ',',
#   'вы',
#   'не',
#   'бездарны',
#   ',',
#   'нет',
#   ',',
#   'дескать',
#   ',',
#   'вы',
#   'умны',
#   '"',
#   '...'],
#  ['А', ',', 'вы', 'опять', 'улыбаетесь', '!..'],
#  ['Я', 'опять', 'попался', '.'],
#  ['Вы',
#   'не',
#   'сказали',
#   'бы',
#   ':',
#   '"',
#   'вы',
#   'умны',
#   '"',
#   ',',
#   'ну',
#   'и',
#   'положим',
#   ';',
#   'я',
#   'все',
#   'допускаю',
#   '.'],
#  ['Passons',
#   ',',
#   'как',
#   'говорит',
#   'папаша',
#   ',',
#   'и',
#   ',',
#   'в',
#   'скобках',
#   ',',
#   'не',
#   'сердитесь',
#   'на',
#   'мое',
#   'многословие',
#   '.'],
#  ['Кстати',
#   'вот',
#   'и',
#   'пример',
#   ':',
#   'я',
#   'всегда',
#   'говорю',
#   'много',
#   ',',
#   'то-есть',
#   'много',
#   'слов',
#   ',',
#   'и',
#   'тороплюсь',
#   ',',
#   'и',
#   'у',
#   'меня',
#   'всегда',
#   'не',
#   'выходит',
#   '.'],
#  ['А',
#   'почему',
#   'я',
#   'говорю',
#   'много',
#   'слов',
#   'и',
#   'у',
#   'меня',
#   'не',
#   'выходит',
#   '?'],
#  ['Потому', 'что', 'говорить', 'не', 'умею', '.'],
#  ['Те',
#   ',',
#   'которые',
#   'умеют',
#   'хорошо',
#   'говорить',
#   ',',
#   'те',
#   'коротко',
#   'говорят',
#   '.'],
#  ['Вот',
#   ',',
#   'стало',
#   'быть',
#   ',',
#   'у',
#   'меня',
#   'и',
#   'бездарность',
#   ',',
#   '-',
#   'не',
#   'правда',
#   'ли',
#   '?'],
#  ['Но',
#   'так',
#   'как',
#   'этот',
#   'дар',
#   'бездарности',
#   'у',
#   'меня',
#   'уже',
#   'есть',
#   'натуральный',
#   ',',
#   'так',
#   'почему',
#   'мне',
#   'им',
#   'не',
#   'воспользоваться',
#   'искусственно',
#   '?'],
#  ['Я', 'и', 'пользуюсь', '.'],
#  ['Правда',
#   ',',
#   'собираясь',
#   'сюда',
#   ',',
#   'я',
#   'было',
#   'подумал',
#   'сначала',
#   'молчать',
#   ';',
#   'но',
#   'ведь',
#   'молчать',
#   '-',
#   'большой',
#   'талант',
#   ',',
#   'и',
#   ',',
#   'стало',
#   'быть',
#   ',',
#   'мне',
#   'неприлично',
#   ',',
#   'а',
#   'во-вторых',
#   ',',
#   'молчать',
# ...
#   'я',
#   'не',
#   'мог',
#   'тотчас',
#   'же',
#   'оторваться',
#   'с',
#   'кровью',
#   'от',
#   'того',
#   ',',
#   'к',
#   'чему',
#   'прирос',
#   'с',
#   'детства',
#   ',',
#   'на',
#   'что',
#   'пошли',
#   'все',
#   'восторги',
#   'моих',
#   'надежд',
#   'и',
#   'все',
#   'слезы',
#   'моей',
#   'ненависти',
#   '...'],
#  ['Трудно', 'менять', 'богов', '.'],
#  ['Я',
#   'не',
#   'поверил',
#   'вам',
#   'тогда',
#   ',',
#   'потому',
#   'что',
#   'не',
#   'хотел',
#   'верить',
#   ',',
#   'и',
#   'уцепился',
#   'в',
#   'последний',
#   'раз',
#   'за',
#   'этот',
#   'помойный',
#   'клоак',
#   '...'],
#  ['Но', 'семя', 'осталось', 'и', 'возросло', '.'],
#  ['Серьезно',
#   ',',
#   'скажите',
#   'серьезно',
#   ',',
#   'не',
#   'дочитали',
#   'письма',
#   'моего',
#   'из',
#   'Америки',
#   '?'],
#  ['Может', 'быть', 'не', 'читали', 'вовсе', '?'],
#  ['-',
#   'Я',
#   'прочел',
#   'из',
#   'него',
#   'три',
#   'страницы',
#   ',',
#   'две',
#   'первые',
#   'и',
#   'последнюю',
#   ',',
#   'и',
#   'кроме',
#   'того',
#   'бегло',
#   'переглядел',
#   'средину',
#   '.'],
#  ['Впрочем', 'я', 'все', 'собирался', '...'],
#  ['-',
#   'Э',
#   ',',
#   'все',
#   'равно',
#   ',',
#   'бросьте',
#   ',',
#   'к',
#   'чорту',
#   '!',
#   '-',
#   'махнул',
#   'рукой',
#   'Шатов',
#   '.'],
#  ['-',
#   'Если',
#   'вы',
#   'отступились',
#   'теперь',
#   'от',
#   'тогдашних',
#   'слов',
#   'про',
#   'народ',
#   ',',
#   '.',
#   'то',
#   'как',
#   'могли',
#   'вы',
#   'их',
#   'тогда',
#   'выговорить',
#   '?..'],
#  ['Вот', 'что', 'давит', 'меня', 'теперь', '.'],
#  ['-',
#   'Не',
#   'шутил',
#   'же',
#   'я',
#   'с',
#   'вами',
#   'и',
#   'тогда',
#   ';',
#   'убеждая',
#   'вас',
#   ',',
#   'я',
#   ',',
#   'может',
#   ',',
#   'еще',
#   'больше',
#   'хлопотал',
#   'о',
#   'себе',
#   ',',
#   'чем',
#   'о',
#   'вас',
#   ',',
#   '-',
#   'загадочно',
#   'произнес',
#   'Ставрогин',
#   '.'],
#  ['-', 'Не', 'шутили', '!'],
#  ['В',
#   'Америке',
#   'я',
#   'лежал',
#   'три',
#   'месяца',
#   'на',
#   'соломе',
#   ',',
#   'рядом',
#   'с',
#   'одним',
#   '...',
#   'несчастным',
#   'и',
#   'узнал',
#   'от',
#   'него',
#   ',',
#   'что',
#   'в',
#   'то',
#   'же',
#   'самое',
#   'время',
#   ',',
#   'когда',
#   'вы',
#   'насаждали',
#   'в',
#   'моем',
#   'сердце',
#   'бога',
#   'и',
#   'родину',
#   ',',
#   'в',
#   'то',
#   'же',
#   'самое',
#   'время',
#   'даже',
#   'может',
#   'быть',
#   'в',
#   'те',
#   'же',
#   'самые',
#   'дни',
#   ',',
#   'вы',
#   'отравили',
#   'сердце',
#   'этого',
#   'несчастного',
#   ',',
#   'этого',
#   'маньяка',
#   ',',
#   'Кириллова',
#   ',',
#   'ядом',
#   '...'],
#  ['Вы',
#   'утверждали',
#   'в',
#   'нем',
#   'ложь',
#   'и',
#   'клевету',
#   'и',
#   'довели',
#   'разум',
#   'его',
#   'до',
#   'исступления',
#   '...'],
#  ['Подите',
#   ',',
#   'взгляните',
#   'на',
#   'него',
#   'теперь',
#   ',',
#   'это',
#   'ваше',
#   'создание',
#   '...'],
#  ['Впрочем', 'вы', 'видели', '.'],
#  ['-',
#   'Во-первых',
#   ',',
#   'замечу',
#   'вам',
#   ',',
#   'что',
#   'сам',
#   'Кириллов',
#   'сейчас',
#   'только',
#   'сказал',
#   'мне',
#   ',',
#   'что',
#   'он',
#   'счастлив',
#   'и',
#   'что',
#   'он',
#   'прекрасен',
#   '.'],
#  ['Ваше',
#   'предположение',
#   'о',
#   'том',
#   ',',
#   'что',
#   'все',
#   'это',
#   'произошло',
#   'в',
#   'одно',
#   'и',
#   'то',
#   'же',
#   'время',
#   ',',
#   'почти',
#   'верно',
#   ';',
#   'ну',
#   ',',
#   'и',
#   'что',
#   'же',
#   'из',
#   'всего',
#   'этого',
#   '?'],
#  ['Повторяю',
#   ',',
#   'я',
#   'вас',
#   'ни',
#   'того',
#   ',',
#   'ни',
#   'другого',
#   'не',
#   'обманывал',
#   '.'],
#  ['-', 'Вы', 'атеист', '?'],
#  ['Теперь', 'атеист', '?'],
#  ['-', 'Да', '.'],
#  ['-', 'А', 'тогда', '?'],
#  ['-', 'Точно', 'так', 'же', ',', 'как', 'и', 'тогда', '.'],
#  ['-',
#   'Я',
#   'не',
#   'к',
#   'себе',
#   'просил',
#   'у',
#   'вас',
#   'уважения',
#   ',',
#   'начиная',
#   'разговор',
#   ';',
#   'с',
#   'вашим',
#   'умом',
#   ',',
#   'вы',
#   'бы',
#   'могли',
#   'понять',
#   'это',
#   ',',
#   '-',
#   'в',
#   'негодовании',
#   'пробормотал',
#   'Шатов',
#   '.'],
#  ['-',
#   'Я',
#   'не',
#   'встал',
#   'с',
#   'первого',
#   'вашего',
#   'слова',
#   ',',
#   'не',
#   'закрыл',
#   'разговора',
#   ',',
#   'не',
#   'ушел',
#   'от',
#   'вас',
#   ',',
#   'а',
#   'сижу',
#   'до',
#   'сих',
#   'пор',
#   'и',
#   'смирно',
#   'отвечаю',
#   'на',
#   'ваши',
#   'вопросы',
#   'и',
#   '...',
#   'крики',
#   ',',
#   'стало',
#   'быть',
#   ',',
#   'не',
#   'нарушил',
#   'еще',
#   'к',
#   'вам',
#   'уважения',
#   '.'],
#  ['Шатов',
#   'прервал',
#   ',',
#   'махнув',
#   'рукой',
#   ':',
#   '-',
#   'Вы',
#   'помните',
#   'выражение',
#   'ваше',
#   ':',
#   '"',
#   'атеист',
#   'не',
#   'может',
#   'быть',
#   'русским',
#   '"',
#   ',',
#   '"',
#   'атеист',
#   'тотчас',
#   'же',
#   'перестает',
#   'быть',
#   'русским',
#   '"',
#   ',',
#   'помните',
#   'это',
#   '?'],
#  ['-',
#   'Да',
#   '?',
#   '-',
#   'как',
#   'бы',
#   'переспросил',
#   'Николай',
#   'Всеволодович',
#   '.'],
#  ['-', 'Вы', 'спрашиваете', '?'],
#  ['Вы', 'забыли', '?'],
#  ['А',
#   'между',
#   'тем',
#   'это',
#   'одно',
#   'из',
#   'самых',
#   'точнейших',
#   'указаний',
#   'на',
#   'одну',
#   'из',
#   'главнейших',
#   'особенностей',
#   'русского',
#   'духа',
#   ',',
#   'вами',
#   'угаданную',
#   '.'],
#  ['Не', 'могли', 'вы', 'этого', 'забыть', '?'],
#  ['Я',
#   'напомню',
#   'вам',
#   'больше',
#   ',',
#   '-',
#   'высказали',
#   'тогда',
#   'же',
#   ':',
#   '"',
#   'не',
#   'православный',
#   'не',
#   'может',
#   'быть',
#   'русским',
#   '"',
#   '.'],
#  ['-', 'Я', 'полагаю', ',', 'что', 'это', 'славянофильская', 'мысль', '.'],
#  ['-', 'Нет', ';', 'нынешние', 'славянофилы', 'от', 'нее', 'откажутся', '.'],
#  ['Нынче', 'народ', 'поумнел', '.'],
#  ['Но',
#   'вы',
#   'еще',
#   'дальше',
#   'шли',
#   ':',
#   'вы',
#   'веровали',
#   ',',
#   'что',
#   'римский',
#   'католицизм',
#   'уже',
#   'не',
#   'есть',
#   'христианство',
#   ';',
#   'вы',
#   'утверждали',
#   ',',
#   'что',
#   'Рим',
#   'провозгласил',
#   'Христа',
#   ',',
#   'поддавшегося',
#   'на',
#   'третье',
#   'дьяволово',
#   'искушение',
#   ',',
#   'и',
#   'что',
#   ',',
#   'возвестив',
#   'всему',
#   'свету',
#   ',',
#   'что',
#   'Христос',
#   'без',
#   'царства',
#   'земного',
#   'на',
#   'земле',
#   'устоять',
#   'не',
#   'может',
#   ',',
#   'католичество',
#   'тем',
#   'самым',
#   'провозгласило',
#   'антихриста',
#   'и',
#   'тем',
#   'погубило',
#   'весь',
#   'западный',
#   'мир',
#   '.'],
#  ['Вы',
#   'именно',
#   'указывали',
#   ',',
#   'что',
#   'если',
#   'мучается',
#   'Франция',
#   ',',
#   'то',
#   'единственно',
#   'по',
#   'вине',
#   'католичества',
#   ',',
#   'ибо',
#   'отвергла',
#   'смрадного',
#   'бога',
#   'римского',
#   ',',
#   'а',
#   'нового',
#   'не',
#   'сыскала',
#   '.'],
#  ['Вот', 'что', 'вы', 'тогда', 'могли', 'говорить', '!'],
#  ['Я', 'помню', 'наши', 'разговоры', '.'],
#  ['-',
#   'Если',
#   'б',
#   'я',
#   'веровал',
#   ',',
#   'то',
#   ',',
#   'без',
#   'сомнения',
#   ',',
#   'повторил',
#   'бы',
#   'это',
#   'и',
#   'теперь',
#   ';',
#   'я',
#   'не',
#   'лгал',
#   ',',
#   'говоря',
#   'как',
#   'верующий',
#   ',',
#   '-',
#   'очень',
#   'серьезно',
#   'произнес',
#   'Николай',
#   'Всеволодович',
#   '.'],
#  ['-',
#   'Но',
#   'уверяю',
#   'вас',
#   ',',
#   'что',
#   'на',
#   'меня',
#   'производит',
#   'слишком',
#   'неприятное',
#   'впечатление',
#   'это',
#   'повторение',
#   'прошлых',
#   'мыслей',
#   'моих',
#   '.'],
#  ['Не', 'можете', 'ли', 'вы', 'перестать', '?'],
#  ['-',
#   'Если',
#   'бы',
#   'веровали',
#   '?',
#   '-',
#   'вскричал',
#   'Шатов',
#   ',',
#   'не',
#   'обратив',
#   'ни',
#   'малейшего',
#   'внимания',
#   'на',
#   'просьбу',
#   '.'],
#  ['-',
#   'Но',
#   'не',
#   'вы',
#   'ли',
#   'говорили',
#   'мне',
#   ',',
#   'что',
#   'если',
#   'бы',
#   'математически',
#   'доказали',
#   'вам',
#   ',',
#   'что',
#   'истина',
#   'вне',
#   'Христа',
#   ',',
#   'то',
#   'вы',
#   'бы',
#   'согласились',
#   'лучше',
#   'остаться',
#   'со',
#   'Христом',
#   ',',
#   'нежели',
#   'с',
#   'истиной',
#   '?'],
#  ['Говорили', 'вы', 'это', '?'],
#  ['Говорили', '?'],
#  ['-',
#   'Но',
#   'позвольте',
#   'же',
#   'и',
#   'мне',
#   'наконец',
#   'спросить',
#   ',',
#   '-',
#   'возвысил',
#   'голос',
#   'Ставрогин',
#   ',',
#   '-',
#   'к',
#   'чему',
#   'ведет',
#   'весь',
#   'этот',
#   'нетерпеливый',
#   'и',
#   '...',
#   'злобный',
#   'экзамен',
#   '?'],
#  ['-',
#   'Этот',
#   'экзамен',
#   'пройдет',
#   'навеки',
#   'и',
#   'никогда',
#   'больше',
#   'не',
#   'напомнится',
#   'вам',
#   '.'],
#  ['-',
#   'Вы',
#   'все',
#   'настаиваете',
#   ',',
#   'что',
#   'мы',
#   'вне',
#   'пространства',
#   'и',
#   'времени',
#   '...'],
#  ['-',
#   'Молчите',
#   '!',
#   '-',
#   'вдруг',
#   'крикнул',
#   'Шатов',
#   ',',
#   '-',
#   'я',
#   'глуп',
#   'и',
#   'неловок',
#   ',',
#   'но',
#   'погибай',
#   'мое',
#   'имя',
#   'в',
#   'смешном',
#   '!'],
#  ['Дозволите',
#   'ли',
#   'вы',
#   'мне',
#   'повторить',
#   'пред',
#   'вами',
#   'всю',
#   'главную',
#   'вашу',
#   'тогдашнюю',
#   'мысль',
#   '...'],
#  ['О', ',', 'только', 'десять', 'строк', ',', 'одно', 'заключение', '.'],
#  ['-', 'Повторите', ',', 'если', 'только', 'одно', 'заключение', '...'],
#  ['Ставрогин',
#   'сделал',
#   'было',
#   'движение',
#   'взглянуть',
#   'на',
#   'часы',
#   ',',
#   'но',
#   'удержался',
#   'и',
#   'не',
#   'взглянул',
#   '.'],
#  ['Шатов',
#   'принагнулся',
#   'опять',
#   'на',
#   'стуле',
#   'и',
#   ',',
#   'на',
#   'мгновение',
#   ',',
#   'даже',
#   'опять',
#   'было',
#   'поднял',
#   'палец',
#   '.'],
#  ['-',
#   'Ни',
#   'один',
#   'народ',
#   ',',
#   '-',
#   'начал',
#   'он',
#   ',',
#   'как',
#   'бы',
#   'читая',
#   'по',
#   'строкам',
#   'и',
#   'в',
#   'то',
#   'же',
#   'время',
#   'продолжая',
#   'грозно',
#   'смотреть',
#   'на',
#   'Ставрогина',
#   ',',
#   '-',
#   'ни',
#   'один',
#   'народ',
#   'еще',
#   'не',
#   'устраивался',
#   'на',
#   'началах',
#   'науки',
#   'и',
#   'разума',
#   ';',
#   'не',
#   'было',
#   'ни',
#   'разу',
#   'такого',
#   'примера',
#   ',',
#   'разве',
#   'на',
#   'одну',
#   'минуту',
#   ',',
#   'по',
#   'глупости',
#   '.'],
#  ['Социализм',
#   'по',
#   'существу',
#   'своему',
#   'уже',
#   'должен',
#   'быть',
#   'атеизмом',
#   ',',
#   'ибо',
#   'именно',
#   'провозгласил',
#   ',',
#   'с',
#   'самой',
#   'первой',
#   'строки',
#   ',',
#   'что',
#   'он',
#   'установление',
#   'атеистическое',
#   'и',
#   'намерен',
#   'устроиться',
#   'на',
#   'началах',
#   'науки',
#   'и',
#   'разума',
#   'исключительно',
#   '.'],
#  ['Разум',
#   'и',
#   'наука',
#   'в',
#   'жизни',
#   'народов',
#   'всегда',
#   ',',
#   'теперь',
#   'и',
#   'с',
#   'начала',
#   'веков',
#   ',',
#   'исполняли',
#   'лишь',
#   'должность',
#   'второстепенную',
#   'и',
#   'служебную',
#   ';',
#   'так',
#   'и',
#   'будут',
#   'исполнять',
#   'до',
#   'конца',
#   'веков',
#   '.'],
#  ['Народы',
#   'слагаются',
#   'и',
#   'движутся',
#   'силой',
#   'иною',
#   ',',
#   'повелевающею',
#   'и',
#   'господствующею',
#   ',',
#   'но',
#   'происхождение',
#   'которой',
#   'неизвестно',
#   'и',
#   'необъяснимо',
#   '.'],
#  ['Эта',
#   'сила',
#   'есть',
#   'сила',
#   'неутолимого',
#   'желания',
#   'дойти',
#   'до',
#   'конца',
#   'и',
#   'в',
#   'то',
#   'же',
#   'время',
#   'конец',
#   'отрицающая',
#   '.'],
#  ['Это',
#   'есть',
#   'сила',
#   'беспрерывного',
#   'и',
#   'неустанного',
#   'подтверждения',
#   'своего',
#   'бытия',
#   'и',
#   'отрицания',
#   'смерти',
#   '.'],
#  ['Дух',
#   'жизни',
#   ',',
#   'как',
#   'говорит',
#   'писание',
#   ',',
#   '"',
#   'реки',
#   'воды',
#   'живой',
#   '"',
#   ',',
#   'иссякновением',
#   'которых',
#   'так',
#   'угрожает',
#   'Апокалипсис',
#   '.'],
#  ['Начало',
#   'эстетическое',
#   ',',
#   'как',
#   'говорят',
#   'философы',
#   ',',
#   'начало',
#   'нравственное',
#   ',',
#   'как',
#   'отожествляют',
#   'они',
#   'же',
#   '.'],
#  ['"',
#   'Искание',
#   'бога',
#   '"',
#   ',',
#   'как',
#   'называю',
#   'я',
#   'всего',
#   'проще',
#   '.'],
#  ['Цель',
#   'всего',
#   'движения',
#   'народного',
#   ',',
#   'во',
#   'всяком',
#   'народе',
#   'и',
#   'во',
#   'всякий',
#   'период',
#   'его',
#   'бытия',
#   ',',
#   'есть',
#   'единственно',
#   'лишь',
#   'искание',
#   'бога',
#   ',',
#   'бога',
#   'своего',
#   ',',
#   'непременно',
#   'собственного',
#   ',',
#   'и',
#   'вера',
#   'в',
#   'него',
#   'как',
#   'в',
#   'единого',
#   'истинного',
#   '.'],
#  ['Бог',
#   'есть',
#   'синтетическая',
#   'личность',
#   'всего',
#   'народа',
#   ',',
#   'взятого',
#   'с',
#   'начала',
#   'его',
#   'и',
#   'до',
#   'конца',
#   '.'],
#  ['Никогда',
#   'еще',
#   'не',
#   'было',
#   ',',
#   'чтоб',
#   'у',
#   'всех',
#   'или',
#   'у',
#   'многих',
#   'народов',
#   'был',
#   'один',
#   'общий',
#   'бог',
#   ',',
#   'но',
#   'всегда',
#   'и',
#   'у',
#   'каждого',
#   'был',
#   'особый',
#   '.'],
#  ['Признак',
#   'уничтожения',
#   'народностей',
#   ',',
#   'когда',
#   'боги',
#   'начинают',
#   'становиться',
#   'общими',
#   '.'],
#  ['Когда',
#   'боги',
#   'становятся',
#   'общими',
#   ',',
#   'то',
#   'умирают',
#   'боги',
#   'и',
#   'вера',
#   'в',
#   'них',
#   'вместе',
#   'с',
#   'самими',
#   'народами',
#   '.'],
#  ['Чем', 'сильнее', 'народ', ',', 'тем', 'особливее', 'его', 'бог', '.'],
#  ['Никогда',
#   'еще',
#   'не',
#   'было',
#   'народа',
#   'без',
#   'религии',
#   ',',
#   'то-есть',
#   'без',
#   'понятия',
#   'о',
#   'зле',
#   'и',
#   'добре',
#   '.'],
#  ['У',
#   'всякого',
#   'народа',
#   'свое',
#   'собственное',
#   'понятие',
#   'о',
#   'зле',
#   'и',
#   'добре',
#   'и',
#   'свое',
#   'собственное',
#   'зло',
#   'и',
#   'добро',
#   '.'],
#  ['Когда',
#   'начинают',
#   'у',
#   'многих',
#   'народов',
#   'становиться',
#   'общими',
#   'понятия',
#   'о',
#   'зле',
#   'и',
#   'добре',
#   ',',
#   'тогда',
#   'вымирают',
#   'народы',
#   ',',
#   'и',
#   'тогда',
#   'самое',
#   'различие',
#   'между',
#   'злом',
#   'и',
#   'добром',
#   'начинает',
#   'стираться',
#   'и',
#   'исчезать',
#   '.'],
#  ['Никогда',
#   'разум',
#   'не',
#   'в',
#   'силах',
#   'был',
#   'определить',
#   'зло',
#   'и',
#   'добро',
#   ',',
#   'или',
#   'даже',
#   'отделить',
#   'зло',
#   'от',
#   'добра',
#   ',',
#   'хотя',
#   'приблизительно',
#   ';',
#   'напротив',
#   ',',
#   'всегда',
#   'позорно',
#   'и',
#   'жалко',
#   'смешивал',
#   ';',
#   'наука',
#   'же',
#   'давала',
#   'разрешения',
#   'кулачные',
#   '.'],
#  ['В',
#   'особенности',
#   'этим',
#   'отличалась',
#   'полунаука',
#   ',',
#   'самый',
#   'страшный',
#   'бич',
#   'человечества',
#   ',',
#   'хуже',
#   'мора',
#   ',',
#   'голода',
#   'и',
#   'войны',
#   ',',
#   'не',
#   'известный',
#   'до',
#   'нынешнего',
#   'столетия',
#   '.'],
#  ['Полунаука',
#   '-',
#   'это',
#   'деспот',
#   ',',
#   'каких',
#   'еще',
#   'не',
#   'приходило',
#   'до',
#   'сих',
#   'пор',
#   'никогда',
#   '.'],
#  ['Деспот',
#   ',',
#   'имеющий',
#   'своих',
#   'жрецов',
#   'и',
#   'рабов',
#   ',',
#   'деспот',
#   ',',
#   'пред',
#   'которым',
#   'все',
#   'преклонилось',
#   'с',
#   'любовью',
#   'и',
#   'суеверием',
#   ',',
#   'до',
#   'сих',
#   'пор',
#   'немыслимым',
#   ',',
#   'пред',
#   'которым',
#   'трепещет',
#   'даже',
#   'сама',
#   'наука',
#   'и',
#   'постыдно',
#   'потакает',
#   'ему',
#   '.'],
#  ['Все',
#   'это',
#   'ваши',
#   'собственные',
#   'слова',
#   ',',
#   'Ставрогин',
#   ',',
#   'кроме',
#   'только',
#   'слов',
#   'о',
#   'полунауке',
#   ';',
#   'эти',
#   'мои',
#   ',',
#   'потому',
#   'что',
#   'я',
#   'сам',
#   'только',
#   'полунаука',
#   ',',
#   'а',
#   'стало',
#   'быть',
#   ',',
#   'особенно',
#   'ненавижу',
#   'ее',
#   '.'],
#  ['В',
#   'ваших',
#   'же',
#   'мыслях',
#   'и',
#   'даже',
#   'в',
#   'самых',
#   'словах',
#   'я',
#   'не',
#   'изменил',
#   'ничего',
#   ',',
#   'ни',
#   'единого',
#   'слова',
#   '.'],
#  ['-',
#   'Не',
#   'думаю',
#   ',',
#   'чтобы',
#   'не',
#   'изменили',
#   ',',
#   '-',
#   'осторожно',
#   'заметил',
#   'Ставрогин',
#   ';',
#   '-',
#   'вы',
#   'пламенно',
#   'приняли',
#   'и',
#   'пламенно',
#   'переиначили',
#   ',',
#   'не',
#   'замечая',
#   'того',
#   '.'],
#  ['Уж',
#   'одно',
#   'то',
#   ',',
#   'что',
#   'вы',
#   'бога',
#   'низводите',
#   'до',
#   'простого',
#   'аттрибута',
#   'народности',
#   '...'],
#  ['Он',
#   'с',
#   'усиленным',
#   'и',
#   'особливым',
#   'вниманием',
#   'начал',
#   'вдруг',
#   'следить',
#   'за',
#   'Шатовым',
#   ',',
#   'и',
#   'не',
#   'столько',
#   'за',
#   'словами',
#   'его',
#   ',',
#   'сколько',
#   'за',
#   'ним',
#   'самим',
#   '.'],
#  ['-',
#   'Низвожу',
#   'бога',
#   'до',
#   'аттрибута',
#   'народности',
#   '?',
#   '-',
#   'вскричал',
#   'Шатов',
#   ',',
#   '-',
#   'напротив',
#   ',',
#   'народ',
#   'возношу',
#   'до',
#   'бога',
#   '.'],
#  ['Да', 'и', 'было', 'ли', 'когда-нибудь', 'иначе', '?'],
#  ['Народ', '-', 'это', 'тело', 'божие', '.'],
#  ['Всякий',
#   'народ',
#   'до',
#   'тех',
#   'только',
#   'пор',
#   'и',
#   'народ',
#   ',',
#   'пока',
#   'имеет',
#   'своего',
#   'бога',
#   'особого',
#   ',',
#   'а',
#   'всех',
#   'остальных',
#   'на',
#   'свете',
#   'богов',
#   'исключает',
#   'безо',
#   'всякого',
#   'примирения',
#   ';',
#   'пока',
#   'верует',
#   'в',
#   'то',
#   ',',
#   'что',
#   'своим',
#   'богом',
#   'победит',
#   'и',
#   'изгонит',
#   'из',
#   'мира',
#   'всех',
#   'остальных',
#   'богов',
#   '.'],
#  ['Так',
#   'веровали',
#   'все',
#   'с',
#   'начала',
#   'веков',
#   ',',
#   'все',
#   'великие',
#   'народы',
#   'по',
#   'крайней',
#   'мере',
#   ',',
#   'все',
#   'сколько-нибудь',
#   'отмеченные',
#   ',',
#   'все',
#   'стоявшие',
#   'во',
#   'главе',
#   'человечества',
#   '.'],
#  ['Против', 'факта', 'идти', 'нельзя', '.'],
#  ...]

# %%
# собираем словарь
words = sorted( set.union( *[ set(s) for s in text_ ] ) )
display(len(words))
words
# Out:
# 16643
# ['!',
#  '!!',
#  '!!!..',
#  '!..',
#  '!?',
#  '"',
#  "'",
#  '(',
#  ')',
#  ',',
#  '-',
#  '.',
#  '..',
#  '...',
#  '187',
#  '19-го',
#  ':',
#  ';',
#  '?',
#  '?..',
#  'Adieu',
#  'Alea',
#  'Allons',
#  'Augustin',
#  'Avis',
#  'Ax',
#  'Bonjour',
#  'C',
#  'Candide',
#  'Cela',
#  'Cette',
#  'Cher',
#  'Chere',
#  'Cozak',
#  'Don',
#  'Elle',
#  'Eloignez-la',
#  'Enfin',
#  'Et',
#  'Excellent',
#  'Fantichambre',
#  'Fautre',
#  'Fils',
#  'He',
#  'I',
#  'II',
#  'III',
#  'IV',
#  'Il',
#  'Ils',
#  'Incognito',
#  'Internationale',
#  'J',
#  'Je',
#  'Karmazinoff',
#  'Lembke',
#  'Littre',
#  'Maman',
#  'Mein',
#  'Merci',
#  'Nicolas',
#  'Oui',
#  'P',
#  'Pardon',
#  'Pas',
#  'Passons',
#  'Qu',
#  'Quelque',
#  'Rosenthal',
#  'Savez',
#  'Savez-vous',
#  'Se',
#  'Tant',
#  'Teliatnikoff',
#  'To-есть',
#  'Tous',
#  'Tout',
#  'V',
#  'VI',
#  'VII',
#  'Voil',
#  'Voltaire',
#  'Votre',
#  'Vous',
#  'Voyez-vous',
#  'a',
#  'abreuve',
#  'activit',
#  'ai',
#  'allemand',
#  'ami',
#  'amie',
#  'amis',
#  'ann',
#  'ans',
#  'appelle',
#  'arr',
#  'assure',
#  'au',
#  'aujourd',
#  'autour',
#  'avait',
#  'avec',
#  'aveugle',
#  'b',
#  'bas',
#  'battre',
#  'bauches',
#  'beaucoup',
#  'belle',
#  'belles',
#  'bien',
#  'bienfaisant',
#  'bon',
#  'boudoir',
#  'bourru',
#  'brisons-l',
#  'bruit',
#  'c',
#  'cacha',
#  'calme',
#  'carri',
#  'ce',
#  'cela',
#  'ces',
#  'cette',
#  'ch',
#  'chambre',
#  'chaque',
#  'charmant',
#  'charmante',
#  'cher',
#  'chere',
#  'chet',
#  'chez',
#  'chose',
#  'choses',
#  'choses-l',
#  'cochon',
#  'comme',
#  'commencerai',
#  'comment',
#  'comparaison',
#  'comprenez',
#  'compris',
#  'connais',
#  'connaissez',
#  'consenti',
#  'content',
#  'convertir',
#  'cozak',
#  'critiques',
#  'croire',
#  'croyez',
#  'croyez-vous',
#  'd',
#  'dans',
#  'date',
#  'de',
#  'dedans',
#  'des',
#  'deux',
#  'diatement',
#  'digne',
#  'dira-t-elle',
#  'distance',
#  'dit',
#  'doit',
#  'drapeau',
#  'du',
#  'e',
#  'elle',
#  'emb',
#  'employ',
#  'en',
#  'encore',
#  'enfin',
#  'ennemis',
#  'entendra',
#  'esclandre',
#  'esprits-forts',
#  'est',
#  'et',
#  'fa',
#  'fair',
#  'faire',
#  'faites',
#  'faut',
#  'femmes',
#  'ferai',
#  'figure',
#  'fils',
#  'finie',
#  'fois',
#  'forteresses',
#  'genre',
#  'gens',
#  'gens-l',
#  'guenille',
#  'h',
#  'hauteur',
#  'heure',
#  'historiques',
#  'homme',
#  'hui',
#  'i',
#  'il',
#  'imm',
#  'impuissance',
#  'impur',
#  'index',
#  'invraisemblable',
#  'j',
#  'jacta',
#  'je',
#  'jure',
#  'l',
#  'la',
#  'le',
#  'lecteur',
#  'les',
#  'lieber',
#  'louche',
#  'lui',
#  'm',
#  'm-me',
#  'm-r',
#  'ma',
#  'mais',
#  'manqu',
#  'me',
#  'meilleur',
#  'mes',
#  'mettez',
#  'mieux',
#  'minimum',
#  'moi',
#  'moines',
#  'moment',
#  'mon',
#  'mondes',
#  'mot',
#  'n',
#  'ne',
#  'nom',
#  'non',
#  'nos',
#  'notre',
#  'on',
#  'onnera',
#  'oubli',
#  'oui',
#  'paraisse',
#  'pare',
#  'paresseux',
#  'parlait',
#  'partout',
#  'pas',
#  'passant',
#  'pauvre',
#  'pays',
#  'permise',
#  'petit',
#  'peut',
#  'physionomie',
#  'pierre',
#  'pl',
#  'plaisir',
#  'plus',
#  'politesse',
#  'politiques',
#  'possibles',
#  'pouce',
#  'pour',
#  'pourtant',
#  'pr',
#  'procureur',
#  'prononc',
#  'propre',
#  'proteg',
#  'puis',
#  'qu',
#  'quand',
#  'que',
#  'quelque',
#  'quelques',
#  'qui',
#  'quinze',
#  'quoi',
#  'raison',
#  're',
#  'ri',
#  'rien',
#  'rieux',
#  'rit',
#  'roide',
#  'ross',
#  'roubles',
#  's',
#  'sa',
#  'sacr',
#  'sang',
#  'sans',
#  'sautait',
#  'savez-vous',
#  'se',
#  'sens',
#  'sent',
#  'serai',
#  'seul',
#  'sillons',
#  'simplement',
#  'soit',
#  'son',
#  'sonn',
#  'sont',
#  'soup',
#  'souviens',
#  'suis',
#  'sur',
#  'surexcit',
#  't',
#  'tage',
#  'tais',
#  'tait',
#  'tas',
#  'te',
#  'tenait',
#  'ter',
#  'terrain',
#  'tersbourg',
#  'tes',
#  'tise',
#  'tises',
#  'tombe',
#  'tomberai',
#  'toujours',
#  'tout',
#  'tout-а-fait',
#  'toute',
#  'tr',
#  'tre',
#  'trop',
#  'trouve',
#  'un',
#  'une',
#  'unes',
#  'v',
#  'vero',
#  'vie',
#  'vient',
#  'vingt',
#  'vorante',
#  'voulais',
#  'vous',
#  'voyez',
#  'voyez-vous',
#  'xe-xe',
#  'y',
#  'А',
#  'А-а',
#  'А-а-а',
#  'Авдотье',
#  'Агафья',
#  'Агентом',
#  'Адвокат',
#  'Администраторы',
#  'Акмолинский',
#  'Александрович',
#  'Александровском',
#  'Алексей',
#  'Алексея',
#  'Алеша',
#  'Али',
#  'Амалией',
#  'Амалию',
#  'Америка',
#  'Америке',
#  'Америки',
#  'Америку',
#  'Ан',
#  'Англии',
#  'Андреем',
#  'Андрей',
#  'Андрею',
#  'Андрея',
#  'Аничкова',
#  'Антонович',
#  'Антоновича',
#  'Антоновичем',
#  'Антоновичу',
#  'Антроповна',
#  'Апокалипсис',
#  'Апокалипсисе',
#  'Арина',
#  'Арине',
#  'Арины',
#  'Аристократ',
#  'Артемием',
#  'Артемий',
#  'Артемия',
#  'Архангельск',
#  'Ах',
#  'Б-цах',
#  'БЕСЫ',
#  'Ба',
#  'Базаров',
#  'Байрон',
#  'Байроном',
#  'Бальзака',
#  'Барьер',
#  'Басни',
#  'Батюшка',
#  'Беда',
#  'Бедная',
#  'Бедный',
#  'Бедняжка',
#  'Без',
#  'Безумных',
#  'Белинский',
#  'Белинского',
#  'Берлина',
#  'Берлине',
#  'Берут',
#  'Бешенство',
#  'Бисмарка',
#  'Блага-а-дарен',
#  'Благодарю',
#  'Благодетель',
#  'Благослови',
#  'Бледный',
#  'Близость',
#  'Блюм',
#  'Блюма',
#  'Блюмера',
#  'Блюмом',
#  'Блюму',
#  'Бог',
#  'Бога',
#  'Богородицы',
#  'Богородский',
#  'Богородском',
#  'Богочеловек',
#  'Богоявленская',
#  'Богоявленской',
#  'Богоявленскую',
#  'Боже',
#  'Боитесь',
#  'Бойтесь',
#  'Бока',
#  'Болезненное',
#  'Болен',
#  'Болтовне',
#  'Больны',
#  'Боюсь',
#  'Боязливо',
#  'Боясь',
#  'Братство',
#  'Бред',
#  'Бродяга',
#  'Бросив',
#  'Брыкове',
#  'Будет',
#  'Будто',
#  'Буду',
#  'Будьте',
#  'Бунт',
#  'Бунтуют',
#  'Бутылка',
#  'Бухгалтер',
#  'Бывает',
#  'Быковой',
#  'Был',
#  'Была',
#  'Были',
#  'Было',
#  'Быстрому',
#  'Быть',
#  'Бьюсь',
#  'Бюхнера',
#  'В',
#  'ВОСЬМАЯ',
#  'ВТОРАЯ',
#  'Вавилон',
#  'Вам',
#  'Варвара',
#  'Варваре',
#  'Варварой',
#  'Варвару',
#  'Варвары',
#  'Вас',
#  'Василий',
#  'Ваш',
#  'Ваша',
#  'Ваше',
#  'Вашего',
#  'Вбежавший',
#  'Вдовицу',
#  'Вдруг',
#  'Ведь',
#  'Великий',
#  'Верен',
#  'Верите',
#  'Верно',
#  'Вероятнее',
#  'Вероятно',
#  'Верхишиных',
#  'Верховенские',
#  'Верховенский',
#  'Верховенским',
#  'Верховенского',
#  'Верховенском',
#  'Верховенскому',
#  'Веселые',
#  'Веселым',
#  'Весь',
#  'Ветер',
#  'Ветром',
#  'Взгляд',
#  'Взгляды',
#  'Вздор',
#  'Взял',
#  'Взяли',
#  'Вид',
#  'Видал',
#  'Видали',
#  'Видимо',
#  'Видимое',
#  'Видите',
#  'Видите-с',
#  'Видишь',
#  'Видно',
#  'Вижу',
#  'Визит',
#  'Виноват',
#  'Виновата',
#  'Виргинская',
#  'Виргинские',
#  'Виргинский',
#  'Виргинским',
#  'Виргинского',
#  'Виргинской',
#  'Виргинскому',
#  'Влюбленный',
#  'Вместе',
#  'Вникните',
#  'Во',
#  'Во-первых',
#  'Водосточная',
#  'Воды',
#  'Возбудил',
#  'Возвратясь',
#  'Возьмите',
#  'Войдите',
#  'Волнение',
#  'Воля',
#  'Вон',
#  'Воображаю',
#  'Вообразив',
#  'Вообразите',
#  'Вообще',
#  'Вопрос',
#  'Вопроса',
#  'Ворота',
#  'Воспитанники',
#  'Вот',
#  'Вот-с',
#  'Вошедший',
#  'Вошел',
#  'Впечатление',
#  'Впоследствии',
#  'Впрочем',
#  'Враги',
#  'Время',
#  'Врете',
#  'Все',
#  'Все-таки',
#  'Всеволодович',
#  'Всеволодовича',
#  'Всеволодовиче',
#  'Всеволодовичем',
#  'Всеволодовичу',
#  'Всегда-то',
#  'Всего',
#  'Всем',
#  'Всеобщее',
#  'Всех',
#  'Вспоминались',
#  'Вспомнили',
#  'Вспомните',
#  'Вставайте',
#  'Встаньте',
#  'Встреча',
#  'Вступая',
#  'Всю',
#  'Вся',
#  'Всякий',
#  'Втихомолку',
#  'Вход',
#  'Входили',
#  'Входите',
#  'Вчера',
#  'Вчерашний',
#  'Въехали',
#  'Вы',
#  'Вы-с',
#  'Вы-то',
#  'Выбросил',
#  'Вызов',
#  'Выйдет',
#  'Высекут',
#  'Высокая',
#  'Высокие',
#  'Высокий',
#  'Высоцкого',
#  'Выстрел',
#  'Высшие',
#  'Высылкой',
#  'Выходит',
#  'Выходя',
#  'Вышло',
#  'Г',
#  'ГЛАВА',
#  'Гаганов',
#  'Гаганова',
#  'Гаганову',
#  'Гагановым',
#  'Гамбурга',
#  'Гамбурге',
#  'Где',
#  'Гекерну',
#  'Генерал',
#  'Генеральша',
#  'Гениального',
#  'Герцен',
#  'Герцена',
#  'Гимназист',
#  'Гимназистов',
#  'Главное',
#  'Главною',
#  'Глаза',
#  'Глупейшим',
#  'Глупов',
#  'Глупость',
#  'Гм',
#  'Говори',
#  'Говорил',
#  'Говорили',
#  'Говорите',
#  'Говорить',
#  'Говорю',
#  'Говоря',
#  'Говорят',
#  'Гоголь',
#  'Гони',
#  'Город',
#  'Горшечной',
#  'Горячий',
#  'Господа',
#  'Господи',
#  'Господин',
#  'Гостиного',
#  'Гостином',
#  'Гость',
#  'Грабительство',
#  'Грановского',
#  'Графиня',
#  'Греки',
#  'Гривен',
#  'Гришка',
#  'Гришку',
#  'ДЕВЯТАЯ',
#  'ДЕСЯТАЯ',
#  'Да',
#  'Да-с',
#  'Давайте',
#  'Давешней',
#  'Давно',
#  'Даже',
#  'Дайте',
#  'Далась',
#  'Дались',
#  'Дама',
#  'Дарьей',
#  'Дарьи',
#  'Дарья',
#  'Дать',
#  'Даша',
#  'Даю',
#  'Два',
#  'Двадцать',
#  'Две',
#  'Двери',
#  'Дверь',
#  'Девочка',
#  'Действительно',
#  'Делайте',
#  'Делался',
#  'Дело',
#  'Денег',
#  'Денежные',
#  'День',
#  'Державина',
#  'Деспот',
#  'Десять',
#  'Дикая',
#  'Длинное',
#  'Длинному',
#  'Длинноухий',
#  'Для',
#  'Дмитрия',
#  'Днем',
#  'До',
#  'Довольно',
#  'Довольны',
#  'Догадавшись',
#  'Договаривайте',
#  'Дозволите',
#  'Дозвольте',
#  'Доктор',
#  'Долгое',
#  'Должна',
#  'Должно',
#  'Долой',
#  'Дом',
#  'Дома',
#  'Домой',
#  'Донесет',
#  'Донесли',
#  'Дорогой',
#  'Достоевский',
#  'Дрезден',
#  'Дроздова',
#  'Дроздовы',
#  'Друг',
#  'Другие',
#  'Другого',
#  'Другое',
#  'Думаю',
#  'Думы',
#  'Дураки',
#  'Дурында',
#  'Дух',
#  'Духове',
#  'Духово',
#  'Душа',
#  'Дуэль',
#  'Дяденька',
#  'Евангелие',
#  'Евреи',
#  'Европе',
#  'Европы',
#  'Его',
#  'Егорович',
#  'Егоровича',
#  'Егорыч',
#  'Едва',
#  'Единственно',
#  'Единый',
#  'Ее',
#  'Ей',
#  'Елей',
#  'Ему',
#  'Если',
#  'Есть',
#  'Ефимьевском',
#  'Еще',
#  'Жажда',
#  'Жаль',
#  'Жаль-с',
#  'Ждал',
#  'Ждали',
#  'Жду',
#  'Желание',
#  'Женился',
#  'Женщины',
#  'Жив',
#  'Жизнь',
#  'Жребий',
#  'Жюль',
#  'За',
#  'Забывать',
#  'Забыл',
#  'Заволновались',
#  'Завтра',
#  'Загадочный',
#  'Заговорите',
#  'Задатку',
#  'Заколодило',
#  'Заметив',
#  'Заметьте',
#  'Замечание',
#  'Замечательно',
#  'Замечательные',
#  'Замечу',
#  'Заперлись',
#  'Запнулся',
#  'Запрет',
#  'Заседание',
#  'Заслышав',
#  'Застрелитесь',
#  'Затверженные',
#  'Затем',
#  'Зато',
#  'Затуманится',
#  'Заходил',
#  'Зачем',
#  'Звонко',
#  'Звуки',
#  'Здесь',
#  'Здорова',
#  'Здоровье',
#  'Здравствуйте',
#  'Злато',
#  'Злится',
#  'Злобной',
#  'Злость',
#  'Знаем',
#  'Знаете',
#  'Знай',
#  'Знайте',
#  'Знаком',
#  'Знаменит',
#  'Значит',
#  'Знаю',
#  'Знаю-с',
#  'Золотая',
#  'Золотые',
#  'Зонтик',
#  'Зонтика',
#  'Зосимой',
#  'Зуб',
#  'И',
#  'Ибо',
#  'Ив',
#  'Иван',
#  'Иван-царевич',
#  'Ивана',
#  'Ивана-царевича',
#  'Иванович',
#  'Игренева',
#  'Идем',
#  'Идет',
#  'Идея',
#  'Идите',
#  'Иду',
#  'Из',
#  'Из-под',
#  'Изверг',
#  'Известие',
#  'Известна',
#  'Извините',
#  'Извольте',
#  'Изредка',
#  'Изреки',
#  'Или',
#  'Илье',
#  'Ильич',
#  'Ильичу',
#  'Илья',
#  'Имеете',
#  'Именно',
#  'Имею',
#  'Имеются',
#  'Имя',
#  'Иногда',
#  'Интересно',
#  'Интонация',
#  'Искали',
#  'Искание',
#  'Исполнили',
#  'Исступление',
#  'Истина',
#  'Истинный',
#  'Итак',
#  'Их',
#  'Ищу',
#  'К',
#  'Кабета',
#  'Кабеты',
#  'Кавказ',
#  'Каждое',
#  'Каждый',
#  'Кажется',
#  'Казалось',
#  'Казням',
#  'Как',
#  'Как-нибудь',
#  'Какая',
#  'Какие',
#  'Каким',
#  'Какого',
#  'Какое',
#  'Какой',
#  'Какой-то',
#  'Какую',
#  'Капитан',
#  'Капитон',
#  'Капфиг',
#  'Карлсбаде',
#  'Карльсруэ',
#  'Кармазинов',
#  'Кармазинова',
#  'Кармазинову',
#  'Карьера',
#  'Каторжный',
#  'Кириллов',
#  'Кириллова',
#  'Кириллову',
#  'Кирилловым',
#  'Кладу',
#  'Клянусь',
#  'Книгоношу',
#  'Книжки',
#  'Когда',
#  'Когда-то',
#  'Кого',
#  'Кого-о',
#  'Коли',
#  'Колокола',
#  'Колпак',
#  'Колумб',
#  'Комната',
#  'Кондукторы',
#  'Конечно',
#  'Конечно-с',
#  'Кончив',
#  'Кончилось',
#  'Кончится',
#  'Копернику',
#  'Короваев',
#  'Короваеву',
#  'Краса',
#  'Крестили',
#  'Кричат',
#  'Крови',
#  'Кроме',
#  'Круг',
#  'Крыльцо',
#  'Кстати',
#  'Кто',
#  'Кто-то',
#  'Куда',
#  'Кукольник',
#  'Купец',
#  'Кучер',
#  'Кучки-то',
#  'Кушал',
#  'ЛИЧНОСТЬ',
#  'Лакей',
#  'Ласковое',
#  'Лебядкин',
#  'Лебядкина',
#  'Лебядкина-с',
#  'Лебядкиной',
#  'Лебядкину',
#  'Лебядкины',
#  'Лебядкиным',
#  'Лебядкиных',
#  'Лежит',
#  'Лекций',
#  'Лембка',
#  'Лембками',
#  'Лембке',
#  'Лембку',
#  'Лентяи',
#  'Лень',
#  'Лет',
#  'Либерал',
#  'Лиза',
#  'Лизавета',
#  'Лизавете',
#  'Лизаветой',
#  'Лизавету',
#  'Лизаветы',
#  'Лизу',
#  'Лизы',
#  'Липутин',
#  'Липутина',
#  'Липутину',
#  'Лист',
#  'Лихорадка',
#  'Лицо',
#  'Личности',
#  'Личность',
#  'Лучше',
#  'Люблю',
#  'Любопытно',
#  'Люди',
#  'Лягте',
#  'Лямшин',
#  'Лямшина',
#  'Лямшине',
#  'Лямшину',
#  'Лямшиным',
#  'Ма',
#  'Маврикием',
#  'Маврикий',
#  'Маврикию',
#  'Маврикия',
#  ...]

# %% [markdown]
# ## стеминг  для русского языка из пакета  NLTK

# %%
from nltk.tokenize import sent_tokenize as nltk_sentence_split
from nltk.tokenize import word_tokenize as nltk_tokenize_word
from nltk.stem.snowball import SnowballStemmer

stemmer = SnowballStemmer('russian')

text_ = [ 
    [ # разбиваем предложения на слова
        stemmer.stem(t) # выполняем стеминг
        for t in nltk_tokenize_word(s,language='russian') 
    ] # разбиваем предложения на слова
    for s in nltk_sentence_split(text,language='russian') # режем текст на отдельные предложения
]

display( len(text_) )
text_
# Out:
# 5495
# [['бес',
#   'федор',
#   'михайлович',
#   'достоевск',
#   'част',
#   'втор',
#   'глав',
#   'перв',
#   'ноч',
#   'I',
#   'прошл',
#   'восем',
#   'дне',
#   '.'],
#  ['тепер',
#   ',',
#   'когд',
#   'уж',
#   'все',
#   'прошл',
#   ',',
#   'и',
#   'я',
#   'пиш',
#   'хроник',
#   ',',
#   'мы',
#   'уж',
#   'зна',
#   'в',
#   'чем',
#   'дел',
#   ';',
#   'но',
#   'тогд',
#   'мы',
#   'ещ',
#   'нич',
#   'не',
#   'знал',
#   ',',
#   'и',
#   'естествен',
#   ',',
#   'что',
#   'нам',
#   'представля',
#   'стран',
#   'разн',
#   'вещ',
#   '.'],
#  ['по',
#   'крайн',
#   'мер',
#   'мы',
#   'со',
#   'степан',
#   'трофимович',
#   'в',
#   'перв',
#   'врем',
#   'заперл',
#   'и',
#   'с',
#   'испуг',
#   'наблюда',
#   'изда',
#   '.'],
#  ['я-т',
#   'кой-куд',
#   'ещ',
#   'выход',
#   'и',
#   'по-прежн',
#   'принос',
#   'ем',
#   'разн',
#   'вест',
#   ',',
#   'без',
#   'чег',
#   'он',
#   'и',
#   'проб',
#   'не',
#   'мог',
#   '.'],
#  ['неч',
#   'и',
#   'говор',
#   ',',
#   'что',
#   'по',
#   'город',
#   'пошл',
#   'сам',
#   'разнообразн',
#   'слух',
#   ',',
#   'то-ест',
#   'насчет',
#   'пощечин',
#   ',',
#   'обморок',
#   'лизавет',
#   'николаевн',
#   'и',
#   'проч',
#   'случ',
#   'в',
#   'то',
#   'воскресен',
#   '.'],
#  ['но',
#   'удивительн',
#   'нам',
#   'был',
#   'то',
#   ':',
#   'через',
#   'ког',
#   'эт',
#   'все',
#   'могл',
#   'так',
#   'скор',
#   'и',
#   'точн',
#   'выйт',
#   'наруж',
#   '?'],
#  ['ни',
#   'одн',
#   'из',
#   'присутствова',
#   'тогд',
#   'лиц',
#   'не',
#   'имел',
#   'бы',
#   ',',
#   'кажет',
#   ',',
#   'ни',
#   'нужд',
#   ',',
#   'ни',
#   'выгод',
#   'наруш',
#   'секрет',
#   'происшедш',
#   '.'],
#  ['прислуг',
#   'тогд',
#   'не',
#   'был',
#   ';',
#   'один',
#   'лебядкин',
#   'мог',
#   'бы',
#   'что-нибуд',
#   'разболта',
#   ',',
#   'не',
#   'стольк',
#   'по',
#   'злоб',
#   ',',
#   'пот',
#   'что',
#   'вышел',
#   'тогд',
#   'в',
#   'крайн',
#   'испуг',
#   '(',
#   'а',
#   'страх',
#   'к',
#   'враг',
#   'уничтожа',
#   'и',
#   'злоб',
#   'к',
#   'нем',
#   ')',
#   ',',
#   'а',
#   'единствен',
#   'по',
#   'невоздержн',
#   '.'],
#  ['но',
#   'лебядкин',
#   ',',
#   'вмест',
#   'с',
#   'сестриц',
#   ',',
#   'на',
#   'друг',
#   'же',
#   'ден',
#   'пропа',
#   'без',
#   'вест',
#   ';',
#   'в',
#   'дом',
#   'филиппов',
#   'ег',
#   'не',
#   'оказа',
#   ',',
#   'он',
#   'перееха',
#   'неизвестн',
#   'куд',
#   'и',
#   'точн',
#   'сгинул',
#   '.'],
#  ['шат',
#   ',',
#   'у',
#   'котор',
#   'я',
#   'хотел',
#   'был',
#   'справ',
#   'о',
#   'мар',
#   'тимофеевн',
#   ',',
#   'запер',
#   'и',
#   ',',
#   'кажет',
#   ',',
#   'все',
#   'эт',
#   'восем',
#   'дне',
#   'просидел',
#   'у',
#   'себ',
#   'на',
#   'квартир',
#   ',',
#   'даж',
#   'прерва',
#   'сво',
#   'занят',
#   'в',
#   'город',
#   '.'],
#  ['мен', 'он', 'не', 'приня', '.'],
#  ['я',
#   'был',
#   'зашел',
#   'к',
#   'нем',
#   'во',
#   'вторник',
#   'и',
#   'стукнул',
#   'в',
#   'двер',
#   '.'],
#  ['ответ',
#   'не',
#   'получ',
#   ',',
#   'но',
#   'уверен',
#   ',',
#   'по',
#   'несомнен',
#   'дан',
#   ',',
#   'что',
#   'он',
#   'дом',
#   ',',
#   'постуча',
#   'в',
#   'друг',
#   'раз.',
#   'тогд',
#   'он',
#   ',',
#   'соскоч',
#   'по-видим',
#   'с',
#   'постел',
#   ',',
#   'подошел',
#   'крупн',
#   'шаг',
#   'к',
#   'двер',
#   'и',
#   'крикнул',
#   'мне',
#   'во',
#   'ве',
#   'голос',
#   ':',
#   '``',
#   'шатов',
#   'дом',
#   'нет',
#   "''",
#   '.'],
#  ['я', 'с', 'тем', 'и', 'ушел', '.'],
#  ['мы',
#   'со',
#   'степан',
#   'трофимович',
#   ',',
#   'не',
#   'без',
#   'страх',
#   'за',
#   'смелост',
#   'предположен',
#   ',',
#   'но',
#   'обоюдн',
#   'ободр',
#   'друг',
#   'друг',
#   ',',
#   'останов',
#   'наконец',
#   'на',
#   'одн',
#   'мысл',
#   ':',
#   'мы',
#   'реш',
#   ',',
#   'что',
#   'виновник',
#   'разошедш',
#   'слух',
#   'мог',
#   'быт',
#   'один',
#   'тольк',
#   'петр',
#   'степанович',
#   ',',
#   'хот',
#   'сам',
#   'он',
#   'некотор',
#   'врем',
#   'спуст',
#   ',',
#   'в',
#   'разговор',
#   'с',
#   'отц',
#   ',',
#   'уверя',
#   ',',
#   'что',
#   'заста',
#   'уж',
#   'истор',
#   'во',
#   'всех',
#   'уст',
#   ',',
#   'преимуществен',
#   'в',
#   'клуб',
#   ',',
#   'и',
#   'совершен',
#   'известн',
#   'до',
#   'мельчайш',
#   'подробн',
#   'губернаторш',
#   'и',
#   'е',
#   'супруг',
#   '.'],
#  ['вот',
#   'что',
#   'ещ',
#   'замечательн',
#   ':',
#   'на',
#   'втор',
#   'же',
#   'ден',
#   ',',
#   'в',
#   'понедельник',
#   'ввечер',
#   ',',
#   'я',
#   'встрет',
#   'липутин',
#   ',',
#   'и',
#   'он',
#   'уж',
#   'знал',
#   'все',
#   'до',
#   'последн',
#   'слов',
#   ',',
#   'стал',
#   'быт',
#   ',',
#   'несомнен',
#   'узна',
#   'из',
#   'перв',
#   '.'],
#  ['мног',
#   'из',
#   'дам',
#   '(',
#   'и',
#   'из',
#   'сам',
#   'светск',
#   ')',
#   'любопытствова',
#   'и',
#   'о',
#   '``',
#   'загадочн',
#   'хромоножк',
#   "''",
#   ',',
#   'так',
#   'называ',
#   'мар',
#   'тимофеевн',
#   '.'],
#  ['нашл',
#   'даж',
#   'пожела',
#   'непремен',
#   'увида',
#   'е',
#   'личн',
#   'и',
#   'познаком',
#   ',',
#   'так',
#   'что',
#   'господ',
#   ',',
#   'поспеш',
#   'припрята',
#   'лебядкин',
#   ',',
#   'очевидн',
#   'поступ',
#   'и',
#   'кстат',
#   '.'],
#  ['но',
#   'на',
#   'перв',
#   'план',
#   'все-так',
#   'стоя',
#   'обморок',
#   'лизавет',
#   'николаевн',
#   ',',
#   'и',
#   'эт',
#   'интересова',
#   '``',
#   'ве',
#   'свет',
#   "''",
#   ',',
#   'уж',
#   'по',
#   'том',
#   'одн',
#   ',',
#   'что',
#   'дел',
#   'прям',
#   'каса',
#   'юл',
#   'михайловн',
#   'как',
#   'родственниц',
#   'лизавет',
#   'николаевн',
#   'и',
#   'е',
#   'покровительниц',
#   '.'],
#  ['и', 'чего-ч', 'ни', 'болта', '!'],
#  ['болтовн',
#   'способствова',
#   'и',
#   'таинствен',
#   'обстановк',
#   ':',
#   'об',
#   'дом',
#   ',',
#   'был',
#   'заперт',
#   'наглух',
#   ';',
#   'лизавет',
#   'николаевн',
#   ',',
#   'как',
#   'рассказыва',
#   ',',
#   'лежа',
#   'в',
#   'бел',
#   'горячк',
#   ';',
#   'то',
#   'же',
#   'утвержда',
#   'и',
#   'о',
#   'никола',
#   'всеволодович',
#   ',',
#   'с',
#   'отвратительн',
#   'подробн',
#   'о',
#   'выбит',
#   'будт',
#   'бы',
#   'зуб',
#   'и',
#   'о',
#   'распухш',
#   'от',
#   'флюс',
#   'щек',
#   'ег',
#   '.'],
#  ['говор',
#   'даж',
#   'по',
#   'уголк',
#   ',',
#   'что',
#   'у',
#   'нас',
#   'может',
#   'быт',
#   'будет',
#   'убийств',
#   ',',
#   'что',
#   'ставрогин',
#   'не',
#   'так',
#   ',',
#   'чтоб',
#   'снест',
#   'так',
#   'обид',
#   ',',
#   'и',
#   'убьет',
#   'шатов',
#   ',',
#   'но',
#   'таинствен',
#   ',',
#   'как',
#   'в',
#   'корсиканск',
#   'вендетт',
#   '.'],
#  ['мысл',
#   'эт',
#   'нрав',
#   ';',
#   'но',
#   'большинств',
#   'наш',
#   'светск',
#   'молодеж',
#   'выслушива',
#   'все',
#   'эт',
#   'с',
#   'презрен',
#   'и',
#   'с',
#   'вид',
#   'сам',
#   'пренебрежительн',
#   'равнодуш',
#   ',',
#   'разумеет',
#   ',',
#   'напускн',
#   '.'],
#  ['вообщ',
#   'древн',
#   'враждебн',
#   'наш',
#   'обществ',
#   'к',
#   'никола',
#   'всеволодович',
#   'обознач',
#   'ярк',
#   '.'],
#  ['даж',
#   'солидн',
#   'люд',
#   'стрем',
#   'обвин',
#   'ег',
#   ',',
#   'хот',
#   'и',
#   'сам',
#   'не',
#   'знал',
#   'в',
#   'чем',
#   '.'],
#  ['шепот',
#   'рассказыва',
#   ',',
#   'что',
#   'будт',
#   'бы',
#   'он',
#   'погуб',
#   'чест',
#   'лизавет',
#   'николаевн',
#   ',',
#   'и',
#   'что',
#   'межд',
#   'ним',
#   'был',
#   'интриг',
#   'в',
#   'швейцар',
#   '.'],
#  ['конечн',
#   'осторожн',
#   'люд',
#   'сдержива',
#   ',',
#   'но',
#   'все',
#   'однак',
#   'же',
#   'слуша',
#   'с',
#   'аппетит',
#   '.'],
#  ['был',
#   'и',
#   'друг',
#   'разговор',
#   ',',
#   'но',
#   'не',
#   'общ',
#   ',',
#   'а',
#   'частн',
#   ',',
#   'редк',
#   'и',
#   'почт',
#   'закрыт',
#   ',',
#   'чрезвычайн',
#   'стран',
#   'и',
#   'о',
#   'существован',
#   'котор',
#   'я',
#   'упомина',
#   'лиш',
#   'для',
#   'предупрежден',
#   'читател',
#   ',',
#   'единствен',
#   'в',
#   'вид',
#   'дальн',
#   'событ',
#   'мо',
#   'рассказ',
#   '.'],
#  ['имен',
#   ':',
#   'говор',
#   'ин',
#   ',',
#   'хмур',
#   'бров',
#   'и',
#   'бог',
#   'знает',
#   'на',
#   'как',
#   'основан',
#   ',',
#   'что',
#   'никола',
#   'всеволодович',
#   'имеет',
#   'какое-т',
#   'особен',
#   'дел',
#   'в',
#   'наш',
#   'губерн',
#   ',',
#   'что',
#   'он',
#   'чрез',
#   'граф',
#   'к.',
#   'вошел',
#   'в',
#   'петербург',
#   'в',
#   'какие-т',
#   'высш',
#   'отношен',
#   ',',
#   'что',
#   'он',
#   'даж',
#   ',',
#   'может',
#   'быт',
#   ',',
#   'служ',
#   'и',
#   'чут',
#   'ли',
#   'не',
#   'снабж',
#   'от',
#   'кого-т',
#   'какими-т',
#   'поручен',
#   '.'],
#  ['когд',
#   'очен',
#   'уж',
#   'солидн',
#   'и',
#   'сдержа',
#   'люд',
#   'на',
#   'этот',
#   'слух',
#   'улыба',
#   ',',
#   'благоразумн',
#   'замеч',
#   ',',
#   'что',
#   'человек',
#   ',',
#   'живущ',
#   'скандал',
#   'и',
#   'начина',
#   'у',
#   'нас',
#   'с',
#   'флюс',
#   ',',
#   'не',
#   'похож',
#   'на',
#   'чиновник',
#   ',',
#   'то',
#   'им',
#   'шепот',
#   'замеча',
#   ',',
#   'что',
#   'служ',
#   'он',
#   'не',
#   'то',
#   'чтоб',
#   'оффициальн',
#   ',',
#   'а',
#   'так',
#   'сказа',
#   'конфиденциальн',
#   ',',
#   'и',
#   'что',
#   'в',
#   'так',
#   'случа',
#   'сам',
#   'служб',
#   'треб',
#   ',',
#   'чтоб',
#   'служа',
#   'как',
#   'можн',
#   'мен',
#   'поход',
#   'на',
#   'чиновник',
#   '.'],
#  ['так',
#   'замечан',
#   'производ',
#   'эффект',
#   ';',
#   'у',
#   'нас',
#   'известн',
#   'был',
#   ',',
#   'что',
#   'на',
#   'земств',
#   'наш',
#   'губерн',
#   'смотр',
#   'в',
#   'столиц',
#   'с',
#   'некотор',
#   'особ',
#   'вниман',
#   '.'],
#  ['повтор',
#   ',',
#   'эт',
#   'слух',
#   'тольк',
#   'мелькнул',
#   'и',
#   'исчезл',
#   'бесследн',
#   ',',
#   'до',
#   'времен',
#   ',',
#   'при',
#   'перв',
#   'появлен',
#   'никол',
#   'всеволодович',
#   ';',
#   'но',
#   'замеч',
#   ',',
#   'что',
#   'причин',
#   'мног',
#   'слух',
#   'был',
#   'отчаст',
#   'нескольк',
#   'кратк',
#   ',',
#   'но',
#   'злобн',
#   'слов',
#   ',',
#   'неясн',
#   'и',
#   'отрывист',
#   'произнесен',
#   'в',
#   'клуб',
#   'недавн',
#   'возврат',
#   'из',
#   'петербург',
#   'отставн',
#   'капитан',
#   'гвард',
#   'артем',
#   'павлович',
#   'гаганов',
#   ',',
#   'весьм',
#   'крупн',
#   'помещик',
#   'наш',
#   'губерн',
#   'и',
#   'уезд',
#   ',',
#   'столичн',
#   'светск',
#   'человек',
#   'и',
#   'сын',
#   'покойн',
#   'павл',
#   'павлович',
#   'гаганов',
#   ',',
#   'тог',
#   'сам',
#   'почтен',
#   'старшин',
#   ',',
#   'с',
#   'котор',
#   'никола',
#   'всеволодович',
#   'имел',
#   ',',
#   'четыр',
#   'слишк',
#   'год',
#   'том',
#   'назад',
#   ',',
#   'то',
#   'необычайн',
#   'по',
#   'сво',
#   'грубост',
#   'и',
#   'внезапн',
#   'столкновен',
#   ',',
#   'о',
#   'котор',
#   'я',
#   'уж',
#   'упомина',
#   'прежд',
#   ',',
#   'в',
#   'начал',
#   'мо',
#   'рассказ',
#   '.'],
#  ['всем',
#   'тотчас',
#   'же',
#   'стал',
#   'известн',
#   ',',
#   'что',
#   'юл',
#   'михайловн',
#   'сдела',
#   'варвар',
#   'петровн',
#   'чрезвычайн',
#   'виз',
#   ',',
#   'и',
#   'что',
#   'у',
#   'крыльц',
#   'дом',
#   'е',
#   'объяв',
#   ',',
#   'что',
#   '``',
#   'по',
#   'нездоров',
#   'не',
#   'могут',
#   'приня',
#   "''",
#   '.'],
#  ['такж',
#   'и',
#   'то',
#   ',',
#   'что',
#   'дня',
#   'через',
#   'два',
#   'посл',
#   'сво',
#   'визит',
#   'юл',
#   'михайловн',
#   'посыла',
#   'узна',
#   'о',
#   'здоров',
#   'варвар',
#   'петровн',
#   'нарочн',
#   '.'],
#  ['наконец',
#   'приня',
#   'везд',
#   '``',
#   'защища',
#   "''",
#   'варвар',
#   'петровн',
#   ',',
#   'конечн',
#   'лиш',
#   'в',
#   'сам',
#   'высш',
#   'смысл',
#   ',',
#   'то',
#   '``',
#   'ест',
#   'по',
#   'возможн',
#   'в',
#   'сам',
#   'неопределен',
#   '.'],
#  ['все',
#   'же',
#   'первоначальн',
#   'тороплив',
#   'намек',
#   'о',
#   'воскресн',
#   'истор',
#   'выслуша',
#   'строг',
#   'и',
#   'холодн',
#   ',',
#   'так',
#   'что',
#   'в',
#   'послед',
#   'дни',
#   ',',
#   'в',
#   'е',
#   'присутств',
#   ',',
#   'он',
#   'уж',
#   'не',
#   'возобновля',
#   '.'],
#  ['так',
#   'образ',
#   'и',
#   'укреп',
#   'везд',
#   'мысл',
#   ',',
#   'что',
#   'юл',
#   'михайловн',
#   'известн',
#   'не',
#   'тольк',
#   'вся',
#   'эт',
#   'таинствен',
#   'истор',
#   ',',
#   'но',
#   'и',
#   'ве',
#   'е',
#   'таинствен',
#   'смысл',
#   'до',
#   'мельчайш',
#   'подробн',
#   ',',
#   'и',
#   'не',
#   'как',
#   'посторон',
#   ',',
#   'а',
#   'как',
#   'соучастниц',
#   '.'],
#  ['замеч',
#   'кстат',
#   ',',
#   'что',
#   'он',
#   'нача',
#   'уж',
#   'приобрета',
#   'у',
#   'нас',
#   ',',
#   'помаленьк',
#   ',',
#   'то',
#   'высш',
#   'влиян',
#   ',',
#   'котор',
#   'так',
#   'несомнен',
#   'добива',
#   'и',
#   'жажда',
#   ',',
#   'и',
#   'уж',
#   'начина',
#   'видет',
#   'себ',
#   '``',
#   'окружен',
#   "''",
#   '.'],
#  ['част',
#   'обществ',
#   'призна',
#   'за',
#   'не',
#   'практическ',
#   'ум',
#   'и',
#   'такт',
#   '...',
#   'но',
#   'об',
#   'эт',
#   'посл',
#   '.'],
#  ['е',
#   'же',
#   'покровительств',
#   'объясня',
#   'отчаст',
#   'и',
#   'весьм',
#   'быстр',
#   'успех',
#   'петр',
#   'степанович',
#   'в',
#   'наш',
#   'обществ',
#   ',',
#   '-',
#   'успех',
#   ',',
#   'особен',
#   'пораз',
#   'тогд',
#   'степа',
#   'трофимович',
#   '.'],
#  ['мы', 'с', 'ним', 'может', 'быт', 'и', 'преувеличива', '.'],
#  ['во-перв',
#   ',',
#   'петр',
#   'степанович',
#   'перезнаком',
#   'почт',
#   'мгновен',
#   'со',
#   'всем',
#   'город',
#   ',',
#   'в',
#   'перв',
#   'же',
#   'четыр',
#   'дня',
#   'посл',
#   'сво',
#   'появлен',
#   '.'],
#  ['появ',
#   'он',
#   'в',
#   'воскресен',
#   ',',
#   'а',
#   'во',
#   'вторник',
#   'я',
#   'уж',
#   'встрет',
#   'ег',
#   'в',
#   'коляск',
#   'с',
#   'артем',
#   'павлович',
#   'гаганов',
#   ',',
#   'человек',
#   'горд',
#   ',',
#   'раздражительн',
#   'и',
#   'заносчив',
#   ',',
#   'несмотр',
#   'на',
#   'всю',
#   'ег',
#   'светскост',
#   ',',
#   'и',
#   'с',
#   'котор',
#   ',',
#   'по',
#   'характер',
#   'ег',
#   ',',
#   'довольн',
#   'трудн',
#   'был',
#   'уж',
#   '.'],
#  ['у',
#   'губернатор',
#   'петр',
#   'степанович',
#   'был',
#   'тож',
#   'прин',
#   'прекрасн',
#   ',',
#   'до',
#   'тог',
#   ',',
#   'что',
#   'тотчас',
#   'же',
#   'стал',
#   'в',
#   'положен',
#   'близк',
#   'ил',
#   'так-сказа',
#   'обласка',
#   'молод',
#   'человек',
#   ';',
#   'обеда',
#   'у',
#   'юл',
#   'михайловн',
#   'почт',
#   'ежедневн',
#   '.'],
#  ['познаком',
#   'он',
#   'с',
#   'не',
#   'ещ',
#   'в',
#   'швейцар',
#   ',',
#   'но',
#   'в',
#   'быстр',
#   'успех',
#   'ег',
#   'в',
#   'дом',
#   'ег',
#   'превосходительств',
#   'действительн',
#   'заключа',
#   'нечт',
#   'любопытн',
#   '.'],
#  ['все-так',
#   'он',
#   'слыл',
#   'же',
#   'когда-т',
#   'заграничн',
#   'революционер',
#   ',',
#   'правд',
#   'ли',
#   ',',
#   'нет',
#   'ли',
#   ',',
#   'участвова',
#   'в',
#   'каких-т',
#   'заграничн',
#   'издан',
#   'и',
#   'конгресс',
#   ',',
#   '``',
#   'что',
#   'можн',
#   'даж',
#   'из',
#   'газет',
#   'доказа',
#   "''",
#   ',',
#   'как',
#   'злобн',
#   'выраз',
#   'мне',
#   'при',
#   'встреч',
#   'алеш',
#   'телятник',
#   ',',
#   'тепер',
#   ',',
#   'ув',
#   ',',
#   'отставн',
#   'чиновничек',
#   ',',
#   'а',
#   'прежд',
#   'тож',
#   'обласка',
#   'молод',
#   'человек',
#   'в',
#   'дом',
#   'стар',
#   'губернатор',
#   '.'],
#  ['но',
#   'тут',
#   'стоя',
#   'однак',
#   'же',
#   'факт',
#   ':',
#   'бывш',
#   'революционер',
#   'яв',
#   'в',
#   'любезн',
#   'отечеств',
#   'не',
#   'тольк',
#   'без',
#   'всяк',
#   'беспокойств',
#   ',',
#   'но',
#   'чут',
#   'ли',
#   'не',
#   'с',
#   'поощрен',
#   ';',
#   'стал',
#   'быт',
#   ',',
#   'нич',
#   ',',
#   'может',
#   ',',
#   'и',
#   'не',
#   'был',
#   '.'],
#  ['липутин',
#   'шепнул',
#   'мне',
#   'раз',
#   ',',
#   'что',
#   ',',
#   'по',
#   'слух',
#   ',',
#   'петр',
#   'степанович',
#   'будт',
#   'бы',
#   'где-т',
#   'принес',
#   'покаян',
#   'и',
#   'получ',
#   'отпущен',
#   ',',
#   'назва',
#   'нескольк',
#   'проч',
#   'им',
#   ',',
#   'и',
#   'так',
#   'образ',
#   ',',
#   'может',
#   ',',
#   'и',
#   'успел',
#   'уж',
#   'заслуж',
#   'вин',
#   ',',
#   'обещ',
#   'и',
#   'впред',
#   'быт',
#   'полезн',
#   'отечеств',
#   '.'],
#  ['я',
#   'переда',
#   'эт',
#   'ядовит',
#   'фраз',
#   'степан',
#   'трофимович',
#   ',',
#   'и',
#   'тот',
#   ',',
#   'несмотр',
#   'на',
#   'то',
#   ',',
#   'что',
#   'был',
#   'почт',
#   'не',
#   'в',
#   'состоян',
#   'сообража',
#   ',',
#   'сильн',
#   'задума',
#   '.'],
#  ['впоследств',
#   'обнаруж',
#   ',',
#   'что',
#   'петр',
#   'степанович',
#   'приеха',
#   'к',
#   'нам',
#   'с',
#   'чрезвычайн',
#   'почтен',
#   'рекомендательн',
#   'письм',
#   ',',
#   'по',
#   'крайн',
#   'мер',
#   'привез',
#   'одн',
#   'к',
#   'губернаторш',
#   'от',
#   'одн',
#   'чрезвычайн',
#   'важн',
#   'петербургск',
#   'старушк',
#   ',',
#   'муж',
#   'котор',
#   'был',
#   'одн',
#   'из',
#   'сам',
#   'значительн',
#   'петербургск',
#   'старичк',
#   '.'],
#  ['эт',
#   'старушк',
#   ',',
#   'крестн',
#   'мат',
#   'юл',
#   'михайловн',
#   ',',
#   'упомина',
#   'в',
#   'письм',
#   'сво',
#   ',',
#   'что',
#   'и',
#   'граф',
#   'к.',
#   'хорош',
#   'знает',
#   'петр',
#   'степанович',
#   ',',
#   'чрез',
#   'никол',
#   'всеволодович',
#   ',',
#   'обласка',
#   'ег',
#   'и',
#   'наход',
#   '``',
#   'достойн',
#   'молод',
#   'человек',
#   ',',
#   'несмотр',
#   'на',
#   'бывш',
#   'заблужден',
#   "''",
#   '.'],
#  ['юл',
#   'михайловн',
#   'до',
#   'крайност',
#   'цен',
#   'сво',
#   'скудн',
#   'и',
#   'с',
#   'так',
#   'труд',
#   'поддержива',
#   'связ',
#   'с',
#   '``',
#   'высш',
#   'мир',
#   "''",
#   'и',
#   'уж',
#   'конечн',
#   'был',
#   'рад',
#   'письм',
#   'важн',
#   'старушк',
#   ';',
#   'но',
#   'все-так',
#   'остава',
#   'тут',
#   'нечт',
#   'как',
#   'бы',
#   'и',
#   'особен',
#   '.'],
#  ['даж',
#   'супруг',
#   'сво',
#   'постав',
#   'к',
#   'петр',
#   'степанович',
#   'в',
#   'отношен',
#   'почт',
#   'фамилиарн',
#   ',',
#   'так',
#   'что',
#   'г.',
#   'фон-лембк',
#   'жалова',
#   '...',
#   'но',
#   'об',
#   'эт',
#   'тож',
#   'посл',
#   '.'],
#  ['замеч',
#   'тож',
#   'для',
#   'памят',
#   ',',
#   'что',
#   'и',
#   'велик',
#   'писател',
#   'весьм',
#   'благосклон',
#   'отнес',
#   'к',
#   'петр',
#   'степанович',
#   'и',
#   'тотчас',
#   'же',
#   'приглас',
#   'ег',
#   'к',
#   'себ',
#   '.'],
#  ['так',
#   'поспешн',
#   'так',
#   'надут',
#   'соб',
#   'человек',
#   'кольнул',
#   'степа',
#   'трофимович',
#   'больн',
#   'всег',
#   ';',
#   'но',
#   'я',
#   'объясн',
#   'себ',
#   'инач',
#   ':',
#   'зазыв',
#   'к',
#   'себ',
#   'нигилист',
#   ',',
#   'г.',
#   'кармазин',
#   'уж',
#   'конечн',
#   'имел',
#   'в',
#   'вид',
#   'сношен',
#   'ег',
#   'с',
#   'прогрессивн',
#   'юнош',
#   'обе',
#   'столиц',
#   '.'],
#  ['велик',
#   'писател',
#   'болезнен',
#   'трепета',
#   'пред',
#   'нов',
#   'революцион',
#   'молодеж',
#   'и',
#   ',',
#   'воображ',
#   ',',
#   'по',
#   'незнан',
#   'дел',
#   ',',
#   'что',
#   'в',
#   'рук',
#   'е',
#   'ключ',
#   'русск',
#   'будущн',
#   ',',
#   'унизительн',
#   'к',
#   'ним',
#   'подлизыва',
#   ',',
#   'главн',
#   'пот',
#   'что',
#   'он',
#   'не',
#   'обраща',
#   'на',
#   'нег',
#   'никак',
#   'вниман',
#   '.'],
#  ['II',
#   'петр',
#   'степанович',
#   'забежа',
#   'раз',
#   'два',
#   'и',
#   'к',
#   'родител',
#   ',',
#   'и',
#   ',',
#   'к',
#   'несчаст',
#   'мо',
#   ',',
#   'об',
#   'раз',
#   'в',
#   'мо',
#   'отсутств',
#   '.'],
#  ['в',
#   'перв',
#   'раз',
#   'посет',
#   'ег',
#   'в',
#   'сред',
#   ',',
#   'то-ест',
#   'на',
#   'четверт',
#   'лиш',
#   'ден',
#   'посл',
#   'то',
#   'перв',
#   'встреч',
#   ',',
#   'да',
#   'и',
#   'то',
#   'по',
#   'дел',
#   '.'],
#  ['кстат',
#   ',',
#   'расчет',
#   'по',
#   'имен',
#   'оконч',
#   'у',
#   'них',
#   'как-т',
#   'неслышн',
#   'и',
#   'невидн',
#   '.'],
#  ['варвар',
#   'петровн',
#   'взял',
#   'все',
#   'на',
#   'себ',
#   'и',
#   'все',
#   'выплат',
#   ',',
#   'разумеет',
#   ',',
#   'приобрет',
#   'землиц',
#   ',',
#   'а',
#   'степа',
#   'трофимович',
#   'тольк',
#   'уведом',
#   'о',
#   'том',
#   ',',
#   'что',
#   'все',
#   'конч',
#   ',',
#   'и',
#   'уполномочен',
#   'варвар',
#   'петровн',
#   ',',
#   'камердинер',
#   'е',
#   'алекс',
#   'егорович',
#   ',',
#   'поднес',
#   'ем',
#   'что-т',
#   'подписа',
#   ',',
#   'что',
#   'он',
#   'и',
#   'исполн',
#   'молч',
#   'и',
#   'с',
#   'чрезвычайн',
#   'достоинств',
#   '.'],
#  ['замеч',
#   'по',
#   'повод',
#   'достоинств',
#   ',',
#   'что',
#   'я',
#   'почт',
#   'не',
#   'узнава',
#   'наш',
#   'прежн',
#   'старичк',
#   'в',
#   'эт',
#   'дни',
#   '.'],
#  ['он',
#   'держа',
#   'себ',
#   'как',
#   'никогд',
#   'прежд',
#   ',',
#   'стал',
#   'удивительн',
#   'молчал',
#   ',',
#   'даж',
#   'не',
#   'написа',
#   'ни',
#   'одн',
#   'письм',
#   'варвар',
#   'петровн',
#   'с',
#   'сам',
#   'воскресен',
#   ',',
#   'что',
#   'я',
#   'счел',
#   'бы',
#   'чуд',
#   ',',
#   'а',
#   'главн',
#   'стал',
#   'споко',
#   '.'],
#  ['он',
#   'укреп',
#   'на',
#   'какой-т',
#   'окончательн',
#   'и',
#   'чрезвычайн',
#   'ид',
#   ',',
#   'придава',
#   'ем',
#   'спокойств',
#   ',',
#   'эт',
#   'был',
#   'видн',
#   '.'],
#  ['он', 'нашел', 'эт', 'ид', ',', 'сидел', 'и', 'чего-т', 'ждал', '.'],
#  ['снача',
#   'впроч',
#   'был',
#   'бол',
#   ',',
#   'особен',
#   'в',
#   'понедельник',
#   ';',
#   'был',
#   'холерин',
#   '.'],
#  ['тож',
#   'и',
#   'без',
#   'вест',
#   'проб',
#   'не',
#   'мог',
#   'во',
#   'все',
#   'врем',
#   ';',
#   'но',
#   'лиш',
#   'тольк',
#   'я',
#   ',',
#   'оставл',
#   'факт',
#   ',',
#   'переход',
#   'к',
#   'сут',
#   'дел',
#   'и',
#   'высказыва',
#   'какие-нибуд',
#   'предположен',
#   ',',
#   'то',
#   'он',
#   'тотчас',
#   'же',
#   'начина',
#   'маха',
#   'на',
#   'мен',
#   'рук',
#   ',',
#   'чтоб',
#   'я',
#   'переста',
#   '.'],
#  ['но',
#   'об',
#   'свидан',
#   'с',
#   'сынк',
#   'все-так',
#   'болезнен',
#   'на',
#   'нег',
#   'подействова',
#   ',',
#   'хот',
#   'и',
#   'не',
#   'поколеба',
#   '.'],
#  ['в',
#   'об',
#   'эт',
#   'дня',
#   ',',
#   'посл',
#   'свидан',
#   ',',
#   'он',
#   'лежа',
#   'на',
#   'диван',
#   ',',
#   'обмота',
#   'голов',
#   'платк',
#   ',',
#   'намочен',
#   'в',
#   'уксус',
#   ';',
#   'но',
#   'в',
#   'высш',
#   'смысл',
#   'продолжа',
#   'остава',
#   'спокойн',
#   '.'],
#  ['иногд',
#   ',',
#   'впроч',
#   ',',
#   'он',
#   'и',
#   'не',
#   'маха',
#   'на',
#   'мен',
#   'рук',
#   '.'],
#  ['иногд',
#   'тож',
#   'каза',
#   'мне',
#   ',',
#   'что',
#   'принят',
#   'таинствен',
#   'решим',
#   'как',
#   'бы',
#   'оставля',
#   'ег',
#   ',',
#   'и',
#   'что',
#   'он',
#   'начина',
#   'борот',
#   'с',
#   'каким-т',
#   'нов',
#   'соблазнительн',
#   'наплыв',
#   'ид',
#   '.'],
#  ['эт', 'был', 'мгновен', ',', 'но', 'я', 'отмеча', 'их', '.'],
#  ['я',
#   'подозрева',
#   ',',
#   'что',
#   'ем',
#   'очен',
#   'бы',
#   'хотел',
#   'опя',
#   'заяв',
#   'себ',
#   ',',
#   'выйт',
#   'из',
#   'уединен',
#   ',',
#   'предлож',
#   'борьб',
#   ',',
#   'зада',
#   'последн',
#   'битв',
#   '.'],
#  ['-', 'Cher', ',', 'я', 'бы', 'их', 'разгром', '!'],
#  ['-',
#   'вырва',
#   'у',
#   'нег',
#   'в',
#   'четверг',
#   'вечер',
#   ',',
#   'посл',
#   'втор',
#   'свидан',
#   'с',
#   'петр',
#   'степанович',
#   ',',
#   'когд',
#   'он',
#   'лежа',
#   ',',
#   'протянувш',
#   'на',
#   'диван',
#   ',',
#   'с',
#   'голов',
#   ',',
#   'обернут',
#   'полотенц',
#   '.'],
#  ['до',
#   'эт',
#   'минут',
#   'он',
#   'во',
#   'ве',
#   'ден',
#   'ещ',
#   'ни',
#   'слов',
#   'не',
#   'сказа',
#   'со',
#   'мно',
#   '.'],
#  ['-',
#   '``',
#   'Fils',
#   ',',
#   'fils',
#   'чйр',
#   "''",
#   'и',
#   'так',
#   'дал',
#   ',',
#   'я',
#   'соглас',
#   ',',
#   'что',
#   'все',
#   'эт',
#   'выражен',
#   'вздор',
#   ',',
#   'кухарочн',
#   'словар',
#   ',',
#   'да',
#   'и',
#   'пуст',
#   'их',
#   ',',
#   'я',
#   'сам',
#   'тепер',
#   'виж',
#   '.'],
#  ['я',
#   'ег',
#   'не',
#   'корм',
#   'и',
#   'не',
#   'по',
#   ',',
#   'я',
#   'отосла',
#   'ег',
#   'из',
#   'берлин',
#   'в',
#   'ску',
#   'губерн',
#   ',',
#   'грудн',
#   'ребенк',
#   ',',
#   'по',
#   'почт',
#   ',',
#   'ну',
#   'и',
#   'так',
#   'дал',
#   ',',
#   'я',
#   'соглас',
#   '...',
#   '``',
#   'ты',
#   ',',
#   'говор',
#   ',',
#   'мен',
#   'не',
#   'по',
#   'и',
#   'по',
#   'почт',
#   'высла',
#   ',',
#   'да',
#   'ещ',
#   'зде',
#   'ограб',
#   "''",
#   '.'],
#  ['но',
#   ',',
#   'несчастн',
#   ',',
#   'крич',
#   'ем',
#   ',',
#   'вед',
#   'болел',
#   'же',
#   'я',
#   'за',
#   'теб',
#   'сердц',
#   'всю',
#   'мо',
#   'жизн',
#   ',',
#   'хот',
#   'и',
#   'по',
#   'почт',
#   '!'],
#  ['Il', 'rit', '.'],
#  ['но',
#   'я',
#   'соглас',
#   ',',
#   'соглас',
#   '...',
#   'пуст',
#   'по',
#   'почт',
#   ',',
#   '-',
#   'законч',
#   'он',
#   'как',
#   'в',
#   'бред',
#   '.'],
#  ['-', 'Passons', ',', '-', 'нача', 'он', 'опя', 'через', 'пят', 'минут', '.'],
#  ['-', 'я', 'не', 'понима', 'тургенев', '.'],
#  ['у',
#   'нег',
#   'базар',
#   'эт',
#   'какое-т',
#   'фиктивн',
#   'лиц',
#   ',',
#   'не',
#   'существ',
#   'вовс',
#   ';',
#   'он',
#   'же',
#   'перв',
#   'и',
#   'отвергл',
#   'ег',
#   'тогд',
#   ',',
#   'как',
#   'ни',
#   'на',
#   'что',
#   'не',
#   'похож',
#   '.'],
#  ['этот',
#   'базар',
#   'эт',
#   'какая-т',
#   'неясн',
#   'сме',
#   'ноздрев',
#   'с',
#   'байрон',
#   ',',
#   "c'est",
#   'le',
#   'mot',
#   '!'],
#  ['посмотр',
#   'на',
#   'них',
#   'внимательн',
#   ':',
#   'он',
#   'кувырка',
#   'и',
#   'визжат',
#   'от',
#   'радост',
#   'как',
#   'щенк',
#   'на',
#   'солнц',
#   ',',
#   'он',
#   'счастлив',
#   ',',
#   'он',
#   'победител',
#   '!'],
#  ['как', 'тут', 'байрон', '!', '..'],
#  ['и', 'при', 'том', 'как', 'будн', '!'],
#  ['как',
#   'кухарочн',
#   'раздражительн',
#   'самолюб',
#   ',',
#   'как',
#   'пошленьк',
#   'жаждишк',
#   'faire',
#   'du',
#   'bruit',
#   'autour',
#   'de',
#   'son',
#   'nom',
#   ',',
#   'не',
#   'замеч',
#   ',',
#   'что',
#   'son',
#   'nom',
#   '...',
#   'о',
#   ',',
#   'карикатур',
#   '!'],
#  ['помил',
#   ',',
#   'крич',
#   'ем',
#   ',',
#   'да',
#   'неужт',
#   'ты',
#   'себ',
#   'так',
#   'как',
#   'ест',
#   'люд',
#   'взам',
#   'христ',
#   'предлож',
#   'жела',
#   '?'],
#  ['Il', 'rit', '.'],
#  ['Il', 'rit', 'beaucoup', ',', 'il', 'rit', 'trop', '.'],
#  ['у', 'нег', 'какая-т', 'стран', 'улыбк', '.'],
#  ['у', 'ег', 'матер', 'не', 'был', 'так', 'улыбк', '.'],
#  ['Il', 'rit', 'toujours', '.'],
#  ['опя', 'наступ', 'молчан', '.'],
#  ['-',
#   'он',
#   'хитр',
#   ';',
#   'в',
#   'воскресен',
#   'он',
#   'сговор',
#   '...',
#   '-',
#   'брякнул',
#   'он',
#   'вдруг',
#   '.'],
#  ['-',
#   'о',
#   ',',
#   'без',
#   'сомнен',
#   ',',
#   '-',
#   'вскрича',
#   'я',
#   ',',
#   'навостр',
#   'уш',
#   ',',
#   '-',
#   'все',
#   'эт',
#   'стачк',
#   'и',
#   'сшит',
#   'бел',
#   'нитк',
#   ',',
#   'и',
#   'так',
#   'дурн',
#   'разыгра',
#   '.'],
#  ['-', 'я', 'не', 'про', 'то', '.'],
#  ['знает',
#   'ли',
#   ',',
#   'что',
#   'все',
#   'эт',
#   'был',
#   'нарочн',
#   'сшит',
#   'бел',
#   'нитк',
#   ',',
#   'чтоб',
#   'замет',
#   'те',
#   '...',
#   'ком',
#   'над',
#   '.'],
#  ['понима', 'эт', '?'],
#  ['-', 'нет', ',', 'не', 'понима', '.'],
#  ['-', 'Tant', 'mieux', '.'],
#  ['Passons', '.'],
#  ['я', 'очен', 'раздраж', 'сегодн', '.'],
#  ['-',
#   'да',
#   'зач',
#   'же',
#   'вы',
#   'с',
#   'ним',
#   'спор',
#   ',',
#   'степа',
#   'трофимович',
#   '?'],
#  ['-', 'проговор', 'я', 'укоризнен', '.'],
#  ['-', 'Je', 'voulais', 'convertir', '.'],
#  ['конечн', 'смейт', '.'],
#  ['Cette',
#   'pauvre',
#   'тет',
#   ',',
#   'elle',
#   'entendra',
#   'de',
#   'belles',
#   'choses',
#   '!'],
#  ['о',
#   ',',
#   'друг',
#   'мо',
#   ',',
#   'повер',
#   'ли',
#   ',',
#   'что',
#   'я',
#   'давеч',
#   'ощут',
#   'себ',
#   'патриот',
#   '!'],
#  ['впроч',
#   'я',
#   'всегд',
#   'сознава',
#   'себ',
#   'русск',
#   '...',
#   'да',
#   'настоя',
#   'русск',
#   'и',
#   'не',
#   'может',
#   'быт',
#   'инач',
#   ',',
#   'как',
#   'мы',
#   'с',
#   'вам',
#   '.'],
#  ['Il',
#   'у',
#   'a',
#   'ла',
#   'dedans',
#   'quelque',
#   'chose',
#   "d'aveugle",
#   'et',
#   'de',
#   'louche',
#   '.'],
#  ['-', 'непремен', ',', '-', 'ответ', 'я', '.'],
#  ['-',
#   'друг',
#   'мо',
#   ',',
#   'настоя',
#   'правд',
#   'всегд',
#   'не',
#   'правдоподобн',
#   ',',
#   'знает',
#   'ли',
#   'вы',
#   'эт',
#   '?'],
#  ['чтоб',
#   'сдела',
#   'правд',
#   'правдоподобн',
#   ',',
#   'нужн',
#   'непремен',
#   'подмеша',
#   'к',
#   'не',
#   'лжи',
#   '.'],
#  ['люд', 'всегд', 'так', 'и', 'поступа', '.'],
#  ['может', 'быт', ',', 'тут', 'ест', ',', 'чег', 'мы', 'не', 'понима', '.'],
#  ['как',
#   'вы',
#   'дума',
#   ',',
#   'ест',
#   'тут',
#   ',',
#   'чег',
#   'мы',
#   'не',
#   'понима',
#   'в',
#   'эт',
#   'победоносн',
#   'визг',
#   '?'],
#  ['я', 'бы', 'жела', ',', 'чтоб', 'был', '.'],
#  ['я', 'бы', 'жела', '.'],
#  ['я', 'промолча', '.'],
#  ['он', 'тож', 'очен', 'долг', 'молча', '.'],
#  ['-',
#   'говор',
#   ',',
#   'французск',
#   'ум',
#   '...',
#   '-',
#   'залепета',
#   'он',
#   'вдруг',
#   'точн',
#   'в',
#   'жар',
#   ',',
#   '-',
#   'эт',
#   'лож',
#   ',',
#   'эт',
#   'всегд',
#   'так',
#   'и',
#   'был',
#   '.'],
#  ['зач', 'клевета', 'на', 'французск', 'ум', '?'],
#  ['тут',
#   'прост',
#   'русск',
#   'лен',
#   ',',
#   'наш',
#   'унизительн',
#   'бессил',
#   'произвест',
#   'ид',
#   ',',
#   'наш',
#   'отвратительн',
#   'паразитств',
#   'в',
#   'ряд',
#   'народ',
#   '.'],
#  ['Ils',
#   'sont',
#   'tout',
#   'simplement',
#   'des',
#   'paresseux',
#   ',',
#   'а',
#   'не',
#   'французск',
#   'ум.',
#   'о',
#   ',',
#   'русск',
#   'должн',
#   'бы',
#   'быт',
#   'истребл',
#   'для',
#   'благ',
#   'человечеств',
#   'как',
#   'вредн',
#   'паразит',
#   '!'],
#  ['мы',
#   'вовс',
#   ',',
#   'вовс',
#   'не',
#   'к',
#   'том',
#   'стрем',
#   ';',
#   'я',
#   'нич',
#   'не',
#   'понима',
#   '.'],
#  ['я', 'переста', 'понима', '!'],
#  ['да',
#   'понима',
#   'ли',
#   ',',
#   'крич',
#   'ем',
#   ',',
#   'понима',
#   'ли',
#   ',',
#   'что',
#   'есл',
#   'у',
#   'вас',
#   'гильйотин',
#   'на',
#   'перв',
#   'план',
#   'и',
#   'с',
#   'так',
#   'восторг',
#   ',',
#   'то',
#   'эт',
#   'единствен',
#   'пот',
#   ',',
#   'что',
#   'руб',
#   'голов',
#   'всег',
#   'легч',
#   ',',
#   'а',
#   'имет',
#   'ид',
#   'всег',
#   'трудн',
#   '!'],
#  ['Vous', 'ктес', 'des', 'paresseux', '!'],
#  ['Votre',
#   'drapeau',
#   'est',
#   'une',
#   'guenille',
#   ',',
#   'une',
#   'impuissance',
#   '.'],
#  ['эт',
#   'телег',
#   ',',
#   'ил',
#   'как',
#   'там',
#   ':',
#   '``',
#   'стук',
#   'телег',
#   ',',
#   'подвозя',
#   'хлеб',
#   'человечеств',
#   "''",
#   ',',
#   'полезн',
#   'сикстинск',
#   'мадон',
#   ',',
#   'ил',
#   'как',
#   'у',
#   'них',
#   'там',
#   '...',
#   'une',
#   'бктис',
#   'dans',
#   'се',
#   'genre',
#   '.'],
#  ['но',
#   'понима',
#   'ли',
#   ',',
#   'крич',
#   'ем',
#   ',',
#   'понима',
#   'ли',
#   'ты',
#   ',',
#   'что',
#   'человек',
#   'кром',
#   'счаст',
#   'так',
#   'же',
#   'точн',
#   'и',
#   'совершен',
#   'во',
#   'стольк',
#   'же',
#   'необходим',
#   'и',
#   'несчаст',
#   '!'],
#  ['Il', 'rit', '.'],
#  ['ты',
#   ',',
#   'говор',
#   ',',
#   'зде',
#   'бонм',
#   'отпуска',
#   ',',
#   '``',
#   'неж',
#   'сво',
#   'член',
#   '(',
#   'он',
#   'пакостн',
#   'выраз',
#   ')',
#   'на',
#   'бархатн',
#   'диван',
#   "''",
#   '...',
#   'и',
#   'заметьт',
#   ',',
#   'эт',
#   'наш',
#   'привычк',
#   'на',
#   'ты',
#   'отц',
#   'с',
#   'сын',
#   ';',
#   'хорош',
#   ',',
#   'когд',
#   'об',
#   'согласн',
#   ',',
#   'ну',
#   ',',
#   'а',
#   'есл',
#   'руга',
#   '?'],
#  ['с', 'минут', 'опя', 'помолча', '.'],
#  ['-',
#   'Cher',
#   ',',
#   '-',
#   'заключ',
#   'он',
#   'вдруг',
#   ',',
#   'быстр',
#   'приподня',
#   ',',
#   '-',
#   'знает',
#   'ли',
#   ',',
#   'что',
#   'эт',
#   'непремен',
#   'чем-нибуд',
#   'конч',
#   '?'],
#  ['-', 'уж', 'конечн', ',', '-', 'сказа', 'я', '.'],
#  ['-', 'Vous', 'ne', 'comprenez', 'pas', '.'],
#  ['Passons', '.'],
#  ['но',
#   '...',
#   'обыкновен',
#   'на',
#   'свет',
#   'конча',
#   'нич',
#   ',',
#   'но',
#   'зде',
#   'будет',
#   'конец',
#   ',',
#   'непремен',
#   ',',
#   'непремен',
#   '!'],
#  ['он',
#   'встал',
#   ',',
#   'прошел',
#   'по',
#   'комнат',
#   'в',
#   'сильн',
#   'волнен',
#   'и',
#   ',',
#   'дойд',
#   'опя',
#   'до',
#   'дива',
#   ',',
#   'бессильн',
#   'повал',
#   'на',
#   'нег',
#   '.'],
#  ['в',
#   'пятниц',
#   'утр',
#   'петр',
#   'степанович',
#   'уеха',
#   'куда-т',
#   'в',
#   'уезд',
#   'и',
#   'проб',
#   'до',
#   'понедельник',
#   '.'],
#  ['об',
#   'отъезд',
#   'ег',
#   'я',
#   'узна',
#   'от',
#   'липутин',
#   ',',
#   'и',
#   'тут',
#   'же',
#   ',',
#   'как-т',
#   'к',
#   'разговор',
#   ',',
#   'узна',
#   'от',
#   'нег',
#   ',',
#   'что',
#   'лебядкин',
#   ',',
#   'братец',
#   'и',
#   'сестриц',
#   ',',
#   'об',
#   'где-т',
#   'за',
#   'рек',
#   ',',
#   'в',
#   'горшечн',
#   'слободк',
#   '.'],
#  ['``',
#   'я',
#   'же',
#   'и',
#   'перевоз',
#   "''",
#   ',',
#   'прибав',
#   'липутин',
#   ',',
#   'и',
#   ',',
#   'прерва',
#   'о',
#   'лебядкин',
#   ',',
#   'вдруг',
#   'возвест',
#   'мне',
#   ',',
#   'что',
#   'лизавет',
#   'николаевн',
#   'выход',
#   'за',
#   'маврик',
#   'николаевич',
#   ',',
#   'и',
#   'хот',
#   'эт',
#   'и',
#   'не',
#   'объявл',
#   ',',
#   'но',
#   'помолвк',
#   'был',
#   'и',
#   'дел',
#   'поконч',
#   '.'],
#  ['назавтр',
#   'я',
#   'встрет',
#   'лизавет',
#   'николаевн',
#   'верх',
#   'в',
#   'сопровожден',
#   'маврик',
#   'николаевич',
#   ',',
#   'выеха',
#   'в',
#   'перв',
#   'раз',
#   'посл',
#   'болезн',
#   '.'],
#  ['он',
#   'сверкнул',
#   'на',
#   'мен',
#   'изда',
#   'глаз',
#   ',',
#   'засмея',
#   'и',
#   'очен',
#   'дружеск',
#   'кивнул',
#   'голов',
#   '.'],
#  ['все',
#   'эт',
#   'я',
#   'переда',
#   'степан',
#   'трофимович',
#   ';',
#   'он',
#   'обрат',
#   'некотор',
#   'вниман',
#   'лиш',
#   'на',
#   'извест',
#   'о',
#   'лебядкин',
#   '.'],
#  ['а',
#   'тепер',
#   ',',
#   'описа',
#   'наш',
#   'загадочн',
#   'положен',
#   'в',
#   'продолжен',
#   'эт',
#   'восьм',
#   'дне',
#   ',',
#   'когд',
#   'мы',
#   'ещ',
#   'нич',
#   'не',
#   'знал',
#   ',',
#   'приступл',
#   'к',
#   'описан',
#   'послед',
#   'событ',
#   'мо',
#   'хроник',
#   ',',
#   'и',
#   'уж',
#   ',',
#   'так',
#   'сказа',
#   ',',
#   'с',
#   'знан',
#   'дел',
#   ',',
#   'в',
#   'том',
#   'вид',
#   ',',
#   'как',
#   'все',
#   'эт',
#   'откр',
#   'и',
#   'объясн',
#   'тепер',
#   '.'],
#  ['начн',
#   'имен',
#   'с',
#   'восьм',
#   'дня',
#   'посл',
#   'тог',
#   'воскресен',
#   ',',
#   'то-ест',
#   'с',
#   'понедельник',
#   'вечер',
#   '-',
#   'пот',
#   'что',
#   'в',
#   'сущност',
#   'с',
#   'эт',
#   'вечер',
#   'и',
#   'нача',
#   '``',
#   'нов',
#   'истор',
#   "''",
#   '.'],
#  ['III', 'был', 'сем', 'час', 'вечер', '.'],
#  ['никола',
#   'всеволодович',
#   'сидел',
#   'один',
#   'в',
#   'сво',
#   'кабинет',
#   ',',
#   '-',
#   'комнат',
#   'им',
#   'ещ',
#   'прежд',
#   'излюблен',
#   ',',
#   'высок',
#   ',',
#   'устла',
#   'ковр',
#   ',',
#   'уставлен',
#   'нескольк',
#   'тяжел',
#   ',',
#   'старин',
#   'фасон',
#   'мебел',
#   '.'],
#  ['он',
#   'сидел',
#   'в',
#   'угл',
#   'на',
#   'диван',
#   ',',
#   'одет',
#   'как',
#   'бы',
#   'для',
#   'выход',
#   ',',
#   'но',
#   ',',
#   'каза',
#   ',',
#   'никуд',
#   'не',
#   'собира',
#   ',',
#   'на',
#   'стол',
#   'пред',
#   'ним',
#   'стоя',
#   'ламп',
#   'с',
#   'абажур',
#   '.'],
#  ['бок', 'и', 'угл', 'больш', 'комнат', 'остава', 'в', 'тен', '.'],
#  ['взгляд',
#   'ег',
#   'был',
#   'задумч',
#   'и',
#   'сосредоточ',
#   ',',
#   'не',
#   'совс',
#   'споко',
#   ';',
#   'лиц',
#   'устал',
#   'и',
#   'нескольк',
#   'похудевш',
#   '.'],
#  ['бол',
#   'он',
#   'был',
#   'действительн',
#   'флюс',
#   ';',
#   'но',
#   'слух',
#   'о',
#   'выбит',
#   'зуб',
#   'был',
#   'преувелич',
#   '.'],
#  ['зуб',
#   'тольк',
#   'шата',
#   ',',
#   'но',
#   'тепер',
#   'снов',
#   'окреп',
#   ';',
#   'был',
#   'тож',
#   'рассеч',
#   'изнутр',
#   'верхн',
#   'губ',
#   ',',
#   'но',
#   'и',
#   'эт',
#   'заж',
#   '.'],
#  ['флюс',
#   'же',
#   'не',
#   'проход',
#   'всю',
#   'недел',
#   'лиш',
#   'пот',
#   ',',
#   'что',
#   'больн',
#   'не',
#   'хотел',
#   'приня',
#   'доктор',
#   'и',
#   'воврем',
#   'дат',
#   'разреза',
#   'опухол',
#   ',',
#   'а',
#   'ждал',
#   ',',
#   'пок',
#   'нар',
#   'сам',
#   'прорвет',
#   '.'],
#  ['он',
#   'не',
#   'тольк',
#   'доктор',
#   ',',
#   'но',
#   'и',
#   'мат',
#   'едв',
#   'допуска',
#   'к',
#   'себ',
#   ',',
#   'и',
#   'то',
#   'на',
#   'минут',
#   ',',
#   'один',
#   'раз',
#   'на',
#   'дню',
#   'и',
#   'непремен',
#   'в',
#   'сумерк',
#   ',',
#   'когд',
#   'уж',
#   'станов',
#   'темн',
#   ',',
#   'а',
#   'огн',
#   'ещ',
#   'не',
#   'подава',
#   '.'],
#  ['не',
#   'принима',
#   'он',
#   'тож',
#   'и',
#   'петр',
#   'степанович',
#   ',',
#   'котор',
#   'однак',
#   'же',
#   'по',
#   'два',
#   'и',
#   'по',
#   'три',
#   'раз',
#   'в',
#   'ден',
#   'забега',
#   'к',
#   'варвар',
#   'петровн',
#   ',',
#   'пок',
#   'остава',
#   'в',
#   'город',
#   '.'],
#  ['и',
#   'вот',
#   'наконец',
#   'в',
#   'понедельник',
#   ',',
#   'возврат',
#   'поутр',
#   'посл',
#   'сво',
#   'трехдневн',
#   'отлучк',
#   ',',
#   'обега',
#   'ве',
#   'город',
#   'и',
#   'отобеда',
#   'у',
#   'юл',
#   'михайловн',
#   ',',
#   'петр',
#   'степанович',
#   'к',
#   'вечер',
#   'яв',
#   'наконец',
#   'к',
#   'нетерпелив',
#   'ожида',
#   'ег',
#   'варвар',
#   'петровн',
#   '.'],
#  ['запрет', 'был', 'снят', ',', 'никола', 'всеволодович', 'принима', '.'],
#  ['варвар',
#   'петровн',
#   'сам',
#   'подвел',
#   'гост',
#   'к',
#   'двер',
#   'кабинет',
#   ';',
#   'он',
#   'давн',
#   'жела',
#   'их',
#   'свидан',
#   ',',
#   'а',
#   'петр',
#   'степанович',
#   'дал',
#   'е',
#   'слов',
#   'забежа',
#   'к',
#   'не',
#   'от',
#   'Nicolas',
#   'и',
#   'пересказа',
#   '.'],
#  ['робк',
#   'постуча',
#   'он',
#   'к',
#   'никола',
#   'всеволодович',
#   'и',
#   ',',
#   'не',
#   'получ',
#   'ответ',
#   ',',
#   'осмел',
#   'приотвор',
#   'двер',
#   'вершк',
#   'на',
#   'два',
#   '.'],
#  ['-',
#   'Nicolas',
#   ',',
#   'мог',
#   'я',
#   'ввест',
#   'к',
#   'теб',
#   'петр',
#   'степанович',
#   '?'],
#  ['-',
#   'тих',
#   'и',
#   'сдержа',
#   'спрос',
#   'он',
#   ',',
#   'стар',
#   'разглядет',
#   'никол',
#   'всеволодович',
#   'из-з',
#   'ламп',
#   '.'],
#  ['-', 'можн', ',', 'можн', ',', 'конечн', 'можн', '!'],
#  ['-',
#   'громк',
#   'и',
#   'весел',
#   'крикнул',
#   'сам',
#   'петр',
#   'степанович',
#   ',',
#   'отвор',
#   'двер',
#   'сво',
#   'рук',
#   'и',
#   'вошел',
#   '.'],
#  ['никола',
#   'всеволодович',
#   'не',
#   'слыха',
#   'стук',
#   'в',
#   'двер',
#   ',',
#   'а',
#   'расслыша',
#   'лиш',
#   'тольк',
#   'робк',
#   'вопрос',
#   'мамаш',
#   ',',
#   'но',
#   'не',
#   'успел',
#   'на',
#   'нег',
#   'ответ',
#   '.'],
#  ['пред',
#   'ним',
#   'в',
#   'эт',
#   'минут',
#   'лежа',
#   'тольк',
#   'что',
#   'прочита',
#   'им',
#   'письм',
#   ',',
#   'над',
#   'котор',
#   'он',
#   'сильн',
#   'задума',
#   '.'],
#  ['он',
#   'вздрогнул',
#   ',',
#   'заслыша',
#   'внезапн',
#   'окрик',
#   'петр',
#   'степанович',
#   ',',
#   'и',
#   'поскор',
#   'накр',
#   'письм',
#   'попа',
#   'под',
#   'рук',
#   'преспап',
#   ',',
#   'но',
#   'не',
#   'совс',
#   'уда',
#   ':',
#   'угол',
#   'письм',
#   'и',
#   'почт',
#   'ве',
#   'конверт',
#   'выглядыва',
#   'наруж',
#   '.'],
#  ['-',
#   'я',
#   'нарочн',
#   'крикнул',
#   'из',
#   'все',
#   'сил',
#   ',',
#   'чтоб',
#   'вы',
#   'успел',
#   'приготов',
#   ',',
#   '-',
#   'тороплив',
#   'с',
#   'удивительн',
#   'наивност',
#   'прошепта',
#   'петр',
#   'степанович',
#   ',',
#   'подбег',
#   'к',
#   'стол',
#   ',',
#   'и',
#   'миг',
#   'устав',
#   'на',
#   'преспап',
#   'и',
#   'на',
#   'угол',
#   'письм',
#   '.'],
#  ['-',
#   'и',
#   'конечн',
#   'успел',
#   'подглядет',
#   ',',
#   'как',
#   'я',
#   'прята',
#   'от',
#   'вас',
#   'под',
#   'преспап',
#   'тольк',
#   'что',
#   'получен',
#   'мно',
#   'письм',
#   ',',
#   '-',
#   'спокойн',
#   'проговор',
#   'никола',
#   'всеволодович',
#   ',',
#   'не',
#   'трог',
#   'с',
#   'мест',
#   '.'],
#  ['-', 'письм', '?'],
#  ['бог', 'с', 'вам', 'и', 'с', 'ваш', 'письм', ',', 'мне', 'что', '!'],
#  ['-',
#   'воскликнул',
#   'гост',
#   ',',
#   '-',
#   'но',
#   '...',
#   'главн',
#   ',',
#   '-',
#   'зашепта',
#   'он',
#   'опя',
#   ',',
#   'обертыв',
#   'к',
#   'двер',
#   ',',
#   'уж',
#   'заперт',
#   ',',
#   'и',
#   'кив',
#   'в',
#   'ту',
#   'сторон',
#   'голов',
#   '.'],
#  ['-',
#   'он',
#   'никогд',
#   'не',
#   'подслушива',
#   ',',
#   '-',
#   'холодн',
#   'замет',
#   'никола',
#   'всеволодович',
#   '.'],
#  ['-', 'то-ест', 'есл', 'б', 'и', 'подслушива', '!'],
#  ['-',
#   'миг',
#   'подхват',
#   ',',
#   'весел',
#   'возвыш',
#   'голос',
#   'и',
#   'усажив',
#   'в',
#   'кресл',
#   ',',
#   'петр',
#   'степанович',
#   '.'],
#  ['-',
#   'я',
#   'нич',
#   'прот',
#   'эт',
#   ',',
#   'я',
#   'тольк',
#   'тепер',
#   'бежа',
#   'поговор',
#   'наедин',
#   '...',
#   'ну',
#   ',',
#   'наконец-т',
#   'я',
#   'к',
#   'вам',
#   'доб',
#   '!'],
#  ['прежд', 'всег', 'как', 'здоров', '?'],
#  ['виж',
#   ',',
#   'что',
#   'прекрасн',
#   ',',
#   'и',
#   'завтр',
#   ',',
#   'может',
#   'быт',
#   ',',
#   'вы',
#   'яв',
#   ',',
#   '-',
#   'а',
#   '?'],
#  ['-', 'может', 'быт', '.'],
#  ['-', 'разреш', 'их', 'наконец', ',', 'разреш', 'мен', '!'],
#  ['-',
#   'неистов',
#   'зажестикулирова',
#   'он',
#   'с',
#   'шутлив',
#   'и',
#   'приятн',
#   'вид',
#   '.'],
#  ['-',
#   'есл',
#   'б',
#   'вы',
#   'знал',
#   ',',
#   'что',
#   'я',
#   'долж',
#   'был',
#   'им',
#   'наболта',
#   '.'],
#  ['а', 'впроч', 'вы', 'знает', '.'],
#  ['-', 'он', 'засмея', '.'],
#  ['-', 'всег', 'не', 'зна', '.'],
#  ['я',
#   'слыша',
#   'тольк',
#   'от',
#   'матер',
#   ',',
#   'что',
#   'вы',
#   'очен',
#   '...',
#   'двига',
#   '.'],
#  ['-',
#   'то-ест',
#   'я',
#   'вед',
#   'нич',
#   'определен',
#   ',',
#   '-',
#   'вскинул',
#   'вдруг',
#   'петр',
#   'степанович',
#   ',',
#   'как',
#   'бы',
#   'защищ',
#   'от',
#   'ужасн',
#   'нападен',
#   ',',
#   '-',
#   'знает',
#   ',',
#   'я',
#   'пуст',
#   'в',
#   'ход',
#   'жен',
#   'шатов',
#   ',',
#   'то-ест',
#   'слух',
#   'о',
#   'ваш',
#   'связ',
#   'в',
#   'париж',
#   ',',
#   'чем',
#   'и',
#   'объясня',
#   'конечн',
#   'тот',
#   'случа',
#   'в',
#   'воскресен',
#   '...',
#   'вы',
#   'не',
#   'серд',
#   '?'],
#  ['-', 'убежд', ',', 'что', 'вы', 'очен', 'стара', '.'],
#  ['-', 'ну', ',', 'я', 'тольк', 'эт', 'и', 'боя', '.'],
#  ['а',
#   'впроч',
#   'что',
#   'ж',
#   'эт',
#   'знач',
#   ':',
#   '``',
#   'очен',
#   'стара',
#   "''",
#   '?'],
#  ['эт', 'вед', 'упрек', '.'],
#  ['впроч',
#   'вы',
#   'прям',
#   'став',
#   ',',
#   'я',
#   'всег',
#   'больш',
#   'боя',
#   ',',
#   'ид',
#   'сюд',
#   ',',
#   'что',
#   'вы',
#   'не',
#   'захот',
#   'прям',
#   'постав',
#   '.'],
#  ['-',
#   'я',
#   'нич',
#   'и',
#   'не',
#   'хоч',
#   'прям',
#   'став',
#   ',',
#   '-',
#   'проговор',
#   'никола',
#   'всеволодович',
#   'с',
#   'некотор',
#   'раздражен',
#   ',',
#   'но',
#   'тотчас',
#   'же',
#   'усмехнул',
#   '.'],
#  ['-',
#   'я',
#   'не',
#   'про',
#   'то',
#   ';',
#   'не',
#   'про',
#   'то',
#   ',',
#   'не',
#   'ошиб',
#   ',',
#   'не',
#   'про',
#   'то',
#   '!'],
#  ['-',
#   'замаха',
#   'рук',
#   'петр',
#   'степанович',
#   ',',
#   'сыпл',
#   'слов',
#   'как',
#   'горох',
#   'и',
#   'тотчас',
#   'же',
#   'обрадова',
#   'раздражительн',
#   'хозяин',
#   '.'],
#  ['-',
#   'я',
#   'не',
#   'стан',
#   'вас',
#   'раздража',
#   'наш',
#   'дел',
#   ',',
#   'особен',
#   'в',
#   'ваш',
#   'теперешн',
#   'положен',
#   '.'],
#  ['я',
#   'прибежа',
#   'тольк',
#   'о',
#   'воскресн',
#   'случа',
#   ',',
#   'и',
#   'то',
#   'в',
#   'сам',
#   'необходим',
#   'мер',
#   ',',
#   'пот',
#   'нельз',
#   'же',
#   'вед',
#   '.'],
#  ['я',
#   'с',
#   'сам',
#   'открыт',
#   'объяснен',
#   ',',
#   'в',
#   'котор',
#   'нужда',
#   'главн',
#   'я',
#   ',',
#   'а',
#   'не',
#   'вы',
#   ',',
#   '-',
#   'эт',
#   'для',
#   'ваш',
#   'самолюб',
#   ',',
#   'но',
#   'в',
#   'то',
#   'же',
#   'врем',
#   'эт',
#   'и',
#   'правд',
#   '.'],
#  ['я',
#   'пришел',
#   ',',
#   'чтоб',
#   'быт',
#   'с',
#   'эт',
#   'пор',
#   'всегд',
#   'откровен',
#   '.'],
#  ['-', 'стал', 'быт', ',', 'прежд', 'был', 'неоткровен', '?'],
#  ['-', 'и', 'вы', 'эт', 'знает', 'сам', '.'],
#  ['я',
#   'хитр',
#   'мног',
#   'раз',
#   '...',
#   'вы',
#   'улыбнул',
#   ',',
#   'очен',
#   'рад',
#   'улыбк',
#   ',',
#   'как',
#   'предлог',
#   'для',
#   'разъяснен',
#   ';',
#   'я',
#   'вед',
#   'нарочн',
#   'вызва',
#   'улыбк',
#   'хвастлив',
#   'слов',
#   '``',
#   'хитр',
#   "''",
#   ',',
#   'для',
#   'тог',
#   ',',
#   'чтоб',
#   'вы',
#   'тотчас',
#   'же',
#   'и',
#   'рассерд',
#   ':',
#   'как',
#   'эт',
#   'я',
#   'смел',
#   'подума',
#   ',',
#   'что',
#   'мог',
#   'хитр',
#   ',',
#   'а',
#   'мне',
#   ',',
#   'чтоб',
#   'сейчас',
#   'же',
#   'объясн',
#   '.'],
#  ['вид', ',', 'вид', ',', 'как', 'я', 'стал', 'тепер', 'откровен', '!'],
#  ['ну-с', ',', 'угодн', 'вам', 'выслуша', '?'],
#  ['в',
#   'выражен',
#   'лиц',
#   'никол',
#   'всеволодович',
#   ',',
#   'презрительн',
#   'спокойн',
#   'и',
#   'даж',
#   'насмешлив',
#   ',',
#   'несмотр',
#   'на',
#   'все',
#   'очевидн',
#   'желан',
#   'гост',
#   'раздраж',
#   'хозяин',
#   'нахальн',
#   'сво',
#   'заран',
#   'наготовлен',
#   'и',
#   'с',
#   'намерен',
#   'груб',
#   'наивност',
#   ',',
#   '-',
#   'выраз',
#   'наконец',
#   'нескольк',
#   'тревожн',
#   'любопытств',
#   '.'],
#  ['-',
#   'слуша',
#   'же',
#   ',',
#   '-',
#   'завертел',
#   'петр',
#   'степанович',
#   'пущ',
#   'прежн',
#   '.'],
#  ['-',
#   'отправл',
#   'сюд',
#   ',',
#   'то-ест',
#   'вообщ',
#   'сюд',
#   ',',
#   'в',
#   'этот',
#   'город',
#   ',',
#   'деся',
#   'дне',
#   'назад',
#   ',',
#   'я',
#   'конечн',
#   'реш',
#   'взят',
#   'рол',
#   '.'],
#  ['сам',
#   'бы',
#   'лучш',
#   'совс',
#   'без',
#   'рол',
#   ',',
#   'сво',
#   'собствен',
#   'лиц',
#   ',',
#   'не',
#   'так',
#   'ли',
#   '?'],
#  ['нич',
#   'нет',
#   'хитр',
#   ',',
#   'как',
#   'собствен',
#   'лиц',
#   ',',
#   'пот',
#   'что',
#   'никт',
#   'не',
#   'повер',
#   '.'],
#  ['я',
#   ',',
#   'призна',
#   ',',
#   'хотел',
#   'был',
#   'взят',
#   'дурачк',
#   ',',
#   'пот',
#   'что',
#   'дурачек',
#   'легч',
#   ',',
#   'чем',
#   'собствен',
#   'лиц',
#   ';',
#   'но',
#   'так',
#   'как',
#   'дурачек',
#   'все-так',
#   'крайност',
#   ',',
#   'а',
#   'крайност',
#   'возбужда',
#   'любопытств',
#   ',',
#   'то',
#   'я',
#   'и',
#   'останов',
#   'на',
#   'собствен',
#   'лиц',
#   'окончательн',
#   '.'],
#  ['ну-с', ',', 'как', 'же', 'мо', 'собствен', 'лиц', '?'],
#  ['золот',
#   'средин',
#   ':',
#   'ни',
#   'глуп',
#   ',',
#   'ни',
#   'ум',
#   ',',
#   'довольн',
#   'бездар',
#   'и',
#   'с',
#   'лун',
#   'соскоч',
#   ',',
#   'как',
#   'говор',
#   'зде',
#   'благоразумн',
#   'люд',
#   ',',
#   'не',
#   'так',
#   'ли',
#   '?'],
#  ['-',
#   'что',
#   'ж',
#   ',',
#   'может',
#   'быт',
#   'и',
#   'так',
#   ',',
#   '-',
#   'чуть-чут',
#   'улыбнул',
#   'никола',
#   'всеволодович',
#   '.'],
#  ['-',
#   'а',
#   ',',
#   'вы',
#   'согласн',
#   '-',
#   'очен',
#   'рад',
#   ';',
#   'я',
#   'знал',
#   'вперед',
#   ',',
#   'что',
#   'эт',
#   'ваш',
#   'собствен',
#   'мысл',
#   '...',
#   'не',
#   'беспокойт',
#   ',',
#   'не',
#   'беспокойт',
#   ',',
#   'я',
#   'не',
#   'серж',
#   'и',
#   'вовс',
#   'не',
#   'для',
#   'тог',
#   'определ',
#   'себ',
#   'в',
#   'так',
#   'вид',
#   ',',
#   'чтоб',
#   'вызва',
#   'ваш',
#   'обратн',
#   'похвал',
#   ':',
#   '``',
#   'нет',
#   ',',
#   'деска',
#   ',',
#   'вы',
#   'не',
#   'бездарн',
#   ',',
#   'нет',
#   ',',
#   'деска',
#   ',',
#   'вы',
#   'умн',
#   "''",
#   '...',
#   'а',
#   ',',
#   'вы',
#   'опя',
#   'улыба',
#   '!',
#   '..'],
#  ['я', 'опя', 'попа', '.'],
#  ['вы',
#   'не',
#   'сказа',
#   'бы',
#   ':',
#   '``',
#   'вы',
#   'умн',
#   "''",
#   ',',
#   'ну',
#   'и',
#   'полож',
#   ';',
#   'я',
#   'все',
#   'допуска',
#   '.'],
#  ['Passons',
#   ',',
#   'как',
#   'говор',
#   'папаш',
#   ',',
#   'и',
#   ',',
#   'в',
#   'скобк',
#   ',',
#   'не',
#   'серд',
#   'на',
#   'мо',
#   'многослов',
#   '.'],
#  ['кстат',
#   'вот',
#   'и',
#   'пример',
#   ':',
#   'я',
#   'всегд',
#   'говор',
#   'мног',
#   ',',
#   'то-ест',
#   'мног',
#   'слов',
#   ',',
#   'и',
#   'торопл',
#   ',',
#   'и',
#   'у',
#   'мен',
#   'всегд',
#   'не',
#   'выход',
#   '.'],
#  ['а',
#   'поч',
#   'я',
#   'говор',
#   'мног',
#   'слов',
#   'и',
#   'у',
#   'мен',
#   'не',
#   'выход',
#   '?'],
#  ['пот', 'что', 'говор', 'не', 'ум', '.'],
#  ['те',
#   ',',
#   'котор',
#   'умеют',
#   'хорош',
#   'говор',
#   ',',
#   'те',
#   'коротк',
#   'говор',
#   '.'],
#  ['вот',
#   ',',
#   'стал',
#   'быт',
#   ',',
#   'у',
#   'мен',
#   'и',
#   'бездарн',
#   ',',
#   '-',
#   'не',
#   'правд',
#   'ли',
#   '?'],
#  ['но',
#   'так',
#   'как',
#   'этот',
#   'дар',
#   'бездарн',
#   'у',
#   'мен',
#   'уж',
#   'ест',
#   'натуральн',
#   ',',
#   'так',
#   'поч',
#   'мне',
#   'им',
#   'не',
#   'воспользова',
#   'искусствен',
#   '?'],
#  ['я', 'и', 'польз', '.'],
#  ['правд',
#   ',',
#   'собир',
#   'сюд',
#   ',',
#   'я',
#   'был',
#   'подума',
#   'снача',
#   'молча',
#   ';',
#   'но',
#   'вед',
#   'молча',
#   '-',
#   'больш',
#   'талант',
#   ',',
#   'и',
#   ',',
#   'стал',
#   'быт',
#   ',',
#   'мне',
#   'неприличн',
#   ',',
#   'а',
#   'во-втор',
#   ',',
#   'молча',
#   'все-так',
#   'вед',
#   'опасн',
#   ';',
#   'ну',
#   'я',
#   'и',
#   'реш',
#   'окончательн',
#   ',',
#   'что',
#   'лучш',
#   'всег',
#   'говор',
#   ',',
#   'но',
#   'имен',
#   'по-бездарн',
#   ',',
#   'то-ест',
#   'мног',
#   ',',
#   'мног',
#   ',',
#   'мног',
#   ',',
#   'очен',
#   'тороп',
#   'доказыва',
#   'и',
#   'под',
#   'конец',
#   'всегд',
#   'спута',
#   'в',
#   'сво',
#   'собствен',
#   'доказательств',
#   ',',
#   'так',
#   'чтоб',
#   'слушател',
#   'отошел',
#   'от',
#   'вас',
#   'без',
#   'конц',
#   ',',
#   'развед',
#   'рук',
#   ',',
#   'а',
#   'всег',
#   'бы',
#   'лучш',
#   'плюнув',
#   '.'],
#  ['выйдет',
#   ',',
#   'во-перв',
#   ',',
#   'что',
#   'вы',
#   'увер',
#   'в',
#   'сво',
#   'простодуш',
#   ',',
#   'очен',
#   'надоел',
#   'и',
#   'был',
#   'непонят',
#   '-',
#   'все',
#   'три',
#   'выгод',
#   'раз',
#   '!'],
#  ['помил',
#   ',',
#   'кто',
#   'посл',
#   'эт',
#   'станет',
#   'вас',
#   'подозрева',
#   'в',
#   'таинствен',
#   'замысл',
#   '?'],
#  ['да',
#   'всяк',
#   'из',
#   'них',
#   'личн',
#   'обид',
#   'на',
#   'тог',
#   ',',
#   'кто',
#   'скажет',
#   ',',
#   'что',
#   'я',
#   'с',
#   'тайн',
#   'замысл',
#   '.'],
#  ['а',
#   'я',
#   'к',
#   'том',
#   'же',
#   'иногд',
#   'рассмеш',
#   '-',
#   'а',
#   'эт',
#   'уж',
#   'драгоцен',
#   '.'],
#  ['да',
#   'он',
#   'мне',
#   'тепер',
#   'все',
#   'прост',
#   'уж',
#   'за',
#   'то',
#   'одн',
#   ',',
#   'что',
#   'мудрец',
#   ',',
#   'издава',
#   'там',
#   'прокламац',
#   ',',
#   'оказа',
#   'зде',
#   'глуп',
#   'их',
#   'сам',
#   ',',
#   'не',
#   'так',
#   'ли',
#   '?'],
#  ['по', 'ваш', 'улыбк', 'виж', ',', 'что', 'одобря', '.'],
#  ['никола',
#   'всеволодович',
#   'вовс',
#   ',',
#   'впроч',
#   ',',
#   'не',
#   'улыба',
#   ',',
#   'а',
#   'напрот',
#   'слуша',
#   'нахмурен',
#   'и',
#   'нескольк',
#   'нетерпелив',
#   '.'],
#  ['-', 'а', '?'],
#  ['что', '?'],
#  ['вы', ',', 'кажет', ',', 'сказа', ':', '``', 'все', 'равн', "''", '?'],
#  ['-',
#   'затреща',
#   'петр',
#   'степанович',
#   '(',
#   'никола',
#   'всеволодович',
#   'вовс',
#   'нич',
#   'не',
#   'говор',
#   ')',
#   '.'],
#  ['-',
#   'конечн',
#   ',',
#   'конечн',
#   ';',
#   'уверя',
#   'вас',
#   ',',
#   'что',
#   'я',
#   'вовс',
#   'не',
#   'для',
#   'тог',
#   ',',
#   'чтоб',
#   'вас',
#   'товариществ',
#   'компрометирова',
#   '.'],
#  ['а',
#   'знает',
#   ',',
#   'вы',
#   'ужасн',
#   'сегодн',
#   'вскидчив',
#   ';',
#   'я',
#   'к',
#   'вам',
#   'прибежа',
#   'с',
#   'открыт',
#   'и',
#   'весел',
#   'душ',
#   ',',
#   'а',
#   'вы',
#   'кажд',
#   'мо',
#   'словц',
#   'в',
#   'лык',
#   'став',
#   ';',
#   'уверя',
#   'же',
#   'вас',
#   ',',
#   'что',
#   'сегодн',
#   'ни',
#   'о',
#   'чем',
#   'щекотлив',
#   'не',
#   'заговор',
#   ',',
#   'слов',
#   'да',
#   ',',
#   'и',
#   'на',
#   'все',
#   'ваш',
#   'услов',
#   'заран',
#   'соглас',
#   '!'],
#  ['никола', 'всеволодович', 'упорн', 'молча', '.'],
#  ['-', 'а', '?'],
#  ['что', '?'],
#  ['вы', 'что-т', 'сказа', '?'],
#  ['виж',
#   ',',
#   'виж',
#   ',',
#   'что',
#   'я',
#   'опя',
#   ',',
#   'кажет',
#   ',',
#   'смороз',
#   ';',
#   'вы',
#   'не',
#   'предлага',
#   'услов',
#   ',',
#   'да',
#   'и',
#   'не',
#   'предлож',
#   ',',
#   'вер',
#   ',',
#   'вер',
#   ',',
#   'ну',
#   'успокойт',
#   ';',
#   'я',
#   'и',
#   'сам',
#   'вед',
#   'зна',
#   ',',
#   'что',
#   'мне',
#   'не',
#   'сто',
#   'их',
#   'предлага',
#   ',',
#   'так',
#   'ли',
#   '?'],
#  ['я',
#   'за',
#   'вас',
#   'вперед',
#   'отвеча',
#   'и',
#   '-',
#   'уж',
#   'конечн',
#   'от',
#   'бездарн',
#   ';',
#   'бездарн',
#   'и',
#   'бездарн',
#   '...',
#   'вы',
#   'смеет',
#   '?'],
#  ['а', '?'],
#  ['что', '?'],
#  ['-',
#   'нич',
#   ',',
#   '-',
#   'усмехнул',
#   'наконец',
#   'никола',
#   'всеволодович',
#   ',',
#   '-',
#   'я',
#   'припомн',
#   'сейчас',
#   ',',
#   'что',
#   'действительн',
#   'обозва',
#   'вас',
#   'как-т',
#   'бездарн',
#   ',',
#   'но',
#   'вас',
#   'тогд',
#   'не',
#   'был',
#   ',',
#   'знач',
#   ',',
#   'вам',
#   'переда',
#   '...',
#   'я',
#   'бы',
#   'вас',
#   'прос',
#   'поскор',
#   'к',
#   'дел',
#   '.'],
#  ['-',
#   'да',
#   ',',
#   'я',
#   'вед',
#   'у',
#   'дел',
#   'и',
#   'ест',
#   ',',
#   'я',
#   'имен',
#   'по',
#   'повод',
#   'воскресен',
#   '!'],
#  ['-',
#   'залепета',
#   'петр',
#   'степанович',
#   ',',
#   '-',
#   'ну',
#   'чем',
#   ',',
#   'чем',
#   'я',
#   'был',
#   'в',
# ...
#   ',',
#   'две',
#   'перв',
#   'и',
#   'последн',
#   ',',
#   'и',
#   'кром',
#   'тог',
#   'бегл',
#   'переглядел',
#   'средин',
#   '.'],
#  ['впроч',
#   'я',
#   'все',
#   'собира',
#   '...',
#   '-',
#   'э',
#   ',',
#   'все',
#   'равн',
#   ',',
#   'бросьт',
#   ',',
#   'к',
#   'чорт',
#   '!'],
#  ['-', 'махнул', 'рук', 'шат', '.'],
#  ['-',
#   'есл',
#   'вы',
#   'отступ',
#   'тепер',
#   'от',
#   'тогдашн',
#   'слов',
#   'про',
#   'народ',
#   ',',
#   '.'],
#  ['то', 'как', 'могл', 'вы', 'их', 'тогд', 'выговор', '?', '..'],
#  ['вот', 'что', 'дав', 'мен', 'тепер', '.'],
#  ['-',
#   'не',
#   'шут',
#   'же',
#   'я',
#   'с',
#   'вам',
#   'и',
#   'тогд',
#   ';',
#   'убежд',
#   'вас',
#   ',',
#   'я',
#   ',',
#   'может',
#   ',',
#   'ещ',
#   'больш',
#   'хлопота',
#   'о',
#   'себ',
#   ',',
#   'чем',
#   'о',
#   'вас',
#   ',',
#   '-',
#   'загадочн',
#   'произнес',
#   'ставрогин',
#   '.'],
#  ['-', 'не', 'шут', '!'],
#  ['в',
#   'америк',
#   'я',
#   'лежа',
#   'три',
#   'месяц',
#   'на',
#   'солом',
#   ',',
#   'ряд',
#   'с',
#   'одн',
#   '...',
#   'несчастн',
#   'и',
#   'узна',
#   'от',
#   'нег',
#   ',',
#   'что',
#   'в',
#   'то',
#   'же',
#   'сам',
#   'врем',
#   ',',
#   'когд',
#   'вы',
#   'насажда',
#   'в',
#   'мо',
#   'сердц',
#   'бог',
#   'и',
#   'родин',
#   ',',
#   'в',
#   'то',
#   'же',
#   'сам',
#   'врем',
#   'даж',
#   'может',
#   'быт',
#   'в',
#   'те',
#   'же',
#   'сам',
#   'дни',
#   ',',
#   'вы',
#   'отрав',
#   'сердц',
#   'эт',
#   'несчастн',
#   ',',
#   'эт',
#   'маньяк',
#   ',',
#   'кириллов',
#   ',',
#   'яд',
#   '...',
#   'вы',
#   'утвержда',
#   'в',
#   'нем',
#   'лож',
#   'и',
#   'клевет',
#   'и',
#   'довел',
#   'разум',
#   'ег',
#   'до',
#   'исступлен',
#   '...',
#   'под',
#   ',',
#   'взглян',
#   'на',
#   'нег',
#   'тепер',
#   ',',
#   'эт',
#   'ваш',
#   'создан',
#   '...',
#   'впроч',
#   'вы',
#   'видел',
#   '.'],
#  ['-',
#   'во-перв',
#   ',',
#   'замеч',
#   'вам',
#   ',',
#   'что',
#   'сам',
#   'кирилл',
#   'сейчас',
#   'тольк',
#   'сказа',
#   'мне',
#   ',',
#   'что',
#   'он',
#   'счастл',
#   'и',
#   'что',
#   'он',
#   'прекрас',
#   '.'],
#  ['ваш',
#   'предположен',
#   'о',
#   'том',
#   ',',
#   'что',
#   'все',
#   'эт',
#   'произошл',
#   'в',
#   'одн',
#   'и',
#   'то',
#   'же',
#   'врем',
#   ',',
#   'почт',
#   'верн',
#   ';',
#   'ну',
#   ',',
#   'и',
#   'что',
#   'же',
#   'из',
#   'всег',
#   'эт',
#   '?'],
#  ['повторя',
#   ',',
#   'я',
#   'вас',
#   'ни',
#   'тог',
#   ',',
#   'ни',
#   'друг',
#   'не',
#   'обманыва',
#   '.'],
#  ['-', 'вы', 'атеист', '?'],
#  ['тепер', 'атеист', '?'],
#  ['-', 'да', '.'],
#  ['-', 'а', 'тогд', '?'],
#  ['-', 'точн', 'так', 'же', ',', 'как', 'и', 'тогд', '.'],
#  ['-',
#   'я',
#   'не',
#   'к',
#   'себ',
#   'прос',
#   'у',
#   'вас',
#   'уважен',
#   ',',
#   'начин',
#   'разговор',
#   ';',
#   'с',
#   'ваш',
#   'ум',
#   ',',
#   'вы',
#   'бы',
#   'могл',
#   'поня',
#   'эт',
#   ',',
#   '-',
#   'в',
#   'негодован',
#   'пробормота',
#   'шат',
#   '.'],
#  ['-',
#   'я',
#   'не',
#   'встал',
#   'с',
#   'перв',
#   'ваш',
#   'слов',
#   ',',
#   'не',
#   'закр',
#   'разговор',
#   ',',
#   'не',
#   'ушел',
#   'от',
#   'вас',
#   ',',
#   'а',
#   'сиж',
#   'до',
#   'сих',
#   'пор',
#   'и',
#   'смирн',
#   'отвеча',
#   'на',
#   'ваш',
#   'вопрос',
#   'и',
#   '...',
#   'крик',
#   ',',
#   'стал',
#   'быт',
#   ',',
#   'не',
#   'наруш',
#   'ещ',
#   'к',
#   'вам',
#   'уважен',
#   '.'],
#  ['шат',
#   'прерва',
#   ',',
#   'махнув',
#   'рук',
#   ':',
#   '-',
#   'вы',
#   'помн',
#   'выражен',
#   'ваш',
#   ':',
#   '``',
#   'атеист',
#   'не',
#   'может',
#   'быт',
#   'русск',
#   "''",
#   ',',
#   '``',
#   'атеист',
#   'тотчас',
#   'же',
#   'переста',
#   'быт',
#   'русск',
#   "''",
#   ',',
#   'помн',
#   'эт',
#   '?'],
#  ['-', 'да', '?'],
#  ['-', 'как', 'бы', 'переспрос', 'никола', 'всеволодович', '.'],
#  ['-', 'вы', 'спрашива', '?'],
#  ['вы', 'заб', '?'],
#  ['а',
#   'межд',
#   'тем',
#   'эт',
#   'одн',
#   'из',
#   'сам',
#   'точн',
#   'указан',
#   'на',
#   'одн',
#   'из',
#   'главн',
#   'особен',
#   'русск',
#   'дух',
#   ',',
#   'вам',
#   'угада',
#   '.'],
#  ['не', 'могл', 'вы', 'эт', 'заб', '?'],
#  ['я',
#   'напомн',
#   'вам',
#   'больш',
#   ',',
#   '-',
#   'высказа',
#   'тогд',
#   'же',
#   ':',
#   '``',
#   'не',
#   'православн',
#   'не',
#   'может',
#   'быт',
#   'русск',
#   "''",
#   '.'],
#  ['-', 'я', 'полага', ',', 'что', 'эт', 'славянофильск', 'мысл', '.'],
#  ['-', 'нет', ';', 'нынешн', 'славянофил', 'от', 'не', 'откажут', '.'],
#  ['нынч', 'народ', 'поумнел', '.'],
#  ['но',
#   'вы',
#   'ещ',
#   'дальш',
#   'шли',
#   ':',
#   'вы',
#   'верова',
#   ',',
#   'что',
#   'римск',
#   'католицизм',
#   'уж',
#   'не',
#   'ест',
#   'христианств',
#   ';',
#   'вы',
#   'утвержда',
#   ',',
#   'что',
#   'рим',
#   'провозглас',
#   'христ',
#   ',',
#   'подда',
#   'на',
#   'трет',
#   'дьяволов',
#   'искушен',
#   ',',
#   'и',
#   'что',
#   ',',
#   'возвест',
#   'всем',
#   'свет',
#   ',',
#   'что',
#   'христос',
#   'без',
#   'царств',
#   'земн',
#   'на',
#   'земл',
#   'устоя',
#   'не',
#   'может',
#   ',',
#   'католичеств',
#   'тем',
#   'сам',
#   'провозглас',
#   'антихрист',
#   'и',
#   'тем',
#   'погуб',
#   'ве',
#   'западн',
#   'мир.',
#   'вы',
#   'имен',
#   'указыва',
#   ',',
#   'что',
#   'есл',
#   'муча',
#   'франц',
#   ',',
#   'то',
#   'единствен',
#   'по',
#   'вин',
#   'католичеств',
#   ',',
#   'иб',
#   'отвергл',
#   'смрадн',
#   'бог',
#   'римск',
#   ',',
#   'а',
#   'нов',
#   'не',
#   'сыска',
#   '.'],
#  ['вот', 'что', 'вы', 'тогд', 'могл', 'говор', '!'],
#  ['я', 'помн', 'наш', 'разговор', '.'],
#  ['-',
#   'есл',
#   'б',
#   'я',
#   'верова',
#   ',',
#   'то',
#   ',',
#   'без',
#   'сомнен',
#   ',',
#   'повтор',
#   'бы',
#   'эт',
#   'и',
#   'тепер',
#   ';',
#   'я',
#   'не',
#   'лгал',
#   ',',
#   'говор',
#   'как',
#   'вер',
#   ',',
#   '-',
#   'очен',
#   'серьезн',
#   'произнес',
#   'никола',
#   'всеволодович',
#   '.'],
#  ['-',
#   'но',
#   'уверя',
#   'вас',
#   ',',
#   'что',
#   'на',
#   'мен',
#   'производ',
#   'слишк',
#   'неприятн',
#   'впечатлен',
#   'эт',
#   'повторен',
#   'прошл',
#   'мысл',
#   'мо',
#   '.'],
#  ['не', 'может', 'ли', 'вы', 'переста', '?'],
#  ['-', 'есл', 'бы', 'верова', '?'],
#  ['-',
#   'вскрича',
#   'шат',
#   ',',
#   'не',
#   'обрат',
#   'ни',
#   'мал',
#   'вниман',
#   'на',
#   'просьб',
#   '.'],
#  ['-',
#   'но',
#   'не',
#   'вы',
#   'ли',
#   'говор',
#   'мне',
#   ',',
#   'что',
#   'есл',
#   'бы',
#   'математическ',
#   'доказа',
#   'вам',
#   ',',
#   'что',
#   'истин',
#   'вне',
#   'христ',
#   ',',
#   'то',
#   'вы',
#   'бы',
#   'соглас',
#   'лучш',
#   'оста',
#   'со',
#   'христ',
#   ',',
#   'нежел',
#   'с',
#   'истин',
#   '?'],
#  ['говор', 'вы', 'эт', '?'],
#  ['говор', '?'],
#  ['-',
#   'но',
#   'позвольт',
#   'же',
#   'и',
#   'мне',
#   'наконец',
#   'спрос',
#   ',',
#   '-',
#   'возвыс',
#   'голос',
#   'ставрогин',
#   ',',
#   '-',
#   'к',
#   'чем',
#   'ведет',
#   'ве',
#   'этот',
#   'нетерпелив',
#   'и',
#   '...',
#   'злобн',
#   'экзам',
#   '?'],
#  ['-',
#   'этот',
#   'экзам',
#   'пройдет',
#   'навек',
#   'и',
#   'никогд',
#   'больш',
#   'не',
#   'напомн',
#   'вам',
#   '.'],
#  ['-',
#   'вы',
#   'все',
#   'настаива',
#   ',',
#   'что',
#   'мы',
#   'вне',
#   'пространств',
#   'и',
#   'времен',
#   '...',
#   '-',
#   'молч',
#   '!'],
#  ['-',
#   'вдруг',
#   'крикнул',
#   'шат',
#   ',',
#   '-',
#   'я',
#   'глуп',
#   'и',
#   'неловок',
#   ',',
#   'но',
#   'погиба',
#   'мо',
#   'им',
#   'в',
#   'смешн',
#   '!'],
#  ['дозвол',
#   'ли',
#   'вы',
#   'мне',
#   'повтор',
#   'пред',
#   'вам',
#   'всю',
#   'главн',
#   'ваш',
#   'тогдашн',
#   'мысл',
#   '...',
#   'о',
#   ',',
#   'тольк',
#   'деся',
#   'строк',
#   ',',
#   'одн',
#   'заключен',
#   '.'],
#  ['-',
#   'повтор',
#   ',',
#   'есл',
#   'тольк',
#   'одн',
#   'заключен',
#   '...',
#   'ставрогин',
#   'сдела',
#   'был',
#   'движен',
#   'взглянут',
#   'на',
#   'час',
#   ',',
#   'но',
#   'удержа',
#   'и',
#   'не',
#   'взглянул',
#   '.'],
#  ['шат',
#   'принагнул',
#   'опя',
#   'на',
#   'стул',
#   'и',
#   ',',
#   'на',
#   'мгновен',
#   ',',
#   'даж',
#   'опя',
#   'был',
#   'подня',
#   'палец',
#   '.'],
#  ['-',
#   'ни',
#   'один',
#   'народ',
#   ',',
#   '-',
#   'нача',
#   'он',
#   ',',
#   'как',
#   'бы',
#   'чит',
#   'по',
#   'строк',
#   'и',
#   'в',
#   'то',
#   'же',
#   'врем',
#   'продолж',
#   'грозн',
#   'смотрет',
#   'на',
#   'ставрогин',
#   ',',
#   '-',
#   'ни',
#   'один',
#   'народ',
#   'ещ',
#   'не',
#   'устраива',
#   'на',
#   'начал',
#   'наук',
#   'и',
#   'разум',
#   ';',
#   'не',
#   'был',
#   'ни',
#   'раз',
#   'так',
#   'пример',
#   ',',
#   'разв',
#   'на',
#   'одн',
#   'минут',
#   ',',
#   'по',
#   'глупост',
#   '.'],
#  ['социализм',
#   'по',
#   'существ',
#   'сво',
#   'уж',
#   'долж',
#   'быт',
#   'атеизм',
#   ',',
#   'иб',
#   'имен',
#   'провозглас',
#   ',',
#   'с',
#   'сам',
#   'перв',
#   'строк',
#   ',',
#   'что',
#   'он',
#   'установлен',
#   'атеистическ',
#   'и',
#   'намер',
#   'устро',
#   'на',
#   'начал',
#   'наук',
#   'и',
#   'разум',
#   'исключительн',
#   '.'],
#  ['разум',
#   'и',
#   'наук',
#   'в',
#   'жизн',
#   'народ',
#   'всегд',
#   ',',
#   'тепер',
#   'и',
#   'с',
#   'нача',
#   'век',
#   ',',
#   'исполня',
#   'лиш',
#   'должност',
#   'второстепен',
#   'и',
#   'служебн',
#   ';',
#   'так',
#   'и',
#   'будут',
#   'исполня',
#   'до',
#   'конц',
#   'век',
#   '.'],
#  ['народ',
#   'слага',
#   'и',
#   'движут',
#   'сил',
#   'ин',
#   ',',
#   'повелева',
#   'и',
#   'господств',
#   ',',
#   'но',
#   'происхожден',
#   'котор',
#   'неизвестн',
#   'и',
#   'необъясним',
#   '.'],
#  ['эт',
#   'сил',
#   'ест',
#   'сил',
#   'неутолим',
#   'желан',
#   'дойт',
#   'до',
#   'конц',
#   'и',
#   'в',
#   'то',
#   'же',
#   'врем',
#   'конец',
#   'отрица',
#   '.'],
#  ['эт',
#   'ест',
#   'сил',
#   'беспрерывн',
#   'и',
#   'неуста',
#   'подтвержден',
#   'сво',
#   'быт',
#   'и',
#   'отрицан',
#   'смерт',
#   '.'],
#  ['дух',
#   'жизн',
#   ',',
#   'как',
#   'говор',
#   'писан',
#   ',',
#   '``',
#   'рек',
#   'вод',
#   'жив',
#   "''",
#   ',',
#   'иссякновен',
#   'котор',
#   'так',
#   'угрожа',
#   'апокалипсис',
#   '.'],
#  ['нача',
#   'эстетическ',
#   ',',
#   'как',
#   'говор',
#   'философ',
#   ',',
#   'нача',
#   'нравствен',
#   ',',
#   'как',
#   'отожествля',
#   'он',
#   'же',
#   '.'],
#  ['``', 'искан', 'бог', "''", ',', 'как', 'называ', 'я', 'всег', 'прощ', '.'],
#  ['цел',
#   'всег',
#   'движен',
#   'народн',
#   ',',
#   'во',
#   'всяк',
#   'народ',
#   'и',
#   'во',
#   'всяк',
#   'период',
#   'ег',
#   'быт',
#   ',',
#   'ест',
#   'единствен',
#   'лиш',
#   'искан',
#   'бог',
#   ',',
#   'бог',
#   'сво',
#   ',',
#   'непремен',
#   'собствен',
#   ',',
#   'и',
#   'вер',
#   'в',
#   'нег',
#   'как',
#   'в',
#   'един',
#   'истин',
#   '.'],
#  ['бог',
#   'ест',
#   'синтетическ',
#   'личност',
#   'всег',
#   'народ',
#   ',',
#   'взят',
#   'с',
#   'нача',
#   'ег',
#   'и',
#   'до',
#   'конц',
#   '.'],
#  ['никогд',
#   'ещ',
#   'не',
#   'был',
#   ',',
#   'чтоб',
#   'у',
#   'всех',
#   'ил',
#   'у',
#   'мног',
#   'народ',
#   'был',
#   'один',
#   'общ',
#   'бог',
#   ',',
#   'но',
#   'всегд',
#   'и',
#   'у',
#   'кажд',
#   'был',
#   'особ',
#   '.'],
#  ['признак',
#   'уничтожен',
#   'народн',
#   ',',
#   'когд',
#   'бог',
#   'начина',
#   'станов',
#   'общ',
#   '.'],
#  ['когд',
#   'бог',
#   'станов',
#   'общ',
#   ',',
#   'то',
#   'умира',
#   'бог',
#   'и',
#   'вер',
#   'в',
#   'них',
#   'вмест',
#   'с',
#   'сам',
#   'народ',
#   '.'],
#  ['чем', 'сильн', 'народ', ',', 'тем', 'особлив', 'ег', 'бог', '.'],
#  ['никогд',
#   'ещ',
#   'не',
#   'был',
#   'народ',
#   'без',
#   'религ',
#   ',',
#   'то-ест',
#   'без',
#   'понят',
#   'о',
#   'зле',
#   'и',
#   'добр',
#   '.'],
#  ['у',
#   'всяк',
#   'народ',
#   'сво',
#   'собствен',
#   'понят',
#   'о',
#   'зле',
#   'и',
#   'добр',
#   'и',
#   'сво',
#   'собствен',
#   'зло',
#   'и',
#   'добр',
#   '.'],
#  ['когд',
#   'начина',
#   'у',
#   'мног',
#   'народ',
#   'станов',
#   'общ',
#   'понят',
#   'о',
#   'зле',
#   'и',
#   'добр',
#   ',',
#   'тогд',
#   'вымира',
#   'народ',
#   ',',
#   'и',
#   'тогд',
#   'сам',
#   'различ',
#   'межд',
#   'злом',
#   'и',
#   'добр',
#   'начина',
#   'стира',
#   'и',
#   'исчеза',
#   '.'],
#  ['никогд',
#   'разум',
#   'не',
#   'в',
#   'сил',
#   'был',
#   'определ',
#   'зло',
#   'и',
#   'добр',
#   ',',
#   'ил',
#   'даж',
#   'отдел',
#   'зло',
#   'от',
#   'добр',
#   ',',
#   'хот',
#   'приблизительн',
#   ';',
#   'напрот',
#   ',',
#   'всегд',
#   'позорн',
#   'и',
#   'жалк',
#   'смешива',
#   ';',
#   'наук',
#   'же',
#   'дава',
#   'разрешен',
#   'кулачн',
#   '.'],
#  ['в',
#   'особен',
#   'эт',
#   'отлича',
#   'полунаук',
#   ',',
#   'сам',
#   'страшн',
#   'бич',
#   'человечеств',
#   ',',
#   'хуж',
#   'мор',
#   ',',
#   'голод',
#   'и',
#   'войн',
#   ',',
#   'не',
#   'известн',
#   'до',
#   'нынешн',
#   'столет',
#   '.'],
#  ['полунаук',
#   '-',
#   'эт',
#   'деспот',
#   ',',
#   'как',
#   'ещ',
#   'не',
#   'приход',
#   'до',
#   'сих',
#   'пор',
#   'никогд',
#   '.'],
#  ['деспот',
#   ',',
#   'имеющ',
#   'сво',
#   'жрец',
#   'и',
#   'раб',
#   ',',
#   'деспот',
#   ',',
#   'пред',
#   'котор',
#   'все',
#   'преклон',
#   'с',
#   'любов',
#   'и',
#   'суевер',
#   ',',
#   'до',
#   'сих',
#   'пор',
#   'немыслим',
#   ',',
#   'пред',
#   'котор',
#   'трепещет',
#   'даж',
#   'сам',
#   'наук',
#   'и',
#   'постыдн',
#   'потака',
#   'ем',
#   '.'],
#  ['все',
#   'эт',
#   'ваш',
#   'собствен',
#   'слов',
#   ',',
#   'ставрогин',
#   ',',
#   'кром',
#   'тольк',
#   'слов',
#   'о',
#   'полунаук',
#   ';',
#   'эт',
#   'мо',
#   ',',
#   'пот',
#   'что',
#   'я',
#   'сам',
#   'тольк',
#   'полунаук',
#   ',',
#   'а',
#   'стал',
#   'быт',
#   ',',
#   'особен',
#   'ненавиж',
#   'е',
#   '.'],
#  ['в',
#   'ваш',
#   'же',
#   'мысл',
#   'и',
#   'даж',
#   'в',
#   'сам',
#   'слов',
#   'я',
#   'не',
#   'измен',
#   'нич',
#   ',',
#   'ни',
#   'един',
#   'слов',
#   '.'],
#  ['-',
#   'не',
#   'дума',
#   ',',
#   'чтоб',
#   'не',
#   'измен',
#   ',',
#   '-',
#   'осторожн',
#   'замет',
#   'ставрогин',
#   ';',
#   '-',
#   'вы',
#   'пламен',
#   'приня',
#   'и',
#   'пламен',
#   'переинач',
#   ',',
#   'не',
#   'замеч',
#   'тог',
#   '.'],
#  ['уж',
#   'одн',
#   'то',
#   ',',
#   'что',
#   'вы',
#   'бог',
#   'низвод',
#   'до',
#   'прост',
#   'аттрибут',
#   'народн',
#   '...',
#   'он',
#   'с',
#   'усилен',
#   'и',
#   'особлив',
#   'вниман',
#   'нача',
#   'вдруг',
#   'след',
#   'за',
#   'шатов',
#   ',',
#   'и',
#   'не',
#   'стольк',
#   'за',
#   'слов',
#   'ег',
#   ',',
#   'скольк',
#   'за',
#   'ним',
#   'сам',
#   '.'],
#  ['-', 'низвож', 'бог', 'до', 'аттрибут', 'народн', '?'],
#  ['-',
#   'вскрича',
#   'шат',
#   ',',
#   '-',
#   'напрот',
#   ',',
#   'народ',
#   'вознош',
#   'до',
#   'бог',
#   '.'],
#  ['да', 'и', 'был', 'ли', 'когда-нибуд', 'инач', '?'],
#  ['народ', '-', 'эт', 'тел', 'бож', '.'],
#  ['всяк',
#   'народ',
#   'до',
#   'тех',
#   'тольк',
#   'пор',
#   'и',
#   'народ',
#   ',',
#   'пок',
#   'имеет',
#   'сво',
#   'бог',
#   'особ',
#   ',',
#   'а',
#   'всех',
#   'остальн',
#   'на',
#   'свет',
#   'бог',
#   'исключа',
#   'без',
#   'всяк',
#   'примирен',
#   ';',
#   'пок',
#   'вер',
#   'в',
#   'то',
#   ',',
#   'что',
#   'сво',
#   'бог',
#   'побед',
#   'и',
#   'изгон',
#   'из',
#   'мир',
#   'всех',
#   'остальн',
#   'бог',
#   '.'],
#  ['так',
#   'верова',
#   'все',
#   'с',
#   'нача',
#   'век',
#   ',',
#   'все',
#   'велик',
#   'народ',
#   'по',
#   'крайн',
#   'мер',
#   ',',
#   'все',
#   'сколько-нибуд',
#   'отмечен',
#   ',',
#   'все',
#   'стоя',
#   'во',
#   'глав',
#   'человечеств',
#   '.'],
#  ['прот', 'факт', 'идт', 'нельз', '.'],
#  ['евр',
#   'жил',
#   'лиш',
#   'для',
#   'тог',
#   ',',
#   'чтоб',
#   'дожда',
#   'бог',
#   'истин',
#   ',',
#   'и',
#   'остав',
#   'мир',
#   'бог',
#   'истин',
#   '.'],
#  ['грек',
#   'боготвор',
#   'природ',
#   'и',
#   'завеща',
#   'мир',
#   'сво',
#   'религ',
#   ',',
#   'то-ест',
#   'философ',
#   'и',
#   'искусств',
#   '.'],
#  ['рим',
#   'обоготвор',
#   'народ',
#   'в',
#   'государств',
#   'и',
#   'завеща',
#   'народ',
#   'государств',
#   '.'],
#  ['франц',
#   'в',
#   'продолжен',
#   'все',
#   'сво',
#   'длин',
#   'истор',
#   'был',
#   'одн',
#   'лиш',
#   'воплощен',
#   'и',
#   'развит',
#   'ид',
#   'римск',
#   'бог',
#   ',',
#   'и',
#   'есл',
#   'сброс',
#   'наконец',
#   'в',
#   'бездн',
#   'сво',
#   'римск',
#   'бог',
#   'и',
#   'удар',
#   'в',
#   'атеизм',
#   ',',
#   'котор',
#   'называ',
#   'у',
#   'них',
#   'покамест',
#   'социализм',
#   ',',
#   'то',
#   'единствен',
#   'пот',
#   'лиш',
#   ',',
#   'что',
#   'атеизм',
#   'все-так',
#   'здоров',
#   'римск',
#   'католичеств',
#   '.'],
#  ['есл',
#   'велик',
#   'народ',
#   'не',
#   'вер',
#   ',',
#   'что',
#   'в',
#   'нем',
#   'одн',
#   'истин',
#   '(',
#   'имен',
#   'в',
#   'одн',
#   'и',
#   'имен',
#   'исключительн',
#   ')',
#   ',',
#   'есл',
#   'не',
#   'вер',
#   ',',
#   'что',
#   'он',
#   'один',
#   'способ',
#   'и',
#   'призва',
#   'всех',
#   'воскрес',
#   'и',
#   'спаст',
#   'сво',
#   'истин',
#   ',',
#   'то',
#   'он',
#   'тотчас',
#   'же',
#   'переста',
#   'быт',
#   'велик',
#   'народ',
#   'и',
#   'тотчас',
#   'же',
#   'обраща',
#   'в',
#   'этнографическ',
#   'материа',
#   ',',
#   'а',
#   'не',
#   'в',
#   'велик',
#   'народ',
#   '.'],
#  ['истин',
#   'велик',
#   'народ',
#   'никогд',
#   'не',
#   'может',
#   'примир',
#   'со',
#   'второстепен',
#   'рол',
#   'в',
#   'человечеств',
#   ',',
#   'ил',
#   'даж',
#   'с',
#   'первостепен',
#   ',',
#   'а',
#   'непремен',
#   'и',
#   'исключительн',
#   'с',
#   'перв',
#   '.'],
#  ['кто', 'теря', 'эт', 'вер', ',', 'тот', 'уж', 'не', 'народ', '.'],
#  ['но',
#   'истин',
#   'одн',
#   ',',
#   'а',
#   ',',
#   'стал',
#   'быт',
#   ',',
#   'тольк',
#   'един',
#   'из',
#   'народ',
#   'и',
#   'может',
#   'имет',
#   'бог',
#   'истин',
#   ',',
#   'хот',
#   'бы',
#   'остальн',
#   'народ',
#   'и',
#   'имел',
#   'сво',
#   'особ',
#   'и',
#   'велик',
#   'бог',
#   '.'],
#  ...]

# %%
# собираем словарь
words = sorted( set.union( *[ set(s) for s in text_ ] ) )
display(len(words))
words
# Out:
# 8275
# ['!',
#  "'",
#  "''",
#  '(',
#  ')',
#  ',',
#  '-',
#  '.',
#  '..',
#  '...',
#  '187',
#  '19-го',
#  ':',
#  ';',
#  '?',
#  'Adieu',
#  'Alea',
#  'Allons',
#  'Augustin',
#  'Avis',
#  'Ax',
#  'Bonjour',
#  "C'est",
#  'Candide',
#  'Cela',
#  'Cette',
#  'Cher',
#  'Chere',
#  'Cozak',
#  'Cьйта',
#  'Don',
#  'Elle',
#  'Eloignez-la',
#  'Enfin',
#  'Et',
#  'Excellent',
#  'Fantichambre',
#  'Fautre',
#  'Fils',
#  'He',
#  'I',
#  'II',
#  'III',
#  'IV',
#  'Il',
#  'Ils',
#  'Incognito',
#  'Internationale',
#  "J'ai",
#  'Je',
#  'Jьйтаис',
#  'Karmazinoff',
#  'Lembke',
#  'Littre',
#  'Maman',
#  'Mein',
#  'Merci',
#  'Nicolas',
#  'Oui',
#  'Pardon',
#  'Pas',
#  'Passons',
#  'Pйтерсбоург',
#  "Qu'en",
#  "Qu'un",
#  'Quelque',
#  'Rosenthal',
#  'Savez',
#  'Savez-vous',
#  'Se',
#  'Tant',
#  'Teliatnikoff',
#  'Tous',
#  'Tout',
#  'Tо-ест',
#  'V',
#  'VI',
#  'VII',
#  'Voltaire',
#  'Votre',
#  'Vous',
#  'Voyez-vous',
#  'Vо',
#  '``',
#  'a',
#  'abreuve',
#  'ami',
#  'amie',
#  'amis',
#  'ans',
#  'au',
#  "aujourd'hui",
#  'autour',
#  'avait',
#  'avec',
#  'bas',
#  'battre',
#  'beaucoup',
#  'belle',
#  'belles',
#  'bien',
#  'bienfaisant',
#  'bon',
#  'boudoir',
#  'bourru',
#  'bruit',
#  "c'est",
#  'cacha',
#  'calme',
#  'ce',
#  'cela',
#  'ces',
#  'cette',
#  'chambre',
#  'chaque',
#  'charmant',
#  'charmante',
#  'cher',
#  'chere',
#  'chez',
#  'chose',
#  'choses',
#  'cochon',
#  'comme',
#  'commencerai',
#  'comment',
#  'comparaison',
#  'comprenez',
#  'compris',
#  'connais',
#  'connaissez',
#  'consenti',
#  'content',
#  'convertir',
#  'cozak',
#  'critiques',
#  'croire',
#  'croyez',
#  'croyez-vous',
#  'cа',
#  'cарриир',
#  "d'allemand",
#  "d'aveugle",
#  'dans',
#  'date',
#  'de',
#  'dedans',
#  'des',
#  'deux',
#  'digne',
#  'dira-t-elle',
#  'distance',
#  'dit',
#  'doit',
#  'drapeau',
#  'du',
#  'e',
#  'elle',
#  'en',
#  'encore',
#  'enfin',
#  'ennemis',
#  'entendra',
#  'esclandre',
#  'esprits-forts',
#  'est',
#  'et',
#  'fair',
#  'faire',
#  'faites',
#  'faut',
#  'femmes',
#  'ferai',
#  'figure',
#  'fils',
#  'finie',
#  'fois',
#  'forteresses',
#  'genre',
#  'gens',
#  'guenille',
#  'hauteur',
#  'heure',
#  'historiques',
#  'homme',
#  'i.',
#  'il',
#  'impuissance',
#  'impur',
#  'index',
#  'invraisemblable',
#  "j'ai",
#  'jacta',
#  'je',
#  'jure',
#  "l'assure",
#  'la',
#  'le',
#  'lecteur',
#  'les',
#  'lieber',
#  'louche',
#  'lui',
#  'm',
#  "m'en",
#  'm-me',
#  'm-r',
#  'ma',
#  'mais',
#  'me',
#  'meilleur',
#  'mes',
#  'mettez',
#  'mieux',
#  'minimum',
#  'moi',
#  'moines',
#  'moment',
#  'mon',
#  'mondes',
#  'mot',
#  "n'ai",
#  "n'est",
#  'ne',
#  'nom',
#  'non',
#  'nos',
#  'notre',
#  'on',
#  'oui',
#  'paraisse',
#  'paresseux',
#  'parlait',
#  'partout',
#  'pas',
#  'passant',
#  'pauvre',
#  'pays',
#  'permise',
#  'petit',
#  'peut',
#  'physionomie',
#  'pierre',
#  'plaisir',
#  'plus',
#  'politesse',
#  'politiques',
#  'possibles',
#  'pouce',
#  'pour',
#  'pourtant',
#  'procureur',
#  'propre',
#  'puis',
#  "qu'il",
#  "qu'on",
#  "qu'un",
#  'quand',
#  'que',
#  'quelque',
#  'quelques',
#  'qui',
#  'quinze',
#  'quoi',
#  'raison',
#  'rien',
#  'rit',
#  'roide',
#  'roubles',
#  "s'appelle",
#  'sa',
#  'sang',
#  'sans',
#  'sautait',
#  'savez-vous',
#  'se',
#  'sens',
#  'sent',
#  'serai',
#  'seul',
#  'sillons',
#  'simplement',
#  'soit',
#  'son',
#  'sont',
#  'souviens',
#  'suis',
#  'sur',
#  'tas',
#  'tenait',
#  'terrain',
#  'tombe',
#  'tomberai',
#  'toujours',
#  'tout',
#  'toute',
#  'trop',
#  'trouve',
#  'un',
#  'une',
#  'unes',
#  'vero',
#  'vie',
#  'vient',
#  'vingt',
#  'voulais',
#  'vous',
#  'voyez',
#  'voyez-vous',
#  'xe-xe',
#  'y',
#  'а',
#  'а-',
#  'а-а-',
#  'а-на-фе-м',
#  'аcтивит',
#  'абажур',
#  'абрютирова',
#  'авдот',
#  'автоматическ',
#  'автор',
#  'авторитет',
#  'агаф',
#  'агент',
#  'аглицк',
#  'адвокат',
#  'административн',
#  'администратор',
#  'администрац',
#  'адрес',
#  'адресова',
#  'адск',
#  'азарт',
#  'азиятск',
#  'академ',
#  'аккурат',
#  'аккуратн',
#  'акмолинск',
#  'актер',
#  'актрис',
#  'акушер',
#  'акушерок',
#  'акцент',
#  'ал',
#  'алекс',
#  'александрович',
#  'александровск',
#  'алексе',
#  'алеш',
#  'аллегор',
#  'алтар',
#  'альб',
#  'алюмин',
#  'амал',
#  'амбиц',
#  'америк',
#  'американск',
#  'американц',
#  'ан',
#  'ангел',
#  'англ',
#  'английск',
#  'англичан',
#  'андр',
#  'андре',
#  'анекдот',
#  'анекдотик',
#  'анекдотическ',
#  'аничков',
#  'аннй',
#  'анонимн',
#  'антихрист',
#  'антонович',
#  'антроповн',
#  'аплодир',
#  'апокалипсис',
#  'аппет',
#  'аппетит',
#  'аргумент',
#  'арест',
#  'арестова',
#  'арин',
#  'аристократ',
#  'аристократическ',
#  'аркан',
#  'аррктер',
#  'артельщик',
#  'артем',
#  'артиллер',
#  'артиллерист',
#  'архангельск',
#  'архиер',
#  'аршин',
#  'асессор',
#  'ассигнац',
#  'астрол',
#  'атеизм',
#  'атеист',
#  'атеистическ',
#  'атестова',
#  'аттрибут',
#  'афронт',
#  'аффилиац',
#  'аффильир',
#  'аффильирова',
#  'ах',
#  'ахнул',
#  'б',
#  'б-цах',
#  'ба',
#  'баб',
#  'базар',
#  'байрон',
#  'бакенбард',
#  'бал',
#  'бал.',
#  'балага',
#  'баловств',
#  'бальзак',
#  'банк',
#  'банкомет',
#  'бант',
#  'бара',
#  'бараба',
#  'барабан',
#  'баран',
#  'барин',
#  'барич',
#  'барств',
#  'бархат',
#  'бархатн',
#  'барченок',
#  'барын',
#  'барышн',
#  'барьер',
#  'баск',
#  'басн',
#  'баст',
#  'батистов',
#  'батюшк',
#  'башмак',
#  'бег',
#  'бега',
#  'бегл',
#  'бегут',
#  'бед',
#  'бедн',
#  'бедност',
#  'бедняжк',
#  'бедова',
#  'бежа',
#  'без',
#  'безбож',
#  'безбоязнен',
#  'безбров',
#  'безвер',
#  'безграничн',
#  'бездар',
#  'бездарн',
#  'бездельник',
#  'бездн',
#  'бездушн',
#  'безличн',
#  'безмерн',
#  'безмолвн',
#  'безмятежн',
#  'безнадежн',
#  'безнаказа',
#  'безнравств',
#  'безнравствен',
#  'безобраз',
#  'безобразн',
#  'безотрадн',
#  'безотчетн',
#  'безразлич',
#  'безрассуд',
#  'безукоризнен',
#  'безум',
#  'безумн',
#  'безусловн',
#  'бел',
#  'беленьк',
#  'белинск',
#  'беллетристик',
#  'беллетристическ',
#  'белобрыс',
#  'белокур',
#  'бенефис',
#  'бер',
#  'берег',
#  'бережн',
#  'берейтер',
#  'берет',
#  'берлин',
#  'берут',
#  'берущ',
#  'бес',
#  'бесенок',
#  'бесконечн',
#  'бескорыстн',
#  'беснова',
#  'беспардон',
#  'беспечн',
#  'бесподобн',
#  'беспок',
#  'беспоко',
#  'беспокойн',
#  'беспокойств',
#  'беспокойт',
#  'беспомощн',
#  'беспорядк',
#  'беспорядок',
#  'беспорядочн',
#  'беспредельн',
#  'беспредметн',
#  'беспрекословн',
#  'беспрерывн',
#  'бессвязн',
#  'бессил',
#  'бессильн',
#  'бесследн',
#  'бессмен',
#  'бессмыслен',
#  'бессмыслиц',
#  'бессознательн',
#  'бесстыдн',
#  'бестактн',
#  'бестолков',
#  'бесцеремон',
#  'бесчеловеч',
#  'бесчест',
#  'бесчестн',
#  'бесчинств',
#  'бесчислен',
#  'беш',
#  'бешенств',
#  'бивш',
#  'билет',
#  'бинокл',
#  'бинокол',
#  'биограф',
#  'бисмарк',
#  'бит',
#  'битв',
#  'бич',
#  'бкте',
#  'бктис',
#  'бктисес',
#  'благ',
#  'блага-а-дар',
#  'благоговейн',
#  'благоговел',
#  'благоговен',
#  'благода',
#  'благодар',
#  'благодарн',
#  'благодарны-т',
#  'благодат',
#  'благоденств',
#  'благодетел',
#  'благодетельн',
#  'благодеян',
#  'благодуш',
#  'благодушн',
#  'благонадеж',
#  'благонадежн',
#  'благополучн',
#  'благоприятн',
#  'благоразумн',
#  'благородн',
#  'благородств',
#  'благосклон',
#  'благослов',
#  'благотворн',
#  'блажен',
#  'блаженств',
#  'блед',
#  'бледн',
#  'бледне',
#  'бледнеет',
#  'бледнел',
#  'блеск',
#  'блеснул',
#  'блест',
#  'ближ',
#  'ближайш',
#  'ближн',
#  'близ',
#  'близк',
#  'близок-т',
#  'близорук',
#  'близост',
#  'блудлив',
#  'блюд',
#  'блюм',
#  'блюмер',
#  'бо',
#  'бог',
#  'бога-саваоф',
#  'богаделенк',
#  'богадельн',
#  'богат',
#  'богатств',
#  'богач',
#  'богоматер',
#  'богомолец',
#  'богомольн',
#  'богоносец',
#  'богородиц',
#  'богородск',
#  'боготвор',
#  'богочеловек',
#  'богоявленск',
#  'бодр',
#  'боев',
#  'бож',
#  'божествен',
#  'бойк',
#  'бойт',
#  'бок',
#  'бока',
#  'боков',
#  'бол',
#  'болезн',
#  'болезнен',
#  'болел',
#  'болот',
#  'болта',
#  'болтовн',
#  'больн',
#  'больниц',
#  'больш',
#  'большинств',
#  'бонм',
#  'борд',
#  'борет',
#  'бормота',
#  'бород',
#  'бородавк',
#  'бородач',
#  'борот',
#  'борьб',
#  'бос',
#  'бочк',
#  'боя',
#  'боязлив',
#  'боязн',
#  'боярин',
#  'боярск',
#  'боярств',
#  'брак',
#  'брал',
#  'бран',
#  'брат',
#  'братец',
#  'братств',
#  'братц',
#  'брачн',
#  'бред',
#  'бреж',
#  'брезга',
#  'брезглив',
#  'брезгова',
#  'брем',
#  'бремен',
#  'бривш',
#  'бриллиантов',
#  'брисонс-л',
#  'бров',
#  'брод',
#  'бродяг',
#  'брос',
#  'броса',
#  'бросьт',
#  'брош',
#  'брызг',
#  'брызга',
#  'брыков',
#  'брюнет',
#  'брюнеточк',
#  'брюх',
#  'брюшк',
#  'брякнет',
#  'брякнул',
#  'буд',
#  'будет',
#  'будеш',
#  'будн',
#  'будт',
#  'будуар',
#  'будут',
#  'будуч',
#  'будущ',
#  'будущн',
#  'будьт',
#  'буйн',
#  'букашк',
#  'букв',
#  'буквальн',
#  'букл',
#  'булочк',
#  'булочник',
#  'бумаг',
#  'бумажк',
#  'бумажн',
#  'бумажник',
#  'бунт',
#  'бунтова',
#  'бунтовщик',
#  'бур',
#  'бурбон',
#  'бутылк',
#  'буфет',
#  'бухгалтер',
#  'буян',
#  'бы',
#  'бы-с',
#  'быва',
#  'бывал-с',
#  'бывал-с.',
#  'бывш',
#  'быков',
#  'был',
#  'было-с',
#  'быстр',
#  'быстром-т',
#  'быстрот',
#  'быт',
#  'бьет',
#  'бью',
#  'бьют',
#  'бьющ',
#  'бюхнер',
#  'в',
#  'в-трет',
#  'вавилон',
#  'вагон',
#  'важн',
#  'важничан',
#  'важно-угрюм',
#  'важност',
#  'вал',
#  'вальс',
#  'валя',
#  'вам',
#  'вам-т',
#  'варвар',
#  'варев',
#  'варен',
#  'вариант',
#  'варьирова',
#  'вас',
#  'вас-т',
#  'васил',
#  'ват',
#  'ваш',
#  'ваш-т',
#  'вбег',
#  'вбежа',
#  'введет',
#  'ввек',
#  'ввер',
#  'ввергнув',
#  'вверх',
#  'ввест',
#  'ввечер',
#  'ввод',
#  'ввяза',
#  'вглядел',
#  'вглядыв',
#  'вглядыва',
#  'вдво',
#  'вдела',
#  'вдобавок',
#  'вдов',
#  'вдовиц',
#  'вдогонк',
#  'вдол',
#  'вдохновен',
#  'вдруг',
#  'ве',
#  'вед',
#  'веда',
#  'ведет',
#  'ведр',
#  'вежл',
#  'вежлив',
#  'вежливо-фамильярн',
#  'везд',
#  'везл',
#  'везт',
#  'век',
#  'вел',
#  'велел',
#  'велет',
#  'велик',
#  'велика',
#  'великодушн',
#  'велич',
#  'величав',
#  'величествен',
#  'вендетт',
#  'венц',
#  'венча',
#  'вер',
#  'вера-т',
#  'верб',
#  'верн',
#  'верова',
#  'вероятн',
#  'верст',
#  'верт',
#  'вертел',
#  'верует',
#  'веруют-с',
#  'верх',
#  'верхишин',
#  'верхн',
#  'верхов',
#  'верховенск',
#  'верховн',
#  'вершин',
#  'вершк',
#  'верьт',
#  'весел',
#  'веселк',
#  'веселя',
#  'веск',
#  'вескост',
#  'весн',
#  'вест',
#  'весьм',
#  'ветер',
#  'ветр',
#  'ветрен',
#  'ветх',
#  'ветчин',
#  'вечер',
#  'вечеринк',
#  'вечерк',
#  'вечерн',
#  'вечерок',
#  'вечн',
#  'веша',
#  'вешалк',
#  'вещ',
#  'веща',
#  'вещиц',
#  'взад',
#  'взаимн',
#  'взаимност',
#  'взайм',
#  'взам',
#  'взапуск',
#  'взбалмошн',
#  'взбес',
#  'взвид',
#  'взвизг',
#  'взвизгнул',
#  'взволн',
#  'взволнова',
#  'взгляд',
#  'взглян',
#  'взглянет',
#  'взглянув',
#  'взглянул',
#  'взглянут',
#  'вздернут',
#  'вздор',
#  'вздор-с',
#  'вздохнул',
#  'вздрагива',
#  'вздрогнув',
#  'вздрогнул',
#  'вздума',
#  'вздыха',
#  'взир',
#  'взира',
#  'взмост',
#  'взобра',
#  'взор',
#  'взорва',
#  'взраст',
#  'взрыв',
#  'взъерошен',
#  'взыска',
#  'взыскательн',
#  'взяв',
#  'взявш',
#  'взял',
#  'взят',
#  'виг',
#  'вид',
#  'вида',
#  'виде-с',
#  'виде-с.',
#  'видел',
#  'видет',
#  'видим',
#  'видите-с',
#  'видите-с.',
#  'видн',
#  'видыва',
#  'виж',
#  'виз',
#  'визг',
#  'визглив',
#  'визжа',
#  'визжат',
#  'визит',
#  'вил',
#  'вин',
#  'винов',
#  'виноват',
#  'виновн',
#  'виновник',
#  'виноград',
#  'виньетк',
#  'виргинск',
#  'висок',
#  'виц',
#  'вкопа',
#  'вкус',
#  'вкуша',
#  'власт',
#  'властн',
#  'влекл',
#  'влета',
#  'влетел',
#  'влит',
#  'влия',
#  'влиян',
#  'влюб',
#  'влюбл',
#  'влюблен',
#  'вменя',
#  'вмест',
#  'вмешива',
#  'вне',
#  'внезапн',
#  'внес',
#  'внесен',
#  'внесш',
#  'вниз',
#  'вникн',
#  'вниман',
#  'внимательн',
#  'внов',
#  'внутр',
#  'внуш',
#  'внуша',
#  'внушительн',
#  'во',
#  'во-втор',
#  'во-перв',
#  'вовек',
#  'воврем',
#  'вовс',
#  'вод',
#  'водев',
#  'водк',
#  'водосточн',
#  'воен',
#  'воз',
#  'возбуд',
#  'возбужд',
#  'возбужда',
#  'возбужден',
#  'возвест',
#  'возвещ',
#  'возвеща',
#  'возвещен',
#  'возвра',
#  'возврат',
#  'возвраща',
#  'возвыс',
#  'возвыш',
#  'возглас',
#  'воздейств',
#  'воздух',
#  'воздушн',
#  'воззван',
#  'воззрен',
#  'возлага',
#  'возмож',
#  'возможн',
#  'возмутительн',
#  'возмуща',
#  'вознаград',
#  'вознамер',
#  'возненавидел',
#  'вознес',
#  'вознесл',
#  'вознос',
#  'вознош',
#  'возобновлен',
#  'возобновля',
#  'возоп',
#  'возража',
#  'возражен',
#  ...]

# %% [markdown]
# количество слов в словаре уменьшилось
# 8275 против 16 658 случае NLTK токенайзера без стеминга

# %% [markdown]
# ## лемматизатор для русского языка из пакета Natasha

# %%
from natasha import Doc
from natasha import Segmenter
from natasha import MorphVocab
from natasha import NewsEmbedding
from natasha import NewsMorphTagger

# выполняем сегментацию строки на токены
doc = Doc(text) 
doc.segment( Segmenter() )
# doc.sents[77].tokens
# выполняем морфологический анализ
doc.tag_morph( NewsMorphTagger( NewsEmbedding() ) )

# выполняем лематизацию
morph_vocab = MorphVocab() # лемматизатор
for t in doc.tokens: t.lemmatize(morph_vocab)

# собираем нормализованный текст 
text_ =  [ [ t.lemma for t in s.tokens ] for s in doc.sents ]

# %%
text_
# Out:
# [['бес',
#   'федор',
#   'михаилович',
#   'достоевский',
#   'часть',
#   'второй',
#   'глава',
#   'первый',
#   'ночь',
#   'i',
#   'пройти',
#   'восемь',
#   'день',
#   '.'],
#  ['теперь',
#   ',',
#   'когда',
#   'уже',
#   'весь',
#   'пройти',
#   ',',
#   'и',
#   'я',
#   'писать',
#   'хроника',
#   ',',
#   'мы',
#   'уже',
#   'знать',
#   'в',
#   'что',
#   'дело',
#   ';',
#   'но',
#   'тогда',
#   'мы',
#   'еще',
#   'ничто',
#   'не',
#   'знать',
#   ',',
#   'и',
#   'естественно',
#   ',',
#   'что',
#   'мы',
#   'представляться',
#   'странный',
#   'разный',
#   'вещь',
#   '.'],
#  ['по',
#   'крайний',
#   'мера',
#   'мы',
#   'с',
#   'степан',
#   'трофимович',
#   'в',
#   'первый',
#   'время',
#   'запереться',
#   'и',
#   'с',
#   'испуг',
#   'наблюдать',
#   'издать',
#   '.'],
#  ['я-то',
#   'кой-куда',
#   'еще',
#   'выходить',
#   'и',
#   'по-прежнему',
#   'приносить',
#   'он',
#   'разный',
#   'весть',
#   ',',
#   'без',
#   'что',
#   'он',
#   'и',
#   'пробыть',
#   'не',
#   'мочь',
#   '.'],
#  ['нечего',
#   'и',
#   'говорить',
#   ',',
#   'что',
#   'по',
#   'город',
#   'пойти',
#   'самый',
#   'разнообразный',
#   'слух',
#   ',',
#   'то-есть',
#   'насчет',
#   'пощечина',
#   ',',
#   'обморок',
#   'лизавета',
#   'николаевич',
#   'и',
#   'прочий',
#   'случиться',
#   'в',
#   'тот',
#   'воскресение',
#   '.'],
#  ['но',
#   'удивительный',
#   'мы',
#   'быть',
#   'тот',
#   ':',
#   'через',
#   'кто',
#   'это',
#   'весь',
#   'мочь',
#   'так',
#   'скоро',
#   'и',
#   'точно',
#   'выйти',
#   'наружу',
#   '?'],
#  ['ни',
#   'один',
#   'из',
#   'присутствовать',
#   'тогда',
#   'лицо',
#   'не',
#   'иметь',
#   'бы',
#   ',',
#   'казаться',
#   ',',
#   'ни',
#   'нужда',
#   ',',
#   'ни',
#   'выгода',
#   'нарушить',
#   'секрет',
#   'произойти',
#   '.'],
#  ['прислуга',
#   'тогда',
#   'не',
#   'быть',
#   ';',
#   'один',
#   'лебядкин',
#   'мочь',
#   'бы',
#   'что-нибудь',
#   'разболтать',
#   ',',
#   'не',
#   'столько',
#   'по',
#   'злоба',
#   ',',
#   'потому',
#   'что',
#   'выйти',
#   'тогда',
#   'в',
#   'крайний',
#   'испуг',
#   '(',
#   'а',
#   'страх',
#   'к',
#   'враг',
#   'уничтожать',
#   'и',
#   'злоба',
#   'к',
#   'он',
#   ')',
#   ',',
#   'а',
#   'единственно',
#   'по',
#   'невоздержность',
#   '.'],
#  ['но',
#   'лебядкин',
#   ',',
#   'вместе',
#   'с',
#   'сестрица',
#   ',',
#   'на',
#   'другой',
#   'же',
#   'день',
#   'пропасть',
#   'без',
#   'весть',
#   ';',
#   'в',
#   'дом',
#   'филиппов',
#   'он',
#   'не',
#   'оказаться',
#   ',',
#   'он',
#   'переехать',
#   'неизвестно',
#   'куда',
#   'и',
#   'точно',
#   'сгинуть',
#   '.'],
#  ['шат',
#   ',',
#   'у',
#   'который',
#   'я',
#   'хотеть',
#   'быть',
#   'справиться',
#   'о',
#   'марья',
#   'тимофеевич',
#   ',',
#   'запереться',
#   'и',
#   ',',
#   'казаться',
#   ',',
#   'весь',
#   'этот',
#   'восемь',
#   'день',
#   'просидеть',
#   'у',
#   'себя',
#   'на',
#   'квартира',
#   ',',
#   'даже',
#   'прервать',
#   'свой',
#   'занятие',
#   'в',
#   'город',
#   '.'],
#  ['я', 'он', 'не', 'принять', '.'],
#  ['я',
#   'быть',
#   'зайти',
#   'к',
#   'он',
#   'в',
#   'вторник',
#   'и',
#   'стукнуть',
#   'в',
#   'дверь',
#   '.'],
#  ['ответ',
#   'не',
#   'получить',
#   ',',
#   'но',
#   'уверенный',
#   ',',
#   'по',
#   'несомненный',
#   'данные',
#   ',',
#   'что',
#   'он',
#   'дома',
#   ',',
#   'постучаться',
#   'в',
#   'другой',
#   'раз',
#   '.'],
#  ['тогда',
#   'он',
#   ',',
#   'соскочив',
#   'по-видимому',
#   'с',
#   'постель',
#   ',',
#   'подойти',
#   'крупный',
#   'шаг',
#   'к',
#   'дверь',
#   'и',
#   'крикнуть',
#   'я',
#   'в',
#   'весь',
#   'голос',
#   ':',
#   '"',
#   'шатов',
#   'дома',
#   'нет',
#   '"',
#   '.'],
#  ['я', 'с', 'тот', 'и', 'уйти', '.'],
#  ['мы',
#   'с',
#   'степан',
#   'трофимович',
#   ',',
#   'не',
#   'без',
#   'страх',
#   'за',
#   'смелость',
#   'предположение',
#   ',',
#   'но',
#   'обоюдно',
#   'ободрять',
#   'друг',
#   'друг',
#   ',',
#   'остановиться',
#   'наконец',
#   'на',
#   'один',
#   'мысль',
#   ':',
#   'мы',
#   'решить',
#   ',',
#   'что',
#   'виновник',
#   'разойтись',
#   'слух',
#   'мочь',
#   'быть',
#   'один',
#   'только',
#   'петр',
#   'степанович',
#   ',',
#   'хотя',
#   'сам',
#   'он',
#   'некоторый',
#   'время',
#   'спустя',
#   ',',
#   'в',
#   'разговор',
#   'с',
#   'отец',
#   ',',
#   'уверять',
#   ',',
#   'что',
#   'застать',
#   'уже',
#   'история',
#   'в',
#   'весь',
#   'уста',
#   ',',
#   'преимущественно',
#   'в',
#   'клуб',
#   ',',
#   'и',
#   'совершенно',
#   'известный',
#   'до',
#   'мелкий',
#   'подробность',
#   'губернаторша',
#   'и',
#   'она',
#   'супруг',
#   '.'],
#  ['вот',
#   'что',
#   'еще',
#   'замечательный',
#   ':',
#   'на',
#   'второй',
#   'же',
#   'день',
#   ',',
#   'в',
#   'понедельник',
#   'ввечеру',
#   ',',
#   'я',
#   'встретить',
#   'липутин',
#   ',',
#   'и',
#   'он',
#   'уже',
#   'знать',
#   'весь',
#   'до',
#   'последний',
#   'слово',
#   ',',
#   'стать',
#   'быть',
#   ',',
#   'несомненно',
#   'узнать',
#   'из',
#   'первый',
#   '.'],
#  ['многий',
#   'из',
#   'дама',
#   '(',
#   'и',
#   'из',
#   'самый',
#   'светский',
#   ')',
#   'любопытствовать',
#   'и',
#   'о',
#   '"',
#   'загадочный',
#   'хромоножка',
#   '"',
#   ',',
#   'так',
#   'называть',
#   'марья',
#   'тимофеевич',
#   '.'],
#  ['найтись',
#   'даже',
#   'пожелать',
#   'непременно',
#   'увидать',
#   'она',
#   'лично',
#   'и',
#   'познакомиться',
#   ',',
#   'так',
#   'что',
#   'господин',
#   ',',
#   'поспешить',
#   'припрятать',
#   'лебядкин',
#   ',',
#   'очевидно',
#   'поступить',
#   'и',
#   'кстати',
#   '.'],
#  ['но',
#   'на',
#   'первый',
#   'план',
#   'все-таки',
#   'стоять',
#   'обморок',
#   'лизавета',
#   'николаевич',
#   ',',
#   'и',
#   'это',
#   'интересоваться',
#   '"',
#   'весь',
#   'свет',
#   '"',
#   ',',
#   'уже',
#   'по',
#   'тот',
#   'один',
#   ',',
#   'что',
#   'дело',
#   'прямо',
#   'касаться',
#   'юлия',
#   'михаилович',
#   'как',
#   'родственница',
#   'лизавета',
#   'николаевич',
#   'и',
#   'она',
#   'покровительница',
#   '.'],
#  ['и', 'чего-чего', 'ни', 'болтать', '!'],
#  ['болтовня',
#   'способствовать',
#   'и',
#   'таинственность',
#   'обстановка',
#   ':',
#   'оба',
#   'дома',
#   ',',
#   'быть',
#   'запереть',
#   'наглухо',
#   ';'],
#  ['лизавета',
#   'николаевич',
#   ',',
#   'как',
#   'рассказывать',
#   ',',
#   'лежать',
#   'в',
#   'белый',
#   'горячка',
#   ';',
#   'то',
#   'же',
#   'утверждать',
#   'и',
#   'о',
#   'николай',
#   'всеволодович',
#   ',',
#   'с',
#   'отвратительный',
#   'подробность',
#   'о',
#   'выбить',
#   'будто',
#   'бы',
#   'зубе',
#   'и',
#   'о',
#   'распухнуть',
#   'от',
#   'флюс',
#   'щека',
#   'он',
#   '.'],
#  ['говорили',
#   'даже',
#   'по',
#   'уголок',
#   ',',
#   'что',
#   'у',
#   'мы',
#   'мочь',
#   'быть',
#   'быть',
#   'убийство',
#   ',',
#   'что',
#   'ставрогин',
#   'не',
#   'таков',
#   ',',
#   'чтобы',
#   'снести',
#   'такой',
#   'обида',
#   ',',
#   'и',
#   'убить',
#   'шатов',
#   ',',
#   'но',
#   'таинственно',
#   ',',
#   'как',
#   'в',
#   'корсиканский',
#   'вендетта',
#   '.'],
#  ['мысль',
#   'этот',
#   'нравиться',
#   ';',
#   'но',
#   'большинство',
#   'наш',
#   'светский',
#   'молодежь',
#   'выслушивать',
#   'весь',
#   'это',
#   'с',
#   'презрение',
#   'и',
#   'с',
#   'вид',
#   'сам',
#   'пренебрежительный',
#   'равнодушие',
#   ',',
#   'разумеется',
#   ',',
#   'напускной',
#   '.'],
#  ['вообще',
#   'древний',
#   'враждебность',
#   'наш',
#   'общество',
#   'к',
#   'николай',
#   'всеволодович',
#   'обозначиться',
#   'ярко',
#   '.'],
#  ['даже',
#   'солидный',
#   'человек',
#   'стремиться',
#   'обвинить',
#   'он',
#   ',',
#   'хотя',
#   'и',
#   'сам',
#   'не',
#   'знать',
#   'в',
#   'что',
#   '.'],
#  ['шепот',
#   'рассказывать',
#   ',',
#   'что',
#   'будто',
#   'бы',
#   'он',
#   'погубить',
#   'честь',
#   'лизавета',
#   'николаевич',
#   ',',
#   'и',
#   'что',
#   'между',
#   'они',
#   'быть',
#   'интрига',
#   'в',
#   'швейцария',
#   '.'],
#  ['конечно',
#   'осторожный',
#   'человек',
#   'сдерживаться',
#   ',',
#   'но',
#   'весь',
#   'однако',
#   'же',
#   'слушать',
#   'с',
#   'аппетит',
#   '.'],
#  ['быть',
#   'и',
#   'другой',
#   'разговор',
#   ',',
#   'но',
#   'не',
#   'общий',
#   ',',
#   'а',
#   'частный',
#   ',',
#   'редкий',
#   'и',
#   'почти',
#   'закрыть',
#   ',',
#   'чрезвычайно',
#   'странный',
#   'и',
#   'о',
#   'существование',
#   'который',
#   'я',
#   'упоминать',
#   'лишь',
#   'для',
#   'предупреждение',
#   'читатель',
#   ',',
#   'единственно',
#   'в',
#   'вид',
#   'дальнейший',
#   'событие',
#   'мой',
#   'рассказ',
#   '.'],
#  ['именно',
#   ':',
#   'говорить',
#   'иной',
#   ',',
#   'хмуря',
#   'бровь',
#   'и',
#   'бог',
#   'знать',
#   'на',
#   'какой',
#   'основание',
#   ',',
#   'что',
#   'николай',
#   'всеволодович',
#   'иметь',
#   'какой-то',
#   'особенный',
#   'дело',
#   'в',
#   'наш',
#   'губерния',
#   ',',
#   'что',
#   'он',
#   'чрез',
#   'граф',
#   'к',
#   '.',
#   'войти',
#   'в',
#   'петербург',
#   'в',
#   'какой-то',
#   'высокий',
#   'отношение',
#   ',',
#   'что',
#   'он',
#   'даже',
#   ',',
#   'мочь',
#   'быть',
#   ',',
#   'служить',
#   'и',
#   'чуть',
#   'ли',
#   'не',
#   'снабдить',
#   'от',
#   'кто-то',
#   'какой-то',
#   'поручение',
#   '.'],
#  ['когда',
#   'очень',
#   'уж',
#   'солидный',
#   'и',
#   'сдержанный',
#   'человек',
#   'на',
#   'этот',
#   'слух',
#   'улыбаться',
#   ',',
#   'благоразумно',
#   'замечать',
#   ',',
#   'что',
#   'человек',
#   ',',
#   'жить',
#   'скандал',
#   'и',
#   'начинающий',
#   'у',
#   'мы',
#   'с',
#   'флюс',
#   ',',
#   'не',
#   'похожий',
#   'на',
#   'чиновник',
#   ',',
#   'то',
#   'они',
#   'шепотом',
#   'замечать',
#   ',',
#   'что',
#   'служить',
#   'он',
#   'не',
#   'тот',
#   'чтоб',
#   'оффициально',
#   ',',
#   'а',
#   'так',
#   'сказать',
#   'конфиденциально',
#   ',',
#   'и',
#   'что',
#   'в',
#   'такой',
#   'случай',
#   'самый',
#   'служба',
#   'требоваться',
#   ',',
#   'чтобы',
#   'служащий',
#   'как',
#   'можно',
#   'менее',
#   'походить',
#   'на',
#   'чиновник',
#   '.'],
#  ['такой',
#   'замечание',
#   'производить',
#   'эффект',
#   ';',
#   'у',
#   'мы',
#   'известный',
#   'быть',
#   ',',
#   'что',
#   'на',
#   'земство',
#   'наш',
#   'губерния',
#   'смотреть',
#   'в',
#   'столица',
#   'с',
#   'некоторый',
#   'особый',
#   'внимание',
#   '.'],
#  ['повторить',
#   ',',
#   'этот',
#   'слух',
#   'только',
#   'мелькнуть',
#   'и',
#   'исчезнуть',
#   'бесследно',
#   ',',
#   'до',
#   'время',
#   ',',
#   'при',
#   'первый',
#   'появление',
#   'николай',
#   'всеволодович',
#   ';',
#   'но',
#   'замечу',
#   ',',
#   'что',
#   'причина',
#   'многий',
#   'слух',
#   'быть',
#   'отчасти',
#   'несколько',
#   'краткий',
#   ',',
#   'но',
#   'злобный',
#   'слово',
#   ',',
#   'неясный',
#   'и',
#   'отрывистый',
#   'произнести',
#   'в',
#   'клуб',
#   'недавно',
#   'возвратиться',
#   'из',
#   'петербург',
#   'отставной',
#   'капитан',
#   'гвардия',
#   'артемий',
#   'павлович',
#   'гаганов',
#   ',',
#   'весьма',
#   'крупный',
#   'помещик',
#   'наш',
#   'губерния',
#   'и',
#   'уезд',
#   ',',
#   'столичный',
#   'светский',
#   'человек',
#   'и',
#   'сын',
#   'покойный',
#   'павел',
#   'павлович',
#   'гаганов',
#   ',',
#   'тот',
#   'сам',
#   'почтенный',
#   'старшина',
#   ',',
#   'с',
#   'который',
#   'николай',
#   'всеволодович',
#   'иметь',
#   ',',
#   'четыре',
#   'слишком',
#   'год',
#   'тот',
#   'назад',
#   ',',
#   'то',
#   'необычайный',
#   'по',
#   'свой',
#   'грубость',
#   'и',
#   'внезапность',
#   'столкновение',
#   ',',
#   'о',
#   'который',
#   'я',
#   'уже',
#   'упоминать',
#   'прежде',
#   ',',
#   'в',
#   'начало',
#   'мой',
#   'рассказ',
#   '.'],
#  ['весь',
#   'тотчас',
#   'же',
#   'стать',
#   'известный',
#   ',',
#   'что',
#   'юлия',
#   'михаилович',
#   'сделать',
#   'варвара',
#   'петрович',
#   'чрезвычайный',
#   'визит',
#   ',',
#   'и',
#   'что',
#   'у',
#   'крыльцо',
#   'дом',
#   'она',
#   'объявить',
#   ',',
#   'что',
#   '"',
#   'по',
#   'нездоровье',
#   'не',
#   'мочь',
#   'принять',
#   '"',
#   '.'],
#  ['также',
#   'и',
#   'тот',
#   ',',
#   'что',
#   'день',
#   'через',
#   'два',
#   'после',
#   'свой',
#   'визит',
#   'юлия',
#   'михаилович',
#   'посылать',
#   'узнать',
#   'о',
#   'здоровье',
#   'варвара',
#   'петрович',
#   'нарочный',
#   '.'],
#  ['наконец',
#   'приняться',
#   'везде',
#   '"',
#   'защищать',
#   '"',
#   'варвара',
#   'петрович',
#   ',',
#   'конечно',
#   'лишь',
#   'в',
#   'сам',
#   'высокий',
#   'смысл',
#   ',',
#   'то',
#   '"',
#   'быть',
#   'по',
#   'возможность',
#   'в',
#   'сам',
#   'неопределенный',
#   '.'],
#  ['все',
#   'же',
#   'первоначальный',
#   'торопливый',
#   'намек',
#   'о',
#   'воскресный',
#   'история',
#   'выслушать',
#   'строго',
#   'и',
#   'холодный',
#   ',',
#   'так',
#   'что',
#   'в',
#   'последующий',
#   'день',
#   ',',
#   'в',
#   'ее',
#   'присутствие',
#   ',',
#   'они',
#   'уже',
#   'не',
#   'возобновляться',
#   '.'],
#  ['такой',
#   'образ',
#   'и',
#   'укрепиться',
#   'везде',
#   'мысль',
#   ',',
#   'что',
#   'юлия',
#   'михаилович',
#   'известный',
#   'не',
#   'только',
#   'весь',
#   'этот',
#   'таинственный',
#   'история',
#   ',',
#   'но',
#   'и',
#   'весь',
#   'ее',
#   'таинственный',
#   'смысл',
#   'до',
#   'мелкий',
#   'подробность',
#   ',',
#   'и',
#   'не',
#   'как',
#   'посторонний',
#   ',',
#   'а',
#   'как',
#   'соучастница',
#   '.'],
#  ['замечу',
#   'кстати',
#   ',',
#   'что',
#   'она',
#   'начать',
#   'уже',
#   'приобретать',
#   'у',
#   'мы',
#   ',',
#   'помаленьку',
#   ',',
#   'то',
#   'высокий',
#   'влияние',
#   ',',
#   'который',
#   'так',
#   'несомненно',
#   'добиваться',
#   'и',
#   'жаждать',
#   ',',
#   'и',
#   'уже',
#   'начинать',
#   'видеть',
#   'себя',
#   '"',
#   'окружить',
#   '"',
#   '.'],
#  ['часть',
#   'общество',
#   'признать',
#   'за',
#   'она',
#   'практический',
#   'ум',
#   'и',
#   'такт',
#   '...',
#   'но',
#   'о',
#   'это',
#   'после',
#   '.'],
#  ['ее',
#   'же',
#   'покровительство',
#   'объясняться',
#   'отчасти',
#   'и',
#   'весьма',
#   'быстрый',
#   'успех',
#   'петр',
#   'степанович',
#   'в',
#   'наш',
#   'общество',
#   ',',
#   '-',
#   'успех',
#   ',',
#   'особенно',
#   'поразить',
#   'тогда',
#   'степан',
#   'трофимович',
#   '.'],
#  ['мы', 'с', 'он', 'мочь', 'быть', 'и', 'преувеличивали', '.'],
#  ['во-первых',
#   ',',
#   'петр',
#   'степанович',
#   'перезнакомиться',
#   'почти',
#   'мгновенно',
#   'с',
#   'весь',
#   'город',
#   ',',
#   'в',
#   'первый',
#   'же',
#   'четыре',
#   'день',
#   'после',
#   'свой',
#   'появление',
#   '.'],
#  ['появиться',
#   'он',
#   'в',
#   'воскресение',
#   ',',
#   'а',
#   'в',
#   'вторник',
#   'я',
#   'уже',
#   'встретить',
#   'он',
#   'в',
#   'коляска',
#   'с',
#   'артемий',
#   'павлович',
#   'гаганов',
#   ',',
#   'человек',
#   'гордый',
#   ',',
#   'раздражительный',
#   'и',
#   'заносчивый',
#   ',',
#   'несмотря',
#   'на',
#   'весь',
#   'его',
#   'светскость',
#   ',',
#   'и',
#   'с',
#   'который',
#   ',',
#   'по',
#   'характер',
#   'его',
#   ',',
#   'довольно',
#   'трудный',
#   'быть',
#   'ужиться',
#   '.'],
#  ['у',
#   'губернатор',
#   'петр',
#   'степанович',
#   'быть',
#   'тоже',
#   'принять',
#   'прекрасно',
#   ',',
#   'до',
#   'тот',
#   ',',
#   'что',
#   'тотчас',
#   'же',
#   'стать',
#   'в',
#   'положение',
#   'близкий',
#   'или',
#   'так-сказать',
#   'обласкать',
#   'молодой',
#   'человек',
#   ';',
#   'обедать',
#   'у',
#   'юлия',
#   'михаилович',
#   'почти',
#   'ежедневно',
#   '.'],
#  ['познакомиться',
#   'он',
#   'с',
#   'она',
#   'еще',
#   'в',
#   'швейцария',
#   ',',
#   'но',
#   'в',
#   'быстрый',
#   'успех',
#   'его',
#   'в',
#   'дом',
#   'он',
#   'превосходительство',
#   'действительно',
#   'заключаться',
#   'нечто',
#   'любопытный',
#   '.'],
#  ['все-таки',
#   'он',
#   'слыть',
#   'же',
#   'когда-то',
#   'заграничный',
#   'революционер',
#   ',',
#   'правда',
#   'ли',
#   ',',
#   'нет',
#   'ли',
#   ',',
#   'участвовать',
#   'в',
#   'какой-то',
#   'заграничный',
#   'издание',
#   'и',
#   'конгресс',
#   ',',
#   '"',
#   'что',
#   'можно',
#   'даже',
#   'из',
#   'газета',
#   'доказать',
#   '"',
#   ',',
#   'как',
#   'злобно',
#   'выразиться',
#   'я',
#   'при',
#   'встреча',
#   'алеша',
#   'телятников',
#   ',',
#   'теперь',
#   ',',
#   'увы',
#   ',',
#   'отставной',
#   'чиновничка',
#   ',',
#   'а',
#   'прежде',
#   'тоже',
#   'обласкать',
#   'молодой',
#   'человек',
#   'в',
#   'дом',
#   'старый',
#   'губернатор',
#   '.'],
#  ['но',
#   'тут',
#   'стоять',
#   'однако',
#   'же',
#   'факт',
#   ':',
#   'бывший',
#   'революционер',
#   'явиться',
#   'в',
#   'любезный',
#   'отечество',
#   'не',
#   'только',
#   'без',
#   'всякий',
#   'беспокойство',
#   ',',
#   'но',
#   'чуть',
#   'ли',
#   'не',
#   'с',
#   'поощрение',
#   ';',
#   'стать',
#   'быть',
#   ',',
#   'ничто',
#   ',',
#   'мочь',
#   ',',
#   'и',
#   'не',
#   'быть',
#   '.'],
#  ['липутин',
#   'шепнуть',
#   'я',
#   'раз',
#   ',',
#   'что',
#   ',',
#   'по',
#   'слух',
#   ',',
#   'петр',
#   'степанович',
#   'будто',
#   'бы',
#   'где-то',
#   'принести',
#   'покаяние',
#   'и',
#   'получить',
#   'отпущение',
#   ',',
#   'назвать',
#   'несколько',
#   'прочий',
#   'имя',
#   ',',
#   'и',
#   'такой',
#   'образ',
#   ',',
#   'мочь',
#   ',',
#   'и',
#   'успеть',
#   'уже',
#   'заслужить',
#   'вина',
#   ',',
#   'обещать',
#   'и',
#   'впредь',
#   'быть',
#   'полезный',
#   'отечество',
#   '.'],
#  ['я',
#   'передать',
#   'этот',
#   'ядовитый',
#   'фраза',
#   'степан',
#   'трофимович',
#   ',',
#   'и',
#   'тот',
#   ',',
#   'несмотря',
#   'на',
#   'тот',
#   ',',
#   'что',
#   'быть',
#   'почти',
#   'не',
#   'в',
#   'состояние',
#   'соображать',
#   ',',
#   'сильно',
#   'задуматься',
#   '.'],
#  ['впоследствии',
#   'обнаружиться',
#   ',',
#   'что',
#   'петр',
#   'степанович',
#   'приехать',
#   'к',
#   'мы',
#   'с',
#   'чрезвычайно',
#   'почтенный',
#   'рекомендательный',
#   'письмо',
#   ',',
#   'по',
#   'крайний',
#   'мера',
#   'привезти',
#   'один',
#   'к',
#   'губернаторша',
#   'от',
#   'один',
#   'чрезвычайно',
#   'важный',
#   'петербургский',
#   'старушка',
#   ',',
#   'муж',
#   'который',
#   'быть',
#   'один',
#   'из',
#   'самый',
#   'значительный',
#   'петербургский',
#   'старичок',
#   '.'],
#  ['этот',
#   'старушка',
#   ',',
#   'крестный',
#   'мать',
#   'юлия',
#   'михаилович',
#   ',',
#   'упоминать',
#   'в',
#   'письмо',
#   'свой',
#   ',',
#   'что',
#   'и',
#   'граф',
#   'к',
#   '.',
#   'хорошо',
#   'знать',
#   'петр',
#   'степанович',
#   ',',
#   'чрез',
#   'николай',
#   'всеволодович',
#   ',',
#   'обласкать',
#   'он',
#   'и',
#   'находить',
#   '"',
#   'достойный',
#   'молодой',
#   'человек',
#   ',',
#   'несмотря',
#   'на',
#   'бывший',
#   'заблуждение',
#   '"',
#   '.'],
#  ['юлия',
#   'михаилович',
#   'до',
#   'крайность',
#   'ценить',
#   'свой',
#   'скудный',
#   'и',
#   'с',
#   'такой',
#   'труд',
#   'поддерживать',
#   'связь',
#   'с',
#   '"',
#   'высокий',
#   'мир',
#   '"',
#   'и',
#   'уж',
#   'конечно',
#   'быть',
#   'рад',
#   'письмо',
#   'важный',
#   'старушка',
#   ';',
#   'но',
#   'все-таки',
#   'оставаться',
#   'тут',
#   'нечто',
#   'как',
#   'бы',
#   'и',
#   'особенный',
#   '.'],
#  ['даже',
#   'супруг',
#   'свой',
#   'поставить',
#   'к',
#   'петр',
#   'степанович',
#   'в',
#   'отношение',
#   'почти',
#   'фамилиарный',
#   ',',
#   'так',
#   'что',
#   'г',
#   '.',
#   'фон-лембка',
#   'жаловаться',
#   '...',
#   'но',
#   'о',
#   'это',
#   'тоже',
#   'после',
#   '.'],
#  ['замечу',
#   'тоже',
#   'для',
#   'память',
#   ',',
#   'что',
#   'и',
#   'великий',
#   'писатель',
#   'весьма',
#   'благосклонно',
#   'отнестись',
#   'к',
#   'петр',
#   'степанович',
#   'и',
#   'тотчас',
#   'же',
#   'пригласить',
#   'он',
#   'к',
#   'себя',
#   '.'],
#  ['такой',
#   'поспешность',
#   'такой',
#   'надутый',
#   'себя',
#   'человек',
#   'кольнуть',
#   'степан',
#   'трофимович',
#   'больнее',
#   'весь',
#   ';',
#   'но',
#   'я',
#   'объяснить',
#   'себя',
#   'иначе',
#   ':',
#   'зазывая',
#   'к',
#   'себя',
#   'нигилист',
#   ',',
#   'г',
#   '.',
#   'кармазин',
#   'уж',
#   'конечно',
#   'иметь',
#   'в',
#   'вид',
#   'сношение',
#   'он',
#   'с',
#   'прогрессивный',
#   'юноша',
#   'оба',
#   'столица',
#   '.'],
#  ['великий',
#   'писатель',
#   'болезненно',
#   'трепетать',
#   'пред',
#   'новый',
#   'революционный',
#   'молодежь',
#   'и',
#   ',',
#   'воображая',
#   ',',
#   'по',
#   'незнание',
#   'дело',
#   ',',
#   'что',
#   'в',
#   'рука',
#   'ее',
#   'ключ',
#   'русский',
#   'будущность',
#   ',',
#   'унизительный',
#   'к',
#   'они',
#   'подлизываться',
#   ',',
#   'главный',
#   'потому',
#   'что',
#   'они',
#   'не',
#   'обращать',
#   'на',
#   'он',
#   'никакой',
#   'внимание',
#   '.'],
#  ['ii',
#   'петр',
#   'степанович',
#   'забежать',
#   'раз',
#   'два',
#   'и',
#   'к',
#   'родитель',
#   ',',
#   'и',
#   ',',
#   'к',
#   'несчастие',
#   'мой',
#   ',',
#   'оба',
#   'раз',
#   'в',
#   'мой',
#   'отсутствие',
#   '.'],
#  ['в',
#   'первый',
#   'раз',
#   'посетить',
#   'он',
#   'в',
#   'среда',
#   ',',
#   'то-есть',
#   'на',
#   'четвертый',
#   'лишь',
#   'день',
#   'после',
#   'тот',
#   'первый',
#   'встреча',
#   ',',
#   'да',
#   'и',
#   'тот',
#   'по',
#   'дело',
#   '.'],
#  ['кстати',
#   ',',
#   'расчет',
#   'по',
#   'имение',
#   'окончиться',
#   'у',
#   'они',
#   'как-то',
#   'неслышно',
#   'и',
#   'невидный',
#   '.'],
#  ['варвара',
#   'петрович',
#   'взять',
#   'весь',
#   'на',
#   'себя',
#   'и',
#   'весь',
#   'выплатить',
#   ',',
#   'разумеется',
#   ',',
#   'приобрести',
#   'землица',
#   ',',
#   'а',
#   'степан',
#   'трофимович',
#   'только',
#   'уведомить',
#   'о',
#   'тот',
#   ',',
#   'что',
#   'весь',
#   'конченый',
#   ',',
#   'и',
#   'уполномоченный',
#   'варвара',
#   'петрович',
#   ',',
#   'камердинер',
#   'она',
#   'алексей',
#   'егорович',
#   ',',
#   'поднести',
#   'он',
#   'что-то',
#   'подписать',
#   ',',
#   'что',
#   'он',
#   'и',
#   'исполнить',
#   'молча',
#   'и',
#   'с',
#   'чрезвычайный',
#   'достоинство',
#   '.'],
#  ['замечу',
#   'по',
#   'повод',
#   'достоинство',
#   ',',
#   'что',
#   'я',
#   'почти',
#   'не',
#   'узнавать',
#   'наш',
#   'прежний',
#   'старичок',
#   'в',
#   'этот',
#   'день',
#   '.'],
#  ['он',
#   'держать',
#   'себя',
#   'как',
#   'никогда',
#   'прежде',
#   ',',
#   'стать',
#   'удивительно',
#   'молчаливый',
#   ',',
#   'даже',
#   'не',
#   'написать',
#   'ни',
#   'один',
#   'письмо',
#   'варвара',
#   'петрович',
#   'с',
#   'сам',
#   'воскресение',
#   ',',
#   'что',
#   'я',
#   'счесть',
#   'бы',
#   'чудо',
#   ',',
#   'а',
#   'главное',
#   'стать',
#   'спокойный',
#   '.'],
#  ['он',
#   'укрепиться',
#   'на',
#   'какой-то',
#   'окончательный',
#   'и',
#   'чрезвычайный',
#   'идея',
#   ',',
#   'придавать',
#   'он',
#   'спокойствие',
#   ',',
#   'это',
#   'быть',
#   'видно',
#   '.'],
#  ['он', 'найти', 'этот', 'идея', ',', 'сидеть', 'и', 'что-то', 'ждать', '.'],
#  ['сначала',
#   'впрочем',
#   'быть',
#   'больной',
#   ',',
#   'особенно',
#   'в',
#   'понедельник',
#   ';',
#   'быть',
#   'холерина',
#   '.'],
#  ['тоже',
#   'и',
#   'без',
#   'весть',
#   'пробыть',
#   'не',
#   'мочь',
#   'в',
#   'весь',
#   'время',
#   ';',
#   'но',
#   'лишь',
#   'только',
#   'я',
#   ',',
#   'оставлять',
#   'факт',
#   ',',
#   'переходить',
#   'к',
#   'суть',
#   'дело',
#   'и',
#   'высказывать',
#   'какой-нибудь',
#   'предположение',
#   ',',
#   'то',
#   'он',
#   'тотчас',
#   'же',
#   'начинать',
#   'махать',
#   'на',
#   'я',
#   'рука',
#   ',',
#   'чтоб',
#   'я',
#   'перестать',
#   '.'],
#  ['но',
#   'оба',
#   'свидание',
#   'с',
#   'сынок',
#   'все-таки',
#   'болезненно',
#   'на',
#   'он',
#   'подействовать',
#   ',',
#   'хотя',
#   'и',
#   'не',
#   'поколебать',
#   '.'],
#  ['в',
#   'оба',
#   'этот',
#   'день',
#   ',',
#   'после',
#   'свидание',
#   ',',
#   'он',
#   'лежать',
#   'на',
#   'диван',
#   ',',
#   'обмотать',
#   'голова',
#   'платок',
#   ',',
#   'намочить',
#   'в',
#   'уксус',
#   ';',
#   'но',
#   'в',
#   'высокий',
#   'смысл',
#   'продолжать',
#   'оставаться',
#   'спокойный',
#   '.'],
#  ['иногда',
#   ',',
#   'впрочем',
#   ',',
#   'он',
#   'и',
#   'не',
#   'махать',
#   'на',
#   'я',
#   'рука',
#   '.'],
#  ['иногда',
#   'тоже',
#   'казаться',
#   'я',
#   ',',
#   'что',
#   'принять',
#   'таинственный',
#   'решимость',
#   'как',
#   'бы',
#   'оставлять',
#   'он',
#   ',',
#   'и',
#   'что',
#   'он',
#   'начинать',
#   'бороться',
#   'с',
#   'какой-то',
#   'новый',
#   'соблазнительный',
#   'наплыв',
#   'идея',
#   '.'],
#  ['это', 'быть', 'мгновение', ',', 'но', 'я', 'отмечать', 'они', '.'],
#  ['я',
#   'подозревать',
#   ',',
#   'что',
#   'он',
#   'очень',
#   'бы',
#   'хотеться',
#   'опять',
#   'заявить',
#   'себя',
#   ',',
#   'выйти',
#   'из',
#   'уединение',
#   ',',
#   'предложить',
#   'борьба',
#   ',',
#   'задать',
#   'последний',
#   'битва',
#   '.'],
#  ['-',
#   'cher',
#   ',',
#   'я',
#   'бы',
#   'они',
#   'разгромить',
#   '!',
#   '-',
#   'вырваться',
#   'у',
#   'он',
#   'в',
#   'четверг',
#   'вечер',
#   ',',
#   'после',
#   'второй',
#   'свидание',
#   'с',
#   'петр',
#   'степанович',
#   ',',
#   'когда',
#   'он',
#   'лежать',
#   ',',
#   'протянуться',
#   'на',
#   'диван',
#   ',',
#   'с',
#   'голова',
#   ',',
#   'обернуть',
#   'полотенце',
#   '.'],
#  ['до',
#   'этот',
#   'минута',
#   'он',
#   'в',
#   'весь',
#   'день',
#   'еще',
#   'ни',
#   'слово',
#   'не',
#   'сказать',
#   'с',
#   'я',
#   '.'],
#  ['-',
#   '"',
#   'fils',
#   ',',
#   'fils',
#   'ch',
#   'й',
#   'ri',
#   '"',
#   'и',
#   'так',
#   'далее',
#   ',',
#   'я',
#   'согласный',
#   ',',
#   'что',
#   'весь',
#   'этот',
#   'выражение',
#   'вздор',
#   ',',
#   'кухарочный',
#   'словарь',
#   ',',
#   'да',
#   'и',
#   'пусть',
#   'они',
#   ',',
#   'я',
#   'сам',
#   'теперь',
#   'видеть',
#   '.'],
#  ['я',
#   'он',
#   'не',
#   'кормить',
#   'и',
#   'не',
#   'поить',
#   ',',
#   'я',
#   'отослать',
#   'он',
#   'из',
#   'берлин',
#   'в',
#   'сковать',
#   'губерния',
#   ',',
#   'грудной',
#   'ребенок',
#   ',',
#   'по',
#   'почта',
#   ',',
#   'ну',
#   'и',
#   'так',
#   'далее',
#   ',',
#   'я',
#   'согласный',
#   '...'],
#  ['"',
#   'ты',
#   ',',
#   'говорить',
#   ',',
#   'я',
#   'не',
#   'поить',
#   'и',
#   'по',
#   'почта',
#   'выслать',
#   ',',
#   'да',
#   'еще',
#   'здесь',
#   'ограбить',
#   '"',
#   '.'],
#  ['но',
#   ',',
#   'несчастный',
#   ',',
#   'кричать',
#   'он',
#   ',',
#   'ведь',
#   'болеть',
#   'же',
#   'я',
#   'за',
#   'ты',
#   'сердце',
#   'весь',
#   'мой',
#   'жизнь',
#   ',',
#   'хотя',
#   'и',
#   'по',
#   'почта',
#   '!'],
#  ['il', 'rit', '.'],
#  ['но',
#   'я',
#   'согласный',
#   ',',
#   'согласный',
#   '...',
#   'пусть',
#   'по',
#   'почта',
#   ',',
#   '-',
#   'закончить',
#   'он',
#   'как',
#   'в',
#   'бред',
#   '.'],
#  ['-',
#   'passons',
#   ',',
#   '-',
#   'начать',
#   'он',
#   'опять',
#   'через',
#   'пять',
#   'минута',
#   '.'],
#  ['-', 'я', 'не', 'понимать', 'тургенев', '.'],
#  ['у',
#   'он',
#   'базаров',
#   'это',
#   'какой-то',
#   'фиктивный',
#   'лицо',
#   ',',
#   'не',
#   'существовать',
#   'вовсе',
#   ';',
#   'они',
#   'же',
#   'первый',
#   'и',
#   'отвергнуть',
#   'он',
#   'тогда',
#   ',',
#   'как',
#   'ни',
#   'на',
#   'что',
#   'не',
#   'похожий',
#   '.'],
#  ['этот',
#   'базаров',
#   'это',
#   'какой-то',
#   'неясный',
#   'смесь',
#   'ноздрев',
#   'с',
#   'байрон',
#   ',',
#   'c',
#   "'",
#   'est',
#   'le',
#   'mot',
#   '!'],
#  ['посмотреть',
#   'на',
#   'они',
#   'внимательно',
#   ':',
#   'они',
#   'кувыркаться',
#   'и',
#   'визжать',
#   'от',
#   'радость',
#   'как',
#   'щенок',
#   'на',
#   'солнце',
#   ',',
#   'они',
#   'счастливый',
#   ',',
#   'они',
#   'победитель',
#   '!'],
#  ['какой', 'тут', 'байрон', '!..'],
#  ['и', 'при', 'тот', 'какой', 'будни', '!'],
#  ['какой',
#   'кухарочный',
#   'раздражительность',
#   'самолюбие',
#   ',',
#   'какой',
#   'пошленький',
#   'жаждишка',
#   'faire',
#   'du',
#   'bruit',
#   'autour',
#   'de',
#   'son',
#   'nom',
#   ',',
#   'не',
#   'замечать',
#   ',',
#   'что',
#   'son',
#   'nom',
#   '...'],
#  ['о', ',', 'карикатура', '!'],
#  ['помиловать',
#   ',',
#   'кричать',
#   'он',
#   ',',
#   'да',
#   'неужто',
#   'ты',
#   'себя',
#   'такой',
#   'как',
#   'быть',
#   'человек',
#   'взамен',
#   'христос',
#   'предложить',
#   'желать',
#   '?'],
#  ['il', 'rit', '.'],
#  ['il', 'rit', 'beaucoup', ',', 'il', 'rit', 'trop', '.'],
#  ['у', 'он', 'какой-то', 'странный', 'улыбка', '.'],
#  ['у', 'он', 'мать', 'не', 'быть', 'такой', 'улыбка', '.'],
#  ['il', 'rit', 'toujours', '.'],
#  ['опять', 'наступить', 'молчание', '.'],
#  ['-',
#   'они',
#   'хитрый',
#   ';',
#   'в',
#   'воскресение',
#   'они',
#   'сговориться',
#   '...',
#   '-',
#   'брякнул',
#   'он',
#   'вдруг',
#   '.'],
#  ['-',
#   'о',
#   ',',
#   'без',
#   'сомнение',
#   ',',
#   '-',
#   'вскричать',
#   'я',
#   ',',
#   'навострить',
#   'ухо',
#   ',',
#   '-',
#   'весь',
#   'это',
#   'стачка',
#   'и',
#   'сшить',
#   'белый',
#   'нитка',
#   ',',
#   'и',
#   'так',
#   'дурно',
#   'разыграть',
#   '.'],
#  ['-', 'я', 'не', 'про', 'тот', '.'],
#  ['знать',
#   'ли',
#   ',',
#   'что',
#   'весь',
#   'это',
#   'быть',
#   'нарочно',
#   'сшить',
#   'белый',
#   'нитка',
#   ',',
#   'чтобы',
#   'заметить',
#   'тот',
#   '...',
#   'кто',
#   'надо',
#   '.'],
#  ['понимать', 'это', '?'],
#  ['-', 'нет', ',', 'не', 'понимать', '.'],
#  ['-', 'tant', 'mieux', '.'],
#  ['passons', '.'],
#  ['я', 'очень', 'раздражить', 'сегодня', '.'],
#  ['-',
#   'да',
#   'зачем',
#   'же',
#   'вы',
#   'с',
#   'он',
#   'спорить',
#   ',',
#   'степан',
#   'трофимович',
#   '?',
#   '-',
#   'проговорить',
#   'я',
#   'укоризненный',
#   '.'],
#  ['-', 'je', 'voulais', 'convertir', '.'],
#  ['конечно', 'смеяться', '.'],
#  ['cette',
#   'pauvre',
#   'тетя',
#   ',',
#   'elle',
#   'entendra',
#   'de',
#   'belles',
#   'choses',
#   '!'],
#  ['о',
#   ',',
#   'друг',
#   'мой',
#   ',',
#   'поверить',
#   'ли',
#   ',',
#   'что',
#   'я',
#   'давеча',
#   'ощутить',
#   'себя',
#   'патриот',
#   '!'],
#  ['впрочем',
#   'я',
#   'всегда',
#   'сознавать',
#   'себя',
#   'русский',
#   '...',
#   'да',
#   'настоящий',
#   'русский',
#   'и',
#   'не',
#   'мочь',
#   'быть',
#   'иначе',
#   ',',
#   'как',
#   'мы',
#   'с',
#   'вы',
#   '.'],
#  ['il',
#   'у',
#   'a',
#   'l',
#   'а',
#   'dedans',
#   'quelque',
#   'chose',
#   'd',
#   "'",
#   'aveugle',
#   'et',
#   'de',
#   'louche',
#   '.'],
#  ['-', 'непременно', ',', '-', 'ответить', 'я', '.'],
#  ['-',
#   'друг',
#   'мой',
#   ',',
#   'настоящий',
#   'правда',
#   'всегда',
#   'не',
#   'правдоподобный',
#   ',',
#   'знать',
#   'ли',
#   'вы',
#   'это',
#   '?'],
#  ['чтобы',
#   'сделать',
#   'правда',
#   'правдоподобнее',
#   ',',
#   'нужный',
#   'непременно',
#   'подмешать',
#   'к',
#   'она',
#   'ложь',
#   '.'],
#  ['человек', 'всегда', 'так', 'и', 'поступать', '.'],
#  ['мочь', 'быть', ',', 'тут', 'быть', ',', 'что', 'мы', 'не', 'понимать', '.'],
#  ['как',
#   'вы',
#   'думать',
#   ',',
#   'быть',
#   'тут',
#   ',',
#   'что',
#   'мы',
#   'не',
#   'понимать',
#   'в',
#   'этот',
#   'победоносный',
#   'визг',
#   '?'],
#  ['я', 'бы', 'желать', ',', 'чтобы', 'быть', '.'],
#  ['я', 'бы', 'желать', '.'],
#  ['я', 'промолчать', '.'],
#  ['он', 'тоже', 'очень', 'долго', 'молчать', '.'],
#  ['-',
#   'говорить',
#   ',',
#   'французский',
#   'ум',
#   '...',
#   '-',
#   'залепетал',
#   'он',
#   'вдруг',
#   'точно',
#   'в',
#   'жара',
#   ',',
#   '-',
#   'это',
#   'ложь',
#   ',',
#   'это',
#   'всегда',
#   'так',
#   'и',
#   'быть',
#   '.'],
#  ['зачем', 'клеветать', 'на', 'французский', 'ум', '?'],
#  ['тут',
#   'просто',
#   'русский',
#   'лень',
#   ',',
#   'наш',
#   'унизительный',
#   'бессилие',
#   'произвести',
#   'идея',
#   ',',
#   'наш',
#   'отвратительный',
#   'паразитство',
#   'в',
#   'ряд',
#   'народ',
#   '.'],
#  ['ils',
#   'sont',
#   'tout',
#   'simplement',
#   'des',
#   'paresseux',
#   ',',
#   'а',
#   'не',
#   'французский',
#   'ум',
#   '.',
#   'о',
#   ',',
#   'русский',
#   'должный',
#   'бы',
#   'быть',
#   'истребить',
#   'для',
#   'благо',
#   'человечество',
#   'как',
#   'вредный',
#   'паразит',
#   '!'],
#  ['мы',
#   'вовсе',
#   ',',
#   'вовсе',
#   'не',
#   'к',
#   'тот',
#   'стремиться',
#   ';',
#   'я',
#   'ничто',
#   'не',
#   'понимать',
#   '.'],
#  ['я', 'перестать', 'понимать', '!'],
#  ['да',
#   'понимать',
#   'ли',
#   ',',
#   'кричать',
#   'он',
#   ',',
#   'понимать',
#   'ли',
#   ',',
#   'что',
#   'если',
#   'у',
#   'вы',
#   'гильйотина',
#   'на',
#   'первый',
#   'план',
#   'и',
#   'с',
#   'такой',
#   'восторг',
#   ',',
#   'то',
#   'это',
#   'единственно',
#   'потому',
#   ',',
#   'что',
#   'рубить',
#   'голова',
#   'весь',
#   'легче',
#   ',',
#   'а',
#   'иметь',
#   'идея',
#   'весь',
#   'труднее',
#   '!'],
#  ['vous', 'к', 'tes', 'des', 'paresseux', '!'],
#  ['votre',
#   'drapeau',
#   'est',
#   'une',
#   'guenille',
#   ',',
#   'une',
#   'impuissance',
#   '.'],
#  ['этот',
#   'телега',
#   ',',
#   'или',
#   'как',
#   'там',
#   ':',
#   '"',
#   'стук',
#   'телега',
#   ',',
#   'подвозить',
#   'хлеб',
#   'человечество',
#   '"',
#   ',',
#   'полезнее',
#   'сикстинский',
#   'мадонна',
#   ',',
#   'или',
#   'как',
#   'у',
#   'они',
#   'там',
#   '...',
#   'une',
#   'b',
#   'к',
#   'tise',
#   'dans',
#   'се',
#   'genre',
#   '.'],
#  ['но',
#   'понимать',
#   'ли',
#   ',',
#   'кричать',
#   'он',
#   ',',
#   'понимать',
#   'ли',
#   'ты',
#   ',',
#   'что',
#   'человек',
#   'кроме',
#   'счастие',
#   'так',
#   'же',
#   'точно',
#   'и',
#   'совершенно',
#   'в',
#   'столько',
#   'же',
#   'необходимый',
#   'и',
#   'несчастие',
#   '!'],
#  ['il', 'rit', '.'],
#  ['ты',
#   ',',
#   'говорить',
#   ',',
#   'здесь',
#   'бонмо',
#   'отпускать',
#   ',',
#   '"',
#   'нежить',
#   'свой',
#   'член',
#   '(',
#   'он',
#   'пакостнее',
#   'выразиться',
#   ')',
#   'на',
#   'бархатный',
#   'диван',
#   '"',
#   '...'],
#  ['и',
#   'заметьте',
#   ',',
#   'этот',
#   'наш',
#   'привычка',
#   'на',
#   'ты',
#   'отец',
#   'с',
#   'сын',
#   ';',
#   'хорошо',
#   ',',
#   'когда',
#   'оба',
#   'согласный',
#   ',',
#   'ну',
#   ',',
#   'а',
#   'если',
#   'ругаться',
#   '?'],
#  ['с', 'минута', 'опять', 'помолчать', '.'],
#  ['-',
#   'cher',
#   ',',
#   '-',
#   'заключить',
#   'он',
#   'вдруг',
#   ',',
#   'быстро',
#   'приподняться',
#   ',',
#   '-',
#   'знать',
#   'ли',
#   ',',
#   'что',
#   'это',
#   'непременно',
#   'что-нибудь',
#   'кончиться',
#   '?'],
#  ['-', 'уж', 'конечно', ',', '-', 'сказать', 'я', '.'],
#  ['-', 'vous', 'ne', 'comprenez', 'pas', '.'],
#  ['passons', '.'],
#  ['но',
#   '...',
#   'обыкновенно',
#   'на',
#   'свет',
#   'кончаться',
#   'ничто',
#   ',',
#   'но',
#   'здесь',
#   'быть',
#   'конец',
#   ',',
#   'непременно',
#   ',',
#   'непременно',
#   '!'],
#  ['он',
#   'встать',
#   ',',
#   'пройтись',
#   'по',
#   'комната',
#   'в',
#   'сильный',
#   'волнение',
#   'и',
#   ',',
#   'дойти',
#   'опять',
#   'до',
#   'диван',
#   ',',
#   'бессильно',
#   'повалиться',
#   'на',
#   'он',
#   '.'],
#  ['в',
#   'пятница',
#   'утро',
#   'петр',
#   'степанович',
#   'уехать',
#   'куда-то',
#   'в',
#   'уезд',
#   'и',
#   'пробыть',
#   'до',
#   'понедельник',
#   '.'],
#  ['о',
#   'отъезд',
#   'он',
#   'я',
#   'узнать',
#   'от',
#   'липутин',
#   ',',
#   'и',
#   'тут',
#   'же',
#   ',',
#   'как-то',
#   'к',
#   'разговор',
#   ',',
#   'узнать',
#   'от',
#   'он',
#   ',',
#   'что',
#   'лебядкина',
#   ',',
#   'братец',
#   'и',
#   'сестрица',
#   ',',
#   'оба',
#   'где-то',
#   'за',
#   'река',
#   ',',
#   'в',
#   'горшечный',
#   'слободка',
#   '.'],
#  ['"',
#   'я',
#   'же',
#   'и',
#   'перевозить',
#   '"',
#   ',',
#   'прибавить',
#   'липутин',
#   ',',
#   'и',
#   ',',
#   'прервать',
#   'о',
#   'лебядкин',
#   ',',
#   'вдруг',
#   'возвестить',
#   'я',
#   ',',
#   'что',
#   'лизавета',
#   'николаевич',
#   'выходить',
#   'за',
#   'маврикий',
#   'николаевич',
#   ',',
#   'и',
#   'хоть',
#   'это',
#   'и',
#   'не',
#   'объявить',
#   ',',
#   'но',
#   'помолвка',
#   'быть',
#   'и',
#   'дело',
#   'покончить',
#   '.'],
#  ['назавтра',
#   'я',
#   'встретить',
#   'лизавета',
#   'николаевич',
#   'верх',
#   'в',
#   'сопровождение',
#   'маврикий',
#   'николаевич',
#   ',',
#   'выехать',
#   'в',
#   'первый',
#   'раз',
#   'после',
#   'болезнь',
#   '.'],
#  ['она',
#   'сверкнуть',
#   'на',
#   'я',
#   'издать',
#   'глаз',
#   ',',
#   'засмеяться',
#   'и',
#   'очень',
#   'дружески',
#   'кивнуть',
#   'голова',
#   '.'],
#  ['весь',
#   'это',
#   'я',
#   'передать',
#   'степан',
#   'трофимович',
#   ';',
#   'он',
#   'обратить',
#   'некоторый',
#   'внимание',
#   'лишь',
#   'на',
#   'известие',
#   'о',
#   'лебядкин',
#   '.'],
#  ['а',
#   'теперь',
#   ',',
#   'описать',
#   'наш',
#   'загадочный',
#   'положение',
#   'в',
#   'продолжение',
#   'этот',
#   'восемь',
#   'день',
#   ',',
#   'когда',
#   'мы',
#   'еще',
#   'ничто',
#   'не',
#   'знать',
#   ',',
#   'приступить',
#   'к',
#   'описание',
#   'последующий',
#   'событие',
#   'мой',
#   'хроника',
#   ',',
#   'и',
#   'уже',
#   ',',
#   'так',
#   'сказать',
#   ',',
#   'с',
#   'знание',
#   'дело',
#   ',',
#   'в',
#   'тот',
#   'вид',
#   ',',
#   'как',
#   'весь',
#   'это',
#   'открыться',
#   'и',
#   'объясниться',
#   'теперь',
#   '.'],
#  ['начать',
#   'именно',
#   'с',
#   'восьмой',
#   'день',
#   'после',
#   'тот',
#   'воскресение',
#   ',',
#   'то-есть',
#   'с',
#   'понедельник',
#   'вечер',
#   '-',
#   'потому',
#   'что',
#   'в',
#   'сущность',
#   'с',
#   'этот',
#   'вечер',
#   'и',
#   'начаться',
#   '"',
#   'новый',
#   'история',
#   '"',
#   '.'],
#  ['iii', 'быть', 'семь', 'час', 'вечер', '.'],
#  ['николай',
#   'всеволодович',
#   'сидеть',
#   'один',
#   'в',
#   'свой',
#   'кабинет',
#   ',',
#   '-',
#   'комната',
#   'они',
#   'еще',
#   'прежде',
#   'излюбленный',
#   ',',
#   'высокий',
#   ',',
#   'устлать',
#   'ковер',
#   ',',
#   'уставить',
#   'несколько',
#   'тяжелою',
#   ',',
#   'старинный',
#   'фасон',
#   'мебель',
#   '.'],
#  ['он',
#   'сидеть',
#   'в',
#   'угол',
#   'на',
#   'диван',
#   ',',
#   'одеть',
#   'как',
#   'бы',
#   'для',
#   'выход',
#   ',',
#   'но',
#   ',',
#   'казаться',
#   ',',
#   'никуда',
#   'не',
#   'собираться',
#   ',',
#   'на',
#   'стол',
#   'пред',
#   'он',
#   'стоять',
#   'лампа',
#   'с',
#   'абажур',
#   '.'],
#  ['бок', 'и', 'угол', 'большой', 'комната', 'оставаться', 'в', 'тень', '.'],
#  ['взгляд',
#   'его',
#   'быть',
#   'задумчивый',
#   'и',
#   'сосредоточить',
#   ',',
#   'не',
#   'совсем',
#   'спокойный',
#   ';',
#   'лицо',
#   'усталый',
#   'и',
#   'несколько',
#   'похудевшее',
#   '.'],
#  ['больной',
#   'он',
#   'быть',
#   'действительно',
#   'флюс',
#   ';',
#   'но',
#   'слух',
#   'о',
#   'выбить',
#   'зуб',
#   'быть',
#   'преувеличить',
#   '.'],
#  ['зуб',
#   'только',
#   'шататься',
#   ',',
#   'но',
#   'теперь',
#   'снова',
#   'окрепнуть',
#   ';',
#   'быть',
#   'тоже',
#   'рассечь',
#   'изнутри',
#   'верхний',
#   'губа',
#   ',',
#   'но',
#   'и',
#   'это',
#   'зажить',
#   '.'],
#  ['флюс',
#   'же',
#   'не',
#   'проходить',
#   'весь',
#   'неделя',
#   'лишь',
#   'потому',
#   ',',
#   'что',
#   'больной',
#   'не',
#   'хотеть',
#   'принять',
#   'доктор',
#   'и',
#   'вовремя',
#   'дать',
#   'разрезать',
#   'опухоль',
#   ',',
#   'а',
#   'ждать',
#   ',',
#   'пока',
#   'нарыв',
#   'сам',
#   'прорваться',
#   '.'],
#  ['он',
#   'не',
#   'только',
#   'доктор',
#   ',',
#   'но',
#   'и',
#   'мать',
#   'едва',
#   'допускать',
#   'к',
#   'себя',
#   ',',
#   'и',
#   'то',
#   'на',
#   'минута',
#   ',',
#   'один',
#   'раз',
#   'на',
#   'день',
#   'и',
#   'непременно',
#   'в',
#   'сумерки',
#   ',',
#   'когда',
#   'уже',
#   'становиться',
#   'темный',
#   ',',
#   'а',
#   'огонь',
#   'еще',
#   'не',
#   'подавать',
#   '.'],
#  ['не',
#   'принимать',
#   'он',
#   'тоже',
#   'и',
#   'петр',
#   'степанович',
#   ',',
#   'который',
#   'однако',
#   'же',
#   'по',
#   'два',
#   'и',
#   'по',
#   'три',
#   'раз',
#   'в',
#   'день',
#   'забегать',
#   'к',
#   'варвара',
#   'петрович',
#   ',',
#   'пока',
#   'оставаться',
#   'в',
#   'город',
#   '.'],
#  ['и',
#   'вот',
#   'наконец',
#   'в',
#   'понедельник',
#   ',',
#   'возвратясь',
#   'поутру',
#   'после',
#   'свой',
#   'трехдневный',
#   'отлучка',
#   ',',
#   'обегать',
#   'весь',
#   'город',
#   'и',
#   'отобедав',
#   'у',
#   'юлия',
#   'михаилович',
#   ',',
#   'петр',
#   'степанович',
#   'к',
#   'вечер',
#   'явиться',
#   'наконец',
#   'к',
#   'нетерпеливо',
#   'ожидать',
#   'он',
#   'варвара',
#   'петрович',
#   '.'],
#  ['запрет', 'быть', 'снять', ',', 'николай', 'всеволодович', 'принимать', '.'],
#  ['варвара',
#   'петрович',
#   'сам',
#   'подвести',
#   'гость',
#   'к',
#   'дверь',
#   'кабинет',
#   ';',
#   'она',
#   'давно',
#   'желать',
#   'они',
#   'свиданья',
#   ',',
#   'а',
#   'петр',
#   'степанович',
#   'дать',
#   'она',
#   'слово',
#   'забежать',
#   'к',
#   'она',
#   'от',
#   'nicolas',
#   'и',
#   'пересказать',
#   '.'],
#  ['робко',
#   'постучаться',
#   'она',
#   'к',
#   'николай',
#   'всеволодович',
#   'и',
#   ',',
#   'не',
#   'получать',
#   'ответ',
#   ',',
#   'осмелиться',
#   'приотворить',
#   'дверь',
#   'вершок',
#   'на',
#   'два',
#   '.'],
#  ['-',
#   'nicolas',
#   ',',
#   'мочь',
#   'я',
#   'ввести',
#   'к',
#   'ты',
#   'петр',
#   'степанович',
#   '?',
#   '-',
#   'тихо',
#   'и',
#   'сдержанно',
#   'спросить',
#   'она',
#   ',',
#   'стараться',
#   'разглядеть',
#   'николай',
#   'всеволодович',
#   'из-за',
#   'лампа',
#   '.'],
#  ['-',
#   'можно',
#   ',',
#   'можно',
#   ',',
#   'конечно',
#   'можно',
#   '!',
#   '-',
#   'громко',
#   'и',
#   'весело',
#   'крикнуть',
#   'сам',
#   'петр',
#   'степанович',
#   ',',
#   'отворить',
#   'дверь',
#   'свой',
#   'рука',
#   'и',
#   'войти',
#   '.'],
#  ['николай',
#   'всеволодович',
#   'не',
#   'слыхать',
#   'стук',
#   'в',
#   'дверь',
#   ',',
#   'а',
#   'расслышать',
#   'лишь',
#   'только',
#   'робкий',
#   'вопрос',
#   'мамаша',
#   ',',
#   'но',
#   'не',
#   'успеть',
#   'на',
#   'он',
#   'ответить',
#   '.'],
#  ['пред',
#   'он',
#   'в',
#   'этот',
#   'минута',
#   'лежать',
#   'только',
#   'что',
#   'прочитать',
#   'они',
#   'письмо',
#   ',',
#   'над',
#   'который',
#   'он',
#   'сильно',
#   'задуматься',
#   '.'],
#  ['он',
#   'вздрогнуть',
#   ',',
#   'заслышать',
#   'внезапный',
#   'окрик',
#   'петр',
#   'степанович',
#   ',',
#   'и',
#   'скорый',
#   'накрыть',
#   'письмо',
#   'попасться',
#   'под',
#   'рука',
#   'преспапье',
#   ',',
#   'но',
#   'не',
#   'совсем',
#   'удаться',
#   ':',
#   'угол',
#   'письмо',
#   'и',
#   'почти',
#   'весь',
#   'конверт',
#   'выглядывать',
#   'наружу',
#   '.'],
#  ['-',
#   'я',
#   'нарочно',
#   'крикнуть',
#   'из',
#   'весь',
#   'сила',
#   ',',
#   'чтобы',
#   'вы',
#   'успеть',
#   'приготовиться',
#   ',',
#   '-',
#   'торопливо',
#   'с',
#   'удивительный',
#   'наивность',
#   'прошептать',
#   'петр',
#   'степанович',
#   ',',
#   'подбегать',
#   'к',
#   'стол',
#   ',',
#   'и',
#   'мигом',
#   'уставиться',
#   'на',
#   'преспапье',
#   'и',
#   'на',
#   'угол',
#   'письмо',
#   '.'],
#  ['-',
#   'и',
#   'конечно',
#   'успеть',
#   'подглядеть',
#   ',',
#   'как',
#   'я',
#   'прятать',
#   'от',
#   'вы',
#   'под',
#   'преспапье',
#   'только',
#   'что',
#   'получить',
#   'я',
#   'письмо',
#   ',',
#   '-',
#   'спокойно',
#   'проговорить',
#   'николай',
#   'всеволодович',
#   ',',
#   'не',
#   'трогаться',
#   'с',
#   'место',
#   '.'],
#  ['-', 'письмо', '?'],
#  ['бог',
#   'с',
#   'вы',
#   'и',
#   'с',
#   'ваш',
#   'письмо',
#   ',',
#   'я',
#   'что',
#   '!',
#   '-',
#   'воскликнуть',
#   'гость',
#   ',',
#   '-',
#   'но',
#   '...',
#   'главный',
#   ',',
#   '-',
#   'зашептать',
#   'он',
#   'опять',
#   ',',
#   'обертываться',
#   'к',
#   'дверь',
#   ',',
#   'уже',
#   'запереть',
#   ',',
#   'и',
#   'кивать',
#   'в',
#   'тот',
#   'сторона',
#   'голова',
#   '.'],
#  ['-',
#   'она',
#   'никогда',
#   'не',
#   'подслушивать',
#   ',',
#   '-',
#   'холодно',
#   'заметить',
#   'николай',
#   'всеволодович',
#   '.'],
#  ['-',
#   'то-есть',
#   'если',
#   'б',
#   'и',
#   'подслушивать',
#   '!',
#   '-',
#   'мигом',
#   'подхватить',
#   ',',
#   'весело',
#   'возвышать',
#   'голос',
#   'и',
#   'усаживаться',
#   'в',
#   'кресло',
#   ',',
#   'петр',
#   'степанович',
#   '.'],
#  ['-',
#   'я',
#   'ничто',
#   'против',
#   'это',
#   ',',
#   'я',
#   'только',
#   'теперь',
#   'бежать',
#   'поговорить',
#   'наедине',
#   '...'],
#  ['ну', ',', 'наконец-то', 'я', 'к', 'вы', 'добиться', '!'],
#  ['прежде', 'весь', 'как', 'здоровье', '?'],
#  ['видеть',
#   ',',
#   'что',
#   'прекрасно',
#   ',',
#   'и',
#   'завтра',
#   ',',
#   'мочь',
#   'быть',
#   ',',
#   'вы',
#   'явиться',
#   ',',
#   '-',
#   'а',
#   '?'],
#  ['-', 'мочь', 'быть', '.'],
#  ['-',
#   'разрешить',
#   'они',
#   'наконец',
#   ',',
#   'разрешить',
#   'я',
#   '!',
#   '-',
#   'неистово',
#   'зажестикулировать',
#   'он',
#   'с',
#   'шутливый',
#   'и',
#   'приятный',
#   'вид',
#   '.'],
#  ['-',
#   'если',
#   'б',
#   'вы',
#   'знать',
#   ',',
#   'что',
#   'я',
#   'должный',
#   'быть',
#   'он',
#   'наболтать',
#   '.'],
#  ['а', 'впрочем', 'вы', 'знать', '.'],
#  ['-', 'он', 'засмеяться', '.'],
#  ['-', 'всего', 'не', 'знать', '.'],
#  ['я',
#   'слышать',
#   'только',
#   'от',
#   'мать',
#   ',',
#   'что',
#   'вы',
#   'очень',
#   '...',
#   'двигаться',
#   '.'],
#  ['-',
#   'то-есть',
#   'я',
#   'ведь',
#   'ничто',
#   'определенный',
#   ',',
#   '-',
#   'вскинуться',
#   'вдруг',
#   'петр',
#   'степанович',
#   ',',
#   'как',
#   'бы',
#   'защищаться',
#   'от',
#   'ужасный',
#   'нападение',
#   ',',
#   '-',
#   'знать',
#   ',',
#   'я',
#   'пустить',
#   'в',
#   'ход',
#   'жена',
#   'шатов',
#   ',',
#   'то-есть',
#   'слух',
#   'о',
#   'ваш',
#   'связь',
#   'в',
#   'париж',
#   ',',
#   'чем',
#   'и',
#   'объясняться',
#   'конечно',
#   'тот',
#   'случай',
#   'в',
#   'воскресение',
#   '...',
#   'вы',
#   'не',
#   'сердиться',
#   '?'],
#  ['-', 'убежденный', ',', 'что', 'вы', 'очень', 'стараться', '.'],
#  ['-', 'ну', ',', 'я', 'только', 'это', 'и', 'бояться', '.'],
#  ['а',
#   'впрочем',
#   'что',
#   'ж',
#   'это',
#   'значить',
#   ':',
#   '"',
#   'очень',
#   'стараться',
#   '"',
#   '?'],
#  ['это', 'ведь', 'упрек', '.'],
#  ['впрочем',
#   'вы',
#   'прямо',
#   'ставить',
#   ',',
#   'я',
#   'всего',
#   'большой',
#   'бояться',
#   ',',
#   'идти',
#   'сюда',
#   ',',
#   'что',
#   'вы',
#   'не',
#   'захотеть',
#   'прямо',
#   'поставить',
#   '.'],
#  ['-',
#   'я',
#   'ничто',
#   'и',
#   'не',
#   'хотеть',
#   'прямо',
#   'ставить',
#   ',',
#   '-',
#   'проговорить',
#   'николай',
#   'всеволодович',
#   'с',
#   'некоторый',
#   'раздражение',
#   ',',
#   'но',
#   'тотчас',
#   'же',
#   'усмехнуться',
#   '.'],
#  ['-',
#   'я',
#   'не',
#   'про',
#   'тот',
#   ';',
#   'не',
#   'про',
#   'тот',
#   ',',
#   'не',
#   'ошибиться',
#   ',',
#   'не',
#   'про',
#   'тот',
#   '!',
#   '-',
#   'замахал',
#   'рука',
#   'петр',
#   'степанович',
#   ',',
#   'сыпать',
#   'слово',
#   'как',
#   'горох',
#   'и',
#   'тотчас',
#   'же',
#   'обрадовавшись',
#   'раздражительность',
#   'хозяин',
#   '.'],
#  ['-',
#   'я',
#   'не',
#   'стать',
#   'вы',
#   'раздражать',
#   'наш',
#   'дело',
#   ',',
#   'особенно',
#   'в',
#   'ваш',
#   'теперешний',
#   'положение',
#   '.'],
#  ['я',
#   'прибежать',
#   'только',
#   'о',
#   'воскресный',
#   'случай',
#   ',',
#   'и',
#   'тот',
#   'в',
#   'самый',
#   'необходимый',
#   'мера',
#   ',',
#   'потому',
#   'нельзя',
#   'же',
#   'ведь',
#   '.'],
#  ['я',
#   'с',
#   'самый',
#   'открытый',
#   'объяснение',
#   ',',
#   'в',
#   'который',
#   'нуждаться',
#   'главный',
#   'я',
#   ',',
#   'а',
#   'не',
#   'вы',
#   ',',
#   '-',
#   'это',
#   'для',
#   'ваш',
#   'самолюбие',
#   ',',
#   'но',
#   'в',
#   'тот',
#   'же',
#   'время',
#   'это',
#   'и',
#   'правда',
#   '.'],
#  ['я',
#   'прийти',
#   ',',
#   'чтобы',
#   'быть',
#   'с',
#   'этот',
#   'пора',
#   'всегда',
#   'откровенный',
#   '.'],
#  ['-', 'стать', 'быть', ',', 'прежде', 'быть', 'неоткровенный', '?'],
#  ['-', 'и', 'вы', 'это', 'знать', 'сам', '.'],
#  ['я',
#   'хитрить',
#   'много',
#   'раз',
#   '...',
#   'вы',
#   'улыбнуться',
#   ',',
#   'очень',
#   'рад',
#   'улыбка',
#   ',',
#   'как',
#   'предлог',
#   'для',
#   'разъяснение',
#   ';',
#   'я',
#   'ведь',
#   'нарочно',
#   'вызвать',
#   'улыбка',
#   'хвастливый',
#   'слово',
#   '"',
#   'хитрил',
#   '"',
#   ',',
#   'для',
#   'тот',
#   ',',
#   'чтобы',
#   'вы',
#   'тотчас',
#   'же',
#   'и',
#   'рассердиться',
#   ':',
#   'как',
#   'это',
#   'я',
#   'смелый',
#   'подумать',
#   ',',
#   'что',
#   'мочь',
#   'хитрить',
#   ',',
#   'а',
#   'я',
#   ',',
#   'чтобы',
#   'сейчас',
#   'же',
#   'объясниться',
#   '.'],
#  ['видеть',
#   ',',
#   'видеть',
#   ',',
#   'как',
#   'я',
#   'стать',
#   'теперь',
#   'откровенный',
#   '!'],
#  ['ну-с', ',', 'угодно', 'вы', 'выслушать', '?'],
#  ['в',
#   'выражение',
#   'лицо',
#   'николай',
#   'всеволодович',
#   ',',
#   'презрительно',
#   'спокойный',
#   'и',
#   'даже',
#   'насмешливый',
#   ',',
#   'несмотря',
#   'на',
#   'весь',
#   'очевидный',
#   'желание',
#   'гость',
#   'раздражить',
#   'хозяин',
#   'нахальность',
#   'свой',
#   'заранее',
#   'наготовить',
#   'и',
#   'с',
#   'намерение',
#   'грубый',
#   'наивность',
#   ',',
#   '-',
#   'выразиться',
#   'наконец',
#   'несколько',
#   'тревожный',
#   'любопытство',
#   '.'],
#  ['-',
#   'слушать',
#   'же',
#   ',',
#   '-',
#   'завертеться',
#   'петр',
#   'степанович',
#   'пуще',
#   'прежний',
#   '.'],
#  ['-',
#   'отправляться',
#   'сюда',
#   ',',
#   'то-есть',
#   'вообще',
#   'сюда',
#   ',',
#   'в',
#   'этот',
#   'город',
#   ',',
#   'десять',
#   'день',
#   'назад',
#   ',',
#   'я',
#   'конечно',
#   'решиться',
#   'взять',
#   'роль',
#   '.'],
#  ['самый',
#   'бы',
#   'хороший',
#   'совсем',
#   'без',
#   'роль',
#   ',',
#   'свой',
#   'собственный',
#   'лицо',
#   ',',
#   'не',
#   'так',
#   'ли',
#   '?'],
#  ['ничто',
#   'нет',
#   'хитрее',
#   ',',
#   'как',
#   'собственный',
#   'лицо',
#   ',',
#   'потому',
#   'что',
#   'никто',
#   'не',
#   'поверить',
#   '.'],
#  ['я',
#   ',',
#   'признаться',
#   ',',
#   'хотеть',
#   'быть',
#   'взять',
#   'дурачок',
#   ',',
#   'потому',
#   'что',
#   'дурачек',
#   'легче',
#   ',',
#   'чем',
#   'собственный',
#   'лицо',
#   ';',
#   'но',
#   'так',
#   'как',
#   'дурачек',
#   'все-таки',
#   'крайность',
#   ',',
#   'а',
#   'крайность',
#   'возбуждать',
#   'любопытство',
#   ',',
#   'то',
#   'я',
#   'и',
#   'остановиться',
#   'на',
#   'собственный',
#   'лицо',
#   'окончательно',
#   '.'],
#  ['ну-с', ',', 'какой', 'же', 'мой', 'собственный', 'лицо', '?'],
#  ['золотой',
#   'средина',
#   ':',
#   'ни',
#   'глупый',
#   ',',
#   'ни',
#   'умный',
#   ',',
#   'довольно',
#   'бездарный',
#   'и',
#   'с',
#   'луна',
#   'соскочить',
#   ',',
#   'как',
#   'говорить',
#   'здесь',
#   'благоразумный',
#   'человек',
#   ',',
#   'не',
#   'так',
#   'ли',
#   '?'],
#  ['-',
#   'что',
#   'ж',
#   ',',
#   'мочь',
#   'быть',
#   'и',
#   'так',
#   ',',
#   '-',
#   'чуть-чуть',
#   'улыбнуться',
#   'николай',
#   'всеволодович',
#   '.'],
#  ['-',
#   'а',
#   ',',
#   'вы',
#   'согласный',
#   '-',
#   'очень',
#   'рад',
#   ';',
#   'я',
#   'знать',
#   'вперед',
#   ',',
#   'что',
#   'это',
#   'ваш',
#   'собственный',
#   'мысль',
#   '...'],
#  ['не',
#   'беспокоиться',
#   ',',
#   'не',
#   'беспокоиться',
#   ',',
#   'я',
#   'не',
#   'сердиться',
#   'и',
#   'вовсе',
#   'не',
#   'для',
#   'тот',
#   'определить',
#   'себя',
#   'в',
#   'такой',
#   'вид',
#   ',',
#   'чтобы',
#   'вызвать',
#   'ваш',
#   'обратный',
#   'похвала',
#   ':',
#   '"',
#   'нет',
#   ',',
#   'дескать',
#   ',',
#   'вы',
#   'не',
#   'бездарный',
#   ',',
#   'нет',
#   ',',
#   'дескать',
#   ',',
#   'вы',
#   'умный',
#   '"',
#   '...'],
#  ['а', ',', 'вы', 'опять', 'улыбаться', '!..'],
#  ['я', 'опять', 'попасться', '.'],
#  ['вы',
#   'не',
#   'сказать',
#   'бы',
#   ':',
#   '"',
#   'вы',
#   'умный',
#   '"',
#   ',',
#   'ну',
#   'и',
#   'положить',
#   ';',
#   'я',
#   'весь',
#   'допускать',
#   '.'],
#  ['passons',
#   ',',
#   'как',
#   'говорить',
#   'папаша',
#   ',',
#   'и',
#   ',',
#   'в',
#   'скобка',
#   ',',
#   'не',
#   'сердиться',
#   'на',
#   'мой',
#   'многословие',
#   '.'],
#  ['кстати',
#   'вот',
#   'и',
#   'пример',
#   ':',
#   'я',
#   'всегда',
#   'говорить',
#   'много',
#   ',',
#   'то-есть',
#   'много',
#   'слово',
#   ',',
#   'и',
#   'торопиться',
#   ',',
#   'и',
#   'у',
#   'я',
#   'всегда',
#   'не',
#   'выходить',
#   '.'],
#  ['а',
#   'почему',
#   'я',
#   'говорить',
#   'много',
#   'слово',
#   'и',
#   'у',
#   'я',
#   'не',
#   'выходить',
#   '?'],
#  ['потому', 'что', 'говорить', 'не', 'уметь', '.'],
#  ['тот',
#   ',',
#   'который',
#   'уметь',
#   'хорошо',
#   'говорить',
#   ',',
#   'тот',
#   'коротко',
#   'говорить',
#   '.'],
#  ['вот',
#   ',',
#   'стать',
#   'быть',
#   ',',
#   'у',
#   'я',
#   'и',
#   'бездарность',
#   ',',
#   '-',
#   'не',
#   'правда',
#   'ли',
#   '?'],
#  ['но',
#   'так',
#   'как',
#   'этот',
#   'дар',
#   'бездарность',
#   'у',
#   'я',
#   'уже',
#   'быть',
#   'натуральный',
#   ',',
#   'так',
#   'почему',
#   'я',
#   'они',
#   'не',
#   'воспользоваться',
#   'искусственно',
#   '?'],
#  ['я', 'и', 'пользоваться', '.'],
#  ['правда',
#   ',',
#   'собираться',
#   'сюда',
#   ',',
#   'я',
#   'быть',
#   'подумать',
#   'сначала',
#   'молчать',
#   ';',
#   'но',
#   'ведь',
#   'молчать',
#   '-',
#   'большой',
#   'талант',
#   ',',
#   'и',
#   ',',
#   'стать',
#   'быть',
#   ',',
#   'я',
#   'неприличный',
#   ',',
#   'а',
#   'во-вторых',
#   ',',
#   'молчать',
#   'все-таки',
#   'ведь',
#   'опасный',
#   ';',
#   'ну',
#   'я',
#   'и',
#   'решить',
#   'окончательно',
#   ',',
#   'что',
#   'хороший',
#   'весь',
#   'говорить',
#   ',',
#   'но',
#   'именно',
#   'по-бездарному',
#   ',',
#   'то-есть',
#   'много',
#   ',',
#   'много',
#   ',',
#   'много',
#   ',',
#   'очень',
# ...
#   'и',
#   'я',
#   'вы',
#   'писать',
#   'о',
#   'тот',
#   'из',
#   'америка',
#   ';',
#   'я',
#   'вы',
#   'о',
#   'весь',
#   'писать',
#   '.'],
#  ['да',
#   ',',
#   'я',
#   'не',
#   'мочь',
#   'тотчас',
#   'же',
#   'оторваться',
#   'с',
#   'кровь',
#   'от',
#   'тот',
#   ',',
#   'к',
#   'что',
#   'прирасти',
#   'с',
#   'детство',
#   ',',
#   'на',
#   'что',
#   'пойти',
#   'весь',
#   'восторг',
#   'мой',
#   'надежда',
#   'и',
#   'весь',
#   'слеза',
#   'мой',
#   'ненависть',
#   '...'],
#  ['трудный', 'менять', 'бог', '.'],
#  ['я',
#   'не',
#   'поверить',
#   'вы',
#   'тогда',
#   ',',
#   'потому',
#   'что',
#   'не',
#   'хотеть',
#   'верить',
#   ',',
#   'и',
#   'уцепиться',
#   'в',
#   'последний',
#   'раз',
#   'за',
#   'этот',
#   'помойный',
#   'клоака',
#   '...'],
#  ['но', 'семя', 'остаться', 'и', 'возрасти', '.'],
#  ['серьезно',
#   ',',
#   'сказать',
#   'серьезно',
#   ',',
#   'не',
#   'дочитать',
#   'письмо',
#   'мой',
#   'из',
#   'америка',
#   '?'],
#  ['мочь', 'быть', 'не', 'читать', 'вовсе', '?'],
#  ['-',
#   'я',
#   'прочесть',
#   'из',
#   'он',
#   'три',
#   'страница',
#   ',',
#   'два',
#   'первый',
#   'и',
#   'последний',
#   ',',
#   'и',
#   'кроме',
#   'тот',
#   'бегло',
#   'переглядел',
#   'средина',
#   '.'],
#  ['впрочем', 'я', 'весь', 'собираться', '...'],
#  ['-',
#   'э',
#   ',',
#   'весь',
#   'равный',
#   ',',
#   'бросить',
#   ',',
#   'к',
#   'чорт',
#   '!',
#   '-',
#   'махнуть',
#   'рука',
#   'шат',
#   '.'],
#  ['-',
#   'если',
#   'вы',
#   'отступиться',
#   'теперь',
#   'от',
#   'тогдашний',
#   'слово',
#   'про',
#   'народ',
#   ',',
#   '.',
#   'тот',
#   'как',
#   'мочь',
#   'вы',
#   'они',
#   'тогда',
#   'выговорить',
#   '?..'],
#  ['вот', 'что', 'давить', 'я', 'теперь', '.'],
#  ['-',
#   'не',
#   'шутить',
#   'же',
#   'я',
#   'с',
#   'вы',
#   'и',
#   'тогда',
#   ';',
#   'убеждать',
#   'вы',
#   ',',
#   'я',
#   ',',
#   'мочь',
#   ',',
#   'еще',
#   'больше',
#   'хлопотать',
#   'о',
#   'себя',
#   ',',
#   'чем',
#   'о',
#   'вы',
#   ',',
#   '-',
#   'загадочно',
#   'произнести',
#   'ставрогин',
#   '.'],
#  ['-', 'не', 'шутить', '!'],
#  ['в',
#   'америка',
#   'я',
#   'лежать',
#   'три',
#   'месяц',
#   'на',
#   'солома',
#   ',',
#   'рядом',
#   'с',
#   'один',
#   '...',
#   'несчастный',
#   'и',
#   'узнать',
#   'от',
#   'он',
#   ',',
#   'что',
#   'в',
#   'тот',
#   'же',
#   'самый',
#   'время',
#   ',',
#   'когда',
#   'вы',
#   'насаждать',
#   'в',
#   'мой',
#   'сердце',
#   'бог',
#   'и',
#   'родина',
#   ',',
#   'в',
#   'тот',
#   'же',
#   'самый',
#   'время',
#   'даже',
#   'мочь',
#   'быть',
#   'в',
#   'тот',
#   'же',
#   'самый',
#   'день',
#   ',',
#   'вы',
#   'отравить',
#   'сердце',
#   'этот',
#   'несчастный',
#   ',',
#   'этот',
#   'маньяк',
#   ',',
#   'кириллов',
#   ',',
#   'яд',
#   '...'],
#  ['вы',
#   'утверждать',
#   'в',
#   'он',
#   'ложь',
#   'и',
#   'клевета',
#   'и',
#   'довести',
#   'разум',
#   'он',
#   'до',
#   'исступление',
#   '...'],
#  ['подите',
#   ',',
#   'взглянуть',
#   'на',
#   'он',
#   'теперь',
#   ',',
#   'это',
#   'ваш',
#   'создание',
#   '...'],
#  ['впрочем', 'вы', 'видеть', '.'],
#  ['-',
#   'во-первых',
#   ',',
#   'замечу',
#   'вы',
#   ',',
#   'что',
#   'сам',
#   'кириллов',
#   'сейчас',
#   'только',
#   'сказать',
#   'я',
#   ',',
#   'что',
#   'он',
#   'счастливый',
#   'и',
#   'что',
#   'он',
#   'прекрасный',
#   '.'],
#  ['ваш',
#   'предположение',
#   'о',
#   'тот',
#   ',',
#   'что',
#   'весь',
#   'это',
#   'произойти',
#   'в',
#   'один',
#   'и',
#   'тот',
#   'же',
#   'время',
#   ',',
#   'почти',
#   'верный',
#   ';',
#   'ну',
#   ',',
#   'и',
#   'что',
#   'же',
#   'из',
#   'весь',
#   'это',
#   '?'],
#  ['повторять',
#   ',',
#   'я',
#   'вы',
#   'ни',
#   'тот',
#   ',',
#   'ни',
#   'другой',
#   'не',
#   'обманывать',
#   '.'],
#  ['-', 'вы', 'атеист', '?'],
#  ['теперь', 'атеист', '?'],
#  ['-', 'да', '.'],
#  ['-', 'а', 'тогда', '?'],
#  ['-', 'точно', 'так', 'же', ',', 'как', 'и', 'тогда', '.'],
#  ['-',
#   'я',
#   'не',
#   'к',
#   'себя',
#   'просить',
#   'у',
#   'вы',
#   'уважение',
#   ',',
#   'начинать',
#   'разговор',
#   ';',
#   'с',
#   'ваш',
#   'ум',
#   ',',
#   'вы',
#   'бы',
#   'мочь',
#   'понять',
#   'это',
#   ',',
#   '-',
#   'в',
#   'негодование',
#   'пробормотать',
#   'шат',
#   '.'],
#  ['-',
#   'я',
#   'не',
#   'встать',
#   'с',
#   'первый',
#   'ваш',
#   'слово',
#   ',',
#   'не',
#   'закрыть',
#   'разговор',
#   ',',
#   'не',
#   'уйти',
#   'от',
#   'вы',
#   ',',
#   'а',
#   'сидеть',
#   'до',
#   'сей',
#   'пора',
#   'и',
#   'смирно',
#   'отвечать',
#   'на',
#   'ваш',
#   'вопрос',
#   'и',
#   '...',
#   'крик',
#   ',',
#   'стать',
#   'быть',
#   ',',
#   'не',
#   'нарушить',
#   'еще',
#   'к',
#   'вы',
#   'уважение',
#   '.'],
#  ['шат',
#   'прервать',
#   ',',
#   'махнуть',
#   'рука',
#   ':',
#   '-',
#   'вы',
#   'помнить',
#   'выражение',
#   'ваш',
#   ':',
#   '"',
#   'атеист',
#   'не',
#   'мочь',
#   'быть',
#   'русский',
#   '"',
#   ',',
#   '"',
#   'атеист',
#   'тотчас',
#   'же',
#   'переставать',
#   'быть',
#   'русский',
#   '"',
#   ',',
#   'помнить',
#   'это',
#   '?'],
#  ['-',
#   'да',
#   '?',
#   '-',
#   'как',
#   'бы',
#   'переспросить',
#   'николай',
#   'всеволодович',
#   '.'],
#  ['-', 'вы', 'спрашивать', '?'],
#  ['вы', 'забыть', '?'],
#  ['а',
#   'между',
#   'тот',
#   'это',
#   'один',
#   'из',
#   'самый',
#   'точный',
#   'указание',
#   'на',
#   'один',
#   'из',
#   'главный',
#   'особенность',
#   'русский',
#   'дух',
#   ',',
#   'вы',
#   'угадать',
#   '.'],
#  ['не', 'мочь', 'вы', 'это', 'забыть', '?'],
#  ['я',
#   'напомнить',
#   'вы',
#   'больше',
#   ',',
#   '-',
#   'высказать',
#   'тогда',
#   'же',
#   ':',
#   '"',
#   'не',
#   'православный',
#   'не',
#   'мочь',
#   'быть',
#   'русский',
#   '"',
#   '.'],
#  ['-', 'я', 'полагать', ',', 'что', 'это', 'славянофильский', 'мысль', '.'],
#  ['-', 'нет', ';', 'нынешний', 'славянофил', 'от', 'она', 'отказаться', '.'],
#  ['нынче', 'народ', 'поумнеть', '.'],
#  ['но',
#   'вы',
#   'еще',
#   'далекий',
#   'идти',
#   ':',
#   'вы',
#   'веровать',
#   ',',
#   'что',
#   'римский',
#   'католицизм',
#   'уже',
#   'не',
#   'быть',
#   'христианство',
#   ';',
#   'вы',
#   'утверждать',
#   ',',
#   'что',
#   'рим',
#   'провозгласить',
#   'христос',
#   ',',
#   'поддаться',
#   'на',
#   'третий',
#   'дьяволов',
#   'искушение',
#   ',',
#   'и',
#   'что',
#   ',',
#   'возвестить',
#   'весь',
#   'свет',
#   ',',
#   'что',
#   'христос',
#   'без',
#   'царство',
#   'земной',
#   'на',
#   'земля',
#   'устоять',
#   'не',
#   'мочь',
#   ',',
#   'католичество',
#   'тот',
#   'самый',
#   'провозгласить',
#   'антихрист',
#   'и',
#   'тот',
#   'погубить',
#   'весь',
#   'западный',
#   'мир',
#   '.'],
#  ['вы',
#   'именно',
#   'указывать',
#   ',',
#   'что',
#   'если',
#   'мучиться',
#   'франция',
#   ',',
#   'то',
#   'единственно',
#   'по',
#   'вина',
#   'католичество',
#   ',',
#   'ибо',
#   'отвергнуть',
#   'смрадный',
#   'бог',
#   'римский',
#   ',',
#   'а',
#   'новый',
#   'не',
#   'сыскала',
#   '.'],
#  ['вот', 'что', 'вы', 'тогда', 'мочь', 'говорить', '!'],
#  ['я', 'помнить', 'наш', 'разговор', '.'],
#  ['-',
#   'если',
#   'б',
#   'я',
#   'веровать',
#   ',',
#   'то',
#   ',',
#   'без',
#   'сомнение',
#   ',',
#   'повторить',
#   'бы',
#   'это',
#   'и',
#   'теперь',
#   ';',
#   'я',
#   'не',
#   'лгать',
#   ',',
#   'говорить',
#   'как',
#   'веровать',
#   ',',
#   '-',
#   'очень',
#   'серьезно',
#   'произнести',
#   'николай',
#   'всеволодович',
#   '.'],
#  ['-',
#   'но',
#   'уверять',
#   'вы',
#   ',',
#   'что',
#   'на',
#   'я',
#   'производить',
#   'слишком',
#   'неприятный',
#   'впечатление',
#   'это',
#   'повторение',
#   'прошлый',
#   'мысль',
#   'мой',
#   '.'],
#  ['не', 'мочь', 'ли', 'вы', 'перестать', '?'],
#  ['-',
#   'если',
#   'бы',
#   'веровать',
#   '?',
#   '-',
#   'вскричать',
#   'шат',
#   ',',
#   'не',
#   'обратить',
#   'ни',
#   'малый',
#   'внимание',
#   'на',
#   'просьба',
#   '.'],
#  ['-',
#   'но',
#   'не',
#   'вы',
#   'ли',
#   'говорить',
#   'я',
#   ',',
#   'что',
#   'если',
#   'бы',
#   'математически',
#   'доказать',
#   'вы',
#   ',',
#   'что',
#   'истина',
#   'вне',
#   'христос',
#   ',',
#   'то',
#   'вы',
#   'бы',
#   'согласиться',
#   'хороший',
#   'остаться',
#   'с',
#   'христос',
#   ',',
#   'нежели',
#   'с',
#   'истина',
#   '?'],
#  ['говорить', 'вы', 'это', '?'],
#  ['говорить', '?'],
#  ['-',
#   'но',
#   'позволить',
#   'же',
#   'и',
#   'я',
#   'наконец',
#   'спросить',
#   ',',
#   '-',
#   'возвысить',
#   'голос',
#   'ставрогин',
#   ',',
#   '-',
#   'к',
#   'что',
#   'вести',
#   'весь',
#   'этот',
#   'нетерпеливый',
#   'и',
#   '...',
#   'злобный',
#   'экзамен',
#   '?'],
#  ['-',
#   'этот',
#   'экзамен',
#   'пройти',
#   'навеки',
#   'и',
#   'никогда',
#   'большой',
#   'не',
#   'напомниться',
#   'вы',
#   '.'],
#  ['-',
#   'вы',
#   'весь',
#   'настаивать',
#   ',',
#   'что',
#   'мы',
#   'вне',
#   'пространство',
#   'и',
#   'время',
#   '...'],
#  ['-',
#   'молчать',
#   '!',
#   '-',
#   'вдруг',
#   'крикнуть',
#   'шат',
#   ',',
#   '-',
#   'я',
#   'глупый',
#   'и',
#   'неловкий',
#   ',',
#   'но',
#   'погибать',
#   'мой',
#   'имя',
#   'в',
#   'смешной',
#   '!'],
#  ['дозволите',
#   'ли',
#   'вы',
#   'я',
#   'повторить',
#   'пред',
#   'вы',
#   'весь',
#   'главный',
#   'ваш',
#   'тогдашний',
#   'мысль',
#   '...'],
#  ['о', ',', 'только', 'десять', 'строка', ',', 'один', 'заключение', '.'],
#  ['-', 'повторить', ',', 'если', 'только', 'один', 'заключение', '...'],
#  ['ставрогин',
#   'сделать',
#   'быть',
#   'движение',
#   'взглянуть',
#   'на',
#   'час',
#   ',',
#   'но',
#   'удержаться',
#   'и',
#   'не',
#   'взглянуть',
#   '.'],
#  ['шат',
#   'принагнуться',
#   'опять',
#   'на',
#   'стул',
#   'и',
#   ',',
#   'на',
#   'мгновение',
#   ',',
#   'даже',
#   'опять',
#   'быть',
#   'поднять',
#   'палец',
#   '.'],
#  ['-',
#   'ни',
#   'один',
#   'народ',
#   ',',
#   '-',
#   'начать',
#   'он',
#   ',',
#   'как',
#   'бы',
#   'читать',
#   'по',
#   'строка',
#   'и',
#   'в',
#   'тот',
#   'же',
#   'время',
#   'продолжать',
#   'грозно',
#   'смотреть',
#   'на',
#   'ставрогин',
#   ',',
#   '-',
#   'ни',
#   'один',
#   'народ',
#   'еще',
#   'не',
#   'устраиваться',
#   'на',
#   'начало',
#   'наука',
#   'и',
#   'разум',
#   ';',
#   'не',
#   'быть',
#   'ни',
#   'раз',
#   'такой',
#   'пример',
#   ',',
#   'разве',
#   'на',
#   'один',
#   'минута',
#   ',',
#   'по',
#   'глупость',
#   '.'],
#  ['социализм',
#   'по',
#   'существо',
#   'свой',
#   'уже',
#   'должный',
#   'быть',
#   'атеизм',
#   ',',
#   'ибо',
#   'именно',
#   'провозгласить',
#   ',',
#   'с',
#   'сам',
#   'первый',
#   'строка',
#   ',',
#   'что',
#   'он',
#   'установление',
#   'атеистический',
#   'и',
#   'намеренный',
#   'устроиться',
#   'на',
#   'начало',
#   'наука',
#   'и',
#   'разум',
#   'исключительно',
#   '.'],
#  ['разум',
#   'и',
#   'наука',
#   'в',
#   'жизнь',
#   'народ',
#   'всегда',
#   ',',
#   'теперь',
#   'и',
#   'с',
#   'начало',
#   'век',
#   ',',
#   'исполнять',
#   'лишь',
#   'должность',
#   'второстепенный',
#   'и',
#   'служебный',
#   ';',
#   'так',
#   'и',
#   'быть',
#   'исполнять',
#   'до',
#   'конец',
#   'век',
#   '.'],
#  ['народ',
#   'слагаться',
#   'и',
#   'двигаться',
#   'сила',
#   'ина',
#   ',',
#   'повелевать',
#   'и',
#   'господствующий',
#   ',',
#   'но',
#   'происхождение',
#   'который',
#   'неизвестный',
#   'и',
#   'необъяснимый',
#   '.'],
#  ['этот',
#   'сила',
#   'быть',
#   'сила',
#   'неутолимый',
#   'желание',
#   'дойти',
#   'до',
#   'конец',
#   'и',
#   'в',
#   'тот',
#   'же',
#   'время',
#   'конец',
#   'отрицать',
#   '.'],
#  ['это',
#   'быть',
#   'сила',
#   'беспрерывный',
#   'и',
#   'неустанный',
#   'подтверждение',
#   'свой',
#   'бытие',
#   'и',
#   'отрицание',
#   'смерть',
#   '.'],
#  ['дух',
#   'жизнь',
#   ',',
#   'как',
#   'говорить',
#   'писание',
#   ',',
#   '"',
#   'река',
#   'вода',
#   'живой',
#   '"',
#   ',',
#   'иссякновение',
#   'который',
#   'так',
#   'угрожать',
#   'апокалипсис',
#   '.'],
#  ['начать',
#   'эстетический',
#   ',',
#   'как',
#   'говорить',
#   'философ',
#   ',',
#   'начать',
#   'нравственный',
#   ',',
#   'как',
#   'отожествлять',
#   'они',
#   'же',
#   '.'],
#  ['"',
#   'искание',
#   'бог',
#   '"',
#   ',',
#   'как',
#   'называть',
#   'я',
#   'весь',
#   'проще',
#   '.'],
#  ['цель',
#   'весь',
#   'движение',
#   'народный',
#   ',',
#   'в',
#   'всякий',
#   'народ',
#   'и',
#   'в',
#   'всякий',
#   'период',
#   'его',
#   'бытие',
#   ',',
#   'быть',
#   'единственно',
#   'лишь',
#   'искание',
#   'бог',
#   ',',
#   'бог',
#   'свой',
#   ',',
#   'непременно',
#   'собственный',
#   ',',
#   'и',
#   'вера',
#   'в',
#   'он',
#   'как',
#   'в',
#   'единый',
#   'истинный',
#   '.'],
#  ['бог',
#   'быть',
#   'синтетический',
#   'личность',
#   'весь',
#   'народ',
#   ',',
#   'взять',
#   'с',
#   'начало',
#   'он',
#   'и',
#   'до',
#   'конец',
#   '.'],
#  ['никогда',
#   'еще',
#   'не',
#   'быть',
#   ',',
#   'чтоб',
#   'у',
#   'весь',
#   'или',
#   'у',
#   'многий',
#   'народ',
#   'быть',
#   'один',
#   'общий',
#   'бог',
#   ',',
#   'но',
#   'всегда',
#   'и',
#   'у',
#   'каждый',
#   'быть',
#   'особый',
#   '.'],
#  ['признак',
#   'уничтожение',
#   'народность',
#   ',',
#   'когда',
#   'бог',
#   'начинать',
#   'становиться',
#   'общий',
#   '.'],
#  ['когда',
#   'бог',
#   'становиться',
#   'общий',
#   ',',
#   'то',
#   'умирать',
#   'бог',
#   'и',
#   'вера',
#   'в',
#   'они',
#   'вместе',
#   'с',
#   'сам',
#   'народ',
#   '.'],
#  ['чем', 'сильнее', 'народ', ',', 'тем', 'особливее', 'он', 'бог', '.'],
#  ['никогда',
#   'еще',
#   'не',
#   'быть',
#   'народ',
#   'без',
#   'религия',
#   ',',
#   'то-есть',
#   'без',
#   'понятие',
#   'о',
#   'зло',
#   'и',
#   'добро',
#   '.'],
#  ['у',
#   'всякий',
#   'народ',
#   'свой',
#   'собственный',
#   'понятие',
#   'о',
#   'зло',
#   'и',
#   'добро',
#   'и',
#   'свой',
#   'собственный',
#   'зло',
#   'и',
#   'добро',
#   '.'],
#  ['когда',
#   'начинать',
#   'у',
#   'многий',
#   'народ',
#   'становиться',
#   'общий',
#   'понятие',
#   'о',
#   'зло',
#   'и',
#   'добро',
#   ',',
#   'тогда',
#   'вымирать',
#   'народ',
#   ',',
#   'и',
#   'тогда',
#   'самый',
#   'различие',
#   'между',
#   'зло',
#   'и',
#   'добрый',
#   'начинать',
#   'стираться',
#   'и',
#   'исчезать',
#   '.'],
#  ['никогда',
#   'разум',
#   'не',
#   'в',
#   'сила',
#   'быть',
#   'определить',
#   'зло',
#   'и',
#   'добро',
#   ',',
#   'или',
#   'даже',
#   'отделить',
#   'зло',
#   'от',
#   'добро',
#   ',',
#   'хотя',
#   'приблизительно',
#   ';',
#   'напротив',
#   ',',
#   'всегда',
#   'позорный',
#   'и',
#   'жалко',
#   'смешивать',
#   ';',
#   'наука',
#   'же',
#   'давать',
#   'разрешение',
#   'кулачные',
#   '.'],
#  ['в',
#   'особенность',
#   'это',
#   'отличаться',
#   'полунаука',
#   ',',
#   'самый',
#   'страшный',
#   'бич',
#   'человечество',
#   ',',
#   'хуже',
#   'мор',
#   ',',
#   'голод',
#   'и',
#   'война',
#   ',',
#   'не',
#   'известный',
#   'до',
#   'нынешний',
#   'столетие',
#   '.'],
#  ['полунаука',
#   '-',
#   'это',
#   'деспот',
#   ',',
#   'какой',
#   'еще',
#   'не',
#   'приходить',
#   'до',
#   'сей',
#   'пора',
#   'никогда',
#   '.'],
#  ['деспот',
#   ',',
#   'иметь',
#   'свой',
#   'жрец',
#   'и',
#   'раб',
#   ',',
#   'деспот',
#   ',',
#   'пред',
#   'который',
#   'весь',
#   'преклонилось',
#   'с',
#   'любовь',
#   'и',
#   'суеверие',
#   ',',
#   'до',
#   'сей',
#   'пора',
#   'немыслимый',
#   ',',
#   'пред',
#   'который',
#   'трепетать',
#   'даже',
#   'сам',
#   'наука',
#   'и',
#   'постыдно',
#   'потакать',
#   'он',
#   '.'],
#  ['весь',
#   'это',
#   'ваш',
#   'собственный',
#   'слово',
#   ',',
#   'ставрогин',
#   ',',
#   'кроме',
#   'только',
#   'слово',
#   'о',
#   'полунаука',
#   ';',
#   'этот',
#   'мой',
#   ',',
#   'потому',
#   'что',
#   'я',
#   'сам',
#   'только',
#   'полунаука',
#   ',',
#   'а',
#   'стать',
#   'быть',
#   ',',
#   'особенно',
#   'ненавидеть',
#   'она',
#   '.'],
#  ['в',
#   'ваш',
#   'же',
#   'мысль',
#   'и',
#   'даже',
#   'в',
#   'самый',
#   'слово',
#   'я',
#   'не',
#   'изменить',
#   'ничто',
#   ',',
#   'ни',
#   'единый',
#   'слово',
#   '.'],
#  ['-',
#   'не',
#   'думать',
#   ',',
#   'чтобы',
#   'не',
#   'изменить',
#   ',',
#   '-',
#   'осторожно',
#   'заметить',
#   'ставрогин',
#   ';',
#   '-',
#   'вы',
#   'пламенно',
#   'принять',
#   'и',
#   'пламенно',
#   'переиначить',
#   ',',
#   'не',
#   'замечать',
#   'тот',
#   '.'],
#  ['уж',
#   'один',
#   'тот',
#   ',',
#   'что',
#   'вы',
#   'бог',
#   'низводить',
#   'до',
#   'простой',
#   'аттрибут',
#   'народность',
#   '...'],
#  ['он',
#   'с',
#   'усиленный',
#   'и',
#   'особливый',
#   'внимание',
#   'начать',
#   'вдруг',
#   'следить',
#   'за',
#   'шатов',
#   ',',
#   'и',
#   'не',
#   'столько',
#   'за',
#   'слово',
#   'он',
#   ',',
#   'сколько',
#   'за',
#   'он',
#   'сам',
#   '.'],
#  ['-',
#   'низводить',
#   'бог',
#   'до',
#   'аттрибут',
#   'народность',
#   '?',
#   '-',
#   'вскричать',
#   'шат',
#   ',',
#   '-',
#   'напротив',
#   ',',
#   'народ',
#   'возносить',
#   'до',
#   'бог',
#   '.'],
#  ['да', 'и', 'быть', 'ли', 'когда-нибудь', 'иначе', '?'],
#  ['народ', '-', 'это', 'тело', 'божий', '.'],
#  ['всякий',
#   'народ',
#   'до',
#   'тот',
#   'только',
#   'пора',
#   'и',
#   'народ',
#   ',',
#   'пока',
#   'иметь',
#   'свой',
#   'бог',
#   'особый',
#   ',',
#   'а',
#   'весь',
#   'остальной',
#   'на',
#   'свет',
#   'бог',
#   'исключать',
#   'без',
#   'всякий',
#   'примирение',
#   ';',
#   'пока',
#   'веровать',
#   'в',
#   'тот',
#   ',',
#   'что',
#   'свой',
#   'бог',
#   'победить',
#   'и',
#   'изгнать',
#   'из',
#   'мир',
#   'весь',
#   'остальной',
#   'бог',
#   '.'],
#  ['так',
#   'веровать',
#   'весь',
#   'с',
#   'начало',
#   'век',
#   ',',
#   'весь',
#   'великий',
#   'народ',
#   'по',
#   'крайний',
#   'мера',
#   ',',
#   'весь',
#   'сколько-нибудь',
#   'отметить',
#   ',',
#   'весь',
#   'стоять',
#   'в',
#   'глава',
#   'человечество',
#   '.'],
#  ['против', 'факт', 'идти', 'нельзя', '.'],
#  ...]

# %%
# собираем словарь
words = sorted( set.union( *[ set(s) for s in text_ ] ) )
display(len(words))
words
# Out:
# 8557
# ['!',
#  '!!',
#  '!!!..',
#  '!..',
#  '!?',
#  '"',
#  "'",
#  '(',
#  ')',
#  ',',
#  '-',
#  '.',
#  '..',
#  '...',
#  '187',
#  '19-й',
#  ':',
#  ';',
#  '?',
#  '?..',
#  'a',
#  'abreuve',
#  'activit',
#  'adieu',
#  'ai',
#  'alea',
#  'allemand',
#  'allons',
#  'ami',
#  'amie',
#  'amis',
#  'ann',
#  'ans',
#  'appelle',
#  'arr',
#  'assure',
#  'au',
#  'augustin',
#  'aujourd',
#  'autour',
#  'avait',
#  'avec',
#  'aveugle',
#  'avis',
#  'ax',
#  'b',
#  'bas',
#  'battre',
#  'bauches',
#  'beaucoup',
#  'belle',
#  'belles',
#  'bien',
#  'bienfaisant',
#  'bon',
#  'bonjour',
#  'boudoir',
#  'bourru',
#  'brisons-l',
#  'bruit',
#  'c',
#  'cacha',
#  'calme',
#  'candide',
#  'carri',
#  'ce',
#  'cela',
#  'ces',
#  'cette',
#  'ch',
#  'chambre',
#  'chaque',
#  'charmant',
#  'charmante',
#  'cher',
#  'chere',
#  'chet',
#  'chez',
#  'chose',
#  'choses',
#  'choses-l',
#  'cochon',
#  'comme',
#  'commencerai',
#  'comment',
#  'comparaison',
#  'comprenez',
#  'compris',
#  'connais',
#  'connaissez',
#  'consenti',
#  'content',
#  'convertir',
#  'cozak',
#  'critiques',
#  'croire',
#  'croyez',
#  'croyez-vous',
#  'd',
#  'dans',
#  'date',
#  'de',
#  'dedans',
#  'des',
#  'deux',
#  'diatement',
#  'digne',
#  'dira-t-elle',
#  'distance',
#  'dit',
#  'doit',
#  'don',
#  'drapeau',
#  'du',
#  'e',
#  'elle',
#  'eloignez-la',
#  'emb',
#  'employ',
#  'en',
#  'encore',
#  'enfin',
#  'ennemis',
#  'entendra',
#  'esclandre',
#  'esprits-forts',
#  'est',
#  'et',
#  'excellent',
#  'fa',
#  'fair',
#  'faire',
#  'faites',
#  'fantichambre',
#  'faut',
#  'fautre',
#  'femmes',
#  'ferai',
#  'figure',
#  'fils',
#  'finie',
#  'fois',
#  'forteresses',
#  'genre',
#  'gens',
#  'gens-l',
#  'guenille',
#  'h',
#  'hauteur',
#  'he',
#  'heure',
#  'historiques',
#  'homme',
#  'hui',
#  'i',
#  'ii',
#  'iii',
#  'il',
#  'ils',
#  'imm',
#  'impuissance',
#  'impur',
#  'incognito',
#  'index',
#  'internationale',
#  'invraisemblable',
#  'iv',
#  'j',
#  'jacta',
#  'je',
#  'jure',
#  'karmazinoff',
#  'l',
#  'la',
#  'le',
#  'lecteur',
#  'lembke',
#  'les',
#  'lieber',
#  'littre',
#  'louche',
#  'lui',
#  'm',
#  'm-me',
#  'm-r',
#  'ma',
#  'mais',
#  'maman',
#  'manqu',
#  'me',
#  'meilleur',
#  'mein',
#  'merci',
#  'mes',
#  'mettez',
#  'mieux',
#  'minimum',
#  'moi',
#  'moines',
#  'moment',
#  'mon',
#  'mondes',
#  'mot',
#  'n',
#  'ne',
#  'nicolas',
#  'nom',
#  'non',
#  'nos',
#  'notre',
#  'on',
#  'onnera',
#  'oubli',
#  'oui',
#  'p',
#  'paraisse',
#  'pardon',
#  'pare',
#  'paresseux',
#  'parlait',
#  'partout',
#  'pas',
#  'passant',
#  'passons',
#  'pauvre',
#  'pays',
#  'permise',
#  'petit',
#  'peut',
#  'physionomie',
#  'pierre',
#  'pl',
#  'plaisir',
#  'plus',
#  'politesse',
#  'politiques',
#  'possibles',
#  'pouce',
#  'pour',
#  'pourtant',
#  'pr',
#  'procureur',
#  'prononc',
#  'propre',
#  'proteg',
#  'puis',
#  'qu',
#  'quand',
#  'que',
#  'quelque',
#  'quelques',
#  'qui',
#  'quinze',
#  'quoi',
#  'raison',
#  're',
#  'ri',
#  'rien',
#  'rieux',
#  'rit',
#  'roide',
#  'rosenthal',
#  'ross',
#  'roubles',
#  's',
#  'sa',
#  'sacr',
#  'sang',
#  'sans',
#  'sautait',
#  'savez',
#  'savez-vous',
#  'se',
#  'sens',
#  'sent',
#  'serai',
#  'seul',
#  'sillons',
#  'simplement',
#  'soit',
#  'son',
#  'sonn',
#  'sont',
#  'soup',
#  'souviens',
#  'suis',
#  'sur',
#  'surexcit',
#  't',
#  'tage',
#  'tais',
#  'tait',
#  'tant',
#  'tas',
#  'te',
#  'teliatnikoff',
#  'tenait',
#  'ter',
#  'terrain',
#  'tersbourg',
#  'tes',
#  'tise',
#  'tises',
#  'to-есть',
#  'tombe',
#  'tomberai',
#  'toujours',
#  'tous',
#  'tout',
#  'tout-а-fait',
#  'toute',
#  'tr',
#  'tre',
#  'trop',
#  'trouve',
#  'un',
#  'une',
#  'unes',
#  'v',
#  'vero',
#  'vi',
#  'vie',
#  'vient',
#  'vii',
#  'vingt',
#  'voil',
#  'voltaire',
#  'vorante',
#  'votre',
#  'voulais',
#  'vous',
#  'voyez',
#  'voyez-vous',
#  'xe-xe',
#  'y',
#  'а',
#  'а-bas',
#  'а-а',
#  'а-а-а',
#  'а-на-фе-ма',
#  'абажур',
#  'абрютировать',
#  'авдотья',
#  'автоматический',
#  'автор',
#  'авторитет',
#  'агафья',
#  'агент',
#  'аглицкий',
#  'адвокат',
#  'административный',
#  'администратор',
#  'администрация',
#  'адрес',
#  'адресовать',
#  'адский',
#  'азарт',
#  'азиятский',
#  'академия',
#  'аккуратный',
#  'акмолинский',
#  'актер',
#  'актриса',
#  'акушер',
#  'акушерка',
#  'акцент',
#  'александрович',
#  'александровский',
#  'алексей',
#  'алеша',
#  'али',
#  'аллегория',
#  'алтарь',
#  'аль',
#  'альбом',
#  'алюминий',
#  'аля',
#  'амалия',
#  'амбиция',
#  'америка',
#  'американец',
#  'американский',
#  'ан',
#  'ангел',
#  'английский',
#  'англичанин',
#  'англия',
#  'андрей',
#  'анекдот',
#  'анекдотик',
#  'анекдотический',
#  'аничков',
#  'анонимный',
#  'антихрист',
#  'антонович',
#  'антропович',
#  'аплодировать',
#  'апокалипсис',
#  'аппетит',
#  'аргумент',
#  'арест',
#  'арестовать',
#  'арестуй',
#  'арина',
#  'аристократ',
#  'аристократический',
#  'аркан',
#  'артельщик',
#  'артемий',
#  'артиллерист',
#  'артиллерия',
#  'архангельск',
#  'архиерей',
#  'аршин',
#  'асессор',
#  'ассигнация',
#  'астролом',
#  'атеизм',
#  'атеист',
#  'атеистический',
#  'атестовать',
#  'аттрибут',
#  'афронт',
#  'аффилиация',
#  'аффильировать',
#  'ах',
#  'ахнуть',
#  'б',
#  'б-ца',
#  'ба',
#  'баба',
#  'базаров',
#  'байрон',
#  'бакенбарда',
#  'бал',
#  'балаган',
#  'баловство',
#  'бальзак',
#  'банк',
#  'банкомет',
#  'банкомета',
#  'бант',
#  'барабан',
#  'барабанить',
#  'баран',
#  'бараний',
#  'барин',
#  'барич',
#  'барича',
#  'барство',
#  'бархат',
#  'бархатный',
#  'барченок',
#  'барыня',
#  'барышня',
#  'барьер',
#  'баск',
#  'басня',
#  'баста',
#  'батистовый',
#  'батюшка',
#  'башмак',
#  'бег',
#  'бегать',
#  'бегло',
#  'беглый',
#  'беда',
#  'бедность',
#  'бедный',
#  'бедняжка',
#  'бедовать',
#  'бежать',
#  'без',
#  'безбожие',
#  'безбоязненно',
#  'безбровый',
#  'безверие',
#  'безграничный',
#  'бездарен',
#  'бездарность',
#  'бездарный',
#  'бездельник',
#  'бездна',
#  'бездушный',
#  'безличность',
#  'безмерно',
#  'безмерный',
#  'безмолвно',
#  'безмятежно',
#  'безмятежный',
#  'безнадежность',
#  'безнаказанно',
#  'безнравственный',
#  'безобразие',
#  'безобразный',
#  'безотраднее',
#  'безотчетнее',
#  'безразличный',
#  'безрассудный',
#  'безукоризненно',
#  'безумие',
#  'безумный',
#  'безусловно',
#  'беленькое',
#  'белинский',
#  'беллетристика',
#  'беллетристический',
#  'белобрысый',
#  'белокурый',
#  'белый',
#  'белье',
#  'бенефис',
#  'берег',
#  'бережно',
#  'берейтер',
#  'беречь',
#  'берлин',
#  'бес',
#  'бесенок',
#  'бесконечный',
#  'бескорыстно',
#  'бесноваться',
#  'беспардонный',
#  'беспечно',
#  'бесподобный',
#  'беспокоить',
#  'беспокоиться',
#  'беспокойно',
#  'беспокойный',
#  'беспокойство',
#  'беспомощный',
#  'беспорядок',
#  'беспорядочный',
#  'беспредельность',
#  'беспредельный',
#  'беспредметный',
#  'беспрекословно',
#  'беспрерывно',
#  'беспрерывный',
#  'бессвязный',
#  'бессилие',
#  'бессильно',
#  'бессильный',
#  'бесследно',
#  'бессменно',
#  'бессмысленный',
#  'бессмыслица',
#  'бессознательный',
#  'бесстыдный',
#  'бестактность',
#  'бестактный',
#  'бестолковый',
#  'бесцеремоннее',
#  'бесцеремонно',
#  'бесчеловечие',
#  'бесчестие',
#  'бесчестным',
#  'бесчинство',
#  'бесчисленный',
#  'бешено',
#  'бешенство',
#  'билет',
#  'бинокль',
#  'биноколя',
#  'биография',
#  'бисмарк',
#  'битва',
#  'битый',
#  'бить',
#  'битье',
#  'биться',
#  'бич',
#  'блага-а-дарный',
#  'благо',
#  'благоговейный',
#  'благоговение',
#  'благоговеть',
#  'благодарить',
#  'благодарность',
#  'благодарный',
#  'благодарный-то',
#  'благодаря',
#  'благодать',
#  'благоденствие',
#  'благодетель',
#  'благодетельный',
#  'благодеяние',
#  'благодушие',
#  'благодушно',
#  'благонадежный',
#  'благополучно',
#  'благоприятный',
#  'благоразумно',
#  'благоразумный',
#  'благородный',
#  'благородство',
#  'благосклонно',
#  'благосклонный',
#  'благословить',
#  'благотворный',
#  'блаженный',
#  'блаженство',
#  'бледнее',
#  'бледнеть',
#  'бледный',
#  'блеск',
#  'блеснуть',
#  'блестеть',
#  'ближе',
#  'ближний',
#  'близ',
#  'близкий',
#  'близкий-то',
#  'близко',
#  'близорукий',
#  'близость',
#  'блудливый',
#  'блюдо',
#  'блюм',
#  'блюмер',
#  'бог',
#  'бог-саваоф',
#  'богаделенка',
#  'богадельня',
#  'богатство',
#  'богатый',
#  'богач',
#  'богоматерь',
#  'богомолец',
#  'богомольный',
#  'богоносец',
#  'богородица',
#  'богородский',
#  'боготворить',
#  'богочеловек',
#  'богоявленский',
#  'бодрее',
#  'бодро',
#  'боевой',
#  'божественный',
#  'божий',
#  'бойкий',
#  'бойко',
#  'бок',
#  'бокал',
#  'боковой',
#  'более',
#  'болезненно',
#  'болезненный',
#  'болезнь',
#  'болеть',
#  'болото',
#  'болтать',
#  'болтовня',
#  'боль',
#  'больнее',
#  'больница',
#  'больно',
#  'больной',
#  'больше',
#  'больший',
#  'большинство',
#  'большой',
#  'бонмо',
#  'бордо',
#  'бормотать',
#  'борода',
#  'бородавка',
#  'бородач',
#  'бороть',
#  'бороться',
#  'борьба',
#  'босой',
#  'бочка',
#  'боязливый',
#  'боязние',
#  'боярин',
#  'боярский',
#  'боярство',
#  'боясь',
#  'бояться',
#  'брак',
#  'бранить',
#  'браниться',
#  'брат',
#  'братец',
#  'братия',
#  'братство',
#  'брать',
#  'браться',
#  'брачный',
#  'бред',
#  'бредить',
#  'брежу',
#  'брезгать',
#  'брезгливо',
#  'брезгливый',
#  'брезговать',
#  'бремя',
#  'бриллиантовый',
#  'брить',
#  'бровь',
#  'бродить',
#  'бродяга',
#  'бросать',
#  'бросаться',
#  'бросить',
#  'броситься',
#  'брызгало',
#  'брызги',
#  'брыков',
#  'брюнет',
#  'брюнеточка',
#  'брюхо',
#  'брюшко',
#  'брякнул',
#  'брякнуть',
#  'будить',
#  'будни',
#  'будто',
#  'будуар',
#  'будущее',
#  'будущий',
#  'будущность',
#  'буйный',
#  'букашка',
#  'буква',
#  'буквально',
#  'букля',
#  'булочка',
#  'булочник',
#  'бумага',
#  'бумажка',
#  'бумажник',
#  'бумажный',
#  'бунт',
#  'бунтовать',
#  'бунтовщик',
#  'бунтуют',
#  'бурбон',
#  'буря',
#  'бутылка',
#  'буфет',
#  'бухгалтер',
#  'буянов',
#  'бы',
#  'бы-с',
#  'бывало',
#  'бывать',
#  'бывать-с',
#  'бывший',
#  'быков',
#  'было',
#  'быстро',
#  'быстрота',
#  'быстрый',
#  'быстрый-то',
#  'быт',
#  'бытие',
#  'быть',
#  'быть-с',
#  'бюхнера',
#  'в',
#  'в-третьих',
#  'вавилон',
#  'вагон',
#  'важничание',
#  'важно-угрюмые',
#  'важность',
#  'важный',
#  'вал',
#  'вальс',
#  'валяться',
#  'варвара',
#  'варево',
#  'вареный',
#  'вариант',
#  'варьировать',
#  'вас-то',
#  'василий',
#  'вата',
#  'ваш',
#  'ваш-то',
#  'ваша',
#  'вашея',
#  'вбегать',
#  'вбежать',
#  'ввек',
#  'ввергнуть',
#  'вверить',
#  'вверх',
#  'вверху',
#  'ввести',
#  'ввечеру',
#  'вводить',
#  'ввязаться',
#  'вглядеться',
#  'вглядываться',
#  'вглядываясь',
#  'вдвое',
#  'вделать',
#  'вдобавок',
#  'вдова',
#  'вдовица',
#  'вдовый',
#  'вдогонку',
#  'вдоль',
#  'вдохновение',
#  'вдруг',
#  'ведать',
#  'ведро',
#  'ведь',
#  'вежливо',
#  'вежливо-фамильярный',
#  'вежливость',
#  'вежливый',
#  'везде',
#  'везти',
#  'век',
#  'велено',
#  'велеть',
#  'великан',
#  'великий',
#  'великодушный',
#  'величавый',
#  'величественно',
#  'величие',
#  'вендетта',
#  'венец',
#  'венчать',
#  'вера',
#  'вера-то',
#  'вербоваться',
#  'верить',
#  'верно',
#  'верный',
#  'веровали',
#  'веровать',
#  'веровать-с',
#  'вероятно',
#  'вероятный',
#  'верста',
#  'вертелись',
#  'вертеть',
#  'вертеться',
#  'веруете',
#  'верх',
#  'верхишин',
#  'верхний',
#  'верховенский',
#  'верховный',
#  'верховой',
#  'верхом',
#  'вершина',
#  'вершок',
#  'веселее',
#  'веселие',
#  'веселить',
#  'веселиться',
#  'веселка',
#  'весело',
#  'веселость',
#  'веселый',
#  'веский',
#  'вескость',
#  'весна',
#  'вести',
#  'весть',
#  'весь',
#  'весь-то',
#  'весьма',
#  'ветер',
#  'ветренный',
#  'ветреный',
#  'ветхий',
#  'ветчина',
#  'вечер',
#  'вечеринка',
#  'вечерний',
#  'вечерок',
#  'вечно',
#  'вечный',
#  'вешалку',
#  'вешаться',
#  'вещать',
#  'вещица',
#  'вещь',
#  'взад',
#  'взаимно',
#  'взаимность',
#  'взаимный',
#  'взаймы',
#  'взамен',
#  'взапуски',
#  'взбалмошный',
#  'взбеситься',
#  'взвидеть',
#  'взвизг',
#  'взвизгнул',
#  'взвизгнуть',
#  'взволновать',
#  'взволноваться',
#  'взгляд',
#  'взглянете',
#  'взглянуть',
#  'вздернуть',
#  'вздор',
#  'вздор-с',
#  'вздохнуть',
#  'вздрагивать',
#  'вздрогнули',
#  'вздрогнуть',
#  'вздуматься',
#  'вздыхать',
#  'взирать',
#  'взмоститься',
#  'взобраться',
#  'взор',
#  'взорвать',
#  'взрастить',
#  'взрыв',
#  'взъерошить',
#  'взыскательный',
#  'взыскать',
#  'взять',
#  'взяться',
#  'виг',
#  'вид',
#  'вид-с',
#  'видали',
#  'видать',
#  'видаться',
#  'видеть',
#  'видеться',
#  'видимо',
#  'видимый',
#  'видите',
#  'видите-с',
#  'видно',
#  'видный',
#  'видывать',
#  'визг',
#  'визгливее',
#  'визгливый',
#  'визжать',
#  'визит',
#  'вилы',
#  'вина',
#  'винить',
#  'вино',
#  'виноватый',
#  'виновник',
#  'виновный',
#  'виноград',
#  'виньетка',
#  'виргинские',
#  'виргинский',
#  'висок',
#  'вица',
#  'вкопать',
#  'вкус',
#  'вкушать',
#  'властие',
#  'властно',
#  'власть',
#  'влетать',
#  'влететь',
#  'влечь',
#  'влить',
#  'влияние',
#  'влиять',
#  'влюбить',
#  'влюбиться',
#  'вменять',
#  'вместе',
#  'вместо',
#  'вмешиваться',
#  'вне',
#  'внезапно',
#  'внезапность',
#  'внезапный',
#  'внести',
#  'вниз',
#  'внизу',
#  'вникните',
#  'внимание',
#  'внимательно',
#  'вновь',
#  'внутри',
#  'внушать',
#  'внушительнее',
#  'внушительно',
#  'внушить',
#  'во-вторых',
#  'во-первых',
#  'вовеки',
#  'вовремя',
#  'вовсе',
#  'вода',
#  'водевиль',
#  ...]
