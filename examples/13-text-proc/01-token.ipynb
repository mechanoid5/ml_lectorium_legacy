# %% [markdown]
# **извлечение признаков из текста на естественном языке**
#
# токенизация и очистка текста
#
#
# Евгений Борисов borisov.e@solarl.ru

# %% [markdown]
# ## библиотеки

# %%
import numpy as np
np.set_printoptions(precision=2) # вывод на печать до 2 знака
import pandas as pd
import re

# %%
pd.options.display.max_colwidth = 200

# %% [markdown]
# ## загружаем тексты

# %%
# загружаем тексты
data = pd.read_pickle('../data/text/news.pkl')
print('записей:',len(data))
# Out:
# записей: 3196

# %%
for t in data.sample(2)['text'].values:
    print(t,'\n\n = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =\n')
# Out:
# Ученые нашли связь между бритьем лобковых волос и венерическими заболеваниями
#
# 6 декабря 2016 в 17:20
#
# 42.TUT.BY
#
# Стрижка и бритье лобковых волос связаны с повышенным риском заражения венерическими заболеваниями. Научная работа об этом опубликована в журнале Sexually Transmitted Infections, кратко об исследовании сообщает Eurek Alert.
#
# Фото: Reuters
#
# Исследователи из нескольких университетов в США провели опрос среди 7580 добровольцев в возрасте от 18 до 65. Волонтеров попросили рассказать, как они ухаживают за своим волосяным покровом в интимной зоне. Также их распросили о половой жизни и перенесенных инфекциях, передаваемых половым путем.
#
# От волос избавляются бритвой и ножницами
#
# По результатам опроса 74% сообщили, что хотя бы раз стригли или сбривали свои лобковые волосы, это делали 66% мужчин и 84% женщин. Среди них 17% удаляли все волосы по крайней мере раз в месяц, 22% ухаживали за ними ежедневно или еженедельно.
#
# Выяснилось, что те, кто заботился о волосках в интимных местах, вели более активную половую жизнь, имели больше половых партнеров и проводили с ними больше времени. Общее количество сексуальных партнеров было наивысшим в категории «экстремальных грумеров» — тех, кто удалял лобковые волосы больше 11 раз за год.
#
# Самым популярным инструментом для стрижки лобковых волос у мужчин оказалась электрическая бритва (42%), а у женщин — ручная (61%). Примерно каждый пятый опрошенный использовал ножницы.
#
# Чаще стрижка — больше болезней
#
# 13% всех респондентов сообщили, что хоть раз заражались инфекцией, передающейся половым путем (ИППП). В список вошли герпес, папилломавирус человека, сифилис, контагиозный моллюск, гонорея, хламидиоз, ВИЧ, а также лобковые вши.
#
# Ученые заметили положительную корреляцию между бритьем и стрижкой лобковых волос и шансом заразиться ИППП. В среднем интимная стрижка на 80% была связана с более высоким риском наличия инфекций по сравнению с отсутствием ухода.
#
# Интенсивность и частота ухаживания оказалась связана с величиной риска. Для тех, кто удалял волосяной покров часто и регулярно, риск повышался в 3,5 — 4 раза. Зато низкая интенсивность и частота груминга были связаны с удвоением риска получить лобковых вшей.
#
# Ученые отметили, что их исследование — обсервационное и не может быть основой для выводов о причинно-следственных связях. Чтобы объяснить результаты опросов, они предположили, что груминг может быть признаком более высокого уровня сексуальной активности и связанного с ними риска заражения инфекцией. Также интимная стрижка может вызвать крошечные ранки на коже, которые упрощают попадание бактерий и вирусов в организм.
#
#  = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
# На торгах в первый день зимы рубль резко окреп к доллару и евро
#
# 1 декабря 2016 в 12:24
#
# TUT.BY
#
#  = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =

# %%
# выбираем случайный текст
tt = data.sample()['text'].values[0]
tt
# Out:
# 'Сегодня в Париже стал известен обладатель «Золотого мяча». Самую престижную для футболиста индивидуальную награду в четвертый раз получил португалец Криштиану Роналду. Об этом сообщает Eurosport.\n\nВ прошедшем сезоне он выиграл со своей сборной чемпионат Европы, а со своим клубом - мадридским «Реалом» - Лигу чемпионов. Именно это позволило Роналду опередить своего главного конкурента - аргентинца Лионеля Месси.\n\nТеперь у обоих выдающихся футболистов по четыре «Золотых мяча». В сегодняшнем голосовании впервые за последние шесть лет принимали участие только спортивные журналисты - без участия FIFA.\n\nСам Роналду на церемонию не приехал - сейчас он на клубном чемпионате мира. Вместе с Реалом готовится сыграть в полуфинале этого турнира.\n\nФото: imago sportfotodienst / globallookpress'

# %% [markdown]
# ## токенизация и очистка

# %%
def tokenizer(text): return [ t for t in text.split() if t ]

# %%
from Stemmer import Stemmer
# pacman -S python-pystemmer
# pip install pystemmer

# %%
def preprocessor(tt):
    tt = [ t.lower()  for t in tt ] # приведение в lowercase
    tt = [ re.sub( r'https?://[\S]+', 'url', t)  for t in tt ]  # замена интернет ссылок
    tt = [ re.sub( r'[\w\./]+\.[a-z]+', 'url', t) for t in tt  ]  # замена интернет ссылок 
    tt = [ re.sub( r'<[^>]*>', '', t)  for t in tt ] # удаление html тагов
    tt = [ re.sub( r'\W', '', t)  for t in tt ] # удаление лишних символов (НЕ буква и НЕ цифра)
    tt = Stemmer('russian').stemWords( tt ) # стемминг, выделение основы слова
    tt = [ re.sub( r'\b\d+\b', 'digit', t ) for t in tt ] # замена цифр
    tt = [ t for t in tt if len(t)>2 ] # удаление коротких слов (предлогов)
    tt = [ t for t in tt if t not in ['для','под','над','котор'] ] # удаление (предлогов)
    return  [ t.strip() for t in tt if t ]

# %%
preprocessor( tokenizer( tt ) )
# Out:
# ['сегодн',
#  'париж',
#  'стал',
#  'извест',
#  'обладател',
#  'золот',
#  'мяч',
#  'сам',
#  'престижн',
#  'футболист',
#  'индивидуальн',
#  'наград',
#  'четверт',
#  'раз',
#  'получ',
#  'португалец',
#  'криштиан',
#  'роналд',
#  'сообща',
#  'eurosport',
#  'прошедш',
#  'сезон',
#  'выигра',
#  'сво',
#  'сборн',
#  'чемпионат',
#  'европ',
#  'сво',
#  'клуб',
#  'мадридск',
#  'реал',
#  'лиг',
#  'чемпион',
#  'имен',
#  'позвол',
#  'роналд',
#  'оперед',
#  'сво',
#  'главн',
#  'конкурент',
#  'аргентинц',
#  'лионел',
#  'месс',
#  'тепер',
#  'обо',
#  'выда',
#  'футболист',
#  'четыр',
#  'золот',
#  'мяч',
#  'сегодняшн',
#  'голосован',
#  'вперв',
#  'последн',
#  'шест',
#  'лет',
#  'принима',
#  'участ',
#  'тольк',
#  'спортивн',
#  'журналист',
#  'без',
#  'участ',
#  'fifa',
#  'сам',
#  'роналд',
#  'церемон',
#  'приеха',
#  'сейчас',
#  'клубн',
#  'чемпионат',
#  'мир',
#  'вмест',
#  'реал',
#  'готов',
#  'сыгра',
#  'полуфинал',
#  'турнир',
#  'фот',
#  'imago',
#  'sportfotodienst',
#  'globallookpress']

# %% [markdown]
# ## NLTK

# %%
# import nltk
# nltk.download('stopwords')

# Стоп-слова, или Шумовые слова 
# предлоги, суффиксы, причастия, междометия, цифры, частицы и т.п.
# каждое из стоп-слов есть почти во всех документах коллекции

# from nltk.stem.snowball import SnowballStemmer
# print(" ".join(SnowballStemmer.languages))
# snowball = SnowballStemmer('russian')

# %%
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer

# %%
def preprocessor_nltk(tt):
    tt = [ t.lower()  for t in tt ] # приведение в lowercase
    tt = [ re.sub( r'https?://[\S]+', 'url', t)  for t in tt ]  # замена интернет ссылок
    tt = [ re.sub( r'[\w\./]+\.[a-z]+', 'url', t) for t in tt  ]  # замена интернет ссылок 
    tt = [ re.sub( r'<[^>]*>', '', t)  for t in tt ] # удаление html тагов
    tt = [ re.sub( r'\W', '', t)  for t in tt ] # удаление лишних символов (НЕ буква и НЕ цифра)
    tt = [ SnowballStemmer('russian').stem(t) for t in tt if t ]
    tt = [ re.sub( r'\b\d+\b', 'digit', t ) for t in tt ] # замена цифр
    tt = [ t for t in tt if t not in  stopwords.words('russian') ] # удаление stopwords (предлоги и т.п.)

    return  [ t.strip() for t in tt if t ]

# %%
preprocessor_nltk( tokenizer( tt ) )
# Out:
# ['сегодн',
#  'париж',
#  'стал',
#  'извест',
#  'обладател',
#  'золот',
#  'мяч',
#  'престижн',
#  'футболист',
#  'индивидуальн',
#  'наград',
#  'четверт',
#  'получ',
#  'португалец',
#  'криштиан',
#  'роналд',
#  'эт',
#  'сообща',
#  'eurosport',
#  'прошедш',
#  'сезон',
#  'выигра',
#  'сво',
#  'сборн',
#  'чемпионат',
#  'европ',
#  'сво',
#  'клуб',
#  'мадридск',
#  'реал',
#  'лиг',
#  'чемпион',
#  'имен',
#  'эт',
#  'позвол',
#  'роналд',
#  'оперед',
#  'сво',
#  'главн',
#  'конкурент',
#  'аргентинц',
#  'лионел',
#  'месс',
#  'тепер',
#  'обо',
#  'выда',
#  'футболист',
#  'четыр',
#  'золот',
#  'мяч',
#  'сегодняшн',
#  'голосован',
#  'вперв',
#  'последн',
#  'шест',
#  'лет',
#  'принима',
#  'участ',
#  'тольк',
#  'спортивн',
#  'журналист',
#  'участ',
#  'fif',
#  'роналд',
#  'церемон',
#  'приеха',
#  'клубн',
#  'чемпионат',
#  'мир',
#  'вмест',
#  'реал',
#  'готов',
#  'сыгра',
#  'полуфинал',
#  'эт',
#  'турнир',
#  'фот',
#  'imag',
#  'sportfotodienst',
#  'globallookpress']
